# %% [markdown]
# ## Renders for Book Chapter

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
wormhole_dir='/Users/stephen/Stephencwelch Dropbox/Stephen Welch/welch_labs/backpropagation/hackin/wormhole_merged/'
alphas_1=np.linspace(-2.5, 2.5, 512)
loss_2d_1=np.load(wormhole_dir+'000.npy')

# %%
loss_2d_1.shape
# Out:
# (512, 512)

# %%
plt.imshow(loss_2d_1)

# %%
save_dir='/Users/stephen/Stephencwelch Dropbox/welch_labs/ai_book/2_backprop_1/design/assets/loss_landscape_slices_1'

# %%
for i in range(0, 512, 16):
    plt.clf()
    plt.figure(0, (8,3))
    plt.plot(loss_2d_1[i,:], linewidth=2, color='m')
    plt.savefig(save_dir+'/i_'+str(i).zfill(3)+'.svg')

# %%
for i in range(0, 512, 16):
    plt.clf()
    plt.figure(0, (8,3))
    plt.plot(loss_2d_1[:, i], linewidth=2, color='m')
    plt.savefig(save_dir+'/j_'+str(i).zfill(3)+'.svg')
