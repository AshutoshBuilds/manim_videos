# %% [markdown]
# # BaarleNet [Part 7e - MOAR loss landscapes]

# %%
import numpy as np
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import torch.optim as optim
import cv2
from matplotlib.gridspec import GridSpec
from tqdm import tqdm
import os

# %%
def denorm(p, size=960):
    result = np.zeros_like(p)
    result[..., 0] = (p[..., 0] + 1) * (size / 2)
    result[..., 1] = size - ((p[..., 1] + 1) * (size / 2))
    return result

def get_relu_joint(weight_1, weight_2, bias, extent=1):
    if np.abs(weight_2) < 1e-8: 
        x_intercept = -bias / weight_1
        return [[x_intercept, -extent], [x_intercept, extent]] if -extent <= x_intercept <= extent else []
    elif np.abs(weight_1) < 1e-8:
        y_intercept = -bias / weight_2
        return [[-extent, y_intercept], [extent, y_intercept]] if -extent <= y_intercept <= extent else []
    else:
        points = []
        for x in [-extent, extent]:
            y = (-x * weight_1 - bias) / weight_2
            if -extent <= y <= extent: points.append([x, y])
        for y in [-extent, extent]:
            x = (-y * weight_2 - bias) / weight_1
            if -extent <= x <= extent: points.append([x, y])
        unique_points = []
        for p in points:
            is_duplicate = False
            for existing in unique_points:
                if abs(p[0] - existing[0]) < 1e-8 and abs(p[1] - existing[1]) < 1e-8:
                    is_duplicate = True
                    break
            if not is_duplicate:
                unique_points.append(p)
        return unique_points

def viz_map_with_predictions(ax, map, X, y):
    probe=np.zeros((100,100,2))
    for j, xx in enumerate(np.linspace(-1, 1, 100)):
        for k, yy in enumerate(np.linspace(-1, 1, 100)):
            probe[j, k]=[yy,xx]
    probe=probe.reshape(100**2, -1)
    probe_logits=model(torch.tensor(probe).float())
    probe_logits=probe_logits.detach().numpy().reshape(100,100,2)
    probe_softmax = torch.nn.Softmax(dim=1)(torch.tensor(probe_logits.reshape(-1, 2)))
    
    ax.imshow(map.mean(2), cmap='gray')
    ax.imshow(np.flipud(probe_softmax[:,1].reshape(100, 100)), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')
    
    X_denorm=denorm(X[:1000,:])
    # plt.scatter(X_denorm[:,0], X_denorm[:,1], c=y[:1000], s=2, alpha=0.8)
    labels=y[:1000]
    y_hat=torch.argmax(model(torch.tensor(X[:1000,:]).float()).detach(),1).numpy()
    tp_mask=np.logical_and(labels==1, y_hat==1)
    fp_mask=np.logical_and(labels==0, y_hat==1)
    fn_mask=np.logical_and(labels==1, y_hat==0)
    tn_mask=np.logical_and(labels==0, y_hat==0)
    ax.scatter(X_denorm[tp_mask,0], X_denorm[tp_mask,1], c='g', s=3, alpha=0.8)
    ax.scatter(X_denorm[fp_mask,0], X_denorm[fp_mask,1], c='r', marker='x', s=5, alpha=0.8)
    ax.scatter(X_denorm[fn_mask,0], X_denorm[fn_mask,1], c='orange', marker='x', s=5, alpha=0.8)
    ax.scatter(X_denorm[tn_mask,0], X_denorm[tn_mask,1], c='purple', marker='o', s=5, alpha=0.8)

def save_viz(model, save_path=None):
    plt.clf()
    probe=np.zeros((100,100,2))
    for j, xx in enumerate(np.linspace(-1, 1, 100)):
        for k, yy in enumerate(np.linspace(-1, 1, 100)):
            probe[j, k]=[yy,xx]
    probe=probe.reshape(100**2, -1)
    
    h1 = model.model[:2](torch.tensor(probe).float())
    h1 = h1.detach().numpy().reshape(100,100,3)

    h2 = model.model[:3](torch.tensor(probe).float())
    h2 = h2.detach().numpy().reshape(100,100,2)
        
    # First neuron (output index 0)
    j1 = get_relu_joint(model.model[0].weight[0,0].item(), model.model[0].weight[0,1].item(), model.model[0].bias[0].item(), extent=1)
    j1 = denorm(np.array(j1)) if j1 else []
    
    # Second neuron (output index 1)  
    j2 = get_relu_joint(model.model[0].weight[1,0].item(), model.model[0].weight[1,1].item(), model.model[0].bias[1].item(), extent=1)
    j2 = denorm(np.array(j2)) if j2 else []
    
    j3 = get_relu_joint(model.model[0].weight[2,0].item(), model.model[0].weight[2,1].item(), model.model[0].bias[2].item(), extent=1)
    j3 = denorm(np.array(j3)) if j3 else []
    
    fig=plt.figure(0,(10,10)); 
    for i in range(3):
        ax=fig.add_subplot(2,2,i+1)
        ax.imshow(map.mean(2), cmap='gray')
        ax.imshow(np.flipud(h1[:,:,i]>0), 
                   extent=[0, 960, 960, 0],  # This maps to image coordinates
                   alpha=0.7,
                   cmap='viridis')
        if i==0 and len(j1)>0: ax.plot([j1[0][0], j1[1][0]], [j1[0][1], j1[1][1]], '--', color='#FFFFFF', linewidth=2)
        if i==1 and len(j2)>0: ax.plot([j2[0][0], j2[1][0]], [j2[0][1], j2[1][1]], '--', color='#FFFFFF', linewidth=2)
        if i==2 and len(j3)>0: ax.plot([j3[0][0], j3[1][0]], [j3[0][1], j3[1][1]], '--', color='#FFFFFF', linewidth=2)
    
    ax=fig.add_subplot(2,2,4)
    probe_logits=model(torch.tensor(probe).float())
    probe_logits=probe_logits.detach().numpy().reshape(100,100,2)
    probe_softmax = torch.nn.Softmax(dim=1)(torch.tensor(probe_logits.reshape(-1, 2)))
    
    ax.imshow(map.mean(2), cmap='gray')
    # ax.imshow(np.flipud(probe_softmax[:,1].reshape(100, 100)), 
    #            extent=[0, 960, 960, 0],  # This maps to image coordinates
    #            alpha=0.7,
    #            cmap='viridis')
    
    ax.imshow(np.flipud((h2[:,:,1]-h2[:,:,0])>0), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')
    if save_path is not None: plt.savefig(save_path)

# %%
def flatten_weight_dict(weight_dict):
    """
    Flatten a dictionary of weight tensors into a single 1D numpy array
    """
    flattened = []
    for name, tensor in weight_dict.items():
        if tensor is not None:
            flattened.append(tensor.cpu().numpy().flatten())
    return np.concatenate(flattened)

def unflatten_to_weight_dict(flattened_weights, reference_dict):
    """
    Convert flattened weights back to the original dictionary structure
    """
    result = {}
    start_idx = 0
    
    for name, tensor in reference_dict.items():
        if tensor is not None:
            shape = tensor.shape
            size = tensor.numel()
            
            # Extract the portion for this parameter
            param_weights = flattened_weights[start_idx:start_idx + size]
            
            # Reshape and convert to tensor
            result[name] = torch.tensor(param_weights.reshape(shape)).float()
            start_idx += size
    
    return result

# Set model weights function (reused from previous code)
def set_model_weights(model, weight_dict):
    """Set model parameters from weight dictionary"""
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = weight_dict[name]

def compute_loss_at_point(model, X_tensor, y_tensor, criterion):
    """Compute loss at current model parameters"""
    with torch.no_grad():
        outputs = model(X_tensor)
        loss = criterion(outputs, y_tensor)
        return loss.item()

# %%
map=cv2.imread('Baarle-Nassau_-_Baarle-Hertog-en.svg.png')[:,:,(2,1,0)]

belgium_color=np.array([251,234,81])
netherlands_color=np.array([255, 255, 228])

netherlands_region=((map-netherlands_color)**2).sum(-1)<10
belgium_region=((map-belgium_color)**2).sum(-1)<10000

num_points_to_sample=10000 #10000

b_coords=np.array(np.where(belgium_region)).T.astype('float')
n_coords=np.array(np.where(netherlands_region)).T.astype('float')

#flip and normalize
belgium_coords_all=np.zeros_like(b_coords)
netherlands_coords_all=np.zeros_like(n_coords)

belgium_coords_all[:,0]=b_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
belgium_coords_all[:,1]=(960-b_coords[:,0])/(960/2)-1
netherlands_coords_all[:,0]=n_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
netherlands_coords_all[:,1]=(960-n_coords[:,0])/(960/2)-1

## Hmm to balance to classes or do more area proportional? Not sure yet. 
belgium_coords=belgium_coords_all[np.random.choice(len(belgium_coords_all), num_points_to_sample), :]
netherlands_coords=netherlands_coords_all[np.random.choice(len(netherlands_coords_all), num_points_to_sample), :]

X=np.vstack((netherlands_coords, belgium_coords))
y=np.concatenate((np.zeros(len(netherlands_coords)), np.ones(len(belgium_coords)))).astype('int')

rI=np.arange(len(y))
np.random.shuffle(rI)
X=X[rI,:]
y=y[rI]

# %%
plt.scatter(X[:,0], X[:,1], c=y, s=1, alpha=0.3); plt.axis('square');

# %%
class BaarleNet(nn.Module):
    def __init__(self, hidden_layers=[64]):
        super(BaarleNet, self).__init__()
        layers = [nn.Linear(2, hidden_layers[0]), nn.ReLU()]
        for i in range(len(hidden_layers)-1):
            layers.append(nn.Linear(hidden_layers[i], hidden_layers[i+1]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_layers[-1], 2))
        self.layers=layers
        self.model = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.model(x)

# %%
import pickle
import copy
import os

# %% [markdown]
# ## Run same loop, but save best and worst

# %%
X_tensor = torch.FloatTensor(X)
y_tensor = torch.tensor(y)

# Training parameters
num_epochs = 2500 #Trying shorter to reduce arbitrary weight scaling
num_seeds = 128 #8 is nice for quick tests

# Configure output directory
output_dir = "/Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4"  # Change this to your desired directory
os.makedirs(output_dir, exist_ok=True)
print(f"Saving results to: {output_dir}")

# Track best and worst models
best_model_data = {'accuracy': -1, 'seed': None, 'initial_params': None, 'final_params': None}
worst_model_data = {'accuracy': float('inf'), 'seed': None, 'initial_params': None, 'final_params': None}
all_training_data=[]

for seed_idx in range(num_seeds):
    random_seed = seed_idx  # You can change this to any seed generation logic
    torch.manual_seed(random_seed)
    
    # Initialize model and optimizer
    model = BaarleNet([3]) #[3] is probaby the move for this
    #Mess with initialization
    bound=2.5
    with torch.no_grad():
        model.model[0].weight.uniform_(-bound, bound)
        model.model[0].bias.uniform_(-bound, bound)  
        model.model[2].weight.uniform_(-bound, bound)
        model.model[2].bias.uniform_(-bound, bound)  

    print(model.model[0].weight)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    
    # Store initial parameters (deep copy)
    initial_params = {}
    for name, param in model.named_parameters():
        initial_params[name] = param.data.clone()
    
    # Data storage for this run
    training_data = {
        'seed': random_seed,
        'weights_history': [],
        'gradients_history': [],
        'xy_history': [],
        'loss_history': [],
        'accuracy_history': [],
        'initial_params': initial_params  # Store initial params in training data too
    }

    print(f"\n=== Training with seed {random_seed} ===")

    for epoch in range(num_epochs):
        # Get current data point
        current_idx = epoch % len(y)
        # Stochastic
        # current_x = torch.tensor(X[current_idx]).float()
        # current_y = torch.tensor(y[current_idx])

        #Try batch for a second
        current_x = torch.tensor(X).float()
        current_y = torch.tensor(y)  
        
        # Forward pass
        outputs = model(current_x)
        loss = criterion(outputs, current_y)
        if epoch==0:
            print('initial loss = ', loss.item())
        
        # Store current X,y values
        training_data['xy_history'].append({
            'epoch': epoch,
            'x': X[current_idx].copy(),
            'y': y[current_idx]
        })
        
        # Zero gradients
        optimizer.zero_grad()
        
        # Backward pass
        loss.backward()
        
        # Store model weights (deep copy to avoid reference issues)
        current_weights = {}
        for name, param in model.named_parameters():
            current_weights[name] = param.data.clone()
        training_data['weights_history'].append(current_weights)
        
        # Store model gradients (deep copy)
        current_gradients = {}
        for name, param in model.named_parameters():
            if param.grad is not None:
                current_gradients[name] = param.grad.clone()
            else:
                current_gradients[name] = None
        training_data['gradients_history'].append(current_gradients)
        
        # Update parameters
        optimizer.step()
        
        # Store loss
        training_data['loss_history'].append(loss.item())
        
        # Calculate and store accuracy periodically
        if (epoch + 1) % (num_epochs // 10) == 0:
            with torch.no_grad():
                outputs_batch = model(X_tensor)
                accuracy = (torch.argmax(outputs_batch, dim=1) == y_tensor).sum().item() / len(y)
                training_data['accuracy_history'].append({
                    'epoch': epoch,
                    'accuracy': accuracy
                })
                print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Accuracy: {accuracy:.4f}')
    
    # Calculate final accuracy
    with torch.no_grad():
        final_outputs = model(X_tensor)
        final_accuracy = (torch.argmax(final_outputs, dim=1) == y_tensor).sum().item() / len(y)
    
    # Store final parameters (deep copy)
    final_params = {}
    for name, param in model.named_parameters():
        final_params[name] = param.data.clone()
    
    # Check if this is the best or worst model so far
    if final_accuracy > best_model_data['accuracy']:
        best_model_data = {
            'accuracy': final_accuracy,
            'seed': random_seed,
            'initial_params': {name: param.clone() for name, param in initial_params.items()},
            'final_params': {name: param.clone() for name, param in final_params.items()}
        }
        print(f"*** NEW BEST MODEL: Seed {random_seed}, Accuracy {final_accuracy:.4f} ***")
    
    if final_accuracy < worst_model_data['accuracy']:
        worst_model_data = {
            'accuracy': final_accuracy,
            'seed': random_seed,
            'initial_params': {name: param.clone() for name, param in initial_params.items()},
            'final_params': {name: param.clone() for name, param in final_params.items()}
        }
        print(f"*** NEW WORST MODEL: Seed {random_seed}, Accuracy {final_accuracy:.4f} ***")
    
    # Save data as pickle file
    filename = os.path.join(output_dir, f"training_data_seed_{random_seed:02d}_acc_{final_accuracy:.4f}.pkl")
    
    # Add final accuracy and params to the data
    training_data['final_accuracy'] = final_accuracy
    training_data['final_model_state'] = model.state_dict()
    training_data['final_params'] = final_params
    
    with open(filename, 'wb') as f:
        pickle.dump(training_data, f)
    
    print(f"Saved training data to {filename}")
    print(f"Final accuracy: {final_accuracy:.4f}")

    # Restore initial weights for visualization
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = training_data['weights_history'][0][name]

    print(model.model[0].weight)
    viz_fn = os.path.join(output_dir, f"{final_accuracy:.4f}_random_init.png")
    save_viz(model, str(viz_fn))

    all_training_data.append(training_data)

# After all training is complete, save best and worst model data
best_worst_data = {
    'best_model': best_model_data,
    'worst_model': worst_model_data
}

best_worst_filename = os.path.join(output_dir, "best_worst_models.pkl")
with open(best_worst_filename, 'wb') as f:
    pickle.dump(best_worst_data, f)

print(f"\n=== FINAL RESULTS ===")
print(f"Best model: Seed {best_model_data['seed']}, Accuracy {best_model_data['accuracy']:.4f}")
print(f"Worst model: Seed {worst_model_data['seed']}, Accuracy {worst_model_data['accuracy']:.4f}")
print(f"Best/worst model data saved to: {best_worst_filename}")
# Out:
# Saving results to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4
# Parameter containing:
# tensor([[ 1.5001, -1.6949],
#         [-1.0887,  0.9080],
#         [ 2.0760, -0.5145]], requires_grad=True)
#
# === Training with seed 0 ===
# initial loss =  2.3653080463409424
# Epoch [250/2500], Loss: 0.6073, Accuracy: 0.7363
# Epoch [500/2500], Loss: 0.5137, Accuracy: 0.7584
# Epoch [750/2500], Loss: 0.4878, Accuracy: 0.7557
# Epoch [1000/2500], Loss: 0.4812, Accuracy: 0.7571
# Epoch [1250/2500], Loss: 0.4804, Accuracy: 0.7601
# Epoch [1500/2500], Loss: 0.4802, Accuracy: 0.7610
# Epoch [1750/2500], Loss: 0.4802, Accuracy: 0.7617
# Epoch [2000/2500], Loss: 0.4802, Accuracy: 0.7620
# Epoch [2250/2500], Loss: 0.4802, Accuracy: 0.7619
# Epoch [2500/2500], Loss: 0.4802, Accuracy: 0.7620
# *** NEW BEST MODEL: Seed 0, Accuracy 0.7620 ***
# *** NEW WORST MODEL: Seed 0, Accuracy 0.7620 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_00_acc_0.7620.pkl
# Final accuracy: 0.7620
# Parameter containing:
# tensor([[ 1.5001, -1.6949],
#         [-1.0887,  0.9080],
#         [ 2.0760, -0.5145]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0100,  2.1854],
#         [ 0.7780, -0.9310],
#         [-1.5099, -0.4190]], requires_grad=True)
#
# === Training with seed 1 ===
# initial loss =  1.495923399925232
# Epoch [250/2500], Loss: 0.4559, Accuracy: 0.7729
# Epoch [500/2500], Loss: 0.4038, Accuracy: 0.8061
# Epoch [750/2500], Loss: 0.3543, Accuracy: 0.8569
# Epoch [1000/2500], Loss: 0.3500, Accuracy: 0.8562
# Epoch [1250/2500], Loss: 0.3496, Accuracy: 0.8558
# Epoch [1500/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [1750/2500], Loss: 0.3495, Accuracy: 0.8560
# Epoch [2000/2500], Loss: 0.3495, Accuracy: 0.8561
# Epoch [2250/2500], Loss: 0.3495, Accuracy: 0.8558
# Epoch [2500/2500], Loss: 0.3495, Accuracy: 0.8561
# *** NEW BEST MODEL: Seed 1, Accuracy 0.8561 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_01_acc_0.8561.pkl
# Final accuracy: 0.8561
# Parameter containing:
# tensor([[-0.0100,  2.1854],
#         [ 0.7780, -0.9310],
#         [-1.5099, -0.4190]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4748, -0.9611],
#         [ 2.4043, -2.4487],
#         [-0.1698, -0.1981]], requires_grad=True)
#
# === Training with seed 2 ===
# initial loss =  1.151909589767456
# Epoch [250/2500], Loss: 0.4821, Accuracy: 0.7566
# Epoch [500/2500], Loss: 0.4795, Accuracy: 0.7612
# Epoch [750/2500], Loss: 0.4795, Accuracy: 0.7614
# Epoch [1000/2500], Loss: 0.4795, Accuracy: 0.7614
# Epoch [1250/2500], Loss: 0.4795, Accuracy: 0.7614
# Epoch [1500/2500], Loss: 0.4795, Accuracy: 0.7614
# Epoch [1750/2500], Loss: 0.4795, Accuracy: 0.7614
# Epoch [2000/2500], Loss: 0.4792, Accuracy: 0.7614
# Epoch [2250/2500], Loss: 0.4758, Accuracy: 0.7613
# Epoch [2500/2500], Loss: 0.4727, Accuracy: 0.7579
# *** NEW WORST MODEL: Seed 2, Accuracy 0.7579 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_02_acc_0.7579.pkl
# Final accuracy: 0.7579
# Parameter containing:
# tensor([[-1.4748, -0.9611],
#         [ 2.4043, -2.4487],
#         [-0.1698, -0.1981]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.2459,  1.7366],
#         [ 1.8743,  0.7416],
#         [-1.4262,  2.2465]], requires_grad=True)
#
# === Training with seed 3 ===
# initial loss =  0.8940775394439697
# Epoch [250/2500], Loss: 0.4629, Accuracy: 0.7884
# Epoch [500/2500], Loss: 0.4575, Accuracy: 0.7896
# Epoch [750/2500], Loss: 0.4573, Accuracy: 0.7891
# Epoch [1000/2500], Loss: 0.4573, Accuracy: 0.7892
# Epoch [1250/2500], Loss: 0.4573, Accuracy: 0.7892
# Epoch [1500/2500], Loss: 0.4573, Accuracy: 0.7892
# Epoch [1750/2500], Loss: 0.4573, Accuracy: 0.7892
# Epoch [2000/2500], Loss: 0.4573, Accuracy: 0.7892
# Epoch [2250/2500], Loss: 0.4573, Accuracy: 0.7892
# Epoch [2500/2500], Loss: 0.4573, Accuracy: 0.7892
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_03_acc_0.7892.pkl
# Final accuracy: 0.7892
# Parameter containing:
# tensor([[ 2.2459,  1.7366],
#         [ 1.8743,  0.7416],
#         [-1.4262,  2.2465]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4315, -0.9668],
#         [-2.3072,  0.1101],
#         [-0.8963,  0.5369]], requires_grad=True)
#
# === Training with seed 4 ===
# initial loss =  2.0506842136383057
# Epoch [250/2500], Loss: 0.5677, Accuracy: 0.6679
# Epoch [500/2500], Loss: 0.4667, Accuracy: 0.8086
# Epoch [750/2500], Loss: 0.3778, Accuracy: 0.8557
# Epoch [1000/2500], Loss: 0.3606, Accuracy: 0.8582
# Epoch [1250/2500], Loss: 0.3563, Accuracy: 0.8583
# Epoch [1500/2500], Loss: 0.3549, Accuracy: 0.8584
# Epoch [1750/2500], Loss: 0.3542, Accuracy: 0.8579
# Epoch [2000/2500], Loss: 0.3538, Accuracy: 0.8579
# Epoch [2250/2500], Loss: 0.3536, Accuracy: 0.8578
# Epoch [2500/2500], Loss: 0.3534, Accuracy: 0.8578
# *** NEW BEST MODEL: Seed 4, Accuracy 0.8578 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_04_acc_0.8578.pkl
# Final accuracy: 0.8578
# Parameter containing:
# tensor([[-1.4315, -0.9668],
#         [-2.3072,  0.1101],
#         [-0.8963,  0.5369]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.7508, -2.2168],
#         [ 2.1006,  0.8488],
#         [-1.1926, -2.2964]], requires_grad=True)
#
# === Training with seed 5 ===
# initial loss =  2.312230348587036
# Epoch [250/2500], Loss: 0.5384, Accuracy: 0.7268
# Epoch [500/2500], Loss: 0.4401, Accuracy: 0.8040
# Epoch [750/2500], Loss: 0.3863, Accuracy: 0.8085
# Epoch [1000/2500], Loss: 0.3724, Accuracy: 0.8223
# Epoch [1250/2500], Loss: 0.3675, Accuracy: 0.8336
# Epoch [1500/2500], Loss: 0.3627, Accuracy: 0.8400
# Epoch [1750/2500], Loss: 0.3582, Accuracy: 0.8445
# Epoch [2000/2500], Loss: 0.3549, Accuracy: 0.8481
# Epoch [2250/2500], Loss: 0.3528, Accuracy: 0.8502
# Epoch [2500/2500], Loss: 0.3516, Accuracy: 0.8518
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_05_acc_0.8518.pkl
# Final accuracy: 0.8518
# Parameter containing:
# tensor([[ 0.7508, -2.2168],
#         [ 2.1006,  0.8488],
#         [-1.1926, -2.2964]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.5259, -0.6751],
#         [-1.2321, -1.6790],
#         [-1.0834, -0.5709]], requires_grad=True)
#
# === Training with seed 6 ===
# initial loss =  1.9361990690231323
# Epoch [250/2500], Loss: 0.5029, Accuracy: 0.7720
# Epoch [500/2500], Loss: 0.4511, Accuracy: 0.7992
# Epoch [750/2500], Loss: 0.4215, Accuracy: 0.8175
# Epoch [1000/2500], Loss: 0.3558, Accuracy: 0.8547
# Epoch [1250/2500], Loss: 0.3500, Accuracy: 0.8554
# Epoch [1500/2500], Loss: 0.3495, Accuracy: 0.8559
# Epoch [1750/2500], Loss: 0.3495, Accuracy: 0.8561
# Epoch [2000/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2250/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2500/2500], Loss: 0.3495, Accuracy: 0.8562
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_06_acc_0.8562.pkl
# Final accuracy: 0.8562
# Parameter containing:
# tensor([[ 0.5259, -0.6751],
#         [-1.2321, -1.6790],
#         [-1.0834, -0.5709]], requires_grad=True)
# Parameter containing:
# tensor([[-2.1347,  2.3496],
#         [-1.9611,  1.9144],
#         [-0.4341,  1.2860]], requires_grad=True)
#
# === Training with seed 7 ===
# initial loss =  1.7650099992752075
# Epoch [250/2500], Loss: 0.5567, Accuracy: 0.7604
# Epoch [500/2500], Loss: 0.4982, Accuracy: 0.7621
# Epoch [750/2500], Loss: 0.4865, Accuracy: 0.7614
# Epoch [1000/2500], Loss: 0.4824, Accuracy: 0.7608
# Epoch [1250/2500], Loss: 0.4798, Accuracy: 0.7595
# Epoch [1500/2500], Loss: 0.4498, Accuracy: 0.8014
# Epoch [1750/2500], Loss: 0.4459, Accuracy: 0.8098
# Epoch [2000/2500], Loss: 0.4241, Accuracy: 0.8299
# Epoch [2250/2500], Loss: 0.4221, Accuracy: 0.8364
# Epoch [2500/2500], Loss: 0.4220, Accuracy: 0.8368
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_07_acc_0.8368.pkl
# Final accuracy: 0.8368
# Parameter containing:
# tensor([[-2.1347,  2.3496],
#         [-1.9611,  1.9144],
#         [-0.4341,  1.2860]], requires_grad=True)
# Parameter containing:
# tensor([[-1.2266, -0.1585],
#         [-1.6589, -1.6437],
#         [ 0.0516, -1.9659]], requires_grad=True)
#
# === Training with seed 8 ===
# initial loss =  1.4163049459457397
# Epoch [250/2500], Loss: 0.6687, Accuracy: 0.6108
# Epoch [500/2500], Loss: 0.6651, Accuracy: 0.6151
# Epoch [750/2500], Loss: 0.6651, Accuracy: 0.6155
# Epoch [1000/2500], Loss: 0.6651, Accuracy: 0.6158
# Epoch [1250/2500], Loss: 0.6651, Accuracy: 0.6158
# Epoch [1500/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [1750/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2000/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2250/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2500/2500], Loss: 0.6651, Accuracy: 0.6159
# *** NEW WORST MODEL: Seed 8, Accuracy 0.6159 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_08_acc_0.6159.pkl
# Final accuracy: 0.6159
# Parameter containing:
# tensor([[-1.2266, -0.1585],
#         [-1.6589, -1.6437],
#         [ 0.0516, -1.9659]], requires_grad=True)
# Parameter containing:
# tensor([[-0.7661, -0.2617],
#         [ 0.6578,  0.9737],
#         [ 1.6074,  2.0556]], requires_grad=True)
#
# === Training with seed 9 ===
# initial loss =  1.3264061212539673
# Epoch [250/2500], Loss: 0.5567, Accuracy: 0.6804
# Epoch [500/2500], Loss: 0.3953, Accuracy: 0.8386
# Epoch [750/2500], Loss: 0.3698, Accuracy: 0.8435
# Epoch [1000/2500], Loss: 0.3668, Accuracy: 0.8447
# Epoch [1250/2500], Loss: 0.3665, Accuracy: 0.8445
# Epoch [1500/2500], Loss: 0.3664, Accuracy: 0.8442
# Epoch [1750/2500], Loss: 0.3664, Accuracy: 0.8442
# Epoch [2000/2500], Loss: 0.3664, Accuracy: 0.8442
# Epoch [2250/2500], Loss: 0.3664, Accuracy: 0.8441
# Epoch [2500/2500], Loss: 0.3664, Accuracy: 0.8443
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_09_acc_0.8443.pkl
# Final accuracy: 0.8443
# Parameter containing:
# tensor([[-0.7661, -0.2617],
#         [ 0.6578,  0.9737],
#         [ 1.6074,  2.0556]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0884,  0.5750],
#         [-0.0163, -0.2394],
#         [-2.2124, -2.1565]], requires_grad=True)
#
# === Training with seed 10 ===
# initial loss =  0.8563548922538757
# Epoch [250/2500], Loss: 0.6932, Accuracy: 0.4997
# Epoch [500/2500], Loss: 0.6932, Accuracy: 0.4999
# Epoch [750/2500], Loss: 0.6931, Accuracy: 0.5000
# Epoch [1000/2500], Loss: 0.6931, Accuracy: 0.5000
# Epoch [1250/2500], Loss: 0.6931, Accuracy: 0.5000
# Epoch [1500/2500], Loss: 0.6931, Accuracy: 0.5000
# Epoch [1750/2500], Loss: 0.6931, Accuracy: 0.5000
# Epoch [2000/2500], Loss: 0.6931, Accuracy: 0.5000
# Epoch [2250/2500], Loss: 0.6931, Accuracy: 0.5000
# Epoch [2500/2500], Loss: 0.6931, Accuracy: 0.5000
# *** NEW WORST MODEL: Seed 10, Accuracy 0.5000 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_10_acc_0.5000.pkl
# Final accuracy: 0.5000
# Parameter containing:
# tensor([[-0.0884,  0.5750],
#         [-0.0163, -0.2394],
#         [-2.2124, -2.1565]], requires_grad=True)
# Parameter containing:
# tensor([[1.3000, 1.5177],
#         [1.3265, 1.8545],
#         [1.1153, 1.6822]], requires_grad=True)
#
# === Training with seed 11 ===
# initial loss =  2.767516613006592
# Epoch [250/2500], Loss: 0.6532, Accuracy: 0.6397
# Epoch [500/2500], Loss: 0.4842, Accuracy: 0.7786
# Epoch [750/2500], Loss: 0.4394, Accuracy: 0.7864
# Epoch [1000/2500], Loss: 0.4331, Accuracy: 0.8152
# Epoch [1250/2500], Loss: 0.4289, Accuracy: 0.8236
# Epoch [1500/2500], Loss: 0.4240, Accuracy: 0.8319
# Epoch [1750/2500], Loss: 0.3820, Accuracy: 0.8428
# Epoch [2000/2500], Loss: 0.3594, Accuracy: 0.8542
# Epoch [2250/2500], Loss: 0.3562, Accuracy: 0.8559
# Epoch [2500/2500], Loss: 0.3550, Accuracy: 0.8569
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_11_acc_0.8569.pkl
# Final accuracy: 0.8569
# Parameter containing:
# tensor([[1.3000, 1.5177],
#         [1.3265, 1.8545],
#         [1.1153, 1.6822]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.7213, -1.8721],
#         [-0.2719,  0.8003],
#         [-2.2231, -1.7135]], requires_grad=True)
#
# === Training with seed 12 ===
# initial loss =  1.278259038925171
# Epoch [250/2500], Loss: 0.6518, Accuracy: 0.6182
# Epoch [500/2500], Loss: 0.5230, Accuracy: 0.7438
# Epoch [750/2500], Loss: 0.3936, Accuracy: 0.8421
# Epoch [1000/2500], Loss: 0.3519, Accuracy: 0.8559
# Epoch [1250/2500], Loss: 0.3496, Accuracy: 0.8560
# Epoch [1500/2500], Loss: 0.3495, Accuracy: 0.8561
# Epoch [1750/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2000/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2250/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2500/2500], Loss: 0.3495, Accuracy: 0.8562
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_12_acc_0.8562.pkl
# Final accuracy: 0.8562
# Parameter containing:
# tensor([[ 1.7213, -1.8721],
#         [-0.2719,  0.8003],
#         [-2.2231, -1.7135]], requires_grad=True)
# Parameter containing:
# tensor([[-0.8050,  1.6833],
#         [-1.8556,  2.3467],
#         [-0.2524, -0.4847]], requires_grad=True)
#
# === Training with seed 13 ===
# initial loss =  3.6233088970184326
# Epoch [250/2500], Loss: 0.6874, Accuracy: 0.6057
# Epoch [500/2500], Loss: 0.6397, Accuracy: 0.6105
# Epoch [750/2500], Loss: 0.5957, Accuracy: 0.6635
# Epoch [1000/2500], Loss: 0.5066, Accuracy: 0.7754
# Epoch [1250/2500], Loss: 0.4856, Accuracy: 0.7647
# Epoch [1500/2500], Loss: 0.4822, Accuracy: 0.7614
# Epoch [1750/2500], Loss: 0.4811, Accuracy: 0.7606
# Epoch [2000/2500], Loss: 0.4806, Accuracy: 0.7603
# Epoch [2250/2500], Loss: 0.4803, Accuracy: 0.7602
# Epoch [2500/2500], Loss: 0.4801, Accuracy: 0.7601
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_13_acc_0.7601.pkl
# Final accuracy: 0.7601
# Parameter containing:
# tensor([[-0.8050,  1.6833],
#         [-1.8556,  2.3467],
#         [-0.2524, -0.4847]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.4362,  0.7063],
#         [-0.2763, -0.2039],
#         [ 2.2364,  0.5859]], requires_grad=True)
#
# === Training with seed 14 ===
# initial loss =  1.0863581895828247
# Epoch [250/2500], Loss: 0.4925, Accuracy: 0.7619
# Epoch [500/2500], Loss: 0.4814, Accuracy: 0.7601
# Epoch [750/2500], Loss: 0.4802, Accuracy: 0.7598
# Epoch [1000/2500], Loss: 0.4800, Accuracy: 0.7602
# Epoch [1250/2500], Loss: 0.4799, Accuracy: 0.7602
# Epoch [1500/2500], Loss: 0.4798, Accuracy: 0.7582
# Epoch [1750/2500], Loss: 0.4798, Accuracy: 0.7575
# Epoch [2000/2500], Loss: 0.4798, Accuracy: 0.7575
# Epoch [2250/2500], Loss: 0.4798, Accuracy: 0.7575
# Epoch [2500/2500], Loss: 0.4798, Accuracy: 0.7575
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_14_acc_0.7575.pkl
# Final accuracy: 0.7575
# Parameter containing:
# tensor([[ 2.4362,  0.7063],
#         [-0.2763, -0.2039],
#         [ 2.2364,  0.5859]], requires_grad=True)
# Parameter containing:
# tensor([[-1.0007,  2.3707],
#         [-0.7903,  2.0663],
#         [-0.9057,  0.6080]], requires_grad=True)
#
# === Training with seed 15 ===
# initial loss =  2.275965452194214
# Epoch [250/2500], Loss: 0.5823, Accuracy: 0.7065
# Epoch [500/2500], Loss: 0.4982, Accuracy: 0.7662
# Epoch [750/2500], Loss: 0.4844, Accuracy: 0.7601
# Epoch [1000/2500], Loss: 0.4823, Accuracy: 0.7598
# Epoch [1250/2500], Loss: 0.4813, Accuracy: 0.7593
# Epoch [1500/2500], Loss: 0.4808, Accuracy: 0.7591
# Epoch [1750/2500], Loss: 0.4805, Accuracy: 0.7597
# Epoch [2000/2500], Loss: 0.4802, Accuracy: 0.7601
# Epoch [2250/2500], Loss: 0.4800, Accuracy: 0.7605
# Epoch [2500/2500], Loss: 0.4799, Accuracy: 0.7608
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_15_acc_0.7608.pkl
# Final accuracy: 0.7608
# Parameter containing:
# tensor([[-1.0007,  2.3707],
#         [-0.7903,  2.0663],
#         [-0.9057,  0.6080]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4928,  1.9939],
#         [-0.0323, -0.9878],
#         [ 1.4086,  2.3302]], requires_grad=True)
#
# === Training with seed 16 ===
# initial loss =  0.8649446368217468
# Epoch [250/2500], Loss: 0.4680, Accuracy: 0.7921
# Epoch [500/2500], Loss: 0.4319, Accuracy: 0.8036
# Epoch [750/2500], Loss: 0.4015, Accuracy: 0.8336
# Epoch [1000/2500], Loss: 0.3841, Accuracy: 0.8397
# Epoch [1250/2500], Loss: 0.3750, Accuracy: 0.8458
# Epoch [1500/2500], Loss: 0.3704, Accuracy: 0.8474
# Epoch [1750/2500], Loss: 0.3678, Accuracy: 0.8495
# Epoch [2000/2500], Loss: 0.3660, Accuracy: 0.8513
# Epoch [2250/2500], Loss: 0.3647, Accuracy: 0.8521
# Epoch [2500/2500], Loss: 0.3639, Accuracy: 0.8521
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_16_acc_0.8521.pkl
# Final accuracy: 0.8521
# Parameter containing:
# tensor([[-1.4928,  1.9939],
#         [-0.0323, -0.9878],
#         [ 1.4086,  2.3302]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7972,  0.5014],
#         [ 0.3289, -2.0255],
#         [-2.0152, -0.6428]], requires_grad=True)
#
# === Training with seed 17 ===
# initial loss =  3.1511311531066895
# Epoch [250/2500], Loss: 0.6419, Accuracy: 0.6622
# Epoch [500/2500], Loss: 0.6252, Accuracy: 0.6633
# Epoch [750/2500], Loss: 0.5871, Accuracy: 0.7047
# Epoch [1000/2500], Loss: 0.5167, Accuracy: 0.7467
# Epoch [1250/2500], Loss: 0.5129, Accuracy: 0.7473
# Epoch [1500/2500], Loss: 0.5127, Accuracy: 0.7480
# Epoch [1750/2500], Loss: 0.5125, Accuracy: 0.7492
# Epoch [2000/2500], Loss: 0.5122, Accuracy: 0.7520
# Epoch [2250/2500], Loss: 0.5121, Accuracy: 0.7523
# Epoch [2500/2500], Loss: 0.5120, Accuracy: 0.7530
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_17_acc_0.7530.pkl
# Final accuracy: 0.7530
# Parameter containing:
# tensor([[-1.7972,  0.5014],
#         [ 0.3289, -2.0255],
#         [-2.0152, -0.6428]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0263, -1.2684],
#         [ 0.6360,  1.2205],
#         [ 1.3820,  2.0599]], requires_grad=True)
#
# === Training with seed 18 ===
# initial loss =  2.2692675590515137
# Epoch [250/2500], Loss: 0.6384, Accuracy: 0.5000
# Epoch [500/2500], Loss: 0.5920, Accuracy: 0.6669
# Epoch [750/2500], Loss: 0.5873, Accuracy: 0.6788
# Epoch [1000/2500], Loss: 0.5447, Accuracy: 0.7250
# Epoch [1250/2500], Loss: 0.5371, Accuracy: 0.7281
# Epoch [1500/2500], Loss: 0.5362, Accuracy: 0.7288
# Epoch [1750/2500], Loss: 0.5359, Accuracy: 0.7283
# Epoch [2000/2500], Loss: 0.5359, Accuracy: 0.7282
# Epoch [2250/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [2500/2500], Loss: 0.5359, Accuracy: 0.7284
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_18_acc_0.7284.pkl
# Final accuracy: 0.7284
# Parameter containing:
# tensor([[ 0.0263, -1.2684],
#         [ 0.6360,  1.2205],
#         [ 1.3820,  2.0599]], requires_grad=True)
# Parameter containing:
# tensor([[-2.4669,  1.1457],
#         [-0.3475, -1.1182],
#         [-0.7610,  0.2551]], requires_grad=True)
#
# === Training with seed 19 ===
# initial loss =  0.9067867994308472
# Epoch [250/2500], Loss: 0.5219, Accuracy: 0.7446
# Epoch [500/2500], Loss: 0.5130, Accuracy: 0.7462
# Epoch [750/2500], Loss: 0.5125, Accuracy: 0.7493
# Epoch [1000/2500], Loss: 0.5121, Accuracy: 0.7527
# Epoch [1250/2500], Loss: 0.5120, Accuracy: 0.7531
# Epoch [1500/2500], Loss: 0.5120, Accuracy: 0.7530
# Epoch [1750/2500], Loss: 0.5120, Accuracy: 0.7530
# Epoch [2000/2500], Loss: 0.5120, Accuracy: 0.7530
# Epoch [2250/2500], Loss: 0.5120, Accuracy: 0.7530
# Epoch [2500/2500], Loss: 0.5120, Accuracy: 0.7530
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_19_acc_0.7530.pkl
# Final accuracy: 0.7530
# Parameter containing:
# tensor([[-2.4669,  1.1457],
#         [-0.3475, -1.1182],
#         [-0.7610,  0.2551]], requires_grad=True)
# Parameter containing:
# tensor([[-0.2851,  0.6283],
#         [-2.3105,  1.0650],
#         [-0.8854,  2.3156]], requires_grad=True)
#
# === Training with seed 20 ===
# initial loss =  1.5086537599563599
# Epoch [250/2500], Loss: 0.5670, Accuracy: 0.6982
# Epoch [500/2500], Loss: 0.5404, Accuracy: 0.7270
# Epoch [750/2500], Loss: 0.5371, Accuracy: 0.7282
# Epoch [1000/2500], Loss: 0.5363, Accuracy: 0.7288
# Epoch [1250/2500], Loss: 0.5360, Accuracy: 0.7285
# Epoch [1500/2500], Loss: 0.5359, Accuracy: 0.7281
# Epoch [1750/2500], Loss: 0.5359, Accuracy: 0.7282
# Epoch [2000/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [2250/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [2500/2500], Loss: 0.5359, Accuracy: 0.7284
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_20_acc_0.7284.pkl
# Final accuracy: 0.7284
# Parameter containing:
# tensor([[-0.2851,  0.6283],
#         [-2.3105,  1.0650],
#         [-0.8854,  2.3156]], requires_grad=True)
# Parameter containing:
# tensor([[-2.3289, -0.5032],
#         [ 1.0914,  1.5508],
#         [ 0.0048, -2.2223]], requires_grad=True)
#
# === Training with seed 21 ===
# initial loss =  1.2367810010910034
# Epoch [250/2500], Loss: 0.5160, Accuracy: 0.7622
# Epoch [500/2500], Loss: 0.4750, Accuracy: 0.7829
# Epoch [750/2500], Loss: 0.4687, Accuracy: 0.7776
# Epoch [1000/2500], Loss: 0.4676, Accuracy: 0.7791
# Epoch [1250/2500], Loss: 0.4641, Accuracy: 0.7864
# Epoch [1500/2500], Loss: 0.4608, Accuracy: 0.7884
# Epoch [1750/2500], Loss: 0.4588, Accuracy: 0.7880
# Epoch [2000/2500], Loss: 0.4579, Accuracy: 0.7879
# Epoch [2250/2500], Loss: 0.4576, Accuracy: 0.7893
# Epoch [2500/2500], Loss: 0.4574, Accuracy: 0.7894
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_21_acc_0.7894.pkl
# Final accuracy: 0.7894
# Parameter containing:
# tensor([[-2.3289, -0.5032],
#         [ 1.0914,  1.5508],
#         [ 0.0048, -2.2223]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.4888,  1.7972],
#         [-0.6698,  0.9744],
#         [-0.8285,  0.8407]], requires_grad=True)
#
# === Training with seed 22 ===
# initial loss =  2.218278408050537
# Epoch [250/2500], Loss: 0.6068, Accuracy: 0.6622
# Epoch [500/2500], Loss: 0.5842, Accuracy: 0.6808
# Epoch [750/2500], Loss: 0.4570, Accuracy: 0.7929
# Epoch [1000/2500], Loss: 0.4354, Accuracy: 0.8029
# Epoch [1250/2500], Loss: 0.3896, Accuracy: 0.8295
# Epoch [1500/2500], Loss: 0.3686, Accuracy: 0.8371
# Epoch [1750/2500], Loss: 0.3616, Accuracy: 0.8510
# Epoch [2000/2500], Loss: 0.3580, Accuracy: 0.8547
# Epoch [2250/2500], Loss: 0.3561, Accuracy: 0.8556
# Epoch [2500/2500], Loss: 0.3550, Accuracy: 0.8570
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_22_acc_0.8570.pkl
# Final accuracy: 0.8570
# Parameter containing:
# tensor([[ 1.4888,  1.7972],
#         [-0.6698,  0.9744],
#         [-0.8285,  0.8407]], requires_grad=True)
# Parameter containing:
# tensor([[-0.8260, -0.2295],
#         [-1.2403,  0.6550],
#         [-1.6467, -0.9388]], requires_grad=True)
#
# === Training with seed 23 ===
# initial loss =  0.7603692412376404
# Epoch [250/2500], Loss: 0.5417, Accuracy: 0.7256
# Epoch [500/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [750/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [1000/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [1250/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [1500/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [1750/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [2000/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [2250/2500], Loss: 0.5359, Accuracy: 0.7284
# Epoch [2500/2500], Loss: 0.5359, Accuracy: 0.7284
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_23_acc_0.7284.pkl
# Final accuracy: 0.7284
# Parameter containing:
# tensor([[-0.8260, -0.2295],
#         [-1.2403,  0.6550],
#         [-1.6467, -0.9388]], requires_grad=True)
# Parameter containing:
# tensor([[-0.9760, -1.0056],
#         [-0.7452, -2.2353],
#         [-1.5058,  1.5109]], requires_grad=True)
#
# === Training with seed 24 ===
# initial loss =  5.870674133300781
# Epoch [250/2500], Loss: 0.6615, Accuracy: 0.5437
# Epoch [500/2500], Loss: 0.5155, Accuracy: 0.7316
# Epoch [750/2500], Loss: 0.5089, Accuracy: 0.7416
# Epoch [1000/2500], Loss: 0.5078, Accuracy: 0.7437
# Epoch [1250/2500], Loss: 0.5072, Accuracy: 0.7439
# Epoch [1500/2500], Loss: 0.5069, Accuracy: 0.7436
# Epoch [1750/2500], Loss: 0.5068, Accuracy: 0.7428
# Epoch [2000/2500], Loss: 0.5068, Accuracy: 0.7419
# Epoch [2250/2500], Loss: 0.5067, Accuracy: 0.7414
# Epoch [2500/2500], Loss: 0.5067, Accuracy: 0.7411
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_24_acc_0.7411.pkl
# Final accuracy: 0.7411
# Parameter containing:
# tensor([[-0.9760, -1.0056],
#         [-0.7452, -2.2353],
#         [-1.5058,  1.5109]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0905,  2.3628],
#         [ 1.9063, -2.4719],
#         [-0.9718,  2.1921]], requires_grad=True)
#
# === Training with seed 25 ===
# initial loss =  0.9194877743721008
# Epoch [250/2500], Loss: 0.4863, Accuracy: 0.7776
# Epoch [500/2500], Loss: 0.4698, Accuracy: 0.7752
# Epoch [750/2500], Loss: 0.4694, Accuracy: 0.7760
# Epoch [1000/2500], Loss: 0.4665, Accuracy: 0.7826
# Epoch [1250/2500], Loss: 0.4602, Accuracy: 0.7886
# Epoch [1500/2500], Loss: 0.4581, Accuracy: 0.7882
# Epoch [1750/2500], Loss: 0.4575, Accuracy: 0.7894
# Epoch [2000/2500], Loss: 0.4573, Accuracy: 0.7893
# Epoch [2250/2500], Loss: 0.4573, Accuracy: 0.7893
# Epoch [2500/2500], Loss: 0.4572, Accuracy: 0.7893
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_25_acc_0.7893.pkl
# Final accuracy: 0.7893
# Parameter containing:
# tensor([[ 0.0905,  2.3628],
#         [ 1.9063, -2.4719],
#         [-0.9718,  2.1921]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.1308,  2.0386],
#         [-1.8635, -2.4261],
#         [-0.5303,  2.1976]], requires_grad=True)
#
# === Training with seed 26 ===
# initial loss =  5.523708820343018
# Epoch [250/2500], Loss: 0.5950, Accuracy: 0.7087
# Epoch [500/2500], Loss: 0.4798, Accuracy: 0.7718
# Epoch [750/2500], Loss: 0.4167, Accuracy: 0.8153
# Epoch [1000/2500], Loss: 0.3913, Accuracy: 0.8303
# Epoch [1250/2500], Loss: 0.3797, Accuracy: 0.8340
# Epoch [1500/2500], Loss: 0.3713, Accuracy: 0.8365
# Epoch [1750/2500], Loss: 0.3654, Accuracy: 0.8488
# Epoch [2000/2500], Loss: 0.3613, Accuracy: 0.8512
# Epoch [2250/2500], Loss: 0.3586, Accuracy: 0.8540
# Epoch [2500/2500], Loss: 0.3567, Accuracy: 0.8550
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_26_acc_0.8550.pkl
# Final accuracy: 0.8550
# Parameter containing:
# tensor([[ 2.1308,  2.0386],
#         [-1.8635, -2.4261],
#         [-0.5303,  2.1976]], requires_grad=True)
# Parameter containing:
# tensor([[-1.2464,  1.3234],
#         [ 1.4255, -2.3941],
#         [-1.3851,  0.7563]], requires_grad=True)
#
# === Training with seed 27 ===
# initial loss =  0.6381925344467163
# Epoch [250/2500], Loss: 0.3727, Accuracy: 0.8418
# Epoch [500/2500], Loss: 0.3674, Accuracy: 0.8449
# Epoch [750/2500], Loss: 0.3666, Accuracy: 0.8450
# Epoch [1000/2500], Loss: 0.3664, Accuracy: 0.8447
# Epoch [1250/2500], Loss: 0.3664, Accuracy: 0.8444
# Epoch [1500/2500], Loss: 0.3664, Accuracy: 0.8443
# Epoch [1750/2500], Loss: 0.3664, Accuracy: 0.8443
# Epoch [2000/2500], Loss: 0.3664, Accuracy: 0.8443
# Epoch [2250/2500], Loss: 0.3664, Accuracy: 0.8443
# Epoch [2500/2500], Loss: 0.3664, Accuracy: 0.8443
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_27_acc_0.8443.pkl
# Final accuracy: 0.8443
# Parameter containing:
# tensor([[-1.2464,  1.3234],
#         [ 1.4255, -2.3941],
#         [-1.3851,  0.7563]], requires_grad=True)
# Parameter containing:
# tensor([[-2.1348,  2.2932],
#         [-0.5350, -0.8428],
#         [ 2.3360,  0.1177]], requires_grad=True)
#
# === Training with seed 28 ===
# initial loss =  2.5486345291137695
# Epoch [250/2500], Loss: 0.6255, Accuracy: 0.6518
# Epoch [500/2500], Loss: 0.5680, Accuracy: 0.7598
# Epoch [750/2500], Loss: 0.5075, Accuracy: 0.7771
# Epoch [1000/2500], Loss: 0.4802, Accuracy: 0.7873
# Epoch [1250/2500], Loss: 0.4713, Accuracy: 0.7803
# Epoch [1500/2500], Loss: 0.4700, Accuracy: 0.7780
# Epoch [1750/2500], Loss: 0.4697, Accuracy: 0.7762
# Epoch [2000/2500], Loss: 0.4695, Accuracy: 0.7756
# Epoch [2250/2500], Loss: 0.4694, Accuracy: 0.7758
# Epoch [2500/2500], Loss: 0.4686, Accuracy: 0.7773
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_28_acc_0.7773.pkl
# Final accuracy: 0.7773
# Parameter containing:
# tensor([[-2.1348,  2.2932],
#         [-0.5350, -0.8428],
#         [ 2.3360,  0.1177]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.6002,  0.9240],
#         [-0.4141,  2.2426],
#         [-0.3339, -0.5049]], requires_grad=True)
#
# === Training with seed 29 ===
# initial loss =  2.1887712478637695
# Epoch [250/2500], Loss: 0.5897, Accuracy: 0.7217
# Epoch [500/2500], Loss: 0.5059, Accuracy: 0.7376
# Epoch [750/2500], Loss: 0.4744, Accuracy: 0.7739
# Epoch [1000/2500], Loss: 0.4663, Accuracy: 0.7768
# Epoch [1250/2500], Loss: 0.4614, Accuracy: 0.7814
# Epoch [1500/2500], Loss: 0.4585, Accuracy: 0.7846
# Epoch [1750/2500], Loss: 0.4578, Accuracy: 0.7870
# Epoch [2000/2500], Loss: 0.4575, Accuracy: 0.7879
# Epoch [2250/2500], Loss: 0.4574, Accuracy: 0.7880
# Epoch [2500/2500], Loss: 0.4573, Accuracy: 0.7889
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_29_acc_0.7889.pkl
# Final accuracy: 0.7889
# Parameter containing:
# tensor([[ 1.6002,  0.9240],
#         [-0.4141,  2.2426],
#         [-0.3339, -0.5049]], requires_grad=True)
# Parameter containing:
# tensor([[-2.2935, -1.9367],
#         [ 0.9862,  1.8799],
#         [-0.9184, -1.0055]], requires_grad=True)
#
# === Training with seed 30 ===
# initial loss =  2.4274652004241943
# Epoch [250/2500], Loss: 0.6686, Accuracy: 0.6480
# Epoch [500/2500], Loss: 0.5673, Accuracy: 0.6817
# Epoch [750/2500], Loss: 0.5130, Accuracy: 0.7508
# Epoch [1000/2500], Loss: 0.4077, Accuracy: 0.8217
# Epoch [1250/2500], Loss: 0.3729, Accuracy: 0.8376
# Epoch [1500/2500], Loss: 0.3630, Accuracy: 0.8501
# Epoch [1750/2500], Loss: 0.3588, Accuracy: 0.8537
# Epoch [2000/2500], Loss: 0.3565, Accuracy: 0.8554
# Epoch [2250/2500], Loss: 0.3552, Accuracy: 0.8569
# Epoch [2500/2500], Loss: 0.3545, Accuracy: 0.8574
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_30_acc_0.8574.pkl
# Final accuracy: 0.8574
# Parameter containing:
# tensor([[-2.2935, -1.9367],
#         [ 0.9862,  1.8799],
#         [-0.9184, -1.0055]], requires_grad=True)
# Parameter containing:
# tensor([[-1.8010, -1.7756],
#         [ 1.0809,  1.9316],
#         [ 1.1709,  1.9634]], requires_grad=True)
#
# === Training with seed 31 ===
# initial loss =  3.255380153656006
# Epoch [250/2500], Loss: 0.6577, Accuracy: 0.6005
# Epoch [500/2500], Loss: 0.6342, Accuracy: 0.5876
# Epoch [750/2500], Loss: 0.5792, Accuracy: 0.7514
# Epoch [1000/2500], Loss: 0.5519, Accuracy: 0.7686
# Epoch [1250/2500], Loss: 0.4703, Accuracy: 0.7943
# Epoch [1500/2500], Loss: 0.4414, Accuracy: 0.8101
# Epoch [1750/2500], Loss: 0.3927, Accuracy: 0.8317
# Epoch [2000/2500], Loss: 0.3698, Accuracy: 0.8367
# Epoch [2250/2500], Loss: 0.3610, Accuracy: 0.8512
# Epoch [2500/2500], Loss: 0.3572, Accuracy: 0.8549
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_31_acc_0.8549.pkl
# Final accuracy: 0.8549
# Parameter containing:
# tensor([[-1.8010, -1.7756],
#         [ 1.0809,  1.9316],
#         [ 1.1709,  1.9634]], requires_grad=True)
# Parameter containing:
# tensor([[-2.0436,  1.0884],
#         [ 1.1356, -0.0163],
#         [ 2.1537, -0.6616]], requires_grad=True)
#
# === Training with seed 32 ===
# initial loss =  1.5847468376159668
# Epoch [250/2500], Loss: 0.6651, Accuracy: 0.6155
# Epoch [500/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [750/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [1000/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [1250/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [1500/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [1750/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2000/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2250/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2500/2500], Loss: 0.6651, Accuracy: 0.6159
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_32_acc_0.6159.pkl
# Final accuracy: 0.6159
# Parameter containing:
# tensor([[-2.0436,  1.0884],
#         [ 1.1356, -0.0163],
#         [ 2.1537, -0.6616]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.7678,  0.3328],
#         [-1.2429, -2.2657],
#         [ 0.9862,  1.0504]], requires_grad=True)
#
# === Training with seed 33 ===
# initial loss =  0.9219999313354492
# Epoch [250/2500], Loss: 0.4659, Accuracy: 0.8011
# Epoch [500/2500], Loss: 0.3543, Accuracy: 0.8582
# Epoch [750/2500], Loss: 0.3500, Accuracy: 0.8565
# Epoch [1000/2500], Loss: 0.3496, Accuracy: 0.8562
# Epoch [1250/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [1500/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [1750/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2000/2500], Loss: 0.3495, Accuracy: 0.8561
# Epoch [2250/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2500/2500], Loss: 0.3495, Accuracy: 0.8562
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_33_acc_0.8562.pkl
# Final accuracy: 0.8562
# Parameter containing:
# tensor([[ 1.7678,  0.3328],
#         [-1.2429, -2.2657],
#         [ 0.9862,  1.0504]], requires_grad=True)
# Parameter containing:
# tensor([[-1.2626, -1.5245],
#         [-0.9545, -0.3216],
#         [-0.5755, -2.4548]], requires_grad=True)
#
# === Training with seed 34 ===
# initial loss =  0.8308060765266418
# Epoch [250/2500], Loss: 0.4308, Accuracy: 0.8045
# Epoch [500/2500], Loss: 0.3920, Accuracy: 0.8351
# Epoch [750/2500], Loss: 0.3642, Accuracy: 0.8409
# Epoch [1000/2500], Loss: 0.3538, Accuracy: 0.8579
# Epoch [1250/2500], Loss: 0.3535, Accuracy: 0.8576
# Epoch [1500/2500], Loss: 0.3533, Accuracy: 0.8578
# Epoch [1750/2500], Loss: 0.3532, Accuracy: 0.8578
# Epoch [2000/2500], Loss: 0.3531, Accuracy: 0.8581
# Epoch [2250/2500], Loss: 0.3531, Accuracy: 0.8580
# Epoch [2500/2500], Loss: 0.3530, Accuracy: 0.8581
# *** NEW BEST MODEL: Seed 34, Accuracy 0.8581 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_34_acc_0.8581.pkl
# Final accuracy: 0.8581
# Parameter containing:
# tensor([[-1.2626, -1.5245],
#         [-0.9545, -0.3216],
#         [-0.5755, -2.4548]], requires_grad=True)
# Parameter containing:
# tensor([[-0.5383,  1.5826],
#         [ 0.9450,  2.2983],
#         [ 2.0159,  1.1268]], requires_grad=True)
#
# === Training with seed 35 ===
# initial loss =  3.2516849040985107
# Epoch [250/2500], Loss: 0.6218, Accuracy: 0.6589
# Epoch [500/2500], Loss: 0.4963, Accuracy: 0.7513
# Epoch [750/2500], Loss: 0.4763, Accuracy: 0.7893
# Epoch [1000/2500], Loss: 0.4722, Accuracy: 0.7820
# Epoch [1250/2500], Loss: 0.4698, Accuracy: 0.7772
# Epoch [1500/2500], Loss: 0.4650, Accuracy: 0.7804
# Epoch [1750/2500], Loss: 0.4614, Accuracy: 0.7793
# Epoch [2000/2500], Loss: 0.4589, Accuracy: 0.7774
# Epoch [2250/2500], Loss: 0.4572, Accuracy: 0.7801
# Epoch [2500/2500], Loss: 0.4559, Accuracy: 0.7828
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_35_acc_0.7828.pkl
# Final accuracy: 0.7828
# Parameter containing:
# tensor([[-0.5383,  1.5826],
#         [ 0.9450,  2.2983],
#         [ 2.0159,  1.1268]], requires_grad=True)
# Parameter containing:
# tensor([[-1.6732, -0.8220],
#         [-2.0071, -0.0430],
#         [-1.7555,  0.0274]], requires_grad=True)
#
# === Training with seed 36 ===
# initial loss =  0.726815402507782
# Epoch [250/2500], Loss: 0.5102, Accuracy: 0.7334
# Epoch [500/2500], Loss: 0.5070, Accuracy: 0.7400
# Epoch [750/2500], Loss: 0.5068, Accuracy: 0.7398
# Epoch [1000/2500], Loss: 0.5067, Accuracy: 0.7398
# Epoch [1250/2500], Loss: 0.5067, Accuracy: 0.7399
# Epoch [1500/2500], Loss: 0.5067, Accuracy: 0.7399
# Epoch [1750/2500], Loss: 0.5067, Accuracy: 0.7399
# Epoch [2000/2500], Loss: 0.5067, Accuracy: 0.7399
# Epoch [2250/2500], Loss: 0.5067, Accuracy: 0.7399
# Epoch [2500/2500], Loss: 0.5067, Accuracy: 0.7399
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_36_acc_0.7399.pkl
# Final accuracy: 0.7399
# Parameter containing:
# tensor([[-1.6732, -0.8220],
#         [-2.0071, -0.0430],
#         [-1.7555,  0.0274]], requires_grad=True)
# Parameter containing:
# tensor([[-2.4866,  1.8835],
#         [-1.0201,  2.1632],
#         [ 1.9526,  0.5728]], requires_grad=True)
#
# === Training with seed 37 ===
# initial loss =  0.7698470950126648
# Epoch [250/2500], Loss: 0.3825, Accuracy: 0.8505
# Epoch [500/2500], Loss: 0.3647, Accuracy: 0.8554
# Epoch [750/2500], Loss: 0.3636, Accuracy: 0.8567
# Epoch [1000/2500], Loss: 0.3634, Accuracy: 0.8570
# Epoch [1250/2500], Loss: 0.3634, Accuracy: 0.8573
# Epoch [1500/2500], Loss: 0.3634, Accuracy: 0.8575
# Epoch [1750/2500], Loss: 0.3634, Accuracy: 0.8575
# Epoch [2000/2500], Loss: 0.3634, Accuracy: 0.8575
# Epoch [2250/2500], Loss: 0.3634, Accuracy: 0.8575
# Epoch [2500/2500], Loss: 0.3634, Accuracy: 0.8575
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_37_acc_0.8575.pkl
# Final accuracy: 0.8575
# Parameter containing:
# tensor([[-2.4866,  1.8835],
#         [-1.0201,  2.1632],
#         [ 1.9526,  0.5728]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4195, -2.0027],
#         [ 2.1549,  2.1249],
#         [ 0.4685, -1.3043]], requires_grad=True)
#
# === Training with seed 38 ===
# initial loss =  3.159899950027466
# Epoch [250/2500], Loss: 0.6861, Accuracy: 0.6102
# Epoch [500/2500], Loss: 0.6710, Accuracy: 0.6234
# Epoch [750/2500], Loss: 0.6680, Accuracy: 0.6245
# Epoch [1000/2500], Loss: 0.6669, Accuracy: 0.6240
# Epoch [1250/2500], Loss: 0.6662, Accuracy: 0.6225
# Epoch [1500/2500], Loss: 0.6658, Accuracy: 0.6209
# Epoch [1750/2500], Loss: 0.6655, Accuracy: 0.6190
# Epoch [2000/2500], Loss: 0.6653, Accuracy: 0.6177
# Epoch [2250/2500], Loss: 0.6651, Accuracy: 0.6161
# Epoch [2500/2500], Loss: 0.6651, Accuracy: 0.6159
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_38_acc_0.6159.pkl
# Final accuracy: 0.6159
# Parameter containing:
# tensor([[-1.4195, -2.0027],
#         [ 2.1549,  2.1249],
#         [ 0.4685, -1.3043]], requires_grad=True)
# Parameter containing:
# tensor([[-0.8070,  2.3498],
#         [ 1.2417,  1.3437],
#         [ 0.1317,  1.3854]], requires_grad=True)
#
# === Training with seed 39 ===
# initial loss =  2.042400360107422
# Epoch [250/2500], Loss: 0.4461, Accuracy: 0.8011
# Epoch [500/2500], Loss: 0.3836, Accuracy: 0.8318
# Epoch [750/2500], Loss: 0.3689, Accuracy: 0.8450
# Epoch [1000/2500], Loss: 0.3619, Accuracy: 0.8505
# Epoch [1250/2500], Loss: 0.3583, Accuracy: 0.8538
# Epoch [1500/2500], Loss: 0.3561, Accuracy: 0.8552
# Epoch [1750/2500], Loss: 0.3549, Accuracy: 0.8566
# Epoch [2000/2500], Loss: 0.3542, Accuracy: 0.8570
# Epoch [2250/2500], Loss: 0.3538, Accuracy: 0.8574
# Epoch [2500/2500], Loss: 0.3535, Accuracy: 0.8581
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_39_acc_0.8581.pkl
# Final accuracy: 0.8581
# Parameter containing:
# tensor([[-0.8070,  2.3498],
#         [ 1.2417,  1.3437],
#         [ 0.1317,  1.3854]], requires_grad=True)
# Parameter containing:
# tensor([[-1.9351,  0.8893],
#         [-2.4134, -1.8983],
#         [-1.8183,  1.5446]], requires_grad=True)
#
# === Training with seed 40 ===
# initial loss =  3.677671432495117
# Epoch [250/2500], Loss: 0.6803, Accuracy: 0.6379
# Epoch [500/2500], Loss: 0.6395, Accuracy: 0.6897
# Epoch [750/2500], Loss: 0.5447, Accuracy: 0.7327
# Epoch [1000/2500], Loss: 0.5212, Accuracy: 0.7443
# Epoch [1250/2500], Loss: 0.5153, Accuracy: 0.7428
# Epoch [1500/2500], Loss: 0.5131, Accuracy: 0.7461
# Epoch [1750/2500], Loss: 0.5127, Accuracy: 0.7478
# Epoch [2000/2500], Loss: 0.5126, Accuracy: 0.7491
# Epoch [2250/2500], Loss: 0.5124, Accuracy: 0.7505
# Epoch [2500/2500], Loss: 0.5121, Accuracy: 0.7521
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_40_acc_0.7521.pkl
# Final accuracy: 0.7521
# Parameter containing:
# tensor([[-1.9351,  0.8893],
#         [-2.4134, -1.8983],
#         [-1.8183,  1.5446]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0579, -1.4615],
#         [-0.9683, -2.2074],
#         [ 1.6568, -0.2169]], requires_grad=True)
#
# === Training with seed 41 ===
# initial loss =  1.278243899345398
# Epoch [250/2500], Loss: 0.4974, Accuracy: 0.7681
# Epoch [500/2500], Loss: 0.4520, Accuracy: 0.8040
# Epoch [750/2500], Loss: 0.3777, Accuracy: 0.8442
# Epoch [1000/2500], Loss: 0.3516, Accuracy: 0.8575
# Epoch [1250/2500], Loss: 0.3498, Accuracy: 0.8568
# Epoch [1500/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [1750/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2000/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2250/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2500/2500], Loss: 0.3495, Accuracy: 0.8562
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_41_acc_0.8562.pkl
# Final accuracy: 0.8562
# Parameter containing:
# tensor([[-0.0579, -1.4615],
#         [-0.9683, -2.2074],
#         [ 1.6568, -0.2169]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3695, -1.1671],
#         [ 0.6372, -1.1518],
#         [-0.2932, -1.0154]], requires_grad=True)
#
# === Training with seed 42 ===
# initial loss =  2.42879581451416
# Epoch [250/2500], Loss: 0.5747, Accuracy: 0.7540
# Epoch [500/2500], Loss: 0.5230, Accuracy: 0.7498
# Epoch [750/2500], Loss: 0.4901, Accuracy: 0.7789
# Epoch [1000/2500], Loss: 0.4810, Accuracy: 0.7815
# Epoch [1250/2500], Loss: 0.4775, Accuracy: 0.7782
# Epoch [1500/2500], Loss: 0.4745, Accuracy: 0.7768
# Epoch [1750/2500], Loss: 0.4708, Accuracy: 0.7634
# Epoch [2000/2500], Loss: 0.4698, Accuracy: 0.7601
# Epoch [2250/2500], Loss: 0.4697, Accuracy: 0.7584
# Epoch [2500/2500], Loss: 0.4697, Accuracy: 0.7581
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_42_acc_0.7581.pkl
# Final accuracy: 0.7581
# Parameter containing:
# tensor([[ 0.3695, -1.1671],
#         [ 0.6372, -1.1518],
#         [-0.2932, -1.0154]], requires_grad=True)
# Parameter containing:
# tensor([[-1.1194,  1.6978],
#         [-1.7186, -1.9640],
#         [ 1.1307, -0.8797]], requires_grad=True)
#
# === Training with seed 43 ===
# initial loss =  3.511876106262207
# Epoch [250/2500], Loss: 0.5946, Accuracy: 0.7088
# Epoch [500/2500], Loss: 0.4286, Accuracy: 0.7893
# Epoch [750/2500], Loss: 0.3839, Accuracy: 0.8366
# Epoch [1000/2500], Loss: 0.3729, Accuracy: 0.8434
# Epoch [1250/2500], Loss: 0.3699, Accuracy: 0.8442
# Epoch [1500/2500], Loss: 0.3682, Accuracy: 0.8445
# Epoch [1750/2500], Loss: 0.3672, Accuracy: 0.8444
# Epoch [2000/2500], Loss: 0.3667, Accuracy: 0.8447
# Epoch [2250/2500], Loss: 0.3665, Accuracy: 0.8445
# Epoch [2500/2500], Loss: 0.3664, Accuracy: 0.8446
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_43_acc_0.8446.pkl
# Final accuracy: 0.8446
# Parameter containing:
# tensor([[-1.1194,  1.6978],
#         [-1.7186, -1.9640],
#         [ 1.1307, -0.8797]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.0583,  1.4894],
#         [-1.1077,  1.9736],
#         [ 0.8469,  1.9750]], requires_grad=True)
#
# === Training with seed 44 ===
# initial loss =  0.8330327868461609
# Epoch [250/2500], Loss: 0.4822, Accuracy: 0.7799
# Epoch [500/2500], Loss: 0.4592, Accuracy: 0.7896
# Epoch [750/2500], Loss: 0.4574, Accuracy: 0.7893
# Epoch [1000/2500], Loss: 0.4572, Accuracy: 0.7892
# Epoch [1250/2500], Loss: 0.4572, Accuracy: 0.7893
# Epoch [1500/2500], Loss: 0.4572, Accuracy: 0.7893
# Epoch [1750/2500], Loss: 0.4572, Accuracy: 0.7893
# Epoch [2000/2500], Loss: 0.4572, Accuracy: 0.7893
# Epoch [2250/2500], Loss: 0.4572, Accuracy: 0.7893
# Epoch [2500/2500], Loss: 0.4572, Accuracy: 0.7893
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_44_acc_0.7893.pkl
# Final accuracy: 0.7893
# Parameter containing:
# tensor([[ 1.0583,  1.4894],
#         [-1.1077,  1.9736],
#         [ 0.8469,  1.9750]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.7641,  0.5614],
#         [ 2.4168, -1.5870],
#         [-1.8804, -0.3689]], requires_grad=True)
#
# === Training with seed 45 ===
# initial loss =  3.132021188735962
# Epoch [250/2500], Loss: 0.5375, Accuracy: 0.7573
# Epoch [500/2500], Loss: 0.4888, Accuracy: 0.7588
# Epoch [750/2500], Loss: 0.4826, Accuracy: 0.7621
# Epoch [1000/2500], Loss: 0.4811, Accuracy: 0.7630
# Epoch [1250/2500], Loss: 0.4804, Accuracy: 0.7650
# Epoch [1500/2500], Loss: 0.4801, Accuracy: 0.7663
# Epoch [1750/2500], Loss: 0.4793, Accuracy: 0.7726
# Epoch [2000/2500], Loss: 0.4429, Accuracy: 0.8206
# Epoch [2250/2500], Loss: 0.4353, Accuracy: 0.8392
# Epoch [2500/2500], Loss: 0.4327, Accuracy: 0.8397
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_45_acc_0.8397.pkl
# Final accuracy: 0.8397
# Parameter containing:
# tensor([[ 0.7641,  0.5614],
#         [ 2.4168, -1.5870],
#         [-1.8804, -0.3689]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.5762, -0.0950],
#         [ 1.1940, -2.3440],
#         [ 1.0243,  1.1822]], requires_grad=True)
#
# === Training with seed 46 ===
# initial loss =  0.7796791791915894
# Epoch [250/2500], Loss: 0.5969, Accuracy: 0.6562
# Epoch [500/2500], Loss: 0.5969, Accuracy: 0.6564
# Epoch [750/2500], Loss: 0.5969, Accuracy: 0.6564
# Epoch [1000/2500], Loss: 0.5969, Accuracy: 0.6563
# Epoch [1250/2500], Loss: 0.5969, Accuracy: 0.6563
# Epoch [1500/2500], Loss: 0.5969, Accuracy: 0.6565
# Epoch [1750/2500], Loss: 0.5969, Accuracy: 0.6563
# Epoch [2000/2500], Loss: 0.5969, Accuracy: 0.6565
# Epoch [2250/2500], Loss: 0.5969, Accuracy: 0.6563
# Epoch [2500/2500], Loss: 0.5969, Accuracy: 0.6565
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_46_acc_0.6565.pkl
# Final accuracy: 0.6565
# Parameter containing:
# tensor([[ 1.5762, -0.0950],
#         [ 1.1940, -2.3440],
#         [ 1.0243,  1.1822]], requires_grad=True)
# Parameter containing:
# tensor([[-2.3247, -1.7888],
#         [-0.4718,  0.1703],
#         [ 0.4310, -1.7655]], requires_grad=True)
#
# === Training with seed 47 ===
# initial loss =  1.1942957639694214
# Epoch [250/2500], Loss: 0.5363, Accuracy: 0.7170
# Epoch [500/2500], Loss: 0.5276, Accuracy: 0.7431
# Epoch [750/2500], Loss: 0.5251, Accuracy: 0.7439
# Epoch [1000/2500], Loss: 0.4855, Accuracy: 0.7575
# Epoch [1250/2500], Loss: 0.4808, Accuracy: 0.7592
# Epoch [1500/2500], Loss: 0.4801, Accuracy: 0.7607
# Epoch [1750/2500], Loss: 0.4798, Accuracy: 0.7608
# Epoch [2000/2500], Loss: 0.4797, Accuracy: 0.7608
# Epoch [2250/2500], Loss: 0.4797, Accuracy: 0.7610
# Epoch [2500/2500], Loss: 0.4796, Accuracy: 0.7612
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_47_acc_0.7612.pkl
# Final accuracy: 0.7612
# Parameter containing:
# tensor([[-2.3247, -1.7888],
#         [-0.4718,  0.1703],
#         [ 0.4310, -1.7655]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.0119, -0.3198],
#         [ 1.1754,  1.2594],
#         [-2.1316, -0.8716]], requires_grad=True)
#
# === Training with seed 48 ===
# ...
#         [-1.1279, -1.5649]], requires_grad=True)
#
# === Training with seed 112 ===
# initial loss =  2.1782596111297607
# Epoch [250/2500], Loss: 0.5579, Accuracy: 0.7602
# Epoch [500/2500], Loss: 0.4857, Accuracy: 0.7583
# Epoch [750/2500], Loss: 0.4808, Accuracy: 0.7581
# Epoch [1000/2500], Loss: 0.4800, Accuracy: 0.7591
# Epoch [1250/2500], Loss: 0.4797, Accuracy: 0.7604
# Epoch [1500/2500], Loss: 0.4796, Accuracy: 0.7609
# Epoch [1750/2500], Loss: 0.4796, Accuracy: 0.7611
# Epoch [2000/2500], Loss: 0.4796, Accuracy: 0.7618
# Epoch [2250/2500], Loss: 0.4796, Accuracy: 0.7618
# Epoch [2500/2500], Loss: 0.4796, Accuracy: 0.7617
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_112_acc_0.7617.pkl
# Final accuracy: 0.7617
# Parameter containing:
# tensor([[-1.9621,  2.1035],
#         [-0.6268,  0.7717],
#         [-1.1279, -1.5649]], requires_grad=True)
# Parameter containing:
# tensor([[-1.5887, -1.1632],
#         [-1.5349, -0.6701],
#         [-0.6787,  0.5087]], requires_grad=True)
#
# === Training with seed 113 ===
# initial loss =  4.711731433868408
# Epoch [250/2500], Loss: 0.6702, Accuracy: 0.6163
# Epoch [500/2500], Loss: 0.6664, Accuracy: 0.6225
# Epoch [750/2500], Loss: 0.6658, Accuracy: 0.6204
# Epoch [1000/2500], Loss: 0.6654, Accuracy: 0.6177
# Epoch [1250/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [1500/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [1750/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2000/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2250/2500], Loss: 0.6651, Accuracy: 0.6159
# Epoch [2500/2500], Loss: 0.6651, Accuracy: 0.6159
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_113_acc_0.6159.pkl
# Final accuracy: 0.6159
# Parameter containing:
# tensor([[-1.5887, -1.1632],
#         [-1.5349, -0.6701],
#         [-0.6787,  0.5087]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.8925,  1.0306],
#         [-1.1163,  1.8007],
#         [ 0.4109, -1.5366]], requires_grad=True)
#
# === Training with seed 114 ===
# initial loss =  2.9062085151672363
# Epoch [250/2500], Loss: 0.6130, Accuracy: 0.7018
# Epoch [500/2500], Loss: 0.5729, Accuracy: 0.7771
# Epoch [750/2500], Loss: 0.5541, Accuracy: 0.7737
# Epoch [1000/2500], Loss: 0.4929, Accuracy: 0.7581
# Epoch [1250/2500], Loss: 0.4841, Accuracy: 0.7581
# Epoch [1500/2500], Loss: 0.4820, Accuracy: 0.7594
# Epoch [1750/2500], Loss: 0.4811, Accuracy: 0.7603
# Epoch [2000/2500], Loss: 0.4806, Accuracy: 0.7602
# Epoch [2250/2500], Loss: 0.4803, Accuracy: 0.7604
# Epoch [2500/2500], Loss: 0.4801, Accuracy: 0.7609
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_114_acc_0.7609.pkl
# Final accuracy: 0.7609
# Parameter containing:
# tensor([[ 1.8925,  1.0306],
#         [-1.1163,  1.8007],
#         [ 0.4109, -1.5366]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.6824,  2.0728],
#         [-0.1736, -1.7333],
#         [ 2.0311,  2.2711]], requires_grad=True)
#
# === Training with seed 115 ===
# initial loss =  1.759433388710022
# Epoch [250/2500], Loss: 0.6395, Accuracy: 0.6488
# Epoch [500/2500], Loss: 0.5819, Accuracy: 0.7444
# Epoch [750/2500], Loss: 0.4660, Accuracy: 0.7800
# Epoch [1000/2500], Loss: 0.4605, Accuracy: 0.7811
# Epoch [1250/2500], Loss: 0.4577, Accuracy: 0.7820
# Epoch [1500/2500], Loss: 0.4562, Accuracy: 0.7836
# Epoch [1750/2500], Loss: 0.4549, Accuracy: 0.7845
# Epoch [2000/2500], Loss: 0.4538, Accuracy: 0.7859
# Epoch [2250/2500], Loss: 0.4528, Accuracy: 0.7857
# Epoch [2500/2500], Loss: 0.4522, Accuracy: 0.7868
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_115_acc_0.7868.pkl
# Final accuracy: 0.7868
# Parameter containing:
# tensor([[ 0.6824,  2.0728],
#         [-0.1736, -1.7333],
#         [ 2.0311,  2.2711]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3271, -1.6492],
#         [-1.8422,  0.2030],
#         [ 2.4939,  1.4096]], requires_grad=True)
#
# === Training with seed 116 ===
# initial loss =  2.7025399208068848
# Epoch [250/2500], Loss: 0.6812, Accuracy: 0.5140
# Epoch [500/2500], Loss: 0.6401, Accuracy: 0.6098
# Epoch [750/2500], Loss: 0.6266, Accuracy: 0.6277
# Epoch [1000/2500], Loss: 0.6184, Accuracy: 0.6204
# Epoch [1250/2500], Loss: 0.6105, Accuracy: 0.6233
# Epoch [1500/2500], Loss: 0.6048, Accuracy: 0.6297
# Epoch [1750/2500], Loss: 0.6016, Accuracy: 0.6321
# Epoch [2000/2500], Loss: 0.5998, Accuracy: 0.6331
# Epoch [2250/2500], Loss: 0.5986, Accuracy: 0.6333
# Epoch [2500/2500], Loss: 0.5977, Accuracy: 0.6342
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_116_acc_0.6342.pkl
# Final accuracy: 0.6342
# Parameter containing:
# tensor([[ 0.3271, -1.6492],
#         [-1.8422,  0.2030],
#         [ 2.4939,  1.4096]], requires_grad=True)
# Parameter containing:
# tensor([[-0.2180, -2.3421],
#         [ 1.4697, -2.4124],
#         [-2.0118, -0.4292]], requires_grad=True)
#
# === Training with seed 117 ===
# initial loss =  0.5606502890586853
# Epoch [250/2500], Loss: 0.3962, Accuracy: 0.8134
# Epoch [500/2500], Loss: 0.3931, Accuracy: 0.8127
# Epoch [750/2500], Loss: 0.3931, Accuracy: 0.8123
# Epoch [1000/2500], Loss: 0.3931, Accuracy: 0.8122
# Epoch [1250/2500], Loss: 0.3931, Accuracy: 0.8122
# Epoch [1500/2500], Loss: 0.3931, Accuracy: 0.8122
# Epoch [1750/2500], Loss: 0.3931, Accuracy: 0.8122
# Epoch [2000/2500], Loss: 0.3931, Accuracy: 0.8122
# Epoch [2250/2500], Loss: 0.3931, Accuracy: 0.8122
# Epoch [2500/2500], Loss: 0.3931, Accuracy: 0.8122
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_117_acc_0.8122.pkl
# Final accuracy: 0.8122
# Parameter containing:
# tensor([[-0.2180, -2.3421],
#         [ 1.4697, -2.4124],
#         [-2.0118, -0.4292]], requires_grad=True)
# Parameter containing:
# tensor([[-0.1078, -2.4460],
#         [ 2.1452,  2.3434],
#         [ 0.5511, -1.8756]], requires_grad=True)
#
# === Training with seed 118 ===
# initial loss =  1.0581843852996826
# Epoch [250/2500], Loss: 0.5105, Accuracy: 0.7121
# Epoch [500/2500], Loss: 0.4238, Accuracy: 0.8342
# Epoch [750/2500], Loss: 0.3763, Accuracy: 0.8522
# Epoch [1000/2500], Loss: 0.3729, Accuracy: 0.8492
# Epoch [1250/2500], Loss: 0.3714, Accuracy: 0.8487
# Epoch [1500/2500], Loss: 0.3666, Accuracy: 0.8521
# Epoch [1750/2500], Loss: 0.3646, Accuracy: 0.8569
# Epoch [2000/2500], Loss: 0.3634, Accuracy: 0.8581
# Epoch [2250/2500], Loss: 0.3634, Accuracy: 0.8579
# Epoch [2500/2500], Loss: 0.3634, Accuracy: 0.8579
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_118_acc_0.8579.pkl
# Final accuracy: 0.8579
# Parameter containing:
# tensor([[-0.1078, -2.4460],
#         [ 2.1452,  2.3434],
#         [ 0.5511, -1.8756]], requires_grad=True)
# Parameter containing:
# tensor([[-0.6805, -1.8942],
#         [-1.1642, -1.2139],
#         [ 2.4210, -1.6382]], requires_grad=True)
#
# === Training with seed 119 ===
# initial loss =  0.9533484578132629
# Epoch [250/2500], Loss: 0.4761, Accuracy: 0.7769
# Epoch [500/2500], Loss: 0.4745, Accuracy: 0.7770
# Epoch [750/2500], Loss: 0.4743, Accuracy: 0.7771
# Epoch [1000/2500], Loss: 0.4743, Accuracy: 0.7773
# Epoch [1250/2500], Loss: 0.4743, Accuracy: 0.7772
# Epoch [1500/2500], Loss: 0.4743, Accuracy: 0.7772
# Epoch [1750/2500], Loss: 0.4743, Accuracy: 0.7772
# Epoch [2000/2500], Loss: 0.4743, Accuracy: 0.7772
# Epoch [2250/2500], Loss: 0.4743, Accuracy: 0.7773
# Epoch [2500/2500], Loss: 0.4743, Accuracy: 0.7773
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_119_acc_0.7773.pkl
# Final accuracy: 0.7773
# Parameter containing:
# tensor([[-0.6805, -1.8942],
#         [-1.1642, -1.2139],
#         [ 2.4210, -1.6382]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.1178, -2.4086],
#         [ 1.9563, -1.6790],
#         [-1.4510, -2.4885]], requires_grad=True)
#
# === Training with seed 120 ===
# initial loss =  1.6793851852416992
# Epoch [250/2500], Loss: 0.5211, Accuracy: 0.7649
# Epoch [500/2500], Loss: 0.3728, Accuracy: 0.8450
# Epoch [750/2500], Loss: 0.3537, Accuracy: 0.8560
# Epoch [1000/2500], Loss: 0.3505, Accuracy: 0.8561
# Epoch [1250/2500], Loss: 0.3498, Accuracy: 0.8561
# Epoch [1500/2500], Loss: 0.3496, Accuracy: 0.8560
# Epoch [1750/2500], Loss: 0.3495, Accuracy: 0.8561
# Epoch [2000/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2250/2500], Loss: 0.3495, Accuracy: 0.8562
# Epoch [2500/2500], Loss: 0.3495, Accuracy: 0.8562
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_120_acc_0.8562.pkl
# Final accuracy: 0.8562
# Parameter containing:
# tensor([[ 1.1178, -2.4086],
#         [ 1.9563, -1.6790],
#         [-1.4510, -2.4885]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7093,  2.3840],
#         [-2.1582,  1.9357],
#         [-1.9528, -0.4935]], requires_grad=True)
#
# === Training with seed 121 ===
# initial loss =  0.8348301649093628
# Epoch [250/2500], Loss: 0.5556, Accuracy: 0.7765
# Epoch [500/2500], Loss: 0.4838, Accuracy: 0.7566
# Epoch [750/2500], Loss: 0.4808, Accuracy: 0.7592
# Epoch [1000/2500], Loss: 0.4801, Accuracy: 0.7602
# Epoch [1250/2500], Loss: 0.4799, Accuracy: 0.7610
# Epoch [1500/2500], Loss: 0.4798, Accuracy: 0.7610
# Epoch [1750/2500], Loss: 0.4797, Accuracy: 0.7609
# Epoch [2000/2500], Loss: 0.4796, Accuracy: 0.7612
# Epoch [2250/2500], Loss: 0.4796, Accuracy: 0.7618
# Epoch [2500/2500], Loss: 0.4796, Accuracy: 0.7618
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_121_acc_0.7618.pkl
# Final accuracy: 0.7618
# Parameter containing:
# tensor([[-1.7093,  2.3840],
#         [-2.1582,  1.9357],
#         [-1.9528, -0.4935]], requires_grad=True)
# Parameter containing:
# tensor([[-2.2180,  1.1854],
#         [ 1.7868,  0.1466],
#         [ 1.1935, -1.6323]], requires_grad=True)
#
# === Training with seed 122 ===
# initial loss =  10.063972473144531
# Epoch [250/2500], Loss: 0.6657, Accuracy: 0.6099
# Epoch [500/2500], Loss: 0.6642, Accuracy: 0.6127
# Epoch [750/2500], Loss: 0.6219, Accuracy: 0.6653
# Epoch [1000/2500], Loss: 0.5399, Accuracy: 0.7520
# Epoch [1250/2500], Loss: 0.5043, Accuracy: 0.7597
# Epoch [1500/2500], Loss: 0.4921, Accuracy: 0.7578
# Epoch [1750/2500], Loss: 0.4874, Accuracy: 0.7569
# Epoch [2000/2500], Loss: 0.4850, Accuracy: 0.7562
# Epoch [2250/2500], Loss: 0.4835, Accuracy: 0.7564
# Epoch [2500/2500], Loss: 0.4824, Accuracy: 0.7570
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_122_acc_0.7570.pkl
# Final accuracy: 0.7570
# Parameter containing:
# tensor([[-2.2180,  1.1854],
#         [ 1.7868,  0.1466],
#         [ 1.1935, -1.6323]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.6370, -0.5896],
#         [ 0.8025,  1.7679],
#         [ 0.4658,  0.6836]], requires_grad=True)
#
# === Training with seed 123 ===
# initial loss =  1.7870393991470337
# Epoch [250/2500], Loss: 0.5720, Accuracy: 0.6877
# Epoch [500/2500], Loss: 0.4544, Accuracy: 0.8165
# Epoch [750/2500], Loss: 0.4296, Accuracy: 0.8325
# Epoch [1000/2500], Loss: 0.3840, Accuracy: 0.8507
# Epoch [1250/2500], Loss: 0.3745, Accuracy: 0.8504
# Epoch [1500/2500], Loss: 0.3724, Accuracy: 0.8492
# Epoch [1750/2500], Loss: 0.3711, Accuracy: 0.8485
# Epoch [2000/2500], Loss: 0.3694, Accuracy: 0.8467
# Epoch [2250/2500], Loss: 0.3675, Accuracy: 0.8458
# Epoch [2500/2500], Loss: 0.3668, Accuracy: 0.8452
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_123_acc_0.8452.pkl
# Final accuracy: 0.8452
# Parameter containing:
# tensor([[ 1.6370, -0.5896],
#         [ 0.8025,  1.7679],
#         [ 0.4658,  0.6836]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0146,  0.7972],
#         [ 1.9645, -0.6595],
#         [-0.9666, -0.1287]], requires_grad=True)
#
# === Training with seed 124 ===
# initial loss =  1.507246971130371
# Epoch [250/2500], Loss: 0.4422, Accuracy: 0.8206
# Epoch [500/2500], Loss: 0.3657, Accuracy: 0.8510
# Epoch [750/2500], Loss: 0.3591, Accuracy: 0.8535
# Epoch [1000/2500], Loss: 0.3569, Accuracy: 0.8550
# Epoch [1250/2500], Loss: 0.3554, Accuracy: 0.8559
# Epoch [1500/2500], Loss: 0.3545, Accuracy: 0.8571
# Epoch [1750/2500], Loss: 0.3539, Accuracy: 0.8572
# Epoch [2000/2500], Loss: 0.3536, Accuracy: 0.8577
# Epoch [2250/2500], Loss: 0.3534, Accuracy: 0.8582
# Epoch [2500/2500], Loss: 0.3533, Accuracy: 0.8582
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_124_acc_0.8582.pkl
# Final accuracy: 0.8582
# Parameter containing:
# tensor([[ 0.0146,  0.7972],
#         [ 1.9645, -0.6595],
#         [-0.9666, -0.1287]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.0365,  2.3633],
#         [-0.4849, -2.4662],
#         [-2.4124, -2.2552]], requires_grad=True)
#
# === Training with seed 125 ===
# initial loss =  4.329349517822266
# Epoch [250/2500], Loss: 0.6110, Accuracy: 0.7164
# Epoch [500/2500], Loss: 0.5198, Accuracy: 0.7417
# Epoch [750/2500], Loss: 0.5138, Accuracy: 0.7435
# Epoch [1000/2500], Loss: 0.5129, Accuracy: 0.7456
# Epoch [1250/2500], Loss: 0.5127, Accuracy: 0.7470
# Epoch [1500/2500], Loss: 0.5127, Accuracy: 0.7478
# Epoch [1750/2500], Loss: 0.5126, Accuracy: 0.7482
# Epoch [2000/2500], Loss: 0.5126, Accuracy: 0.7486
# Epoch [2250/2500], Loss: 0.5125, Accuracy: 0.7488
# Epoch [2500/2500], Loss: 0.5124, Accuracy: 0.7500
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_125_acc_0.7500.pkl
# Final accuracy: 0.7500
# Parameter containing:
# tensor([[ 2.0365,  2.3633],
#         [-0.4849, -2.4662],
#         [-2.4124, -2.2552]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7817, -0.0225],
#         [-2.4355, -0.8113],
#         [-1.7391, -0.5384]], requires_grad=True)
#
# === Training with seed 126 ===
# initial loss =  1.4870764017105103
# Epoch [250/2500], Loss: 0.5256, Accuracy: 0.7468
# Epoch [500/2500], Loss: 0.4860, Accuracy: 0.7578
# Epoch [750/2500], Loss: 0.4824, Accuracy: 0.7579
# Epoch [1000/2500], Loss: 0.4813, Accuracy: 0.7592
# Epoch [1250/2500], Loss: 0.4807, Accuracy: 0.7601
# Epoch [1500/2500], Loss: 0.4804, Accuracy: 0.7603
# Epoch [1750/2500], Loss: 0.4801, Accuracy: 0.7603
# Epoch [2000/2500], Loss: 0.4800, Accuracy: 0.7609
# Epoch [2250/2500], Loss: 0.4799, Accuracy: 0.7609
# Epoch [2500/2500], Loss: 0.4798, Accuracy: 0.7609
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_126_acc_0.7609.pkl
# Final accuracy: 0.7609
# Parameter containing:
# tensor([[-1.7817, -0.0225],
#         [-2.4355, -0.8113],
#         [-1.7391, -0.5384]], requires_grad=True)
# Parameter containing:
# tensor([[-1.5422, -2.2576],
#         [-1.0535,  2.3860],
#         [ 2.3552,  1.7956]], requires_grad=True)
#
# === Training with seed 127 ===
# initial loss =  1.7485284805297852
# Epoch [250/2500], Loss: 0.6208, Accuracy: 0.6591
# Epoch [500/2500], Loss: 0.5830, Accuracy: 0.6987
# Epoch [750/2500], Loss: 0.5544, Accuracy: 0.7138
# Epoch [1000/2500], Loss: 0.5426, Accuracy: 0.7251
# Epoch [1250/2500], Loss: 0.5392, Accuracy: 0.7273
# Epoch [1500/2500], Loss: 0.5376, Accuracy: 0.7279
# Epoch [1750/2500], Loss: 0.5368, Accuracy: 0.7281
# Epoch [2000/2500], Loss: 0.5364, Accuracy: 0.7288
# Epoch [2250/2500], Loss: 0.5362, Accuracy: 0.7286
# Epoch [2500/2500], Loss: 0.5360, Accuracy: 0.7285
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/training_data_seed_127_acc_0.7285.pkl
# Final accuracy: 0.7285
# Parameter containing:
# tensor([[-1.5422, -2.2576],
#         [-1.0535,  2.3860],
#         [ 2.3552,  1.7956]], requires_grad=True)
#
# === FINAL RESULTS ===
# Best model: Seed 81, Accuracy 0.8583
# Worst model: Seed 10, Accuracy 0.5000
# Best/worst model data saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/best_worst_models.pkl

# %%
print(f"\n=== FINAL RESULTS ===")
print(f"Best model: Seed {best_model_data['seed']}, Accuracy {best_model_data['accuracy']:.4f}")
print(f"Worst model: Seed {worst_model_data['seed']}, Accuracy {worst_model_data['accuracy']:.4f}")
print(f"Best/worst model data saved to: {best_worst_filename}")
# Out:
# === FINAL RESULTS ===
# Best model: Seed 81, Accuracy 0.8583
# Worst model: Seed 10, Accuracy 0.5000
# Best/worst model data saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/best_worst_models.pkl

# %%
def load_best_worst_data(filepath):
    """Load the best and worst model data"""
    with open(filepath, 'rb') as f:
        data = pickle.load(f)
    return data['best_model'], data['worst_model']

def interpolate_weights(weights1, weights2, alpha):
    """
    Interpolate between two weight dictionaries
    alpha = 0: returns weights1
    alpha = 1: returns weights2
    """
    interpolated = {}
    for name in weights1.keys():
        interpolated[name] = (1 - alpha) * weights1[name] + alpha * weights2[name]
    return interpolated

def set_model_weights(model, weight_dict):
    """Set model parameters from weight dictionary"""
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = weight_dict[name]

def compute_loss_at_point(model, X_tensor, y_tensor, criterion):
    """Compute loss at current model parameters"""
    with torch.no_grad():
        outputs = model(X_tensor)
        loss = criterion(outputs, y_tensor)
        return loss.item()

def create_loss_landscape_2d(best_model_data, worst_model_data, X_tensor, y_tensor, 
                           model_class, model_args, resolution=50, output_dir=None):
    """
    Create 2D loss landscape visualization
    
    Dimension 1 (x-axis): Best model initial -> Best model final
    Dimension 2 (y-axis): Worst model initial -> Best model final
    """
    
    # Create a fresh model for evaluation
    model = model_class(model_args)
    criterion = torch.nn.CrossEntropyLoss()
    
    # Create interpolation grids
    alphas = np.linspace(0, 1, resolution)
    betas = np.linspace(0, 1, resolution)
    
    # Initialize loss landscape
    loss_landscape = np.zeros((resolution, resolution))
    
    print("Computing loss landscape...")
    
    for i, alpha in enumerate(alphas):
        for j, beta in enumerate(betas):
            # Create a proper 2D interpolation grid
            # We want to interpolate between 4 corner points:
            # (0,0) = best_initial
            # (1,0) = best_final  
            # (0,1) = worst_initial
            # (1,1) = worst_final
            
            # Use bilinear interpolation
            # First interpolate along the bottom edge (beta=0): best_initial -> best_final
            bottom_edge = interpolate_weights(
                best_model_data['initial_params'],
                best_model_data['final_params'], 
                alpha
            )
            
            # Then interpolate along the top edge (beta=1): worst_initial -> best_final
            top_edge = interpolate_weights(
                worst_model_data['initial_params'],
                # best_model_data['final_params'],
                worst_model_data['final_params'], #SW Mod
                alpha
            )
            
            # Finally interpolate between bottom and top edges
            final_weights = interpolate_weights(bottom_edge, top_edge, beta)
            
            # Set model weights and compute loss
            set_model_weights(model, final_weights)
            loss = compute_loss_at_point(model, X_tensor, y_tensor, criterion)
            loss_landscape[j, i] = loss
        
        if i % 10 == 0:
            print(f"Progress: {i}/{resolution}")
    
    # Create the visualization
    plt.figure(figsize=(12, 10))
    
    # Create contour plot
    X, Y = np.meshgrid(alphas, betas)
    contour = plt.contour(X, Y, loss_landscape, levels=20, colors='black', alpha=0.6, linewidths=0.8)
    contourf = plt.contourf(X, Y, loss_landscape, levels=50, cmap='viridis', alpha=0.8)
    
    # Add colorbar
    cbar = plt.colorbar(contourf)
    cbar.set_label('Loss', fontsize=12)
    
    # Add contour labels
    plt.clabel(contour, inline=True, fontsize=8, fmt='%.3f')
    
    # Mark key points
    plt.plot(0, 0, 'ro', markersize=10, label=f'Best Initial (Acc: {best_model_data["accuracy"]:.3f})')
    plt.plot(1, 0, 'go', markersize=10, label=f'Best Final (Acc: {best_model_data["accuracy"]:.3f})')  
    plt.plot(0, 1, 'bo', markersize=10, label=f'Worst Initial (Acc: {worst_model_data["accuracy"]:.3f})')
    plt.plot(1, 1, 'go', markersize=8, alpha=0.7)  # Same as best final
    
    # Add arrows to show the training trajectories
    plt.annotate('', xy=(1, 0), xytext=(0, 0), 
                arrowprops=dict(arrowstyle='->', color='red', lw=2, alpha=0.7),
                label='Best model training path')
    
    # Labels and title
    plt.xlabel('Best Model: Initial → Final', fontsize=12)
    plt.ylabel('Worst Initial → Best Final', fontsize=12)
    plt.title('2D Loss Landscape\nInterpolating Between Key Weight Configurations', fontsize=14)
    
    # Legend
    plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
    
    # Grid
    plt.grid(True, alpha=0.3)
    
    # Tight layout
    plt.tight_layout()
    
    # Save if output directory specified
    if output_dir:
        viz_path = os.path.join(output_dir, 'loss_landscape_2d.png')
        plt.savefig(viz_path, dpi=300, bbox_inches='tight')
        print(f"Loss landscape saved to: {viz_path}")
    
    plt.show()
    
    return loss_landscape, alphas, betas

# %%
loss_landscape, alphas, betas = create_loss_landscape_2d(
    best_model_data, 
    worst_model_data, 
    X_tensor, 
    y_tensor,
    BaarleNet,  # Your model class
    [3],        # Your model args
    resolution=50,
    output_dir=output_dir
)
# Out:
# Computing loss landscape...
# Progress: 0/50
# Progress: 10/50
# Progress: 20/50
# Progress: 30/50
# Progress: 40/50
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_14203/3818586867.py:121: UserWarning: Legend does not support handles for Annotation instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
# Loss landscape saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/loss_landscape_2d.png

# %% [markdown]
# - Hey that's kinda what I wanted -> right? Can I just do this?
# - Maybe changing my weight initialization helped here?

# %%
all_training_data[0].keys()
# Out:
# dict_keys(['seed', 'weights_history', 'gradients_history', 'xy_history', 'loss_history', 'accuracy_history', 'initial_params', 'final_accuracy', 'final_model_state', 'final_params'])

# %%
final_accuracies=np.array([t['final_accuracy'] for t in all_training_data])
sI=np.argsort(final_accuracies)

# %%
final_accuracies[sI[:5]]
# Out:
# array([0.5   , 0.5   , 0.6159, 0.6159, 0.6159])

# %%
sI[:5]
# Out:
# array([107,  10,  32,  90,  38])

# %%
i=90

# %%
worst_model_data_2 = {
    'accuracy': all_training_data[i]['final_accuracy'],
    'seed': all_training_data[i]['seed'],
    'initial_params': all_training_data[i]['initial_params'],
    'final_params': all_training_data[i]['final_params']
}

# %%
worst_model_data_2
# Out:
# {'accuracy': 0.6159,
#  'seed': 90,
#  'initial_params': {'model.0.weight': tensor([[-1.1878,  0.5642],
#           [-0.8380, -0.3588],
#           [-0.8220, -0.4216]]),
#   'model.0.bias': tensor([-2.1698, -1.7517,  0.5347]),
#   'model.2.weight': tensor([[-2.0459, -1.3340,  1.2682],
#           [-1.2421, -0.2739, -0.2828]]),
#   'model.2.bias': tensor([-0.6926,  1.8773])},
#  'final_params': {'model.0.weight': tensor([[-1.1878,  0.5642],
#           [-0.8380, -0.3588],
#           [ 0.0990,  0.4523]]),
#   'model.0.bias': tensor([-2.1698, -1.7517,  0.9722]),
#   'model.2.weight': tensor([[-2.0459, -1.3340,  1.4603],
#           [-1.2421, -0.2739, -0.4749]]),
#   'model.2.bias': tensor([-0.3105,  1.4953])}}

# %%
loss_landscape, alphas, betas = create_loss_landscape_2d(
    best_model_data, 
    worst_model_data_2, 
    X_tensor, 
    y_tensor,
    BaarleNet,  # Your model class
    [3],        # Your model args
    resolution=50,
    output_dir=output_dir
)
# Out:
# Computing loss landscape...
# Progress: 0/50
# Progress: 10/50
# Progress: 20/50
# Progress: 30/50
# Progress: 40/50
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_14203/3818586867.py:121: UserWarning: Legend does not support handles for Annotation instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
# Loss landscape saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4/loss_landscape_2d.png

# %%
worst_model_data
# Out:
# {'accuracy': 0.5,
#  'seed': 10,
#  'initial_params': {'model.0.weight': tensor([[-0.0884,  0.5750],
#           [-0.0163, -0.2394],
#           [-2.2124, -2.1565]]),
#   'model.0.bias': tensor([-2.2496, -2.4462, -2.3284]),
#   'model.2.weight': tensor([[-1.8939, -2.2548, -2.3452],
#           [ 1.0959,  1.5334,  1.6893]]),
#   'model.2.bias': tensor([1.3468, 0.8471])},
#  'final_params': {'model.0.weight': tensor([[-0.0884,  0.5750],
#           [-0.0163, -0.2394],
#           [-1.5292, -1.4742]]),
#   'model.0.bias': tensor([-2.2496, -2.4462, -2.9606]),
#   'model.2.weight': tensor([[-1.8939, -2.2548, -1.9092],
#           [ 1.0959,  1.5334,  1.2533]]),
#   'model.2.bias': tensor([1.0970, 1.0970])}}
