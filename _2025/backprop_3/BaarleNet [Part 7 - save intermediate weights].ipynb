# %%
## BaarleNet [Part 7 - save intermediate weights].ipynb

# %%
import numpy as np
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import torch.optim as optim
import cv2
from matplotlib.gridspec import GridSpec
from tqdm import tqdm
import os

# %%
def denorm(p, size=960):
    result = np.zeros_like(p)
    result[..., 0] = (p[..., 0] + 1) * (size / 2)
    result[..., 1] = size - ((p[..., 1] + 1) * (size / 2))
    return result

def get_relu_joint(weight_1, weight_2, bias, extent=1):
    if np.abs(weight_2) < 1e-8: 
        x_intercept = -bias / weight_1
        return [[x_intercept, -extent], [x_intercept, extent]] if -extent <= x_intercept <= extent else []
    elif np.abs(weight_1) < 1e-8:
        y_intercept = -bias / weight_2
        return [[-extent, y_intercept], [extent, y_intercept]] if -extent <= y_intercept <= extent else []
    else:
        points = []
        for x in [-extent, extent]:
            y = (-x * weight_1 - bias) / weight_2
            if -extent <= y <= extent: points.append([x, y])
        for y in [-extent, extent]:
            x = (-y * weight_2 - bias) / weight_1
            if -extent <= x <= extent: points.append([x, y])
        unique_points = []
        for p in points:
            is_duplicate = False
            for existing in unique_points:
                if abs(p[0] - existing[0]) < 1e-8 and abs(p[1] - existing[1]) < 1e-8:
                    is_duplicate = True
                    break
            if not is_duplicate:
                unique_points.append(p)
        return unique_points

def viz_map_with_predictions(ax, map, X, y):
    probe=np.zeros((100,100,2))
    for j, xx in enumerate(np.linspace(-1, 1, 100)):
        for k, yy in enumerate(np.linspace(-1, 1, 100)):
            probe[j, k]=[yy,xx]
    probe=probe.reshape(100**2, -1)
    probe_logits=model(torch.tensor(probe).float())
    probe_logits=probe_logits.detach().numpy().reshape(100,100,2)
    probe_softmax = torch.nn.Softmax(dim=1)(torch.tensor(probe_logits.reshape(-1, 2)))
    
    ax.imshow(map.mean(2), cmap='gray')
    ax.imshow(np.flipud(probe_softmax[:,1].reshape(100, 100)), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')
    
    X_denorm=denorm(X[:1000,:])
    # plt.scatter(X_denorm[:,0], X_denorm[:,1], c=y[:1000], s=2, alpha=0.8)
    labels=y[:1000]
    y_hat=torch.argmax(model(torch.tensor(X[:1000,:]).float()).detach(),1).numpy()
    tp_mask=np.logical_and(labels==1, y_hat==1)
    fp_mask=np.logical_and(labels==0, y_hat==1)
    fn_mask=np.logical_and(labels==1, y_hat==0)
    tn_mask=np.logical_and(labels==0, y_hat==0)
    ax.scatter(X_denorm[tp_mask,0], X_denorm[tp_mask,1], c='g', s=3, alpha=0.8)
    ax.scatter(X_denorm[fp_mask,0], X_denorm[fp_mask,1], c='r', marker='x', s=5, alpha=0.8)
    ax.scatter(X_denorm[fn_mask,0], X_denorm[fn_mask,1], c='orange', marker='x', s=5, alpha=0.8)
    ax.scatter(X_denorm[tn_mask,0], X_denorm[tn_mask,1], c='purple', marker='o', s=5, alpha=0.8)

# %%
map=cv2.imread('Baarle-Nassau_-_Baarle-Hertog-en.svg.png')[:,:,(2,1,0)]

belgium_color=np.array([251,234,81])
netherlands_color=np.array([255, 255, 228])

netherlands_region=((map-netherlands_color)**2).sum(-1)<10
belgium_region=((map-belgium_color)**2).sum(-1)<10000

num_points_to_sample=10000 #10000

b_coords=np.array(np.where(belgium_region)).T.astype('float')
n_coords=np.array(np.where(netherlands_region)).T.astype('float')

#flip and normalize
belgium_coords_all=np.zeros_like(b_coords)
netherlands_coords_all=np.zeros_like(n_coords)

belgium_coords_all[:,0]=b_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
belgium_coords_all[:,1]=(960-b_coords[:,0])/(960/2)-1
netherlands_coords_all[:,0]=n_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
netherlands_coords_all[:,1]=(960-n_coords[:,0])/(960/2)-1

## Hmm to balance to classes or do more area proportional? Not sure yet. 
belgium_coords=belgium_coords_all[np.random.choice(len(belgium_coords_all), num_points_to_sample), :]
netherlands_coords=netherlands_coords_all[np.random.choice(len(netherlands_coords_all), num_points_to_sample), :]

X=np.vstack((netherlands_coords, belgium_coords))
y=np.concatenate((np.zeros(len(netherlands_coords)), np.ones(len(belgium_coords)))).astype('int')

rI=np.arange(len(y))
np.random.shuffle(rI)
X=X[rI,:]
y=y[rI]

# %%
plt.scatter(X[:,0], X[:,1], c=y, s=1, alpha=0.3); plt.axis('square');

# %%
class BaarleNet(nn.Module):
    def __init__(self, hidden_layers=[64]):
        super(BaarleNet, self).__init__()
        layers = [nn.Linear(2, hidden_layers[0]), nn.ReLU()]
        for i in range(len(hidden_layers)-1):
            layers.append(nn.Linear(hidden_layers[i], hidden_layers[i+1]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_layers[-1], 2))
        self.layers=layers
        self.model = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.model(x)

# %%
import pickle
import copy
import os

# %%
# Assuming X and y are already defined
X_tensor = torch.FloatTensor(X)
y_tensor = torch.tensor(y)

# Training parameters
num_epochs = 2500
num_seeds = 32

# Configure output directory
output_dir = "/Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1"  # Change this to your desired directory
os.makedirs(output_dir, exist_ok=True)
print(f"Saving results to: {output_dir}")

for seed_idx in range(num_seeds):
    random_seed = seed_idx  # You can change this to any seed generation logic
    torch.manual_seed(random_seed)
    
    # Initialize model and optimizer
    model = BaarleNet([2])
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    
    # Data storage for this run
    training_data = {
        'seed': random_seed,
        'weights_history': [],
        'gradients_history': [],
        'xy_history': [],
        'loss_history': [],
        'accuracy_history': []
    }
    
    print(f"\n=== Training with seed {random_seed} ===")
    
    for epoch in range(num_epochs):
        # Get current data point
        current_idx = epoch % len(y)
        current_x = torch.tensor(X[current_idx]).float()
        current_y = torch.tensor(y[current_idx])
        
        # Forward pass
        outputs = model(current_x)
        loss = criterion(outputs, current_y)
        
        # Store current X,y values
        training_data['xy_history'].append({
            'epoch': epoch,
            'x': X[current_idx].copy(),
            'y': y[current_idx]
        })
        
        # Zero gradients
        optimizer.zero_grad()
        
        # Backward pass
        loss.backward()
        
        # Store model weights (deep copy to avoid reference issues)
        current_weights = {}
        for name, param in model.named_parameters():
            current_weights[name] = param.data.clone()
        training_data['weights_history'].append(current_weights)
        
        # Store model gradients (deep copy)
        current_gradients = {}
        for name, param in model.named_parameters():
            if param.grad is not None:
                current_gradients[name] = param.grad.clone()
            else:
                current_gradients[name] = None
        training_data['gradients_history'].append(current_gradients)
        
        # Update parameters
        optimizer.step()
        
        # Store loss
        training_data['loss_history'].append(loss.item())
        
        # Calculate and store accuracy periodically
        if (epoch + 1) % (num_epochs // 25) == 0:
            with torch.no_grad():
                outputs_batch = model(X_tensor)
                accuracy = (torch.argmax(outputs_batch, dim=1) == y_tensor).sum().item() / len(y)
                training_data['accuracy_history'].append({
                    'epoch': epoch,
                    'accuracy': accuracy
                })
                print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Accuracy: {accuracy:.4f}')
    
    # Calculate final accuracy
    with torch.no_grad():
        final_outputs = model(X_tensor)
        final_accuracy = (torch.argmax(final_outputs, dim=1) == y_tensor).sum().item() / len(y)
    
    # Save data as pickle file
    filename = os.path.join(output_dir, f"training_data_seed_{random_seed:02d}_acc_{final_accuracy:.4f}.pkl")
    
    # Add final accuracy to the data
    training_data['final_accuracy'] = final_accuracy
    training_data['final_model_state'] = model.state_dict()
    
    with open(filename, 'wb') as f:
        pickle.dump(training_data, f)
    
    print(f"Saved training data to {filename}")
    print(f"Final accuracy: {final_accuracy:.4f}")
# Out:
# Saving results to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1
#
# === Training with seed 0 ===
# Epoch [100/2500], Loss: 0.5314, Accuracy: 0.6455
# Epoch [200/2500], Loss: 0.7383, Accuracy: 0.6086
# Epoch [300/2500], Loss: 0.1958, Accuracy: 0.6002
# Epoch [400/2500], Loss: 0.4821, Accuracy: 0.6067
# Epoch [500/2500], Loss: 0.7303, Accuracy: 0.6407
# Epoch [600/2500], Loss: 0.4941, Accuracy: 0.6533
# Epoch [700/2500], Loss: 0.4496, Accuracy: 0.6472
# Epoch [800/2500], Loss: 0.8096, Accuracy: 0.6709
# Epoch [900/2500], Loss: 0.3102, Accuracy: 0.6620
# Epoch [1000/2500], Loss: 0.4823, Accuracy: 0.7057
# Epoch [1100/2500], Loss: 0.3001, Accuracy: 0.7055
# Epoch [1200/2500], Loss: 0.4625, Accuracy: 0.6778
# Epoch [1300/2500], Loss: 0.5673, Accuracy: 0.7044
# Epoch [1400/2500], Loss: 0.0884, Accuracy: 0.7030
# Epoch [1500/2500], Loss: 1.1289, Accuracy: 0.7041
# Epoch [1600/2500], Loss: 0.0933, Accuracy: 0.7147
# Epoch [1700/2500], Loss: 0.9720, Accuracy: 0.7047
# Epoch [1800/2500], Loss: 1.5760, Accuracy: 0.6455
# Epoch [1900/2500], Loss: 0.6234, Accuracy: 0.7077
# Epoch [2000/2500], Loss: 1.0249, Accuracy: 0.6937
# Epoch [2100/2500], Loss: 0.4626, Accuracy: 0.6748
# Epoch [2200/2500], Loss: 0.3977, Accuracy: 0.7111
# Epoch [2300/2500], Loss: 0.2277, Accuracy: 0.7093
# Epoch [2400/2500], Loss: 0.5075, Accuracy: 0.6972
# Epoch [2500/2500], Loss: 0.4319, Accuracy: 0.7129
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_00_acc_0.7129.pkl
# Final accuracy: 0.7129
#
# === Training with seed 1 ===
# Epoch [100/2500], Loss: 0.5027, Accuracy: 0.5592
# Epoch [200/2500], Loss: 0.6604, Accuracy: 0.5866
# Epoch [300/2500], Loss: 0.3639, Accuracy: 0.6165
# Epoch [400/2500], Loss: 0.5104, Accuracy: 0.6021
# Epoch [500/2500], Loss: 0.8830, Accuracy: 0.6015
# Epoch [600/2500], Loss: 0.4999, Accuracy: 0.6201
# Epoch [700/2500], Loss: 0.4561, Accuracy: 0.6241
# Epoch [800/2500], Loss: 0.6695, Accuracy: 0.5986
# Epoch [900/2500], Loss: 0.3245, Accuracy: 0.5976
# Epoch [1000/2500], Loss: 0.5006, Accuracy: 0.6529
# Epoch [1100/2500], Loss: 0.3110, Accuracy: 0.6497
# Epoch [1200/2500], Loss: 0.5023, Accuracy: 0.6171
# Epoch [1300/2500], Loss: 0.6864, Accuracy: 0.6249
# Epoch [1400/2500], Loss: 0.1131, Accuracy: 0.6413
# Epoch [1500/2500], Loss: 1.0399, Accuracy: 0.6498
# Epoch [1600/2500], Loss: 0.1165, Accuracy: 0.6521
# Epoch [1700/2500], Loss: 0.9192, Accuracy: 0.6430
# Epoch [1800/2500], Loss: 1.8811, Accuracy: 0.6278
# Epoch [1900/2500], Loss: 0.6570, Accuracy: 0.6535
# Epoch [2000/2500], Loss: 0.9242, Accuracy: 0.6545
# Epoch [2100/2500], Loss: 0.5265, Accuracy: 0.6351
# Epoch [2200/2500], Loss: 0.4818, Accuracy: 0.6542
# Epoch [2300/2500], Loss: 0.1473, Accuracy: 0.6502
# Epoch [2400/2500], Loss: 0.5715, Accuracy: 0.6475
# Epoch [2500/2500], Loss: 0.4769, Accuracy: 0.6513
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_01_acc_0.6513.pkl
# Final accuracy: 0.6513
#
# === Training with seed 2 ===
# Epoch [100/2500], Loss: 0.6142, Accuracy: 0.6306
# Epoch [200/2500], Loss: 0.6316, Accuracy: 0.6771
# Epoch [300/2500], Loss: 0.6509, Accuracy: 0.6327
# Epoch [400/2500], Loss: 0.4879, Accuracy: 0.5741
# Epoch [500/2500], Loss: 0.8936, Accuracy: 0.5734
# Epoch [600/2500], Loss: 0.5142, Accuracy: 0.6584
# Epoch [700/2500], Loss: 0.3924, Accuracy: 0.6177
# Epoch [800/2500], Loss: 0.8657, Accuracy: 0.6780
# Epoch [900/2500], Loss: 0.6972, Accuracy: 0.7291
# Epoch [1000/2500], Loss: 0.4122, Accuracy: 0.6611
# Epoch [1100/2500], Loss: 0.7243, Accuracy: 0.7489
# Epoch [1200/2500], Loss: 0.4102, Accuracy: 0.7017
# Epoch [1300/2500], Loss: 1.7205, Accuracy: 0.7366
# Epoch [1400/2500], Loss: 0.5467, Accuracy: 0.7611
# Epoch [1500/2500], Loss: 0.1388, Accuracy: 0.7396
# Epoch [1600/2500], Loss: 0.5416, Accuracy: 0.7221
# Epoch [1700/2500], Loss: 0.2965, Accuracy: 0.7771
# Epoch [1800/2500], Loss: 1.0257, Accuracy: 0.7511
# Epoch [1900/2500], Loss: 0.5286, Accuracy: 0.7612
# Epoch [2000/2500], Loss: 0.5226, Accuracy: 0.7668
# Epoch [2100/2500], Loss: 0.4076, Accuracy: 0.7759
# Epoch [2200/2500], Loss: 0.3784, Accuracy: 0.7649
# Epoch [2300/2500], Loss: 0.3178, Accuracy: 0.7526
# Epoch [2400/2500], Loss: 0.2746, Accuracy: 0.7659
# Epoch [2500/2500], Loss: 0.2518, Accuracy: 0.7575
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_02_acc_0.7575.pkl
# Final accuracy: 0.7575
#
# === Training with seed 3 ===
# Epoch [100/2500], Loss: 0.7735, Accuracy: 0.5044
# Epoch [200/2500], Loss: 0.7231, Accuracy: 0.4749
# Epoch [300/2500], Loss: 0.7785, Accuracy: 0.6046
# Epoch [400/2500], Loss: 0.5889, Accuracy: 0.5945
# Epoch [500/2500], Loss: 0.5588, Accuracy: 0.6109
# Epoch [600/2500], Loss: 0.5590, Accuracy: 0.6291
# Epoch [700/2500], Loss: 0.4999, Accuracy: 0.6409
# Epoch [800/2500], Loss: 0.6427, Accuracy: 0.6342
# Epoch [900/2500], Loss: 0.2847, Accuracy: 0.6388
# Epoch [1000/2500], Loss: 0.5172, Accuracy: 0.6446
# Epoch [1100/2500], Loss: 0.3916, Accuracy: 0.6427
# Epoch [1200/2500], Loss: 0.5229, Accuracy: 0.6443
# Epoch [1300/2500], Loss: 0.5030, Accuracy: 0.6434
# Epoch [1400/2500], Loss: 0.1105, Accuracy: 0.6459
# Epoch [1500/2500], Loss: 1.0320, Accuracy: 0.6513
# Epoch [1600/2500], Loss: 0.1077, Accuracy: 0.6520
# Epoch [1700/2500], Loss: 0.9204, Accuracy: 0.6441
# Epoch [1800/2500], Loss: 1.9300, Accuracy: 0.6266
# Epoch [1900/2500], Loss: 0.6573, Accuracy: 0.6536
# Epoch [2000/2500], Loss: 0.9241, Accuracy: 0.6538
# Epoch [2100/2500], Loss: 0.5266, Accuracy: 0.6361
# Epoch [2200/2500], Loss: 0.4845, Accuracy: 0.6533
# Epoch [2300/2500], Loss: 0.1340, Accuracy: 0.6517
# Epoch [2400/2500], Loss: 0.5716, Accuracy: 0.6468
# Epoch [2500/2500], Loss: 0.4752, Accuracy: 0.6516
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_03_acc_0.6516.pkl
# Final accuracy: 0.6516
#
# === Training with seed 4 ===
# Epoch [100/2500], Loss: 0.6493, Accuracy: 0.5000
# Epoch [200/2500], Loss: 0.6642, Accuracy: 0.5000
# Epoch [300/2500], Loss: 0.7615, Accuracy: 0.5000
# Epoch [400/2500], Loss: 0.6623, Accuracy: 0.5593
# Epoch [500/2500], Loss: 0.6400, Accuracy: 0.5559
# Epoch [600/2500], Loss: 0.6519, Accuracy: 0.5809
# Epoch [700/2500], Loss: 0.5864, Accuracy: 0.6063
# Epoch [800/2500], Loss: 0.7445, Accuracy: 0.5358
# Epoch [900/2500], Loss: 0.6936, Accuracy: 0.5000
# Epoch [1000/2500], Loss: 0.6053, Accuracy: 0.6199
# Epoch [1100/2500], Loss: 0.8389, Accuracy: 0.6220
# Epoch [1200/2500], Loss: 0.6014, Accuracy: 0.6075
# Epoch [1300/2500], Loss: 0.5963, Accuracy: 0.6106
# Epoch [1400/2500], Loss: 0.8378, Accuracy: 0.6229
# Epoch [1500/2500], Loss: 0.9152, Accuracy: 0.6232
# Epoch [1600/2500], Loss: 0.8135, Accuracy: 0.6238
# Epoch [1700/2500], Loss: 0.8173, Accuracy: 0.6184
# Epoch [1800/2500], Loss: 0.7251, Accuracy: 0.5000
# Epoch [1900/2500], Loss: 0.5654, Accuracy: 0.6292
# Epoch [2000/2500], Loss: 0.8587, Accuracy: 0.6279
# Epoch [2100/2500], Loss: 0.5867, Accuracy: 0.6290
# Epoch [2200/2500], Loss: 0.5261, Accuracy: 0.6237
# Epoch [2300/2500], Loss: 0.1794, Accuracy: 0.6194
# Epoch [2400/2500], Loss: 0.6248, Accuracy: 0.6234
# Epoch [2500/2500], Loss: 0.5301, Accuracy: 0.6162
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_04_acc_0.6162.pkl
# Final accuracy: 0.6162
#
# === Training with seed 5 ===
# Epoch [100/2500], Loss: 0.6863, Accuracy: 0.3987
# Epoch [200/2500], Loss: 0.7018, Accuracy: 0.6240
# Epoch [300/2500], Loss: 0.7399, Accuracy: 0.5000
# Epoch [400/2500], Loss: 0.5919, Accuracy: 0.5000
# Epoch [500/2500], Loss: 0.6896, Accuracy: 0.6318
# Epoch [600/2500], Loss: 0.6771, Accuracy: 0.6070
# Epoch [700/2500], Loss: 0.5087, Accuracy: 0.5847
# Epoch [800/2500], Loss: 0.6445, Accuracy: 0.6231
# Epoch [900/2500], Loss: 0.5711, Accuracy: 0.5955
# Epoch [1000/2500], Loss: 0.5085, Accuracy: 0.6358
# Epoch [1100/2500], Loss: 0.5365, Accuracy: 0.6373
# Epoch [1200/2500], Loss: 0.6252, Accuracy: 0.6004
# Epoch [1300/2500], Loss: 0.9859, Accuracy: 0.6310
# Epoch [1400/2500], Loss: 0.4453, Accuracy: 0.6325
# Epoch [1500/2500], Loss: 0.4596, Accuracy: 0.6262
# Epoch [1600/2500], Loss: 0.4382, Accuracy: 0.6294
# Epoch [1700/2500], Loss: 0.4000, Accuracy: 0.6327
# Epoch [1800/2500], Loss: 1.2931, Accuracy: 0.4704
# Epoch [1900/2500], Loss: 1.0623, Accuracy: 0.6380
# Epoch [2000/2500], Loss: 0.8071, Accuracy: 0.6318
# Epoch [2100/2500], Loss: 0.5753, Accuracy: 0.6269
# Epoch [2200/2500], Loss: 0.9780, Accuracy: 0.6303
# Epoch [2300/2500], Loss: 0.6400, Accuracy: 0.6538
# Epoch [2400/2500], Loss: 0.5137, Accuracy: 0.6408
# Epoch [2500/2500], Loss: 0.6390, Accuracy: 0.6395
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_05_acc_0.6395.pkl
# Final accuracy: 0.6395
#
# === Training with seed 6 ===
# Epoch [100/2500], Loss: 0.7486, Accuracy: 0.6156
# Epoch [200/2500], Loss: 0.6423, Accuracy: 0.6280
# Epoch [300/2500], Loss: 0.8834, Accuracy: 0.6211
# Epoch [400/2500], Loss: 0.5395, Accuracy: 0.6276
# Epoch [500/2500], Loss: 0.6652, Accuracy: 0.6327
# Epoch [600/2500], Loss: 0.5283, Accuracy: 0.6276
# Epoch [700/2500], Loss: 0.4492, Accuracy: 0.6343
# Epoch [800/2500], Loss: 0.9189, Accuracy: 0.6317
# Epoch [900/2500], Loss: 0.7704, Accuracy: 0.5987
# Epoch [1000/2500], Loss: 0.5886, Accuracy: 0.6313
# Epoch [1100/2500], Loss: 0.8773, Accuracy: 0.6270
# Epoch [1200/2500], Loss: 0.5319, Accuracy: 0.6239
# Epoch [1300/2500], Loss: 1.7071, Accuracy: 0.6361
# Epoch [1400/2500], Loss: 0.9697, Accuracy: 0.6340
# Epoch [1500/2500], Loss: 0.0951, Accuracy: 0.6345
# Epoch [1600/2500], Loss: 0.9857, Accuracy: 0.6313
# Epoch [1700/2500], Loss: 0.3421, Accuracy: 0.6317
# Epoch [1800/2500], Loss: 0.7327, Accuracy: 0.5000
# Epoch [1900/2500], Loss: 0.5447, Accuracy: 0.6300
# Epoch [2000/2500], Loss: 0.4994, Accuracy: 0.6296
# Epoch [2100/2500], Loss: 0.5923, Accuracy: 0.6317
# Epoch [2200/2500], Loss: 0.5089, Accuracy: 0.6296
# Epoch [2300/2500], Loss: 0.9279, Accuracy: 0.6124
# Epoch [2400/2500], Loss: 0.5029, Accuracy: 0.6230
# Epoch [2500/2500], Loss: 0.4803, Accuracy: 0.6274
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_06_acc_0.6274.pkl
# Final accuracy: 0.6274
#
# === Training with seed 7 ===
# Epoch [100/2500], Loss: 0.6019, Accuracy: 0.5000
# Epoch [200/2500], Loss: 0.6478, Accuracy: 0.5000
# Epoch [300/2500], Loss: 0.6926, Accuracy: 0.6108
# Epoch [400/2500], Loss: 0.5948, Accuracy: 0.6101
# Epoch [500/2500], Loss: 0.8948, Accuracy: 0.6041
# Epoch [600/2500], Loss: 0.5320, Accuracy: 0.6016
# Epoch [700/2500], Loss: 0.4744, Accuracy: 0.6004
# Epoch [800/2500], Loss: 0.6707, Accuracy: 0.6014
# Epoch [900/2500], Loss: 0.3629, Accuracy: 0.6025
# Epoch [1000/2500], Loss: 0.5038, Accuracy: 0.6516
# Epoch [1100/2500], Loss: 0.3368, Accuracy: 0.6488
# Epoch [1200/2500], Loss: 0.5079, Accuracy: 0.6102
# Epoch [1300/2500], Loss: 0.7046, Accuracy: 0.6224
# Epoch [1400/2500], Loss: 0.1229, Accuracy: 0.6413
# Epoch [1500/2500], Loss: 1.0360, Accuracy: 0.6457
# Epoch [1600/2500], Loss: 0.1273, Accuracy: 0.6530
# Epoch [1700/2500], Loss: 0.9188, Accuracy: 0.6411
# Epoch [1800/2500], Loss: 1.8476, Accuracy: 0.6253
# Epoch [1900/2500], Loss: 0.6604, Accuracy: 0.6536
# Epoch [2000/2500], Loss: 0.9222, Accuracy: 0.6534
# Epoch [2100/2500], Loss: 0.5261, Accuracy: 0.6326
# Epoch [2200/2500], Loss: 0.4797, Accuracy: 0.6543
# Epoch [2300/2500], Loss: 0.1526, Accuracy: 0.6503
# Epoch [2400/2500], Loss: 0.5713, Accuracy: 0.6473
# Epoch [2500/2500], Loss: 0.4769, Accuracy: 0.6510
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_07_acc_0.6510.pkl
# Final accuracy: 0.6510
#
# === Training with seed 8 ===
# Epoch [100/2500], Loss: 0.4863, Accuracy: 0.6049
# Epoch [200/2500], Loss: 0.6868, Accuracy: 0.6106
# Epoch [300/2500], Loss: 0.2966, Accuracy: 0.6162
# Epoch [400/2500], Loss: 0.4592, Accuracy: 0.6058
# Epoch [500/2500], Loss: 0.9109, Accuracy: 0.6009
# Epoch [600/2500], Loss: 0.5539, Accuracy: 0.5989
# Epoch [700/2500], Loss: 0.4418, Accuracy: 0.6034
# Epoch [800/2500], Loss: 0.6482, Accuracy: 0.5952
# Epoch [900/2500], Loss: 0.3824, Accuracy: 0.6030
# Epoch [1000/2500], Loss: 0.4784, Accuracy: 0.6492
# Epoch [1100/2500], Loss: 0.2998, Accuracy: 0.6448
# Epoch [1200/2500], Loss: 0.4629, Accuracy: 0.6048
# Epoch [1300/2500], Loss: 0.6623, Accuracy: 0.6395
# Epoch [1400/2500], Loss: 0.0957, Accuracy: 0.6314
# Epoch [1500/2500], Loss: 0.7162, Accuracy: 0.6508
# Epoch [1600/2500], Loss: 0.1263, Accuracy: 0.7130
# Epoch [1700/2500], Loss: 0.6767, Accuracy: 0.7327
# Epoch [1800/2500], Loss: 2.0108, Accuracy: 0.7458
# Epoch [1900/2500], Loss: 0.7915, Accuracy: 0.7594
# Epoch [2000/2500], Loss: 0.7162, Accuracy: 0.7664
# Epoch [2100/2500], Loss: 0.3378, Accuracy: 0.7546
# Epoch [2200/2500], Loss: 0.4834, Accuracy: 0.7449
# Epoch [2300/2500], Loss: 0.2419, Accuracy: 0.7756
# Epoch [2400/2500], Loss: 0.4353, Accuracy: 0.7612
# Epoch [2500/2500], Loss: 0.2950, Accuracy: 0.7605
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_08_acc_0.7605.pkl
# Final accuracy: 0.7605
#
# === Training with seed 9 ===
# Epoch [100/2500], Loss: 0.4541, Accuracy: 0.6035
# Epoch [200/2500], Loss: 0.6466, Accuracy: 0.5953
# Epoch [300/2500], Loss: 0.3461, Accuracy: 0.6189
# Epoch [400/2500], Loss: 0.5158, Accuracy: 0.6163
# Epoch [500/2500], Loss: 0.9663, Accuracy: 0.6137
# Epoch [600/2500], Loss: 0.5529, Accuracy: 0.6101
# Epoch [700/2500], Loss: 0.4441, Accuracy: 0.6002
# Epoch [800/2500], Loss: 0.6354, Accuracy: 0.6110
# Epoch [900/2500], Loss: 0.4194, Accuracy: 0.6177
# Epoch [1000/2500], Loss: 0.4718, Accuracy: 0.6105
# Epoch [1100/2500], Loss: 0.3456, Accuracy: 0.6286
# Epoch [1200/2500], Loss: 0.4918, Accuracy: 0.6067
# Epoch [1300/2500], Loss: 0.8255, Accuracy: 0.6197
# Epoch [1400/2500], Loss: 0.1214, Accuracy: 0.6500
# Epoch [1500/2500], Loss: 0.7012, Accuracy: 0.6418
# Epoch [1600/2500], Loss: 0.1547, Accuracy: 0.6948
# Epoch [1700/2500], Loss: 0.6806, Accuracy: 0.7275
# Epoch [1800/2500], Loss: 1.9467, Accuracy: 0.7372
# Epoch [1900/2500], Loss: 0.8006, Accuracy: 0.7523
# Epoch [2000/2500], Loss: 0.7561, Accuracy: 0.7620
# Epoch [2100/2500], Loss: 0.3568, Accuracy: 0.7534
# Epoch [2200/2500], Loss: 0.5015, Accuracy: 0.7418
# Epoch [2300/2500], Loss: 0.2500, Accuracy: 0.7766
# Epoch [2400/2500], Loss: 0.4360, Accuracy: 0.7602
# Epoch [2500/2500], Loss: 0.3098, Accuracy: 0.7582
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_09_acc_0.7582.pkl
# Final accuracy: 0.7582
#
# === Training with seed 10 ===
# Epoch [100/2500], Loss: 0.4359, Accuracy: 0.6034
# Epoch [200/2500], Loss: 0.7380, Accuracy: 0.6282
# Epoch [300/2500], Loss: 0.1502, Accuracy: 0.6341
# Epoch [400/2500], Loss: 0.4807, Accuracy: 0.6239
# Epoch [500/2500], Loss: 0.6769, Accuracy: 0.6419
# Epoch [600/2500], Loss: 0.5005, Accuracy: 0.6495
# Epoch [700/2500], Loss: 0.4535, Accuracy: 0.6462
# Epoch [800/2500], Loss: 0.8393, Accuracy: 0.6391
# Epoch [900/2500], Loss: 0.2685, Accuracy: 0.6343
# Epoch [1000/2500], Loss: 0.5109, Accuracy: 0.6499
# Epoch [1100/2500], Loss: 0.2599, Accuracy: 0.6528
# Epoch [1200/2500], Loss: 0.5037, Accuracy: 0.6308
# Epoch [1300/2500], Loss: 0.5368, Accuracy: 0.6445
# Epoch [1400/2500], Loss: 0.0830, Accuracy: 0.6452
# Epoch [1500/2500], Loss: 1.0221, Accuracy: 0.6527
# Epoch [1600/2500], Loss: 0.0827, Accuracy: 0.6532
# Epoch [1700/2500], Loss: 0.9033, Accuracy: 0.6503
# Epoch [1800/2500], Loss: 1.9405, Accuracy: 0.6266
# Epoch [1900/2500], Loss: 0.6108, Accuracy: 0.6538
# Epoch [2000/2500], Loss: 0.9085, Accuracy: 0.6525
# Epoch [2100/2500], Loss: 0.5275, Accuracy: 0.6282
# Epoch [2200/2500], Loss: 0.4829, Accuracy: 0.6512
# Epoch [2300/2500], Loss: 0.1351, Accuracy: 0.6530
# Epoch [2400/2500], Loss: 0.5725, Accuracy: 0.6466
# Epoch [2500/2500], Loss: 0.4743, Accuracy: 0.6525
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_10_acc_0.6525.pkl
# Final accuracy: 0.6525
#
# === Training with seed 11 ===
# Epoch [100/2500], Loss: 0.6578, Accuracy: 0.6238
# Epoch [200/2500], Loss: 0.7845, Accuracy: 0.5885
# Epoch [300/2500], Loss: 0.3231, Accuracy: 0.6417
# Epoch [400/2500], Loss: 0.4696, Accuracy: 0.6345
# Epoch [500/2500], Loss: 0.7315, Accuracy: 0.6358
# Epoch [600/2500], Loss: 0.5212, Accuracy: 0.6323
# Epoch [700/2500], Loss: 0.3962, Accuracy: 0.6459
# Epoch [800/2500], Loss: 0.6613, Accuracy: 0.6358
# Epoch [900/2500], Loss: 0.3188, Accuracy: 0.7128
# Epoch [1000/2500], Loss: 0.4788, Accuracy: 0.6439
# Epoch [1100/2500], Loss: 0.3100, Accuracy: 0.7059
# Epoch [1200/2500], Loss: 0.3883, Accuracy: 0.7112
# Epoch [1300/2500], Loss: 0.6654, Accuracy: 0.7268
# Epoch [1400/2500], Loss: 0.0977, Accuracy: 0.7219
# Epoch [1500/2500], Loss: 0.6234, Accuracy: 0.7281
# Epoch [1600/2500], Loss: 0.1515, Accuracy: 0.7437
# Epoch [1700/2500], Loss: 0.6300, Accuracy: 0.7459
# Epoch [1800/2500], Loss: 1.9961, Accuracy: 0.7475
# Epoch [1900/2500], Loss: 0.7584, Accuracy: 0.7660
# Epoch [2000/2500], Loss: 0.6374, Accuracy: 0.7678
# Epoch [2100/2500], Loss: 0.3206, Accuracy: 0.7663
# Epoch [2200/2500], Loss: 0.4745, Accuracy: 0.7500
# Epoch [2300/2500], Loss: 0.2133, Accuracy: 0.7757
# Epoch [2400/2500], Loss: 0.4314, Accuracy: 0.7609
# Epoch [2500/2500], Loss: 0.2720, Accuracy: 0.7604
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_11_acc_0.7604.pkl
# Final accuracy: 0.7604
#
# === Training with seed 12 ===
# Epoch [100/2500], Loss: 0.8076, Accuracy: 0.5000
# Epoch [200/2500], Loss: 0.7096, Accuracy: 0.5000
# Epoch [300/2500], Loss: 0.7763, Accuracy: 0.5000
# Epoch [400/2500], Loss: 0.6446, Accuracy: 0.5000
# Epoch [500/2500], Loss: 0.6759, Accuracy: 0.5000
# Epoch [600/2500], Loss: 0.6623, Accuracy: 0.6552
# Epoch [700/2500], Loss: 0.4990, Accuracy: 0.5724
# Epoch [800/2500], Loss: 0.6422, Accuracy: 0.6280
# Epoch [900/2500], Loss: 0.5710, Accuracy: 0.5978
# Epoch [1000/2500], Loss: 0.5330, Accuracy: 0.6482
# Epoch [1100/2500], Loss: 0.5667, Accuracy: 0.6414
# Epoch [1200/2500], Loss: 0.6398, Accuracy: 0.6088
# Epoch [1300/2500], Loss: 0.9263, Accuracy: 0.6421
# Epoch [1400/2500], Loss: 0.4854, Accuracy: 0.6449
# Epoch [1500/2500], Loss: 0.4980, Accuracy: 0.6333
# Epoch [1600/2500], Loss: 0.4742, Accuracy: 0.6382
# Epoch [1700/2500], Loss: 0.4357, Accuracy: 0.6305
# Epoch [1800/2500], Loss: 1.2551, Accuracy: 0.4559
# Epoch [1900/2500], Loss: 1.0472, Accuracy: 0.6435
# Epoch [2000/2500], Loss: 0.7448, Accuracy: 0.6210
# Epoch [2100/2500], Loss: 0.5742, Accuracy: 0.6289
# Epoch [2200/2500], Loss: 0.9477, Accuracy: 0.6396
# Epoch [2300/2500], Loss: 0.6282, Accuracy: 0.6577
# Epoch [2400/2500], Loss: 0.5490, Accuracy: 0.6492
# Epoch [2500/2500], Loss: 0.6631, Accuracy: 0.6494
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_12_acc_0.6494.pkl
# Final accuracy: 0.6494
#
# === Training with seed 13 ===
# Epoch [100/2500], Loss: 0.8255, Accuracy: 0.5682
# Epoch [200/2500], Loss: 0.7313, Accuracy: 0.6077
# Epoch [300/2500], Loss: 0.8640, Accuracy: 0.6093
# Epoch [400/2500], Loss: 0.5750, Accuracy: 0.6328
# Epoch [500/2500], Loss: 0.5444, Accuracy: 0.6347
# Epoch [600/2500], Loss: 0.5503, Accuracy: 0.6272
# Epoch [700/2500], Loss: 0.4741, Accuracy: 0.6353
# Epoch [800/2500], Loss: 0.9030, Accuracy: 0.6351
# Epoch [900/2500], Loss: 0.7509, Accuracy: 0.6083
# Epoch [1000/2500], Loss: 0.6027, Accuracy: 0.6269
# Epoch [1100/2500], Loss: 0.8746, Accuracy: 0.6270
# Epoch [1200/2500], Loss: 0.5283, Accuracy: 0.6214
# Epoch [1300/2500], Loss: 1.8398, Accuracy: 0.6367
# Epoch [1400/2500], Loss: 0.9839, Accuracy: 0.6326
# Epoch [1500/2500], Loss: 0.0766, Accuracy: 0.6330
# Epoch [1600/2500], Loss: 0.9969, Accuracy: 0.6312
# Epoch [1700/2500], Loss: 0.3388, Accuracy: 0.6302
# Epoch [1800/2500], Loss: 0.7290, Accuracy: 0.5000
# Epoch [1900/2500], Loss: 0.5411, Accuracy: 0.6286
# Epoch [2000/2500], Loss: 0.4825, Accuracy: 0.6284
# Epoch [2100/2500], Loss: 0.5910, Accuracy: 0.6293
# Epoch [2200/2500], Loss: 0.5107, Accuracy: 0.6321
# Epoch [2300/2500], Loss: 0.9071, Accuracy: 0.6082
# Epoch [2400/2500], Loss: 0.5363, Accuracy: 0.6242
# Epoch [2500/2500], Loss: 0.4889, Accuracy: 0.6287
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_13_acc_0.6287.pkl
# Final accuracy: 0.6287
#
# === Training with seed 14 ===
# Epoch [100/2500], Loss: 0.8562, Accuracy: 0.5000
# Epoch [200/2500], Loss: 0.6989, Accuracy: 0.6108
# Epoch [300/2500], Loss: 0.7512, Accuracy: 0.6203
# Epoch [400/2500], Loss: 0.5407, Accuracy: 0.5863
# Epoch [500/2500], Loss: 0.9315, Accuracy: 0.5961
# Epoch [600/2500], Loss: 0.5342, Accuracy: 0.6329
# Epoch [700/2500], Loss: 0.4160, Accuracy: 0.6141
# Epoch [800/2500], Loss: 0.8551, Accuracy: 0.6224
# Epoch [900/2500], Loss: 0.7734, Accuracy: 0.6256
# Epoch [1000/2500], Loss: 0.4030, Accuracy: 0.6053
# Epoch [1100/2500], Loss: 0.6492, Accuracy: 0.6241
# Epoch [1200/2500], Loss: 0.5430, Accuracy: 0.6223
# Epoch [1300/2500], Loss: 1.5577, Accuracy: 0.6164
# Epoch [1400/2500], Loss: 0.6676, Accuracy: 0.6267
# Epoch [1500/2500], Loss: 0.1706, Accuracy: 0.6065
# Epoch [1600/2500], Loss: 0.7243, Accuracy: 0.6643
# Epoch [1700/2500], Loss: 0.2435, Accuracy: 0.7487
# Epoch [1800/2500], Loss: 0.8852, Accuracy: 0.7292
# Epoch [1900/2500], Loss: 0.5439, Accuracy: 0.7610
# Epoch [2000/2500], Loss: 0.6670, Accuracy: 0.7669
# Epoch [2100/2500], Loss: 0.4410, Accuracy: 0.7766
# Epoch [2200/2500], Loss: 0.5053, Accuracy: 0.7588
# Epoch [2300/2500], Loss: 0.4216, Accuracy: 0.7455
# Epoch [2400/2500], Loss: 0.2859, Accuracy: 0.7517
# Epoch [2500/2500], Loss: 0.2896, Accuracy: 0.7569
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_14_acc_0.7569.pkl
# Final accuracy: 0.7569
#
# === Training with seed 15 ===
# Epoch [100/2500], Loss: 0.6196, Accuracy: 0.6734
# Epoch [200/2500], Loss: 0.6654, Accuracy: 0.7124
# Epoch [300/2500], Loss: 0.6628, Accuracy: 0.6758
# Epoch [400/2500], Loss: 0.4658, Accuracy: 0.6876
# Epoch [500/2500], Loss: 0.6003, Accuracy: 0.7095
# Epoch [600/2500], Loss: 0.4266, Accuracy: 0.7658
# Epoch [700/2500], Loss: 0.3235, Accuracy: 0.7365
# Epoch [800/2500], Loss: 0.8906, Accuracy: 0.7684
# Epoch [900/2500], Loss: 0.6134, Accuracy: 0.7433
# Epoch [1000/2500], Loss: 0.4915, Accuracy: 0.7522
# Epoch [1100/2500], Loss: 0.5958, Accuracy: 0.7591
# Epoch [1200/2500], Loss: 0.3523, Accuracy: 0.7658
# Epoch [1300/2500], Loss: 1.7303, Accuracy: 0.7697
# Epoch [1400/2500], Loss: 0.3906, Accuracy: 0.7836
# Epoch [1500/2500], Loss: 0.0827, Accuracy: 0.7577
# Epoch [1600/2500], Loss: 0.4003, Accuracy: 0.7431
# Epoch [1700/2500], Loss: 0.3094, Accuracy: 0.7706
# Epoch [1800/2500], Loss: 1.1560, Accuracy: 0.7512
# Epoch [1900/2500], Loss: 0.4922, Accuracy: 0.7660
# Epoch [2000/2500], Loss: 0.4044, Accuracy: 0.7633
# Epoch [2100/2500], Loss: 0.3913, Accuracy: 0.7742
# Epoch [2200/2500], Loss: 0.3033, Accuracy: 0.7675
# Epoch [2300/2500], Loss: 0.2493, Accuracy: 0.7502
# Epoch [2400/2500], Loss: 0.2538, Accuracy: 0.7654
# Epoch [2500/2500], Loss: 0.2199, Accuracy: 0.7568
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_15_acc_0.7568.pkl
# Final accuracy: 0.7568
#
# === Training with seed 16 ===
# Epoch [100/2500], Loss: 0.5793, Accuracy: 0.5464
# Epoch [200/2500], Loss: 0.7310, Accuracy: 0.7402
# Epoch [300/2500], Loss: 0.5555, Accuracy: 0.7465
# Epoch [400/2500], Loss: 0.5163, Accuracy: 0.7365
# Epoch [500/2500], Loss: 0.7282, Accuracy: 0.7440
# Epoch [600/2500], Loss: 0.3362, Accuracy: 0.7775
# Epoch [700/2500], Loss: 0.2905, Accuracy: 0.7733
# Epoch [800/2500], Loss: 0.7942, Accuracy: 0.7689
# Epoch [900/2500], Loss: 0.3767, Accuracy: 0.7468
# Epoch [1000/2500], Loss: 0.5314, Accuracy: 0.7633
# Epoch [1100/2500], Loss: 0.3944, Accuracy: 0.7767
# Epoch [1200/2500], Loss: 0.2326, Accuracy: 0.7753
# Epoch [1300/2500], Loss: 1.4632, Accuracy: 0.7822
# Epoch [1400/2500], Loss: 0.1687, Accuracy: 0.7798
# Epoch [1500/2500], Loss: 0.0476, Accuracy: 0.7777
# Epoch [1600/2500], Loss: 0.1950, Accuracy: 0.7700
# Epoch [1700/2500], Loss: 0.3894, Accuracy: 0.7768
# Epoch [1800/2500], Loss: 1.7074, Accuracy: 0.7720
# Epoch [1900/2500], Loss: 0.4236, Accuracy: 0.7772
# Epoch [2000/2500], Loss: 0.3125, Accuracy: 0.7720
# Epoch [2100/2500], Loss: 0.2279, Accuracy: 0.7731
# Epoch [2200/2500], Loss: 0.2764, Accuracy: 0.7801
# Epoch [2300/2500], Loss: 0.1195, Accuracy: 0.7753
# Epoch [2400/2500], Loss: 0.3870, Accuracy: 0.7853
# Epoch [2500/2500], Loss: 0.1784, Accuracy: 0.7879
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_16_acc_0.7879.pkl
# Final accuracy: 0.7879
#
# === Training with seed 17 ===
# Epoch [100/2500], Loss: 0.8060, Accuracy: 0.5924
# Epoch [200/2500], Loss: 0.7025, Accuracy: 0.6255
# Epoch [300/2500], Loss: 0.8714, Accuracy: 0.6246
# Epoch [400/2500], Loss: 0.5633, Accuracy: 0.6355
# Epoch [500/2500], Loss: 0.5533, Accuracy: 0.6342
# Epoch [600/2500], Loss: 0.5463, Accuracy: 0.6313
# Epoch [700/2500], Loss: 0.4717, Accuracy: 0.6359
# Epoch [800/2500], Loss: 0.9077, Accuracy: 0.6352
# Epoch [900/2500], Loss: 0.7537, Accuracy: 0.6024
# Epoch [1000/2500], Loss: 0.6371, Accuracy: 0.6239
# Epoch [1100/2500], Loss: 0.8759, Accuracy: 0.6244
# Epoch [1200/2500], Loss: 0.5282, Accuracy: 0.6193
# Epoch [1300/2500], Loss: 1.8220, Accuracy: 0.6364
# Epoch [1400/2500], Loss: 0.9831, Accuracy: 0.6327
# Epoch [1500/2500], Loss: 0.0785, Accuracy: 0.6330
# Epoch [1600/2500], Loss: 0.9950, Accuracy: 0.6313
# Epoch [1700/2500], Loss: 0.3381, Accuracy: 0.6304
# Epoch [1800/2500], Loss: 0.7295, Accuracy: 0.5000
# Epoch [1900/2500], Loss: 0.5412, Accuracy: 0.6284
# Epoch [2000/2500], Loss: 0.4819, Accuracy: 0.6287
# Epoch [2100/2500], Loss: 0.5910, Accuracy: 0.6312
# Epoch [2200/2500], Loss: 0.5096, Accuracy: 0.6318
# Epoch [2300/2500], Loss: 0.9070, Accuracy: 0.6082
# Epoch [2400/2500], Loss: 0.5336, Accuracy: 0.6246
# Epoch [2500/2500], Loss: 0.4888, Accuracy: 0.6286
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_17_acc_0.6286.pkl
# Final accuracy: 0.6286
#
# === Training with seed 18 ===
# Epoch [100/2500], Loss: 0.4317, Accuracy: 0.6125
# Epoch [200/2500], Loss: 0.7297, Accuracy: 0.6115
# Epoch [300/2500], Loss: 0.2427, Accuracy: 0.6145
# Epoch [400/2500], Loss: 0.4362, Accuracy: 0.5982
# Epoch [500/2500], Loss: 0.8490, Accuracy: 0.6119
# Epoch [600/2500], Loss: 0.4959, Accuracy: 0.6273
# Epoch [700/2500], Loss: 0.4137, Accuracy: 0.6309
# Epoch [800/2500], Loss: 0.6533, Accuracy: 0.7233
# Epoch [900/2500], Loss: 0.3549, Accuracy: 0.7356
# Epoch [1000/2500], Loss: 0.4461, Accuracy: 0.7469
# Epoch [1100/2500], Loss: 0.3013, Accuracy: 0.7462
# Epoch [1200/2500], Loss: 0.4589, Accuracy: 0.7343
# Epoch [1300/2500], Loss: 1.2057, Accuracy: 0.7440
# Epoch [1400/2500], Loss: 0.1517, Accuracy: 0.7428
# Epoch [1500/2500], Loss: 0.1981, Accuracy: 0.7729
# Epoch [1600/2500], Loss: 0.2676, Accuracy: 0.7655
# Epoch [1700/2500], Loss: 0.3229, Accuracy: 0.7787
# Epoch [1800/2500], Loss: 1.4718, Accuracy: 0.7499
# Epoch [1900/2500], Loss: 0.4726, Accuracy: 0.7922
# Epoch [2000/2500], Loss: 0.6191, Accuracy: 0.7748
# Epoch [2100/2500], Loss: 0.2774, Accuracy: 0.7836
# Epoch [2200/2500], Loss: 0.5812, Accuracy: 0.7633
# Epoch [2300/2500], Loss: 0.1392, Accuracy: 0.7786
# Epoch [2400/2500], Loss: 0.3380, Accuracy: 0.7814
# Epoch [2500/2500], Loss: 0.1549, Accuracy: 0.7846
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_18_acc_0.7846.pkl
# Final accuracy: 0.7846
#
# === Training with seed 19 ===
# Epoch [100/2500], Loss: 0.6838, Accuracy: 0.4817
# Epoch [200/2500], Loss: 0.6754, Accuracy: 0.5000
# Epoch [300/2500], Loss: 0.7651, Accuracy: 0.5000
# Epoch [400/2500], Loss: 0.6626, Accuracy: 0.5000
# Epoch [500/2500], Loss: 0.6446, Accuracy: 0.5000
# Epoch [600/2500], Loss: 0.6874, Accuracy: 0.5000
# Epoch [700/2500], Loss: 0.6068, Accuracy: 0.5000
# Epoch [800/2500], Loss: 0.6729, Accuracy: 0.5000
# Epoch [900/2500], Loss: 0.5768, Accuracy: 0.5000
# Epoch [1000/2500], Loss: 0.7207, Accuracy: 0.5000
# Epoch [1100/2500], Loss: 0.7232, Accuracy: 0.5000
# Epoch [1200/2500], Loss: 0.6830, Accuracy: 0.5000
# Epoch [1300/2500], Loss: 0.6717, Accuracy: 0.5000
# Epoch [1400/2500], Loss: 0.7361, Accuracy: 0.5000
# Epoch [1500/2500], Loss: 0.7711, Accuracy: 0.5000
# Epoch [1600/2500], Loss: 0.6998, Accuracy: 0.5000
# Epoch [1700/2500], Loss: 0.6691, Accuracy: 0.5000
# Epoch [1800/2500], Loss: 0.9317, Accuracy: 0.5000
# Epoch [1900/2500], Loss: 0.7132, Accuracy: 0.5000
# Epoch [2000/2500], Loss: 0.6997, Accuracy: 0.5000
# Epoch [2100/2500], Loss: 0.7434, Accuracy: 0.5000
# Epoch [2200/2500], Loss: 0.6597, Accuracy: 0.5000
# Epoch [2300/2500], Loss: 0.6805, Accuracy: 0.5000
# Epoch [2400/2500], Loss: 0.7194, Accuracy: 0.5000
# Epoch [2500/2500], Loss: 0.6391, Accuracy: 0.5000
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_19_acc_0.5000.pkl
# Final accuracy: 0.5000
#
# === Training with seed 20 ===
# Epoch [100/2500], Loss: 0.6468, Accuracy: 0.6321
# Epoch [200/2500], Loss: 0.7739, Accuracy: 0.6808
# Epoch [300/2500], Loss: 0.6250, Accuracy: 0.6663
# Epoch [400/2500], Loss: 0.5228, Accuracy: 0.6293
# Epoch [500/2500], Loss: 0.6926, Accuracy: 0.7245
# Epoch [600/2500], Loss: 0.4103, Accuracy: 0.7560
# Epoch [700/2500], Loss: 0.3102, Accuracy: 0.7625
# Epoch [800/2500], Loss: 0.8488, Accuracy: 0.7662
# Epoch [900/2500], Loss: 0.5952, Accuracy: 0.7285
# Epoch [1000/2500], Loss: 0.5140, Accuracy: 0.7543
# Epoch [1100/2500], Loss: 0.5701, Accuracy: 0.7597
# Epoch [1200/2500], Loss: 0.3405, Accuracy: 0.7674
# Epoch [1300/2500], Loss: 1.7812, Accuracy: 0.7757
# Epoch [1400/2500], Loss: 0.3680, Accuracy: 0.7823
# Epoch [1500/2500], Loss: 0.0746, Accuracy: 0.7595
# Epoch [1600/2500], Loss: 0.3837, Accuracy: 0.7438
# Epoch [1700/2500], Loss: 0.3188, Accuracy: 0.7688
# Epoch [1800/2500], Loss: 1.1692, Accuracy: 0.7482
# Epoch [1900/2500], Loss: 0.4756, Accuracy: 0.7638
# Epoch [2000/2500], Loss: 0.3907, Accuracy: 0.7626
# Epoch [2100/2500], Loss: 0.4044, Accuracy: 0.7705
# Epoch [2200/2500], Loss: 0.2791, Accuracy: 0.7655
# Epoch [2300/2500], Loss: 0.2407, Accuracy: 0.7500
# Epoch [2400/2500], Loss: 0.2562, Accuracy: 0.7655
# Epoch [2500/2500], Loss: 0.2207, Accuracy: 0.7579
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_20_acc_0.7579.pkl
# Final accuracy: 0.7579
#
# === Training with seed 21 ===
# Epoch [100/2500], Loss: 0.4969, Accuracy: 0.5852
# Epoch [200/2500], Loss: 0.5387, Accuracy: 0.5587
# Epoch [300/2500], Loss: 0.5388, Accuracy: 0.6454
# Epoch [400/2500], Loss: 0.6163, Accuracy: 0.6218
# Epoch [500/2500], Loss: 0.8778, Accuracy: 0.6240
# Epoch [600/2500], Loss: 0.6604, Accuracy: 0.6090
# Epoch [700/2500], Loss: 0.4624, Accuracy: 0.6297
# Epoch [800/2500], Loss: 0.6041, Accuracy: 0.6292
# Epoch [900/2500], Loss: 0.5373, Accuracy: 0.6298
# Epoch [1000/2500], Loss: 0.4702, Accuracy: 0.6397
# Epoch [1100/2500], Loss: 0.5075, Accuracy: 0.6322
# Epoch [1200/2500], Loss: 0.6510, Accuracy: 0.6254
# Epoch [1300/2500], Loss: 1.0044, Accuracy: 0.6344
# Epoch [1400/2500], Loss: 0.4101, Accuracy: 0.6361
# Epoch [1500/2500], Loss: 0.5244, Accuracy: 0.6276
# Epoch [1600/2500], Loss: 0.4090, Accuracy: 0.6341
# Epoch [1700/2500], Loss: 0.4295, Accuracy: 0.6284
# Epoch [1800/2500], Loss: 1.2920, Accuracy: 0.4806
# Epoch [1900/2500], Loss: 1.0364, Accuracy: 0.6364
# Epoch [2000/2500], Loss: 0.8068, Accuracy: 0.6223
# Epoch [2100/2500], Loss: 0.5762, Accuracy: 0.6212
# Epoch [2200/2500], Loss: 0.8983, Accuracy: 0.6278
# Epoch [2300/2500], Loss: 0.6255, Accuracy: 0.6560
# Epoch [2400/2500], Loss: 0.4972, Accuracy: 0.6479
# Epoch [2500/2500], Loss: 0.6842, Accuracy: 0.6287
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_21_acc_0.6287.pkl
# Final accuracy: 0.6287
#
# === Training with seed 22 ===
# Epoch [100/2500], Loss: 0.5245, Accuracy: 0.6084
# Epoch [200/2500], Loss: 0.6480, Accuracy: 0.5786
# Epoch [300/2500], Loss: 0.3205, Accuracy: 0.5992
# Epoch [400/2500], Loss: 0.5004, Accuracy: 0.5947
# Epoch [500/2500], Loss: 0.8529, Accuracy: 0.6159
# Epoch [600/2500], Loss: 0.5160, Accuracy: 0.6333
# Epoch [700/2500], Loss: 0.4023, Accuracy: 0.6346
# Epoch [800/2500], Loss: 0.6298, Accuracy: 0.6193
# Epoch [900/2500], Loss: 0.3202, Accuracy: 0.6273
# Epoch [1000/2500], Loss: 0.4436, Accuracy: 0.6497
# Epoch [1100/2500], Loss: 0.2785, Accuracy: 0.6492
# Epoch [1200/2500], Loss: 0.4412, Accuracy: 0.6202
# Epoch [1300/2500], Loss: 0.6702, Accuracy: 0.6424
# Epoch [1400/2500], Loss: 0.0861, Accuracy: 0.6934
# Epoch [1500/2500], Loss: 0.6900, Accuracy: 0.6908
# Epoch [1600/2500], Loss: 0.1214, Accuracy: 0.7114
# Epoch [1700/2500], Loss: 0.6888, Accuracy: 0.7379
# Epoch [1800/2500], Loss: 2.0284, Accuracy: 0.7465
# Epoch [1900/2500], Loss: 0.7906, Accuracy: 0.7644
# Epoch [2000/2500], Loss: 0.6858, Accuracy: 0.7706
# Epoch [2100/2500], Loss: 0.3324, Accuracy: 0.7583
# Epoch [2200/2500], Loss: 0.4756, Accuracy: 0.7488
# Epoch [2300/2500], Loss: 0.2384, Accuracy: 0.7749
# Epoch [2400/2500], Loss: 0.4438, Accuracy: 0.7626
# Epoch [2500/2500], Loss: 0.2875, Accuracy: 0.7610
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_22_acc_0.7610.pkl
# Final accuracy: 0.7610
#
# === Training with seed 23 ===
# Epoch [100/2500], Loss: 0.5234, Accuracy: 0.6181
# Epoch [200/2500], Loss: 0.6233, Accuracy: 0.6071
# Epoch [300/2500], Loss: 0.5319, Accuracy: 0.6258
# Epoch [400/2500], Loss: 0.5922, Accuracy: 0.6090
# Epoch [500/2500], Loss: 0.8669, Accuracy: 0.6113
# Epoch [600/2500], Loss: 0.6380, Accuracy: 0.6155
# Epoch [700/2500], Loss: 0.4652, Accuracy: 0.5961
# Epoch [800/2500], Loss: 0.6229, Accuracy: 0.6216
# Epoch [900/2500], Loss: 0.5442, Accuracy: 0.6191
# Epoch [1000/2500], Loss: 0.4466, Accuracy: 0.6284
# Epoch [1100/2500], Loss: 0.4829, Accuracy: 0.6236
# Epoch [1200/2500], Loss: 0.6290, Accuracy: 0.6170
# Epoch [1300/2500], Loss: 1.0833, Accuracy: 0.6280
# Epoch [1400/2500], Loss: 0.3600, Accuracy: 0.6232
# Epoch [1500/2500], Loss: 0.4882, Accuracy: 0.6139
# Epoch [1600/2500], Loss: 0.3546, Accuracy: 0.6256
# Epoch [1700/2500], Loss: 0.4012, Accuracy: 0.6264
# Epoch [1800/2500], Loss: 1.2917, Accuracy: 0.4654
# Epoch [1900/2500], Loss: 1.0065, Accuracy: 0.6307
# Epoch [2000/2500], Loss: 0.8961, Accuracy: 0.6211
# Epoch [2100/2500], Loss: 0.5879, Accuracy: 0.6197
# Epoch [2200/2500], Loss: 0.9311, Accuracy: 0.6208
# Epoch [2300/2500], Loss: 0.6051, Accuracy: 0.6393
# Epoch [2400/2500], Loss: 0.4848, Accuracy: 0.6310
# Epoch [2500/2500], Loss: 0.6420, Accuracy: 0.6329
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_23_acc_0.6329.pkl
# Final accuracy: 0.6329
#
# === Training with seed 24 ===
# Epoch [100/2500], Loss: 0.5750, Accuracy: 0.6004
# Epoch [200/2500], Loss: 0.7877, Accuracy: 0.6072
# Epoch [300/2500], Loss: 0.2115, Accuracy: 0.6390
# Epoch [400/2500], Loss: 0.4232, Accuracy: 0.6347
# Epoch [500/2500], Loss: 0.6782, Accuracy: 0.6325
# Epoch [600/2500], Loss: 0.4223, Accuracy: 0.6390
# Epoch [700/2500], Loss: 0.3231, Accuracy: 0.6449
# Epoch [800/2500], Loss: 0.7020, Accuracy: 0.7318
# Epoch [900/2500], Loss: 0.3746, Accuracy: 0.7409
# Epoch [1000/2500], Loss: 0.4202, Accuracy: 0.7338
# Epoch [1100/2500], Loss: 0.4836, Accuracy: 0.7455
# Epoch [1200/2500], Loss: 0.3681, Accuracy: 0.7450
# Epoch [1300/2500], Loss: 0.9249, Accuracy: 0.7493
# Epoch [1400/2500], Loss: 0.1207, Accuracy: 0.7333
# Epoch [1500/2500], Loss: 0.5018, Accuracy: 0.7360
# Epoch [1600/2500], Loss: 0.2150, Accuracy: 0.7378
# Epoch [1700/2500], Loss: 0.5337, Accuracy: 0.7557
# Epoch [1800/2500], Loss: 1.9694, Accuracy: 0.7397
# Epoch [1900/2500], Loss: 0.7079, Accuracy: 0.7695
# Epoch [2000/2500], Loss: 0.6548, Accuracy: 0.7557
# Epoch [2100/2500], Loss: 0.3776, Accuracy: 0.7724
# Epoch [2200/2500], Loss: 0.5163, Accuracy: 0.7488
# Epoch [2300/2500], Loss: 0.2127, Accuracy: 0.7751
# Epoch [2400/2500], Loss: 0.4059, Accuracy: 0.7583
# Epoch [2500/2500], Loss: 0.2421, Accuracy: 0.7601
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_24_acc_0.7601.pkl
# Final accuracy: 0.7601
#
# === Training with seed 25 ===
# Epoch [100/2500], Loss: 0.7646, Accuracy: 0.5980
# Epoch [200/2500], Loss: 0.6954, Accuracy: 0.6256
# Epoch [300/2500], Loss: 0.8657, Accuracy: 0.6193
# Epoch [400/2500], Loss: 0.5621, Accuracy: 0.6573
# Epoch [500/2500], Loss: 0.5567, Accuracy: 0.7651
# Epoch [600/2500], Loss: 0.4045, Accuracy: 0.7786
# Epoch [700/2500], Loss: 0.3308, Accuracy: 0.7846
# Epoch [800/2500], Loss: 0.8269, Accuracy: 0.7785
# Epoch [900/2500], Loss: 0.3492, Accuracy: 0.7670
# Epoch [1000/2500], Loss: 0.4618, Accuracy: 0.7563
# Epoch [1100/2500], Loss: 0.3811, Accuracy: 0.7753
# Epoch [1200/2500], Loss: 0.2374, Accuracy: 0.7775
# Epoch [1300/2500], Loss: 1.4920, Accuracy: 0.7800
# Epoch [1400/2500], Loss: 0.1630, Accuracy: 0.7823
# Epoch [1500/2500], Loss: 0.0705, Accuracy: 0.7813
# Epoch [1600/2500], Loss: 0.1523, Accuracy: 0.7766
# Epoch [1700/2500], Loss: 0.3939, Accuracy: 0.7774
# Epoch [1800/2500], Loss: 1.7361, Accuracy: 0.7722
# Epoch [1900/2500], Loss: 0.4132, Accuracy: 0.7781
# Epoch [2000/2500], Loss: 0.3680, Accuracy: 0.7746
# Epoch [2100/2500], Loss: 0.2229, Accuracy: 0.7736
# Epoch [2200/2500], Loss: 0.3174, Accuracy: 0.7791
# Epoch [2300/2500], Loss: 0.1142, Accuracy: 0.7721
# Epoch [2400/2500], Loss: 0.4192, Accuracy: 0.7862
# Epoch [2500/2500], Loss: 0.1787, Accuracy: 0.7868
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_25_acc_0.7868.pkl
# Final accuracy: 0.7868
#
# === Training with seed 26 ===
# Epoch [100/2500], Loss: 0.9005, Accuracy: 0.5000
# Epoch [200/2500], Loss: 0.7451, Accuracy: 0.5000
# Epoch [300/2500], Loss: 0.7891, Accuracy: 0.5000
# Epoch [400/2500], Loss: 0.6551, Accuracy: 0.5000
# Epoch [500/2500], Loss: 0.6423, Accuracy: 0.5000
# Epoch [600/2500], Loss: 0.6862, Accuracy: 0.5000
# Epoch [700/2500], Loss: 0.6069, Accuracy: 0.5000
# Epoch [800/2500], Loss: 0.6734, Accuracy: 0.5000
# Epoch [900/2500], Loss: 0.5773, Accuracy: 0.5000
# Epoch [1000/2500], Loss: 0.7211, Accuracy: 0.5000
# Epoch [1100/2500], Loss: 0.7229, Accuracy: 0.5000
# Epoch [1200/2500], Loss: 0.6831, Accuracy: 0.5000
# Epoch [1300/2500], Loss: 0.6718, Accuracy: 0.5000
# Epoch [1400/2500], Loss: 0.7361, Accuracy: 0.5000
# Epoch [1500/2500], Loss: 0.7709, Accuracy: 0.5000
# Epoch [1600/2500], Loss: 0.6998, Accuracy: 0.5000
# Epoch [1700/2500], Loss: 0.6692, Accuracy: 0.5000
# Epoch [1800/2500], Loss: 0.9313, Accuracy: 0.5000
# Epoch [1900/2500], Loss: 0.7133, Accuracy: 0.5000
# Epoch [2000/2500], Loss: 0.6996, Accuracy: 0.5000
# Epoch [2100/2500], Loss: 0.7434, Accuracy: 0.5000
# Epoch [2200/2500], Loss: 0.6598, Accuracy: 0.5000
# Epoch [2300/2500], Loss: 0.6805, Accuracy: 0.5000
# Epoch [2400/2500], Loss: 0.7195, Accuracy: 0.5000
# Epoch [2500/2500], Loss: 0.6391, Accuracy: 0.5000
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_26_acc_0.5000.pkl
# Final accuracy: 0.5000
#
# === Training with seed 27 ===
# Epoch [100/2500], Loss: 0.5843, Accuracy: 0.5000
# Epoch [200/2500], Loss: 0.7292, Accuracy: 0.7698
# Epoch [300/2500], Loss: 0.6828, Accuracy: 0.7104
# Epoch [400/2500], Loss: 0.4326, Accuracy: 0.7129
# Epoch [500/2500], Loss: 0.5701, Accuracy: 0.7275
# Epoch [600/2500], Loss: 0.3959, Accuracy: 0.7734
# Epoch [700/2500], Loss: 0.2994, Accuracy: 0.7550
# Epoch [800/2500], Loss: 0.8977, Accuracy: 0.7637
# Epoch [900/2500], Loss: 0.5911, Accuracy: 0.7595
# Epoch [1000/2500], Loss: 0.4782, Accuracy: 0.7537
# Epoch [1100/2500], Loss: 0.5998, Accuracy: 0.7554
# Epoch [1200/2500], Loss: 0.3209, Accuracy: 0.7649
# Epoch [1300/2500], Loss: 1.7502, Accuracy: 0.7769
# Epoch [1400/2500], Loss: 0.3645, Accuracy: 0.7824
# Epoch [1500/2500], Loss: 0.0670, Accuracy: 0.7601
# Epoch [1600/2500], Loss: 0.3748, Accuracy: 0.7439
# Epoch [1700/2500], Loss: 0.3127, Accuracy: 0.7683
# Epoch [1800/2500], Loss: 1.1915, Accuracy: 0.7511
# Epoch [1900/2500], Loss: 0.4676, Accuracy: 0.7655
# Epoch [2000/2500], Loss: 0.3693, Accuracy: 0.7614
# Epoch [2100/2500], Loss: 0.3843, Accuracy: 0.7730
# Epoch [2200/2500], Loss: 0.2891, Accuracy: 0.7672
# Epoch [2300/2500], Loss: 0.2321, Accuracy: 0.7512
# Epoch [2400/2500], Loss: 0.2627, Accuracy: 0.7654
# Epoch [2500/2500], Loss: 0.2101, Accuracy: 0.7573
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_27_acc_0.7573.pkl
# Final accuracy: 0.7573
#
# === Training with seed 28 ===
# Epoch [100/2500], Loss: 0.4518, Accuracy: 0.5524
# Epoch [200/2500], Loss: 0.6129, Accuracy: 0.6321
# Epoch [300/2500], Loss: 0.4899, Accuracy: 0.6288
# Epoch [400/2500], Loss: 0.5875, Accuracy: 0.6187
# Epoch [500/2500], Loss: 0.9708, Accuracy: 0.6096
# Epoch [600/2500], Loss: 0.4938, Accuracy: 0.6124
# Epoch [700/2500], Loss: 0.4449, Accuracy: 0.6125
# Epoch [800/2500], Loss: 0.6455, Accuracy: 0.6126
# Epoch [900/2500], Loss: 0.4428, Accuracy: 0.6101
# Epoch [1000/2500], Loss: 0.4675, Accuracy: 0.6028
# Epoch [1100/2500], Loss: 0.3574, Accuracy: 0.6091
# Epoch [1200/2500], Loss: 0.5344, Accuracy: 0.6096
# Epoch [1300/2500], Loss: 1.1458, Accuracy: 0.6096
# Epoch [1400/2500], Loss: 0.1713, Accuracy: 0.6121
# Epoch [1500/2500], Loss: 0.7597, Accuracy: 0.5988
# Epoch [1600/2500], Loss: 0.2046, Accuracy: 0.6017
# Epoch [1700/2500], Loss: 0.6946, Accuracy: 0.5977
# Epoch [1800/2500], Loss: 1.7297, Accuracy: 0.5938
# Epoch [1900/2500], Loss: 0.9218, Accuracy: 0.6112
# Epoch [2000/2500], Loss: 0.9787, Accuracy: 0.6420
# Epoch [2100/2500], Loss: 0.5235, Accuracy: 0.6027
# Epoch [2200/2500], Loss: 0.4798, Accuracy: 0.6513
# Epoch [2300/2500], Loss: 0.2135, Accuracy: 0.6501
# Epoch [2400/2500], Loss: 0.5772, Accuracy: 0.6419
# Epoch [2500/2500], Loss: 0.4905, Accuracy: 0.6523
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_28_acc_0.6523.pkl
# Final accuracy: 0.6523
#
# === Training with seed 29 ===
# Epoch [100/2500], Loss: 0.7152, Accuracy: 0.3756
# Epoch [200/2500], Loss: 0.6014, Accuracy: 0.5048
# Epoch [300/2500], Loss: 0.8522, Accuracy: 0.6127
# Epoch [400/2500], Loss: 0.5537, Accuracy: 0.6221
# Epoch [500/2500], Loss: 0.6919, Accuracy: 0.6181
# Epoch [600/2500], Loss: 0.5055, Accuracy: 0.6284
# Epoch [700/2500], Loss: 0.3767, Accuracy: 0.6346
# Epoch [800/2500], Loss: 0.9018, Accuracy: 0.6364
# Epoch [900/2500], Loss: 0.7055, Accuracy: 0.7415
# Epoch [1000/2500], Loss: 0.4577, Accuracy: 0.6846
# Epoch [1100/2500], Loss: 0.7182, Accuracy: 0.7409
# Epoch [1200/2500], Loss: 0.3901, Accuracy: 0.7381
# Epoch [1300/2500], Loss: 1.7576, Accuracy: 0.7618
# Epoch [1400/2500], Loss: 0.5154, Accuracy: 0.7748
# Epoch [1500/2500], Loss: 0.1020, Accuracy: 0.7515
# Epoch [1600/2500], Loss: 0.5017, Accuracy: 0.7342
# Epoch [1700/2500], Loss: 0.3160, Accuracy: 0.7724
# Epoch [1800/2500], Loss: 1.0718, Accuracy: 0.7507
# Epoch [1900/2500], Loss: 0.4988, Accuracy: 0.7591
# Epoch [2000/2500], Loss: 0.4432, Accuracy: 0.7647
# Epoch [2100/2500], Loss: 0.4044, Accuracy: 0.7721
# Epoch [2200/2500], Loss: 0.3284, Accuracy: 0.7652
# Epoch [2300/2500], Loss: 0.2864, Accuracy: 0.7508
# Epoch [2400/2500], Loss: 0.2618, Accuracy: 0.7656
# Epoch [2500/2500], Loss: 0.2358, Accuracy: 0.7571
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_29_acc_0.7571.pkl
# Final accuracy: 0.7571
#
# === Training with seed 30 ===
# Epoch [100/2500], Loss: 0.5280, Accuracy: 0.6306
# Epoch [200/2500], Loss: 0.6102, Accuracy: 0.6353
# Epoch [300/2500], Loss: 0.5704, Accuracy: 0.6417
# Epoch [400/2500], Loss: 0.5459, Accuracy: 0.6101
# Epoch [500/2500], Loss: 0.9480, Accuracy: 0.6116
# Epoch [600/2500], Loss: 0.5084, Accuracy: 0.6417
# Epoch [700/2500], Loss: 0.4282, Accuracy: 0.6060
# Epoch [800/2500], Loss: 0.7380, Accuracy: 0.6438
# Epoch [900/2500], Loss: 0.6105, Accuracy: 0.6569
# Epoch [1000/2500], Loss: 0.4002, Accuracy: 0.5813
# Epoch [1100/2500], Loss: 0.4670, Accuracy: 0.6165
# Epoch [1200/2500], Loss: 0.6658, Accuracy: 0.6229
# Epoch [1300/2500], Loss: 1.3508, Accuracy: 0.5959
# Epoch [1400/2500], Loss: 0.2692, Accuracy: 0.6337
# Epoch [1500/2500], Loss: 0.3404, Accuracy: 0.5772
# Epoch [1600/2500], Loss: 0.4454, Accuracy: 0.5755
# Epoch [1700/2500], Loss: 0.2618, Accuracy: 0.6258
# Epoch [1800/2500], Loss: 1.1807, Accuracy: 0.6825
# Epoch [1900/2500], Loss: 1.1491, Accuracy: 0.6613
# Epoch [2000/2500], Loss: 1.1085, Accuracy: 0.5614
# Epoch [2100/2500], Loss: 0.5109, Accuracy: 0.6584
# Epoch [2200/2500], Loss: 0.9308, Accuracy: 0.5744
# Epoch [2300/2500], Loss: 0.8932, Accuracy: 0.6147
# Epoch [2400/2500], Loss: 0.3184, Accuracy: 0.5634
# Epoch [2500/2500], Loss: 0.5135, Accuracy: 0.6268
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_30_acc_0.6268.pkl
# Final accuracy: 0.6268
#
# === Training with seed 31 ===
# Epoch [100/2500], Loss: 0.5966, Accuracy: 0.6331
# Epoch [200/2500], Loss: 0.7734, Accuracy: 0.6135
# Epoch [300/2500], Loss: 0.2702, Accuracy: 0.6542
# Epoch [400/2500], Loss: 0.4819, Accuracy: 0.6401
# Epoch [500/2500], Loss: 0.7152, Accuracy: 0.6659
# Epoch [600/2500], Loss: 0.4798, Accuracy: 0.6982
# Epoch [700/2500], Loss: 0.4397, Accuracy: 0.6814
# Epoch [800/2500], Loss: 0.8582, Accuracy: 0.6500
# Epoch [900/2500], Loss: 0.3333, Accuracy: 0.6782
# Epoch [1000/2500], Loss: 0.4626, Accuracy: 0.7098
# Epoch [1100/2500], Loss: 0.3115, Accuracy: 0.7079
# Epoch [1200/2500], Loss: 0.4430, Accuracy: 0.6825
# Epoch [1300/2500], Loss: 0.6621, Accuracy: 0.6777
# Epoch [1400/2500], Loss: 0.0984, Accuracy: 0.7035
# Epoch [1500/2500], Loss: 1.1673, Accuracy: 0.7053
# Epoch [1600/2500], Loss: 0.1114, Accuracy: 0.7197
# Epoch [1700/2500], Loss: 0.9947, Accuracy: 0.7096
# Epoch [1800/2500], Loss: 1.4367, Accuracy: 0.6473
# Epoch [1900/2500], Loss: 0.6224, Accuracy: 0.7103
# Epoch [2000/2500], Loss: 1.0409, Accuracy: 0.6996
# Epoch [2100/2500], Loss: 0.4622, Accuracy: 0.6862
# Epoch [2200/2500], Loss: 0.4018, Accuracy: 0.7037
# Epoch [2300/2500], Loss: 0.2273, Accuracy: 0.7075
# Epoch [2400/2500], Loss: 0.5116, Accuracy: 0.7103
# Epoch [2500/2500], Loss: 0.4344, Accuracy: 0.7175
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/2_2_training_weights_1/training_data_seed_31_acc_0.7175.pkl
# Final accuracy: 0.7175

# %%
# random_seed=0 #Random seed of 3 makes for a nice "fold down the edges" deal, wait that's for 2x2
# torch.manual_seed(random_seed)  

# X_tensor = torch.FloatTensor(X)
# y_tensor = torch.tensor(y)

# # Initialize model and optimizer
# model = BaarleNet([2])
# criterion = nn.CrossEntropyLoss()
# # optimizer = optim.SGD(model.parameters(), lr=0.25)
# optimizer = optim.Adam(model.parameters(), lr=0.01) #0.005

# num_epochs = 2500
# for epoch in range(num_epochs):

#     outputs = model(torch.tensor(X[epoch%len(y)]).float())
#     loss = criterion(outputs, torch.tensor(y[epoch%len(y)])) 
    
#     optimizer.zero_grad()
#     loss.backward()
    
#     optimizer.step()
#     if (epoch+1) % (num_epochs//25) == 0:
#         outputs_batch = model(X_tensor)
#         accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)
#         print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Accuracy: {accuracy:.4f}')
# Out:
# Epoch [100/2500], Loss: 0.5027, Accuracy: 0.5592
# Epoch [200/2500], Loss: 0.6604, Accuracy: 0.5866
# Epoch [300/2500], Loss: 0.3639, Accuracy: 0.6165
# Epoch [400/2500], Loss: 0.5104, Accuracy: 0.6021
# Epoch [500/2500], Loss: 0.8830, Accuracy: 0.6015
# Epoch [600/2500], Loss: 0.4999, Accuracy: 0.6201
# Epoch [700/2500], Loss: 0.4561, Accuracy: 0.6241
# Epoch [800/2500], Loss: 0.6695, Accuracy: 0.5986
# Epoch [900/2500], Loss: 0.3245, Accuracy: 0.5976
# Epoch [1000/2500], Loss: 0.5006, Accuracy: 0.6529
# Epoch [1100/2500], Loss: 0.3110, Accuracy: 0.6497
# Epoch [1200/2500], Loss: 0.5023, Accuracy: 0.6171
# Epoch [1300/2500], Loss: 0.6864, Accuracy: 0.6249
# Epoch [1400/2500], Loss: 0.1131, Accuracy: 0.6413
# Epoch [1500/2500], Loss: 1.0399, Accuracy: 0.6498
# Epoch [1600/2500], Loss: 0.1165, Accuracy: 0.6521
# Epoch [1700/2500], Loss: 0.9192, Accuracy: 0.6430
# Epoch [1800/2500], Loss: 1.8811, Accuracy: 0.6278
# Epoch [1900/2500], Loss: 0.6570, Accuracy: 0.6535
# Epoch [2000/2500], Loss: 0.9242, Accuracy: 0.6545
# Epoch [2100/2500], Loss: 0.5265, Accuracy: 0.6351
# Epoch [2200/2500], Loss: 0.4818, Accuracy: 0.6542
# Epoch [2300/2500], Loss: 0.1473, Accuracy: 0.6502
# Epoch [2400/2500], Loss: 0.5715, Accuracy: 0.6475
# Epoch [2500/2500], Loss: 0.4769, Accuracy: 0.6513

# %%
probe=np.zeros((100,100,2))
for j, xx in enumerate(np.linspace(-1, 1, 100)):
    for k, yy in enumerate(np.linspace(-1, 1, 100)):
        probe[j, k]=[yy,xx]
probe=probe.reshape(100**2, -1)

# %%
h2 = model.model[:3](torch.tensor(probe).float())
h2 = h2.detach().numpy().reshape(100,100,2)

# %%
fig=plt.figure(0,(10,5)); 
for i in range(2):
    ax=fig.add_subplot(1,2,i+1)
    ax.imshow(map.mean(2), cmap='gray')
    ax.imshow(np.flipud(h2[:,:,i]>0), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')
