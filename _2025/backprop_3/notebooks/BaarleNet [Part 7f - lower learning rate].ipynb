# %% [markdown]
# # BaarleNet [Part 7f - lower learning rate]

# %%
import numpy as np
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import torch.optim as optim
import cv2
from matplotlib.gridspec import GridSpec
from tqdm import tqdm
import os

# %%
def denorm(p, size=960):
    result = np.zeros_like(p)
    result[..., 0] = (p[..., 0] + 1) * (size / 2)
    result[..., 1] = size - ((p[..., 1] + 1) * (size / 2))
    return result

def get_relu_joint(weight_1, weight_2, bias, extent=1):
    if np.abs(weight_2) < 1e-8: 
        x_intercept = -bias / weight_1
        return [[x_intercept, -extent], [x_intercept, extent]] if -extent <= x_intercept <= extent else []
    elif np.abs(weight_1) < 1e-8:
        y_intercept = -bias / weight_2
        return [[-extent, y_intercept], [extent, y_intercept]] if -extent <= y_intercept <= extent else []
    else:
        points = []
        for x in [-extent, extent]:
            y = (-x * weight_1 - bias) / weight_2
            if -extent <= y <= extent: points.append([x, y])
        for y in [-extent, extent]:
            x = (-y * weight_2 - bias) / weight_1
            if -extent <= x <= extent: points.append([x, y])
        unique_points = []
        for p in points:
            is_duplicate = False
            for existing in unique_points:
                if abs(p[0] - existing[0]) < 1e-8 and abs(p[1] - existing[1]) < 1e-8:
                    is_duplicate = True
                    break
            if not is_duplicate:
                unique_points.append(p)
        return unique_points

def viz_map_with_predictions(ax, map, X, y):
    probe=np.zeros((100,100,2))
    for j, xx in enumerate(np.linspace(-1, 1, 100)):
        for k, yy in enumerate(np.linspace(-1, 1, 100)):
            probe[j, k]=[yy,xx]
    probe=probe.reshape(100**2, -1)
    probe_logits=model(torch.tensor(probe).float())
    probe_logits=probe_logits.detach().numpy().reshape(100,100,2)
    probe_softmax = torch.nn.Softmax(dim=1)(torch.tensor(probe_logits.reshape(-1, 2)))
    
    ax.imshow(map.mean(2), cmap='gray')
    ax.imshow(np.flipud(probe_softmax[:,1].reshape(100, 100)), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')
    
    X_denorm=denorm(X[:1000,:])
    # plt.scatter(X_denorm[:,0], X_denorm[:,1], c=y[:1000], s=2, alpha=0.8)
    labels=y[:1000]
    y_hat=torch.argmax(model(torch.tensor(X[:1000,:]).float()).detach(),1).numpy()
    tp_mask=np.logical_and(labels==1, y_hat==1)
    fp_mask=np.logical_and(labels==0, y_hat==1)
    fn_mask=np.logical_and(labels==1, y_hat==0)
    tn_mask=np.logical_and(labels==0, y_hat==0)
    ax.scatter(X_denorm[tp_mask,0], X_denorm[tp_mask,1], c='g', s=3, alpha=0.8)
    ax.scatter(X_denorm[fp_mask,0], X_denorm[fp_mask,1], c='r', marker='x', s=5, alpha=0.8)
    ax.scatter(X_denorm[fn_mask,0], X_denorm[fn_mask,1], c='orange', marker='x', s=5, alpha=0.8)
    ax.scatter(X_denorm[tn_mask,0], X_denorm[tn_mask,1], c='purple', marker='o', s=5, alpha=0.8)

def save_viz(model, save_path=None):
    plt.clf()
    probe=np.zeros((100,100,2))
    for j, xx in enumerate(np.linspace(-1, 1, 100)):
        for k, yy in enumerate(np.linspace(-1, 1, 100)):
            probe[j, k]=[yy,xx]
    probe=probe.reshape(100**2, -1)
    
    h1 = model.model[:2](torch.tensor(probe).float())
    h1 = h1.detach().numpy().reshape(100,100,3)

    h2 = model.model[:3](torch.tensor(probe).float())
    h2 = h2.detach().numpy().reshape(100,100,2)
        
    # First neuron (output index 0)
    j1 = get_relu_joint(model.model[0].weight[0,0].item(), model.model[0].weight[0,1].item(), model.model[0].bias[0].item(), extent=1)
    j1 = denorm(np.array(j1)) if j1 else []
    
    # Second neuron (output index 1)  
    j2 = get_relu_joint(model.model[0].weight[1,0].item(), model.model[0].weight[1,1].item(), model.model[0].bias[1].item(), extent=1)
    j2 = denorm(np.array(j2)) if j2 else []
    
    j3 = get_relu_joint(model.model[0].weight[2,0].item(), model.model[0].weight[2,1].item(), model.model[0].bias[2].item(), extent=1)
    j3 = denorm(np.array(j3)) if j3 else []
    
    fig=plt.figure(0,(10,10)); 
    for i in range(3):
        ax=fig.add_subplot(2,2,i+1)
        ax.imshow(map.mean(2), cmap='gray')
        ax.imshow(np.flipud(h1[:,:,i]>0), 
                   extent=[0, 960, 960, 0],  # This maps to image coordinates
                   alpha=0.7,
                   cmap='viridis')
        if i==0 and len(j1)>0: ax.plot([j1[0][0], j1[1][0]], [j1[0][1], j1[1][1]], '--', color='#FFFFFF', linewidth=2)
        if i==1 and len(j2)>0: ax.plot([j2[0][0], j2[1][0]], [j2[0][1], j2[1][1]], '--', color='#FFFFFF', linewidth=2)
        if i==2 and len(j3)>0: ax.plot([j3[0][0], j3[1][0]], [j3[0][1], j3[1][1]], '--', color='#FFFFFF', linewidth=2)
    
    ax=fig.add_subplot(2,2,4)
    probe_logits=model(torch.tensor(probe).float())
    probe_logits=probe_logits.detach().numpy().reshape(100,100,2)
    probe_softmax = torch.nn.Softmax(dim=1)(torch.tensor(probe_logits.reshape(-1, 2)))
    
    ax.imshow(map.mean(2), cmap='gray')
    # ax.imshow(np.flipud(probe_softmax[:,1].reshape(100, 100)), 
    #            extent=[0, 960, 960, 0],  # This maps to image coordinates
    #            alpha=0.7,
    #            cmap='viridis')
    
    ax.imshow(np.flipud((h2[:,:,1]-h2[:,:,0])>0), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')
    if save_path is not None: plt.savefig(save_path)

# %%
def flatten_weight_dict(weight_dict):
    """
    Flatten a dictionary of weight tensors into a single 1D numpy array
    """
    flattened = []
    for name, tensor in weight_dict.items():
        if tensor is not None:
            flattened.append(tensor.cpu().numpy().flatten())
    return np.concatenate(flattened)

def unflatten_to_weight_dict(flattened_weights, reference_dict):
    """
    Convert flattened weights back to the original dictionary structure
    """
    result = {}
    start_idx = 0
    
    for name, tensor in reference_dict.items():
        if tensor is not None:
            shape = tensor.shape
            size = tensor.numel()
            
            # Extract the portion for this parameter
            param_weights = flattened_weights[start_idx:start_idx + size]
            
            # Reshape and convert to tensor
            result[name] = torch.tensor(param_weights.reshape(shape)).float()
            start_idx += size
    
    return result

# Set model weights function (reused from previous code)
def set_model_weights(model, weight_dict):
    """Set model parameters from weight dictionary"""
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = weight_dict[name]

def compute_loss_at_point(model, X_tensor, y_tensor, criterion):
    """Compute loss at current model parameters"""
    with torch.no_grad():
        outputs = model(X_tensor)
        loss = criterion(outputs, y_tensor)
        return loss.item()

# %%
map=cv2.imread('Baarle-Nassau_-_Baarle-Hertog-en.svg.png')[:,:,(2,1,0)]

belgium_color=np.array([251,234,81])
netherlands_color=np.array([255, 255, 228])

netherlands_region=((map-netherlands_color)**2).sum(-1)<10
belgium_region=((map-belgium_color)**2).sum(-1)<10000

num_points_to_sample=10000 #10000

b_coords=np.array(np.where(belgium_region)).T.astype('float')
n_coords=np.array(np.where(netherlands_region)).T.astype('float')

#flip and normalize
belgium_coords_all=np.zeros_like(b_coords)
netherlands_coords_all=np.zeros_like(n_coords)

belgium_coords_all[:,0]=b_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
belgium_coords_all[:,1]=(960-b_coords[:,0])/(960/2)-1
netherlands_coords_all[:,0]=n_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
netherlands_coords_all[:,1]=(960-n_coords[:,0])/(960/2)-1

## Hmm to balance to classes or do more area proportional? Not sure yet. 
belgium_coords=belgium_coords_all[np.random.choice(len(belgium_coords_all), num_points_to_sample), :]
netherlands_coords=netherlands_coords_all[np.random.choice(len(netherlands_coords_all), num_points_to_sample), :]

X=np.vstack((netherlands_coords, belgium_coords))
y=np.concatenate((np.zeros(len(netherlands_coords)), np.ones(len(belgium_coords)))).astype('int')

rI=np.arange(len(y))
np.random.shuffle(rI)
X=X[rI,:]
y=y[rI]

# %%
plt.scatter(X[:,0], X[:,1], c=y, s=1, alpha=0.3); plt.axis('square');

# %%
class BaarleNet(nn.Module):
    def __init__(self, hidden_layers=[64]):
        super(BaarleNet, self).__init__()
        layers = [nn.Linear(2, hidden_layers[0]), nn.ReLU()]
        for i in range(len(hidden_layers)-1):
            layers.append(nn.Linear(hidden_layers[i], hidden_layers[i+1]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_layers[-1], 2))
        self.layers=layers
        self.model = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.model(x)

# %%
import pickle
import copy
import os

# %% [markdown]
# ## Run same loop, but save best and worst

# %%
X_tensor = torch.FloatTensor(X)
y_tensor = torch.tensor(y)

# Training parameters
num_epochs = 5000 #Trying shorter to reduce arbitrary weight scaling
num_seeds = 128 #8 is nice for quick tests

# Configure output directory
output_dir = "/Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5"  # Change this to your desired directory
os.makedirs(output_dir, exist_ok=True)
print(f"Saving results to: {output_dir}")

# Track best and worst models
best_model_data = {'accuracy': -1, 'seed': None, 'initial_params': None, 'final_params': None}
worst_model_data = {'accuracy': float('inf'), 'seed': None, 'initial_params': None, 'final_params': None}
all_training_data=[]

for seed_idx in range(num_seeds):
    random_seed = seed_idx  # You can change this to any seed generation logic
    torch.manual_seed(random_seed)
    
    # Initialize model and optimizer
    model = BaarleNet([3]) #[3] is probaby the move for this
    #Mess with initialization
    bound=2.5
    with torch.no_grad():
        model.model[0].weight.uniform_(-bound, bound)
        model.model[0].bias.uniform_(-bound, bound)  
        model.model[2].weight.uniform_(-bound, bound)
        model.model[2].bias.uniform_(-bound, bound)  

    print(model.model[0].weight)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.003) #0.01
    
    # Store initial parameters (deep copy)
    initial_params = {}
    for name, param in model.named_parameters():
        initial_params[name] = param.data.clone()
    
    # Data storage for this run
    training_data = {
        'seed': random_seed,
        'weights_history': [],
        'gradients_history': [],
        'xy_history': [],
        'loss_history': [],
        'accuracy_history': [],
        'initial_params': initial_params  # Store initial params in training data too
    }

    print(f"\n=== Training with seed {random_seed} ===")

    for epoch in range(num_epochs):
        # Get current data point
        current_idx = epoch % len(y)
        # Stochastic
        # current_x = torch.tensor(X[current_idx]).float()
        # current_y = torch.tensor(y[current_idx])

        #Try batch for a second
        current_x = torch.tensor(X).float()
        current_y = torch.tensor(y)  
        
        # Forward pass
        outputs = model(current_x)
        loss = criterion(outputs, current_y)
        if epoch==0:
            print('initial loss = ', loss.item())
        
        # Store current X,y values
        training_data['xy_history'].append({
            'epoch': epoch,
            'x': X[current_idx].copy(),
            'y': y[current_idx]
        })
        
        # Zero gradients
        optimizer.zero_grad()
        
        # Backward pass
        loss.backward()
        
        # Store model weights (deep copy to avoid reference issues)
        current_weights = {}
        for name, param in model.named_parameters():
            current_weights[name] = param.data.clone()
        training_data['weights_history'].append(current_weights)
        
        # Store model gradients (deep copy)
        current_gradients = {}
        for name, param in model.named_parameters():
            if param.grad is not None:
                current_gradients[name] = param.grad.clone()
            else:
                current_gradients[name] = None
        training_data['gradients_history'].append(current_gradients)
        
        # Update parameters
        optimizer.step()
        
        # Store loss
        training_data['loss_history'].append(loss.item())
        
        # Calculate and store accuracy periodically
        if (epoch + 1) % (num_epochs // 10) == 0:
            with torch.no_grad():
                outputs_batch = model(X_tensor)
                accuracy = (torch.argmax(outputs_batch, dim=1) == y_tensor).sum().item() / len(y)
                training_data['accuracy_history'].append({
                    'epoch': epoch,
                    'accuracy': accuracy
                })
                print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Accuracy: {accuracy:.4f}')
    
    # Calculate final accuracy
    with torch.no_grad():
        final_outputs = model(X_tensor)
        final_accuracy = (torch.argmax(final_outputs, dim=1) == y_tensor).sum().item() / len(y)
    
    # Store final parameters (deep copy)
    final_params = {}
    for name, param in model.named_parameters():
        final_params[name] = param.data.clone()
    
    # Check if this is the best or worst model so far
    if final_accuracy > best_model_data['accuracy']:
        best_model_data = {
            'accuracy': final_accuracy,
            'seed': random_seed,
            'initial_params': {name: param.clone() for name, param in initial_params.items()},
            'final_params': {name: param.clone() for name, param in final_params.items()}
        }
        print(f"*** NEW BEST MODEL: Seed {random_seed}, Accuracy {final_accuracy:.4f} ***")
    
    if final_accuracy < worst_model_data['accuracy']:
        worst_model_data = {
            'accuracy': final_accuracy,
            'seed': random_seed,
            'initial_params': {name: param.clone() for name, param in initial_params.items()},
            'final_params': {name: param.clone() for name, param in final_params.items()}
        }
        print(f"*** NEW WORST MODEL: Seed {random_seed}, Accuracy {final_accuracy:.4f} ***")
    
    # Save data as pickle file
    filename = os.path.join(output_dir, f"training_data_seed_{random_seed:02d}_acc_{final_accuracy:.4f}.pkl")
    
    # Add final accuracy and params to the data
    training_data['final_accuracy'] = final_accuracy
    training_data['final_model_state'] = model.state_dict()
    training_data['final_params'] = final_params
    
    with open(filename, 'wb') as f:
        pickle.dump(training_data, f)
    
    print(f"Saved training data to {filename}")
    print(f"Final accuracy: {final_accuracy:.4f}")

    # Restore initial weights for visualization
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = training_data['weights_history'][0][name]

    print(model.model[0].weight)
    viz_fn = os.path.join(output_dir, f"{final_accuracy:.4f}_random_init.png")
    save_viz(model, str(viz_fn))

    all_training_data.append(training_data)

# After all training is complete, save best and worst model data
best_worst_data = {
    'best_model': best_model_data,
    'worst_model': worst_model_data
}

best_worst_filename = os.path.join(output_dir, "best_worst_models.pkl")
with open(best_worst_filename, 'wb') as f:
    pickle.dump(best_worst_data, f)

print(f"\n=== FINAL RESULTS ===")
print(f"Best model: Seed {best_model_data['seed']}, Accuracy {best_model_data['accuracy']:.4f}")
print(f"Worst model: Seed {worst_model_data['seed']}, Accuracy {worst_model_data['accuracy']:.4f}")
print(f"Best/worst model data saved to: {best_worst_filename}")
# Out:
# Saving results to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5
# Parameter containing:
# tensor([[ 1.5001, -1.6949],
#         [-1.0887,  0.9080],
#         [ 2.0760, -0.5145]], requires_grad=True)
#
# === Training with seed 0 ===
# initial loss =  2.3601129055023193
# Epoch [500/5000], Loss: 0.6648, Accuracy: 0.6198
# Epoch [1000/5000], Loss: 0.5733, Accuracy: 0.7471
# Epoch [1500/5000], Loss: 0.5141, Accuracy: 0.7600
# Epoch [2000/5000], Loss: 0.4883, Accuracy: 0.7568
# Epoch [2500/5000], Loss: 0.4778, Accuracy: 0.7598
# Epoch [3000/5000], Loss: 0.4753, Accuracy: 0.7614
# Epoch [3500/5000], Loss: 0.4750, Accuracy: 0.7621
# Epoch [4000/5000], Loss: 0.4750, Accuracy: 0.7628
# Epoch [4500/5000], Loss: 0.4750, Accuracy: 0.7628
# Epoch [5000/5000], Loss: 0.4750, Accuracy: 0.7628
# *** NEW BEST MODEL: Seed 0, Accuracy 0.7628 ***
# *** NEW WORST MODEL: Seed 0, Accuracy 0.7628 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_00_acc_0.7628.pkl
# Final accuracy: 0.7628
# Parameter containing:
# tensor([[ 1.5001, -1.6949],
#         [-1.0887,  0.9080],
#         [ 2.0760, -0.5145]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0100,  2.1854],
#         [ 0.7780, -0.9310],
#         [-1.5099, -0.4190]], requires_grad=True)
#
# === Training with seed 1 ===
# initial loss =  1.505711317062378
# Epoch [500/5000], Loss: 0.4567, Accuracy: 0.7738
# Epoch [1000/5000], Loss: 0.4521, Accuracy: 0.7698
# Epoch [1500/5000], Loss: 0.4134, Accuracy: 0.7992
# Epoch [2000/5000], Loss: 0.3630, Accuracy: 0.8518
# Epoch [2500/5000], Loss: 0.3506, Accuracy: 0.8545
# Epoch [3000/5000], Loss: 0.3496, Accuracy: 0.8538
# Epoch [3500/5000], Loss: 0.3494, Accuracy: 0.8540
# Epoch [4000/5000], Loss: 0.3494, Accuracy: 0.8538
# Epoch [4500/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [5000/5000], Loss: 0.3494, Accuracy: 0.8539
# *** NEW BEST MODEL: Seed 1, Accuracy 0.8539 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_01_acc_0.8539.pkl
# Final accuracy: 0.8539
# Parameter containing:
# tensor([[-0.0100,  2.1854],
#         [ 0.7780, -0.9310],
#         [-1.5099, -0.4190]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4748, -0.9611],
#         [ 2.4043, -2.4487],
#         [-0.1698, -0.1981]], requires_grad=True)
#
# === Training with seed 2 ===
# initial loss =  1.1474406719207764
# Epoch [500/5000], Loss: 0.5004, Accuracy: 0.7658
# Epoch [1000/5000], Loss: 0.4746, Accuracy: 0.7618
# Epoch [1500/5000], Loss: 0.4743, Accuracy: 0.7621
# Epoch [2000/5000], Loss: 0.4743, Accuracy: 0.7623
# Epoch [2500/5000], Loss: 0.4743, Accuracy: 0.7623
# Epoch [3000/5000], Loss: 0.4743, Accuracy: 0.7623
# Epoch [3500/5000], Loss: 0.4743, Accuracy: 0.7623
# Epoch [4000/5000], Loss: 0.4743, Accuracy: 0.7623
# Epoch [4500/5000], Loss: 0.4743, Accuracy: 0.7623
# Epoch [5000/5000], Loss: 0.4743, Accuracy: 0.7622
# *** NEW WORST MODEL: Seed 2, Accuracy 0.7622 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_02_acc_0.7622.pkl
# Final accuracy: 0.7622
# Parameter containing:
# tensor([[-1.4748, -0.9611],
#         [ 2.4043, -2.4487],
#         [-0.1698, -0.1981]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.2459,  1.7366],
#         [ 1.8743,  0.7416],
#         [-1.4262,  2.2465]], requires_grad=True)
#
# === Training with seed 3 ===
# initial loss =  0.8931422829627991
# Epoch [500/5000], Loss: 0.5037, Accuracy: 0.7578
# Epoch [1000/5000], Loss: 0.4591, Accuracy: 0.7917
# Epoch [1500/5000], Loss: 0.4578, Accuracy: 0.7913
# Epoch [2000/5000], Loss: 0.4576, Accuracy: 0.7889
# Epoch [2500/5000], Loss: 0.4576, Accuracy: 0.7889
# Epoch [3000/5000], Loss: 0.4576, Accuracy: 0.7889
# Epoch [3500/5000], Loss: 0.4576, Accuracy: 0.7889
# Epoch [4000/5000], Loss: 0.4576, Accuracy: 0.7889
# Epoch [4500/5000], Loss: 0.4576, Accuracy: 0.7889
# Epoch [5000/5000], Loss: 0.4576, Accuracy: 0.7889
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_03_acc_0.7889.pkl
# Final accuracy: 0.7889
# Parameter containing:
# tensor([[ 2.2459,  1.7366],
#         [ 1.8743,  0.7416],
#         [-1.4262,  2.2465]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4315, -0.9668],
#         [-2.3072,  0.1101],
#         [-0.8963,  0.5369]], requires_grad=True)
#
# === Training with seed 4 ===
# initial loss =  2.0545637607574463
# Epoch [500/5000], Loss: 0.6154, Accuracy: 0.6714
# Epoch [1000/5000], Loss: 0.5273, Accuracy: 0.7293
# Epoch [1500/5000], Loss: 0.4569, Accuracy: 0.7932
# Epoch [2000/5000], Loss: 0.4164, Accuracy: 0.8178
# Epoch [2500/5000], Loss: 0.3810, Accuracy: 0.8370
# Epoch [3000/5000], Loss: 0.3665, Accuracy: 0.8385
# Epoch [3500/5000], Loss: 0.3606, Accuracy: 0.8509
# Epoch [4000/5000], Loss: 0.3574, Accuracy: 0.8533
# Epoch [4500/5000], Loss: 0.3556, Accuracy: 0.8545
# Epoch [5000/5000], Loss: 0.3543, Accuracy: 0.8544
# *** NEW BEST MODEL: Seed 4, Accuracy 0.8544 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_04_acc_0.8544.pkl
# Final accuracy: 0.8544
# Parameter containing:
# tensor([[-1.4315, -0.9668],
#         [-2.3072,  0.1101],
#         [-0.8963,  0.5369]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.7508, -2.2168],
#         [ 2.1006,  0.8488],
#         [-1.1926, -2.2964]], requires_grad=True)
#
# === Training with seed 5 ===
# initial loss =  2.30936598777771
# Epoch [500/5000], Loss: 0.5438, Accuracy: 0.7287
# Epoch [1000/5000], Loss: 0.5112, Accuracy: 0.7599
# Epoch [1500/5000], Loss: 0.4504, Accuracy: 0.8023
# Epoch [2000/5000], Loss: 0.4155, Accuracy: 0.8164
# Epoch [2500/5000], Loss: 0.4042, Accuracy: 0.8216
# Epoch [3000/5000], Loss: 0.3907, Accuracy: 0.8339
# Epoch [3500/5000], Loss: 0.3831, Accuracy: 0.8420
# Epoch [4000/5000], Loss: 0.3796, Accuracy: 0.8446
# Epoch [4500/5000], Loss: 0.3754, Accuracy: 0.8466
# Epoch [5000/5000], Loss: 0.3705, Accuracy: 0.8500
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_05_acc_0.8500.pkl
# Final accuracy: 0.8500
# Parameter containing:
# tensor([[ 0.7508, -2.2168],
#         [ 2.1006,  0.8488],
#         [-1.1926, -2.2964]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.5259, -0.6751],
#         [-1.2321, -1.6790],
#         [-1.0834, -0.5709]], requires_grad=True)
#
# === Training with seed 6 ===
# initial loss =  1.9301406145095825
# Epoch [500/5000], Loss: 0.5415, Accuracy: 0.7174
# Epoch [1000/5000], Loss: 0.4825, Accuracy: 0.7845
# Epoch [1500/5000], Loss: 0.4468, Accuracy: 0.8014
# Epoch [2000/5000], Loss: 0.4351, Accuracy: 0.8111
# Epoch [2500/5000], Loss: 0.4290, Accuracy: 0.8190
# Epoch [3000/5000], Loss: 0.4242, Accuracy: 0.8266
# Epoch [3500/5000], Loss: 0.4205, Accuracy: 0.8284
# Epoch [4000/5000], Loss: 0.4189, Accuracy: 0.8300
# Epoch [4500/5000], Loss: 0.4182, Accuracy: 0.8319
# Epoch [5000/5000], Loss: 0.4178, Accuracy: 0.8334
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_06_acc_0.8334.pkl
# Final accuracy: 0.8334
# Parameter containing:
# tensor([[ 0.5259, -0.6751],
#         [-1.2321, -1.6790],
#         [-1.0834, -0.5709]], requires_grad=True)
# Parameter containing:
# tensor([[-2.1347,  2.3496],
#         [-1.9611,  1.9144],
#         [-0.4341,  1.2860]], requires_grad=True)
#
# === Training with seed 7 ===
# initial loss =  1.7934216260910034
# Epoch [500/5000], Loss: 0.5847, Accuracy: 0.6407
# Epoch [1000/5000], Loss: 0.5240, Accuracy: 0.7705
# Epoch [1500/5000], Loss: 0.4858, Accuracy: 0.7627
# Epoch [2000/5000], Loss: 0.4797, Accuracy: 0.7622
# Epoch [2500/5000], Loss: 0.4773, Accuracy: 0.7621
# Epoch [3000/5000], Loss: 0.4761, Accuracy: 0.7617
# Epoch [3500/5000], Loss: 0.4755, Accuracy: 0.7618
# Epoch [4000/5000], Loss: 0.4751, Accuracy: 0.7617
# Epoch [4500/5000], Loss: 0.4749, Accuracy: 0.7617
# Epoch [5000/5000], Loss: 0.4747, Accuracy: 0.7620
# *** NEW WORST MODEL: Seed 7, Accuracy 0.7620 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_07_acc_0.7620.pkl
# Final accuracy: 0.7620
# Parameter containing:
# tensor([[-2.1347,  2.3496],
#         [-1.9611,  1.9144],
#         [-0.4341,  1.2860]], requires_grad=True)
# Parameter containing:
# tensor([[-1.2266, -0.1585],
#         [-1.6589, -1.6437],
#         [ 0.0516, -1.9659]], requires_grad=True)
#
# === Training with seed 8 ===
# initial loss =  1.4135135412216187
# Epoch [500/5000], Loss: 0.6775, Accuracy: 0.5873
# Epoch [1000/5000], Loss: 0.6642, Accuracy: 0.6108
# Epoch [1500/5000], Loss: 0.6634, Accuracy: 0.6137
# Epoch [2000/5000], Loss: 0.6634, Accuracy: 0.6145
# Epoch [2500/5000], Loss: 0.6634, Accuracy: 0.6147
# Epoch [3000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [3500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [4000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [4500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [5000/5000], Loss: 0.6634, Accuracy: 0.6148
# *** NEW WORST MODEL: Seed 8, Accuracy 0.6148 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_08_acc_0.6148.pkl
# Final accuracy: 0.6148
# Parameter containing:
# tensor([[-1.2266, -0.1585],
#         [-1.6589, -1.6437],
#         [ 0.0516, -1.9659]], requires_grad=True)
# Parameter containing:
# tensor([[-0.7661, -0.2617],
#         [ 0.6578,  0.9737],
#         [ 1.6074,  2.0556]], requires_grad=True)
#
# === Training with seed 9 ===
# initial loss =  1.326350212097168
# Epoch [500/5000], Loss: 0.5913, Accuracy: 0.6659
# Epoch [1000/5000], Loss: 0.4669, Accuracy: 0.8146
# Epoch [1500/5000], Loss: 0.3950, Accuracy: 0.8401
# Epoch [2000/5000], Loss: 0.3738, Accuracy: 0.8452
# Epoch [2500/5000], Loss: 0.3674, Accuracy: 0.8434
# Epoch [3000/5000], Loss: 0.3660, Accuracy: 0.8438
# Epoch [3500/5000], Loss: 0.3658, Accuracy: 0.8449
# Epoch [4000/5000], Loss: 0.3657, Accuracy: 0.8446
# Epoch [4500/5000], Loss: 0.3657, Accuracy: 0.8447
# Epoch [5000/5000], Loss: 0.3657, Accuracy: 0.8446
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_09_acc_0.8446.pkl
# Final accuracy: 0.8446
# Parameter containing:
# tensor([[-0.7661, -0.2617],
#         [ 0.6578,  0.9737],
#         [ 1.6074,  2.0556]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0884,  0.5750],
#         [-0.0163, -0.2394],
#         [-2.2124, -2.1565]], requires_grad=True)
#
# === Training with seed 10 ===
# initial loss =  0.8567241430282593
# Epoch [500/5000], Loss: 0.6935, Accuracy: 0.4981
# Epoch [1000/5000], Loss: 0.6932, Accuracy: 0.4996
# Epoch [1500/5000], Loss: 0.6931, Accuracy: 0.4999
# Epoch [2000/5000], Loss: 0.6931, Accuracy: 0.5000
# Epoch [2500/5000], Loss: 0.6931, Accuracy: 0.5000
# Epoch [3000/5000], Loss: 0.6931, Accuracy: 0.5000
# Epoch [3500/5000], Loss: 0.6931, Accuracy: 0.5000
# Epoch [4000/5000], Loss: 0.6931, Accuracy: 0.5000
# Epoch [4500/5000], Loss: 0.6931, Accuracy: 0.5000
# Epoch [5000/5000], Loss: 0.6931, Accuracy: 0.5000
# *** NEW WORST MODEL: Seed 10, Accuracy 0.5000 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_10_acc_0.5000.pkl
# Final accuracy: 0.5000
# Parameter containing:
# tensor([[-0.0884,  0.5750],
#         [-0.0163, -0.2394],
#         [-2.2124, -2.1565]], requires_grad=True)
# Parameter containing:
# tensor([[1.3000, 1.5177],
#         [1.3265, 1.8545],
#         [1.1153, 1.6822]], requires_grad=True)
#
# === Training with seed 11 ===
# initial loss =  2.7969517707824707
# Epoch [500/5000], Loss: 0.6999, Accuracy: 0.5011
# Epoch [1000/5000], Loss: 0.6194, Accuracy: 0.6500
# Epoch [1500/5000], Loss: 0.4830, Accuracy: 0.7829
# Epoch [2000/5000], Loss: 0.4386, Accuracy: 0.7849
# Epoch [2500/5000], Loss: 0.4313, Accuracy: 0.8149
# Epoch [3000/5000], Loss: 0.4273, Accuracy: 0.8222
# Epoch [3500/5000], Loss: 0.4236, Accuracy: 0.8307
# Epoch [4000/5000], Loss: 0.4188, Accuracy: 0.8372
# Epoch [4500/5000], Loss: 0.4175, Accuracy: 0.8395
# Epoch [5000/5000], Loss: 0.4173, Accuracy: 0.8385
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_11_acc_0.8385.pkl
# Final accuracy: 0.8385
# Parameter containing:
# tensor([[1.3000, 1.5177],
#         [1.3265, 1.8545],
#         [1.1153, 1.6822]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.7213, -1.8721],
#         [-0.2719,  0.8003],
#         [-2.2231, -1.7135]], requires_grad=True)
#
# === Training with seed 12 ===
# initial loss =  1.2538319826126099
# Epoch [500/5000], Loss: 0.6655, Accuracy: 0.5967
# Epoch [1000/5000], Loss: 0.5928, Accuracy: 0.7126
# Epoch [1500/5000], Loss: 0.4878, Accuracy: 0.7522
# Epoch [2000/5000], Loss: 0.3877, Accuracy: 0.8458
# Epoch [2500/5000], Loss: 0.3538, Accuracy: 0.8541
# Epoch [3000/5000], Loss: 0.3498, Accuracy: 0.8535
# Epoch [3500/5000], Loss: 0.3494, Accuracy: 0.8536
# Epoch [4000/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [4500/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [5000/5000], Loss: 0.3494, Accuracy: 0.8539
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_12_acc_0.8539.pkl
# Final accuracy: 0.8539
# Parameter containing:
# tensor([[ 1.7213, -1.8721],
#         [-0.2719,  0.8003],
#         [-2.2231, -1.7135]], requires_grad=True)
# Parameter containing:
# tensor([[-0.8050,  1.6833],
#         [-1.8556,  2.3467],
#         [-0.2524, -0.4847]], requires_grad=True)
#
# === Training with seed 13 ===
# initial loss =  3.6655051708221436
# Epoch [500/5000], Loss: 0.7204, Accuracy: 0.5988
# Epoch [1000/5000], Loss: 0.6749, Accuracy: 0.6082
# Epoch [1500/5000], Loss: 0.6646, Accuracy: 0.6062
# Epoch [2000/5000], Loss: 0.6538, Accuracy: 0.6051
# Epoch [2500/5000], Loss: 0.6155, Accuracy: 0.6490
# Epoch [3000/5000], Loss: 0.5696, Accuracy: 0.6955
# Epoch [3500/5000], Loss: 0.4888, Accuracy: 0.7694
# Epoch [4000/5000], Loss: 0.4777, Accuracy: 0.7637
# Epoch [4500/5000], Loss: 0.4759, Accuracy: 0.7621
# Epoch [5000/5000], Loss: 0.4753, Accuracy: 0.7617
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_13_acc_0.7617.pkl
# Final accuracy: 0.7617
# Parameter containing:
# tensor([[-0.8050,  1.6833],
#         [-1.8556,  2.3467],
#         [-0.2524, -0.4847]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.4362,  0.7063],
#         [-0.2763, -0.2039],
#         [ 2.2364,  0.5859]], requires_grad=True)
#
# === Training with seed 14 ===
# initial loss =  1.0816185474395752
# Epoch [500/5000], Loss: 0.5202, Accuracy: 0.7604
# Epoch [1000/5000], Loss: 0.4803, Accuracy: 0.7610
# Epoch [1500/5000], Loss: 0.4760, Accuracy: 0.7608
# Epoch [2000/5000], Loss: 0.4749, Accuracy: 0.7608
# Epoch [2500/5000], Loss: 0.4745, Accuracy: 0.7612
# Epoch [3000/5000], Loss: 0.4744, Accuracy: 0.7615
# Epoch [3500/5000], Loss: 0.4744, Accuracy: 0.7618
# Epoch [4000/5000], Loss: 0.4744, Accuracy: 0.7618
# Epoch [4500/5000], Loss: 0.4744, Accuracy: 0.7618
# Epoch [5000/5000], Loss: 0.4744, Accuracy: 0.7618
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_14_acc_0.7618.pkl
# Final accuracy: 0.7618
# Parameter containing:
# tensor([[ 2.4362,  0.7063],
#         [-0.2763, -0.2039],
#         [ 2.2364,  0.5859]], requires_grad=True)
# Parameter containing:
# tensor([[-1.0007,  2.3707],
#         [-0.7903,  2.0663],
#         [-0.9057,  0.6080]], requires_grad=True)
#
# === Training with seed 15 ===
# initial loss =  2.3062970638275146
# Epoch [500/5000], Loss: 0.5992, Accuracy: 0.6706
# Epoch [1000/5000], Loss: 0.5605, Accuracy: 0.7194
# Epoch [1500/5000], Loss: 0.4987, Accuracy: 0.7656
# Epoch [2000/5000], Loss: 0.4808, Accuracy: 0.7642
# Epoch [2500/5000], Loss: 0.4775, Accuracy: 0.7621
# Epoch [3000/5000], Loss: 0.4763, Accuracy: 0.7618
# Epoch [3500/5000], Loss: 0.4756, Accuracy: 0.7617
# Epoch [4000/5000], Loss: 0.4752, Accuracy: 0.7617
# Epoch [4500/5000], Loss: 0.4749, Accuracy: 0.7615
# Epoch [5000/5000], Loss: 0.4748, Accuracy: 0.7617
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_15_acc_0.7617.pkl
# Final accuracy: 0.7617
# Parameter containing:
# tensor([[-1.0007,  2.3707],
#         [-0.7903,  2.0663],
#         [-0.9057,  0.6080]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4928,  1.9939],
#         [-0.0323, -0.9878],
#         [ 1.4086,  2.3302]], requires_grad=True)
#
# === Training with seed 16 ===
# initial loss =  0.8625390529632568
# Epoch [500/5000], Loss: 0.5262, Accuracy: 0.7597
# Epoch [1000/5000], Loss: 0.4451, Accuracy: 0.7976
# Epoch [1500/5000], Loss: 0.4301, Accuracy: 0.8065
# Epoch [2000/5000], Loss: 0.4128, Accuracy: 0.8266
# Epoch [2500/5000], Loss: 0.3851, Accuracy: 0.8393
# Epoch [3000/5000], Loss: 0.3792, Accuracy: 0.8416
# Epoch [3500/5000], Loss: 0.3719, Accuracy: 0.8452
# Epoch [4000/5000], Loss: 0.3668, Accuracy: 0.8485
# Epoch [4500/5000], Loss: 0.3638, Accuracy: 0.8517
# Epoch [5000/5000], Loss: 0.3619, Accuracy: 0.8524
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_16_acc_0.8524.pkl
# Final accuracy: 0.8524
# Parameter containing:
# tensor([[-1.4928,  1.9939],
#         [-0.0323, -0.9878],
#         [ 1.4086,  2.3302]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7972,  0.5014],
#         [ 0.3289, -2.0255],
#         [-2.0152, -0.6428]], requires_grad=True)
#
# === Training with seed 17 ===
# initial loss =  3.1601407527923584
# Epoch [500/5000], Loss: 0.6641, Accuracy: 0.6500
# Epoch [1000/5000], Loss: 0.6495, Accuracy: 0.6604
# Epoch [1500/5000], Loss: 0.6446, Accuracy: 0.6562
# Epoch [2000/5000], Loss: 0.6314, Accuracy: 0.6584
# Epoch [2500/5000], Loss: 0.6007, Accuracy: 0.6966
# Epoch [3000/5000], Loss: 0.5225, Accuracy: 0.7416
# Epoch [3500/5000], Loss: 0.5115, Accuracy: 0.7463
# Epoch [4000/5000], Loss: 0.5111, Accuracy: 0.7460
# Epoch [4500/5000], Loss: 0.5110, Accuracy: 0.7466
# Epoch [5000/5000], Loss: 0.5109, Accuracy: 0.7478
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_17_acc_0.7478.pkl
# Final accuracy: 0.7478
# Parameter containing:
# tensor([[-1.7972,  0.5014],
#         [ 0.3289, -2.0255],
#         [-2.0152, -0.6428]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0263, -1.2684],
#         [ 0.6360,  1.2205],
#         [ 1.3820,  2.0599]], requires_grad=True)
#
# === Training with seed 18 ===
# initial loss =  2.2683827877044678
# Epoch [500/5000], Loss: 0.8917, Accuracy: 0.5000
# Epoch [1000/5000], Loss: 0.6049, Accuracy: 0.6543
# Epoch [1500/5000], Loss: 0.5896, Accuracy: 0.6673
# Epoch [2000/5000], Loss: 0.4961, Accuracy: 0.7732
# Epoch [2500/5000], Loss: 0.4582, Accuracy: 0.7909
# Epoch [3000/5000], Loss: 0.4578, Accuracy: 0.7914
# Epoch [3500/5000], Loss: 0.4577, Accuracy: 0.7911
# Epoch [4000/5000], Loss: 0.4577, Accuracy: 0.7909
# Epoch [4500/5000], Loss: 0.4577, Accuracy: 0.7910
# Epoch [5000/5000], Loss: 0.4577, Accuracy: 0.7909
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_18_acc_0.7909.pkl
# Final accuracy: 0.7909
# Parameter containing:
# tensor([[ 0.0263, -1.2684],
#         [ 0.6360,  1.2205],
#         [ 1.3820,  2.0599]], requires_grad=True)
# Parameter containing:
# tensor([[-2.4669,  1.1457],
#         [-0.3475, -1.1182],
#         [-0.7610,  0.2551]], requires_grad=True)
#
# === Training with seed 19 ===
# initial loss =  0.8926551938056946
# Epoch [500/5000], Loss: 0.5277, Accuracy: 0.7388
# Epoch [1000/5000], Loss: 0.5169, Accuracy: 0.7432
# Epoch [1500/5000], Loss: 0.5115, Accuracy: 0.7456
# Epoch [2000/5000], Loss: 0.5111, Accuracy: 0.7462
# Epoch [2500/5000], Loss: 0.5109, Accuracy: 0.7479
# Epoch [3000/5000], Loss: 0.5105, Accuracy: 0.7513
# Epoch [3500/5000], Loss: 0.5105, Accuracy: 0.7506
# Epoch [4000/5000], Loss: 0.5105, Accuracy: 0.7506
# Epoch [4500/5000], Loss: 0.5105, Accuracy: 0.7506
# Epoch [5000/5000], Loss: 0.5105, Accuracy: 0.7506
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_19_acc_0.7506.pkl
# Final accuracy: 0.7506
# Parameter containing:
# tensor([[-2.4669,  1.1457],
#         [-0.3475, -1.1182],
#         [-0.7610,  0.2551]], requires_grad=True)
# Parameter containing:
# tensor([[-0.2851,  0.6283],
#         [-2.3105,  1.0650],
#         [-0.8854,  2.3156]], requires_grad=True)
#
# === Training with seed 20 ===
# initial loss =  1.5106714963912964
# Epoch [500/5000], Loss: 0.6315, Accuracy: 0.5000
# Epoch [1000/5000], Loss: 0.5472, Accuracy: 0.7248
# Epoch [1500/5000], Loss: 0.5371, Accuracy: 0.7305
# Epoch [2000/5000], Loss: 0.5341, Accuracy: 0.7310
# Epoch [2500/5000], Loss: 0.5330, Accuracy: 0.7322
# Epoch [3000/5000], Loss: 0.5326, Accuracy: 0.7320
# Epoch [3500/5000], Loss: 0.5325, Accuracy: 0.7317
# Epoch [4000/5000], Loss: 0.5324, Accuracy: 0.7319
# Epoch [4500/5000], Loss: 0.5324, Accuracy: 0.7318
# Epoch [5000/5000], Loss: 0.5324, Accuracy: 0.7317
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_20_acc_0.7317.pkl
# Final accuracy: 0.7317
# Parameter containing:
# tensor([[-0.2851,  0.6283],
#         [-2.3105,  1.0650],
#         [-0.8854,  2.3156]], requires_grad=True)
# Parameter containing:
# tensor([[-2.3289, -0.5032],
#         [ 1.0914,  1.5508],
#         [ 0.0048, -2.2223]], requires_grad=True)
#
# === Training with seed 21 ===
# initial loss =  1.2267117500305176
# Epoch [500/5000], Loss: 0.5894, Accuracy: 0.6770
# Epoch [1000/5000], Loss: 0.4911, Accuracy: 0.7732
# Epoch [1500/5000], Loss: 0.4737, Accuracy: 0.7851
# Epoch [2000/5000], Loss: 0.4665, Accuracy: 0.7812
# Epoch [2500/5000], Loss: 0.4661, Accuracy: 0.7802
# Epoch [3000/5000], Loss: 0.4660, Accuracy: 0.7796
# Epoch [3500/5000], Loss: 0.4657, Accuracy: 0.7798
# Epoch [4000/5000], Loss: 0.4645, Accuracy: 0.7807
# Epoch [4500/5000], Loss: 0.4619, Accuracy: 0.7863
# Epoch [5000/5000], Loss: 0.4595, Accuracy: 0.7872
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_21_acc_0.7872.pkl
# Final accuracy: 0.7872
# Parameter containing:
# tensor([[-2.3289, -0.5032],
#         [ 1.0914,  1.5508],
#         [ 0.0048, -2.2223]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.4888,  1.7972],
#         [-0.6698,  0.9744],
#         [-0.8285,  0.8407]], requires_grad=True)
#
# === Training with seed 22 ===
# initial loss =  2.2249135971069336
# Epoch [500/5000], Loss: 0.6448, Accuracy: 0.6010
# Epoch [1000/5000], Loss: 0.6095, Accuracy: 0.6584
# Epoch [1500/5000], Loss: 0.5052, Accuracy: 0.7821
# Epoch [2000/5000], Loss: 0.4615, Accuracy: 0.8053
# Epoch [2500/5000], Loss: 0.4302, Accuracy: 0.8239
# Epoch [3000/5000], Loss: 0.4221, Accuracy: 0.8364
# Epoch [3500/5000], Loss: 0.4198, Accuracy: 0.8383
# Epoch [4000/5000], Loss: 0.4188, Accuracy: 0.8386
# Epoch [4500/5000], Loss: 0.4183, Accuracy: 0.8384
# Epoch [5000/5000], Loss: 0.4179, Accuracy: 0.8380
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_22_acc_0.8380.pkl
# Final accuracy: 0.8380
# Parameter containing:
# tensor([[ 1.4888,  1.7972],
#         [-0.6698,  0.9744],
#         [-0.8285,  0.8407]], requires_grad=True)
# Parameter containing:
# tensor([[-0.8260, -0.2295],
#         [-1.2403,  0.6550],
#         [-1.6467, -0.9388]], requires_grad=True)
#
# === Training with seed 23 ===
# initial loss =  0.7565515637397766
# Epoch [500/5000], Loss: 0.5487, Accuracy: 0.7173
# Epoch [1000/5000], Loss: 0.5333, Accuracy: 0.7316
# Epoch [1500/5000], Loss: 0.5325, Accuracy: 0.7317
# Epoch [2000/5000], Loss: 0.5324, Accuracy: 0.7317
# Epoch [2500/5000], Loss: 0.5324, Accuracy: 0.7316
# Epoch [3000/5000], Loss: 0.5324, Accuracy: 0.7317
# Epoch [3500/5000], Loss: 0.5324, Accuracy: 0.7317
# Epoch [4000/5000], Loss: 0.5324, Accuracy: 0.7317
# Epoch [4500/5000], Loss: 0.5324, Accuracy: 0.7317
# Epoch [5000/5000], Loss: 0.5324, Accuracy: 0.7317
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_23_acc_0.7317.pkl
# Final accuracy: 0.7317
# Parameter containing:
# tensor([[-0.8260, -0.2295],
#         [-1.2403,  0.6550],
#         [-1.6467, -0.9388]], requires_grad=True)
# Parameter containing:
# tensor([[-0.9760, -1.0056],
#         [-0.7452, -2.2353],
#         [-1.5058,  1.5109]], requires_grad=True)
#
# === Training with seed 24 ===
# initial loss =  5.868799686431885
# Epoch [500/5000], Loss: 0.9244, Accuracy: 0.5000
# Epoch [1000/5000], Loss: 0.6120, Accuracy: 0.6704
# Epoch [1500/5000], Loss: 0.5191, Accuracy: 0.7380
# Epoch [2000/5000], Loss: 0.5078, Accuracy: 0.7389
# Epoch [2500/5000], Loss: 0.5065, Accuracy: 0.7407
# Epoch [3000/5000], Loss: 0.5058, Accuracy: 0.7404
# Epoch [3500/5000], Loss: 0.5054, Accuracy: 0.7398
# Epoch [4000/5000], Loss: 0.5051, Accuracy: 0.7388
# Epoch [4500/5000], Loss: 0.5049, Accuracy: 0.7374
# Epoch [5000/5000], Loss: 0.5048, Accuracy: 0.7360
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_24_acc_0.7360.pkl
# Final accuracy: 0.7360
# Parameter containing:
# tensor([[-0.9760, -1.0056],
#         [-0.7452, -2.2353],
#         [-1.5058,  1.5109]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0905,  2.3628],
#         [ 1.9063, -2.4719],
#         [-0.9718,  2.1921]], requires_grad=True)
#
# === Training with seed 25 ===
# initial loss =  0.9086661338806152
# Epoch [500/5000], Loss: 0.5562, Accuracy: 0.7055
# Epoch [1000/5000], Loss: 0.4677, Accuracy: 0.7815
# Epoch [1500/5000], Loss: 0.4664, Accuracy: 0.7779
# Epoch [2000/5000], Loss: 0.4662, Accuracy: 0.7772
# Epoch [2500/5000], Loss: 0.4662, Accuracy: 0.7765
# Epoch [3000/5000], Loss: 0.4662, Accuracy: 0.7766
# Epoch [3500/5000], Loss: 0.4662, Accuracy: 0.7766
# Epoch [4000/5000], Loss: 0.4662, Accuracy: 0.7766
# Epoch [4500/5000], Loss: 0.4662, Accuracy: 0.7766
# Epoch [5000/5000], Loss: 0.4662, Accuracy: 0.7766
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_25_acc_0.7766.pkl
# Final accuracy: 0.7766
# Parameter containing:
# tensor([[ 0.0905,  2.3628],
#         [ 1.9063, -2.4719],
#         [-0.9718,  2.1921]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.1308,  2.0386],
#         [-1.8635, -2.4261],
#         [-0.5303,  2.1976]], requires_grad=True)
#
# === Training with seed 26 ===
# initial loss =  5.596512317657471
# Epoch [500/5000], Loss: 0.7208, Accuracy: 0.6192
# Epoch [1000/5000], Loss: 0.5356, Accuracy: 0.7556
# Epoch [1500/5000], Loss: 0.4678, Accuracy: 0.7821
# Epoch [2000/5000], Loss: 0.4182, Accuracy: 0.8166
# Epoch [2500/5000], Loss: 0.3928, Accuracy: 0.8292
# Epoch [3000/5000], Loss: 0.3823, Accuracy: 0.8371
# Epoch [3500/5000], Loss: 0.3735, Accuracy: 0.8386
# Epoch [4000/5000], Loss: 0.3664, Accuracy: 0.8384
# Epoch [4500/5000], Loss: 0.3613, Accuracy: 0.8498
# Epoch [5000/5000], Loss: 0.3579, Accuracy: 0.8528
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_26_acc_0.8528.pkl
# Final accuracy: 0.8528
# Parameter containing:
# tensor([[ 2.1308,  2.0386],
#         [-1.8635, -2.4261],
#         [-0.5303,  2.1976]], requires_grad=True)
# Parameter containing:
# tensor([[-1.2464,  1.3234],
#         [ 1.4255, -2.3941],
#         [-1.3851,  0.7563]], requires_grad=True)
#
# === Training with seed 27 ===
# initial loss =  0.6369763016700745
# Epoch [500/5000], Loss: 0.3731, Accuracy: 0.8450
# Epoch [1000/5000], Loss: 0.3695, Accuracy: 0.8439
# Epoch [1500/5000], Loss: 0.3674, Accuracy: 0.8421
# Epoch [2000/5000], Loss: 0.3658, Accuracy: 0.8449
# Epoch [2500/5000], Loss: 0.3657, Accuracy: 0.8452
# Epoch [3000/5000], Loss: 0.3657, Accuracy: 0.8453
# Epoch [3500/5000], Loss: 0.3657, Accuracy: 0.8453
# Epoch [4000/5000], Loss: 0.3657, Accuracy: 0.8453
# Epoch [4500/5000], Loss: 0.3657, Accuracy: 0.8452
# Epoch [5000/5000], Loss: 0.3657, Accuracy: 0.8453
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_27_acc_0.8453.pkl
# Final accuracy: 0.8453
# Parameter containing:
# tensor([[-1.2464,  1.3234],
#         [ 1.4255, -2.3941],
#         [-1.3851,  0.7563]], requires_grad=True)
# Parameter containing:
# tensor([[-2.1348,  2.2932],
#         [-0.5350, -0.8428],
#         [ 2.3360,  0.1177]], requires_grad=True)
#
# === Training with seed 28 ===
# initial loss =  2.54333233833313
# Epoch [500/5000], Loss: 0.6812, Accuracy: 0.6183
# Epoch [1000/5000], Loss: 0.5983, Accuracy: 0.6607
# Epoch [1500/5000], Loss: 0.5698, Accuracy: 0.7478
# Epoch [2000/5000], Loss: 0.5224, Accuracy: 0.7785
# Epoch [2500/5000], Loss: 0.4890, Accuracy: 0.7814
# Epoch [3000/5000], Loss: 0.4747, Accuracy: 0.7889
# Epoch [3500/5000], Loss: 0.4679, Accuracy: 0.7842
# Epoch [4000/5000], Loss: 0.4665, Accuracy: 0.7793
# Epoch [4500/5000], Loss: 0.4663, Accuracy: 0.7779
# Epoch [5000/5000], Loss: 0.4662, Accuracy: 0.7778
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_28_acc_0.7778.pkl
# Final accuracy: 0.7778
# Parameter containing:
# tensor([[-2.1348,  2.2932],
#         [-0.5350, -0.8428],
#         [ 2.3360,  0.1177]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.6002,  0.9240],
#         [-0.4141,  2.2426],
#         [-0.3339, -0.5049]], requires_grad=True)
#
# === Training with seed 29 ===
# initial loss =  2.1995298862457275
# Epoch [500/5000], Loss: 0.6441, Accuracy: 0.6234
# Epoch [1000/5000], Loss: 0.5607, Accuracy: 0.7279
# Epoch [1500/5000], Loss: 0.5095, Accuracy: 0.7327
# Epoch [2000/5000], Loss: 0.4796, Accuracy: 0.7702
# Epoch [2500/5000], Loss: 0.4686, Accuracy: 0.7742
# Epoch [3000/5000], Loss: 0.4651, Accuracy: 0.7773
# Epoch [3500/5000], Loss: 0.4621, Accuracy: 0.7812
# Epoch [4000/5000], Loss: 0.4596, Accuracy: 0.7851
# Epoch [4500/5000], Loss: 0.4587, Accuracy: 0.7865
# Epoch [5000/5000], Loss: 0.4583, Accuracy: 0.7867
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_29_acc_0.7867.pkl
# Final accuracy: 0.7867
# Parameter containing:
# tensor([[ 1.6002,  0.9240],
#         [-0.4141,  2.2426],
#         [-0.3339, -0.5049]], requires_grad=True)
# Parameter containing:
# tensor([[-2.2935, -1.9367],
#         [ 0.9862,  1.8799],
#         [-0.9184, -1.0055]], requires_grad=True)
#
# === Training with seed 30 ===
# initial loss =  2.445265054702759
# Epoch [500/5000], Loss: 0.6854, Accuracy: 0.5623
# Epoch [1000/5000], Loss: 0.6642, Accuracy: 0.6156
# Epoch [1500/5000], Loss: 0.6496, Accuracy: 0.6218
# Epoch [2000/5000], Loss: 0.5408, Accuracy: 0.7673
# Epoch [2500/5000], Loss: 0.4808, Accuracy: 0.7622
# Epoch [3000/5000], Loss: 0.4752, Accuracy: 0.7613
# Epoch [3500/5000], Loss: 0.4745, Accuracy: 0.7613
# Epoch [4000/5000], Loss: 0.4744, Accuracy: 0.7615
# Epoch [4500/5000], Loss: 0.4744, Accuracy: 0.7620
# Epoch [5000/5000], Loss: 0.4744, Accuracy: 0.7625
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_30_acc_0.7625.pkl
# Final accuracy: 0.7625
# Parameter containing:
# tensor([[-2.2935, -1.9367],
#         [ 0.9862,  1.8799],
#         [-0.9184, -1.0055]], requires_grad=True)
# Parameter containing:
# tensor([[-1.8010, -1.7756],
#         [ 1.0809,  1.9316],
#         [ 1.1709,  1.9634]], requires_grad=True)
#
# === Training with seed 31 ===
# initial loss =  3.2916135787963867
# Epoch [500/5000], Loss: 0.6819, Accuracy: 0.6436
# Epoch [1000/5000], Loss: 0.6477, Accuracy: 0.6073
# Epoch [1500/5000], Loss: 0.6345, Accuracy: 0.6000
# Epoch [2000/5000], Loss: 0.6071, Accuracy: 0.6843
# Epoch [2500/5000], Loss: 0.5579, Accuracy: 0.7749
# Epoch [3000/5000], Loss: 0.5445, Accuracy: 0.7701
# Epoch [3500/5000], Loss: 0.4582, Accuracy: 0.7992
# Epoch [4000/5000], Loss: 0.4073, Accuracy: 0.8278
# Epoch [4500/5000], Loss: 0.3806, Accuracy: 0.8397
# Epoch [5000/5000], Loss: 0.3638, Accuracy: 0.8410
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_31_acc_0.8410.pkl
# Final accuracy: 0.8410
# Parameter containing:
# tensor([[-1.8010, -1.7756],
#         [ 1.0809,  1.9316],
#         [ 1.1709,  1.9634]], requires_grad=True)
# Parameter containing:
# tensor([[-2.0436,  1.0884],
#         [ 1.1356, -0.0163],
#         [ 2.1537, -0.6616]], requires_grad=True)
#
# === Training with seed 32 ===
# initial loss =  1.5841373205184937
# Epoch [500/5000], Loss: 0.6635, Accuracy: 0.6087
# Epoch [1000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [1500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [2000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [2500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [3000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [3500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [4000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [4500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [5000/5000], Loss: 0.6634, Accuracy: 0.6148
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_32_acc_0.6148.pkl
# Final accuracy: 0.6148
# Parameter containing:
# tensor([[-2.0436,  1.0884],
#         [ 1.1356, -0.0163],
#         [ 2.1537, -0.6616]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.7678,  0.3328],
#         [-1.2429, -2.2657],
#         [ 0.9862,  1.0504]], requires_grad=True)
#
# === Training with seed 33 ===
# initial loss =  0.9257454872131348
# Epoch [500/5000], Loss: 0.5218, Accuracy: 0.7728
# Epoch [1000/5000], Loss: 0.3857, Accuracy: 0.8492
# Epoch [1500/5000], Loss: 0.3538, Accuracy: 0.8564
# Epoch [2000/5000], Loss: 0.3503, Accuracy: 0.8540
# Epoch [2500/5000], Loss: 0.3496, Accuracy: 0.8540
# Epoch [3000/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [3500/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [4000/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [4500/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [5000/5000], Loss: 0.3494, Accuracy: 0.8539
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_33_acc_0.8539.pkl
# Final accuracy: 0.8539
# Parameter containing:
# tensor([[ 1.7678,  0.3328],
#         [-1.2429, -2.2657],
#         [ 0.9862,  1.0504]], requires_grad=True)
# Parameter containing:
# tensor([[-1.2626, -1.5245],
#         [-0.9545, -0.3216],
#         [-0.5755, -2.4548]], requires_grad=True)
#
# === Training with seed 34 ===
# initial loss =  0.8332010507583618
# Epoch [500/5000], Loss: 0.4920, Accuracy: 0.7637
# Epoch [1000/5000], Loss: 0.3986, Accuracy: 0.8336
# Epoch [1500/5000], Loss: 0.3717, Accuracy: 0.8365
# Epoch [2000/5000], Loss: 0.3651, Accuracy: 0.8358
# Epoch [2500/5000], Loss: 0.3628, Accuracy: 0.8377
# Epoch [3000/5000], Loss: 0.3620, Accuracy: 0.8386
# Epoch [3500/5000], Loss: 0.3616, Accuracy: 0.8394
# Epoch [4000/5000], Loss: 0.3613, Accuracy: 0.8396
# Epoch [4500/5000], Loss: 0.3612, Accuracy: 0.8395
# Epoch [5000/5000], Loss: 0.3611, Accuracy: 0.8394
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_34_acc_0.8394.pkl
# Final accuracy: 0.8394
# Parameter containing:
# tensor([[-1.2626, -1.5245],
#         [-0.9545, -0.3216],
#         [-0.5755, -2.4548]], requires_grad=True)
# Parameter containing:
# tensor([[-0.5383,  1.5826],
#         [ 0.9450,  2.2983],
#         [ 2.0159,  1.1268]], requires_grad=True)
#
# === Training with seed 35 ===
# initial loss =  3.2693371772766113
# Epoch [500/5000], Loss: 0.6731, Accuracy: 0.6318
# Epoch [1000/5000], Loss: 0.5823, Accuracy: 0.7108
# Epoch [1500/5000], Loss: 0.4978, Accuracy: 0.7501
# Epoch [2000/5000], Loss: 0.4745, Accuracy: 0.7938
# Epoch [2500/5000], Loss: 0.4686, Accuracy: 0.7921
# Epoch [3000/5000], Loss: 0.4641, Accuracy: 0.7901
# Epoch [3500/5000], Loss: 0.4597, Accuracy: 0.7886
# Epoch [4000/5000], Loss: 0.4564, Accuracy: 0.7876
# Epoch [4500/5000], Loss: 0.4540, Accuracy: 0.7869
# Epoch [5000/5000], Loss: 0.4521, Accuracy: 0.7873
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_35_acc_0.7873.pkl
# Final accuracy: 0.7873
# Parameter containing:
# tensor([[-0.5383,  1.5826],
#         [ 0.9450,  2.2983],
#         [ 2.0159,  1.1268]], requires_grad=True)
# Parameter containing:
# tensor([[-1.6732, -0.8220],
#         [-2.0071, -0.0430],
#         [-1.7555,  0.0274]], requires_grad=True)
#
# === Training with seed 36 ===
# initial loss =  0.7271508574485779
# Epoch [500/5000], Loss: 0.5172, Accuracy: 0.7415
# Epoch [1000/5000], Loss: 0.5108, Accuracy: 0.7421
# Epoch [1500/5000], Loss: 0.5053, Accuracy: 0.7386
# Epoch [2000/5000], Loss: 0.5048, Accuracy: 0.7357
# Epoch [2500/5000], Loss: 0.5048, Accuracy: 0.7350
# Epoch [3000/5000], Loss: 0.5048, Accuracy: 0.7348
# Epoch [3500/5000], Loss: 0.5048, Accuracy: 0.7349
# Epoch [4000/5000], Loss: 0.5048, Accuracy: 0.7349
# Epoch [4500/5000], Loss: 0.5048, Accuracy: 0.7349
# Epoch [5000/5000], Loss: 0.5048, Accuracy: 0.7349
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_36_acc_0.7349.pkl
# Final accuracy: 0.7349
# Parameter containing:
# tensor([[-1.6732, -0.8220],
#         [-2.0071, -0.0430],
#         [-1.7555,  0.0274]], requires_grad=True)
# Parameter containing:
# tensor([[-2.4866,  1.8835],
#         [-1.0201,  2.1632],
#         [ 1.9526,  0.5728]], requires_grad=True)
#
# === Training with seed 37 ===
# initial loss =  0.7647391557693481
# Epoch [500/5000], Loss: 0.4278, Accuracy: 0.8293
# Epoch [1000/5000], Loss: 0.3677, Accuracy: 0.8504
# Epoch [1500/5000], Loss: 0.3624, Accuracy: 0.8567
# Epoch [2000/5000], Loss: 0.3615, Accuracy: 0.8576
# Epoch [2500/5000], Loss: 0.3613, Accuracy: 0.8579
# Epoch [3000/5000], Loss: 0.3613, Accuracy: 0.8579
# Epoch [3500/5000], Loss: 0.3613, Accuracy: 0.8577
# Epoch [4000/5000], Loss: 0.3613, Accuracy: 0.8577
# Epoch [4500/5000], Loss: 0.3613, Accuracy: 0.8577
# Epoch [5000/5000], Loss: 0.3613, Accuracy: 0.8577
# *** NEW BEST MODEL: Seed 37, Accuracy 0.8577 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_37_acc_0.8577.pkl
# Final accuracy: 0.8577
# Parameter containing:
# tensor([[-2.4866,  1.8835],
#         [-1.0201,  2.1632],
#         [ 1.9526,  0.5728]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4195, -2.0027],
#         [ 2.1549,  2.1249],
#         [ 0.4685, -1.3043]], requires_grad=True)
#
# === Training with seed 38 ===
# initial loss =  3.191009998321533
# Epoch [500/5000], Loss: 0.7437, Accuracy: 0.5398
# Epoch [1000/5000], Loss: 0.6797, Accuracy: 0.6224
# Epoch [1500/5000], Loss: 0.6712, Accuracy: 0.6218
# Epoch [2000/5000], Loss: 0.6675, Accuracy: 0.6238
# Epoch [2500/5000], Loss: 0.6660, Accuracy: 0.6225
# Epoch [3000/5000], Loss: 0.6651, Accuracy: 0.6203
# Epoch [3500/5000], Loss: 0.6644, Accuracy: 0.6180
# Epoch [4000/5000], Loss: 0.6638, Accuracy: 0.6163
# Epoch [4500/5000], Loss: 0.6634, Accuracy: 0.6147
# Epoch [5000/5000], Loss: 0.6634, Accuracy: 0.6148
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_38_acc_0.6148.pkl
# Final accuracy: 0.6148
# Parameter containing:
# tensor([[-1.4195, -2.0027],
#         [ 2.1549,  2.1249],
#         [ 0.4685, -1.3043]], requires_grad=True)
# Parameter containing:
# tensor([[-0.8070,  2.3498],
#         [ 1.2417,  1.3437],
#         [ 0.1317,  1.3854]], requires_grad=True)
#
# === Training with seed 39 ===
# initial loss =  2.0501465797424316
# Epoch [500/5000], Loss: 0.5613, Accuracy: 0.7199
# Epoch [1000/5000], Loss: 0.4028, Accuracy: 0.8273
# Epoch [1500/5000], Loss: 0.3825, Accuracy: 0.8363
# Epoch [2000/5000], Loss: 0.3704, Accuracy: 0.8381
# Epoch [2500/5000], Loss: 0.3629, Accuracy: 0.8483
# Epoch [3000/5000], Loss: 0.3585, Accuracy: 0.8522
# Epoch [3500/5000], Loss: 0.3560, Accuracy: 0.8538
# Epoch [4000/5000], Loss: 0.3546, Accuracy: 0.8548
# Epoch [4500/5000], Loss: 0.3537, Accuracy: 0.8552
# Epoch [5000/5000], Loss: 0.3531, Accuracy: 0.8551
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_39_acc_0.8551.pkl
# Final accuracy: 0.8551
# Parameter containing:
# tensor([[-0.8070,  2.3498],
#         [ 1.2417,  1.3437],
#         [ 0.1317,  1.3854]], requires_grad=True)
# Parameter containing:
# tensor([[-1.9351,  0.8893],
#         [-2.4134, -1.8983],
#         [-1.8183,  1.5446]], requires_grad=True)
#
# === Training with seed 40 ===
# initial loss =  3.7044312953948975
# Epoch [500/5000], Loss: 0.7098, Accuracy: 0.5980
# Epoch [1000/5000], Loss: 0.6743, Accuracy: 0.6423
# Epoch [1500/5000], Loss: 0.6343, Accuracy: 0.6956
# Epoch [2000/5000], Loss: 0.5583, Accuracy: 0.7212
# Epoch [2500/5000], Loss: 0.5244, Accuracy: 0.7402
# Epoch [3000/5000], Loss: 0.5177, Accuracy: 0.7433
# Epoch [3500/5000], Loss: 0.5132, Accuracy: 0.7427
# Epoch [4000/5000], Loss: 0.5114, Accuracy: 0.7459
# Epoch [4500/5000], Loss: 0.5111, Accuracy: 0.7458
# Epoch [5000/5000], Loss: 0.5110, Accuracy: 0.7468
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_40_acc_0.7468.pkl
# Final accuracy: 0.7468
# Parameter containing:
# tensor([[-1.9351,  0.8893],
#         [-2.4134, -1.8983],
#         [-1.8183,  1.5446]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0579, -1.4615],
#         [-0.9683, -2.2074],
#         [ 1.6568, -0.2169]], requires_grad=True)
#
# === Training with seed 41 ===
# initial loss =  1.2620744705200195
# Epoch [500/5000], Loss: 0.5285, Accuracy: 0.7783
# Epoch [1000/5000], Loss: 0.4789, Accuracy: 0.7698
# Epoch [1500/5000], Loss: 0.4491, Accuracy: 0.7969
# Epoch [2000/5000], Loss: 0.3816, Accuracy: 0.8456
# Epoch [2500/5000], Loss: 0.3544, Accuracy: 0.8558
# Epoch [3000/5000], Loss: 0.3503, Accuracy: 0.8550
# Epoch [3500/5000], Loss: 0.3496, Accuracy: 0.8538
# Epoch [4000/5000], Loss: 0.3494, Accuracy: 0.8540
# Epoch [4500/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [5000/5000], Loss: 0.3494, Accuracy: 0.8539
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_41_acc_0.8539.pkl
# Final accuracy: 0.8539
# Parameter containing:
# tensor([[-0.0579, -1.4615],
#         [-0.9683, -2.2074],
#         [ 1.6568, -0.2169]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3695, -1.1671],
#         [ 0.6372, -1.1518],
#         [-0.2932, -1.0154]], requires_grad=True)
#
# === Training with seed 42 ===
# initial loss =  2.4197394847869873
# Epoch [500/5000], Loss: 0.6455, Accuracy: 0.6499
# Epoch [1000/5000], Loss: 0.5559, Accuracy: 0.7503
# Epoch [1500/5000], Loss: 0.5240, Accuracy: 0.7518
# Epoch [2000/5000], Loss: 0.4940, Accuracy: 0.7768
# Epoch [2500/5000], Loss: 0.4809, Accuracy: 0.7849
# Epoch [3000/5000], Loss: 0.4748, Accuracy: 0.7837
# Epoch [3500/5000], Loss: 0.4727, Accuracy: 0.7801
# Epoch [4000/5000], Loss: 0.4710, Accuracy: 0.7784
# Epoch [4500/5000], Loss: 0.4673, Accuracy: 0.7685
# Epoch [5000/5000], Loss: 0.4652, Accuracy: 0.7642
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_42_acc_0.7642.pkl
# Final accuracy: 0.7642
# Parameter containing:
# tensor([[ 0.3695, -1.1671],
#         [ 0.6372, -1.1518],
#         [-0.2932, -1.0154]], requires_grad=True)
# Parameter containing:
# tensor([[-1.1194,  1.6978],
#         [-1.7186, -1.9640],
#         [ 1.1307, -0.8797]], requires_grad=True)
#
# === Training with seed 43 ===
# initial loss =  3.5097808837890625
# Epoch [500/5000], Loss: 0.6460, Accuracy: 0.6681
# Epoch [1000/5000], Loss: 0.5328, Accuracy: 0.7460
# Epoch [1500/5000], Loss: 0.4322, Accuracy: 0.7864
# Epoch [2000/5000], Loss: 0.3918, Accuracy: 0.8309
# Epoch [2500/5000], Loss: 0.3770, Accuracy: 0.8414
# Epoch [3000/5000], Loss: 0.3716, Accuracy: 0.8445
# Epoch [3500/5000], Loss: 0.3687, Accuracy: 0.8448
# Epoch [4000/5000], Loss: 0.3669, Accuracy: 0.8445
# Epoch [4500/5000], Loss: 0.3661, Accuracy: 0.8452
# Epoch [5000/5000], Loss: 0.3658, Accuracy: 0.8457
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_43_acc_0.8457.pkl
# Final accuracy: 0.8457
# Parameter containing:
# tensor([[-1.1194,  1.6978],
#         [-1.7186, -1.9640],
#         [ 1.1307, -0.8797]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.0583,  1.4894],
#         [-1.1077,  1.9736],
#         [ 0.8469,  1.9750]], requires_grad=True)
#
# === Training with seed 44 ===
# initial loss =  0.8414294719696045
# Epoch [500/5000], Loss: 0.5459, Accuracy: 0.7289
# Epoch [1000/5000], Loss: 0.4699, Accuracy: 0.7842
# Epoch [1500/5000], Loss: 0.4674, Accuracy: 0.7843
# Epoch [2000/5000], Loss: 0.4596, Accuracy: 0.7915
# Epoch [2500/5000], Loss: 0.4574, Accuracy: 0.7916
# Epoch [3000/5000], Loss: 0.4554, Accuracy: 0.7928
# Epoch [3500/5000], Loss: 0.4542, Accuracy: 0.7926
# Epoch [4000/5000], Loss: 0.4538, Accuracy: 0.7925
# Epoch [4500/5000], Loss: 0.4537, Accuracy: 0.7924
# Epoch [5000/5000], Loss: 0.4537, Accuracy: 0.7924
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_44_acc_0.7924.pkl
# Final accuracy: 0.7924
# Parameter containing:
# tensor([[ 1.0583,  1.4894],
#         [-1.1077,  1.9736],
#         [ 0.8469,  1.9750]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.7641,  0.5614],
#         [ 2.4168, -1.5870],
#         [-1.8804, -0.3689]], requires_grad=True)
#
# === Training with seed 45 ===
# initial loss =  3.1400928497314453
# Epoch [500/5000], Loss: 0.5881, Accuracy: 0.7370
# Epoch [1000/5000], Loss: 0.5127, Accuracy: 0.7600
# Epoch [1500/5000], Loss: 0.4848, Accuracy: 0.7609
# Epoch [2000/5000], Loss: 0.4784, Accuracy: 0.7632
# Epoch [2500/5000], Loss: 0.4766, Accuracy: 0.7635
# Epoch [3000/5000], Loss: 0.4756, Accuracy: 0.7639
# Epoch [3500/5000], Loss: 0.4752, Accuracy: 0.7638
# Epoch [4000/5000], Loss: 0.4750, Accuracy: 0.7636
# Epoch [4500/5000], Loss: 0.4426, Accuracy: 0.7999
# Epoch [5000/5000], Loss: 0.4212, Accuracy: 0.8213
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_45_acc_0.8213.pkl
# Final accuracy: 0.8213
# Parameter containing:
# tensor([[ 0.7641,  0.5614],
#         [ 2.4168, -1.5870],
#         [-1.8804, -0.3689]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.5762, -0.0950],
#         [ 1.1940, -2.3440],
#         [ 1.0243,  1.1822]], requires_grad=True)
#
# === Training with seed 46 ===
# initial loss =  0.7779531478881836
# Epoch [500/5000], Loss: 0.5963, Accuracy: 0.6563
# Epoch [1000/5000], Loss: 0.5941, Accuracy: 0.6593
# Epoch [1500/5000], Loss: 0.5941, Accuracy: 0.6594
# Epoch [2000/5000], Loss: 0.5941, Accuracy: 0.6594
# Epoch [2500/5000], Loss: 0.5941, Accuracy: 0.6594
# Epoch [3000/5000], Loss: 0.5941, Accuracy: 0.6594
# Epoch [3500/5000], Loss: 0.5941, Accuracy: 0.6594
# Epoch [4000/5000], Loss: 0.5941, Accuracy: 0.6594
# Epoch [4500/5000], Loss: 0.5941, Accuracy: 0.6594
# Epoch [5000/5000], Loss: 0.5941, Accuracy: 0.6594
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_46_acc_0.6594.pkl
# Final accuracy: 0.6594
# Parameter containing:
# tensor([[ 1.5762, -0.0950],
#         [ 1.1940, -2.3440],
#         [ 1.0243,  1.1822]], requires_grad=True)
# Parameter containing:
# tensor([[-2.3247, -1.7888],
#         [-0.4718,  0.1703],
#         [ 0.4310, -1.7655]], requires_grad=True)
#
# === Training with seed 47 ===
# initial loss =  1.1568511724472046
# Epoch [500/5000], Loss: 0.5624, Accuracy: 0.7101
# Epoch [1000/5000], Loss: 0.5249, Accuracy: 0.7322
# Epoch [1500/5000], Loss: 0.5237, Accuracy: 0.7382
# Epoch [2000/5000], Loss: 0.5235, Accuracy: 0.7411
# Epoch [2500/5000], Loss: 0.5181, Accuracy: 0.7417
# Epoch [3000/5000], Loss: 0.4775, Accuracy: 0.7627
# Epoch [3500/5000], Loss: 0.4751, Accuracy: 0.7617
# Epoch [4000/5000], Loss: 0.4747, Accuracy: 0.7618
# Epoch [4500/5000], Loss: 0.4745, Accuracy: 0.7620
# Epoch [5000/5000], Loss: 0.4745, Accuracy: 0.7618
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_47_acc_0.7618.pkl
# Final accuracy: 0.7618
# Parameter containing:
# tensor([[-2.3247, -1.7888],
#         [-0.4718,  0.1703],
#         [ 0.4310, -1.7655]], requires_grad=True)
# ...
#
# === Training with seed 112 ===
# initial loss =  2.149278163909912
# Epoch [500/5000], Loss: 0.6388, Accuracy: 0.6401
# Epoch [1000/5000], Loss: 0.5086, Accuracy: 0.7673
# Epoch [1500/5000], Loss: 0.4814, Accuracy: 0.7619
# Epoch [2000/5000], Loss: 0.4762, Accuracy: 0.7623
# Epoch [2500/5000], Loss: 0.4748, Accuracy: 0.7614
# Epoch [3000/5000], Loss: 0.4745, Accuracy: 0.7612
# Epoch [3500/5000], Loss: 0.4744, Accuracy: 0.7616
# Epoch [4000/5000], Loss: 0.4744, Accuracy: 0.7620
# Epoch [4500/5000], Loss: 0.4744, Accuracy: 0.7622
# Epoch [5000/5000], Loss: 0.4744, Accuracy: 0.7625
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_112_acc_0.7625.pkl
# Final accuracy: 0.7625
# Parameter containing:
# tensor([[-1.9621,  2.1035],
#         [-0.6268,  0.7717],
#         [-1.1279, -1.5649]], requires_grad=True)
# Parameter containing:
# tensor([[-1.5887, -1.1632],
#         [-1.5349, -0.6701],
#         [-0.6787,  0.5087]], requires_grad=True)
#
# === Training with seed 113 ===
# initial loss =  4.719916820526123
# Epoch [500/5000], Loss: 0.6802, Accuracy: 0.5688
# Epoch [1000/5000], Loss: 0.6675, Accuracy: 0.6212
# Epoch [1500/5000], Loss: 0.6654, Accuracy: 0.6207
# Epoch [2000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [2500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [3000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [3500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [4000/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [4500/5000], Loss: 0.6634, Accuracy: 0.6148
# Epoch [5000/5000], Loss: 0.6634, Accuracy: 0.6148
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_113_acc_0.6148.pkl
# Final accuracy: 0.6148
# Parameter containing:
# tensor([[-1.5887, -1.1632],
#         [-1.5349, -0.6701],
#         [-0.6787,  0.5087]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.8925,  1.0306],
#         [-1.1163,  1.8007],
#         [ 0.4109, -1.5366]], requires_grad=True)
#
# === Training with seed 114 ===
# initial loss =  2.8877646923065186
# Epoch [500/5000], Loss: 0.6613, Accuracy: 0.5724
# Epoch [1000/5000], Loss: 0.5928, Accuracy: 0.7440
# Epoch [1500/5000], Loss: 0.5703, Accuracy: 0.7746
# Epoch [2000/5000], Loss: 0.5591, Accuracy: 0.7695
# Epoch [2500/5000], Loss: 0.4979, Accuracy: 0.7603
# Epoch [3000/5000], Loss: 0.4811, Accuracy: 0.7622
# Epoch [3500/5000], Loss: 0.4774, Accuracy: 0.7621
# Epoch [4000/5000], Loss: 0.4761, Accuracy: 0.7620
# Epoch [4500/5000], Loss: 0.4754, Accuracy: 0.7618
# Epoch [5000/5000], Loss: 0.4750, Accuracy: 0.7618
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_114_acc_0.7618.pkl
# Final accuracy: 0.7618
# Parameter containing:
# tensor([[ 1.8925,  1.0306],
#         [-1.1163,  1.8007],
#         [ 0.4109, -1.5366]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.6824,  2.0728],
#         [-0.1736, -1.7333],
#         [ 2.0311,  2.2711]], requires_grad=True)
#
# === Training with seed 115 ===
# initial loss =  1.7807166576385498
# Epoch [500/5000], Loss: 0.6413, Accuracy: 0.6412
# Epoch [1000/5000], Loss: 0.6235, Accuracy: 0.6775
# Epoch [1500/5000], Loss: 0.5625, Accuracy: 0.7534
# Epoch [2000/5000], Loss: 0.4647, Accuracy: 0.7861
# Epoch [2500/5000], Loss: 0.4569, Accuracy: 0.7861
# Epoch [3000/5000], Loss: 0.4544, Accuracy: 0.7910
# Epoch [3500/5000], Loss: 0.4525, Accuracy: 0.7944
# Epoch [4000/5000], Loss: 0.4508, Accuracy: 0.7967
# Epoch [4500/5000], Loss: 0.4496, Accuracy: 0.7974
# Epoch [5000/5000], Loss: 0.4487, Accuracy: 0.7984
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_115_acc_0.7984.pkl
# Final accuracy: 0.7984
# Parameter containing:
# tensor([[ 0.6824,  2.0728],
#         [-0.1736, -1.7333],
#         [ 2.0311,  2.2711]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3271, -1.6492],
#         [-1.8422,  0.2030],
#         [ 2.4939,  1.4096]], requires_grad=True)
#
# === Training with seed 116 ===
# initial loss =  2.7031912803649902
# Epoch [500/5000], Loss: 0.7308, Accuracy: 0.4262
# Epoch [1000/5000], Loss: 0.6673, Accuracy: 0.5596
# Epoch [1500/5000], Loss: 0.6407, Accuracy: 0.6117
# Epoch [2000/5000], Loss: 0.6293, Accuracy: 0.6276
# Epoch [2500/5000], Loss: 0.6226, Accuracy: 0.6255
# Epoch [3000/5000], Loss: 0.6171, Accuracy: 0.6201
# Epoch [3500/5000], Loss: 0.6113, Accuracy: 0.6223
# Epoch [4000/5000], Loss: 0.6067, Accuracy: 0.6280
# Epoch [4500/5000], Loss: 0.6036, Accuracy: 0.6309
# Epoch [5000/5000], Loss: 0.6018, Accuracy: 0.6319
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_116_acc_0.6319.pkl
# Final accuracy: 0.6319
# Parameter containing:
# tensor([[ 0.3271, -1.6492],
#         [-1.8422,  0.2030],
#         [ 2.4939,  1.4096]], requires_grad=True)
# Parameter containing:
# tensor([[-0.2180, -2.3421],
#         [ 1.4697, -2.4124],
#         [-2.0118, -0.4292]], requires_grad=True)
#
# === Training with seed 117 ===
# initial loss =  0.5640829801559448
# Epoch [500/5000], Loss: 0.4089, Accuracy: 0.8088
# Epoch [1000/5000], Loss: 0.3991, Accuracy: 0.8104
# Epoch [1500/5000], Loss: 0.3985, Accuracy: 0.8102
# Epoch [2000/5000], Loss: 0.3985, Accuracy: 0.8097
# Epoch [2500/5000], Loss: 0.3985, Accuracy: 0.8098
# Epoch [3000/5000], Loss: 0.3985, Accuracy: 0.8098
# Epoch [3500/5000], Loss: 0.3985, Accuracy: 0.8098
# Epoch [4000/5000], Loss: 0.3985, Accuracy: 0.8098
# Epoch [4500/5000], Loss: 0.3985, Accuracy: 0.8098
# Epoch [5000/5000], Loss: 0.3985, Accuracy: 0.8098
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_117_acc_0.8098.pkl
# Final accuracy: 0.8098
# Parameter containing:
# tensor([[-0.2180, -2.3421],
#         [ 1.4697, -2.4124],
#         [-2.0118, -0.4292]], requires_grad=True)
# Parameter containing:
# tensor([[-0.1078, -2.4460],
#         [ 2.1452,  2.3434],
#         [ 0.5511, -1.8756]], requires_grad=True)
#
# === Training with seed 118 ===
# initial loss =  1.054875373840332
# Epoch [500/5000], Loss: 0.5482, Accuracy: 0.6875
# Epoch [1000/5000], Loss: 0.4474, Accuracy: 0.7983
# Epoch [1500/5000], Loss: 0.4192, Accuracy: 0.8351
# Epoch [2000/5000], Loss: 0.3779, Accuracy: 0.8492
# Epoch [2500/5000], Loss: 0.3727, Accuracy: 0.8488
# Epoch [3000/5000], Loss: 0.3709, Accuracy: 0.8481
# Epoch [3500/5000], Loss: 0.3697, Accuracy: 0.8493
# Epoch [4000/5000], Loss: 0.3693, Accuracy: 0.8490
# Epoch [4500/5000], Loss: 0.3692, Accuracy: 0.8487
# Epoch [5000/5000], Loss: 0.3692, Accuracy: 0.8488
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_118_acc_0.8488.pkl
# Final accuracy: 0.8488
# Parameter containing:
# tensor([[-0.1078, -2.4460],
#         [ 2.1452,  2.3434],
#         [ 0.5511, -1.8756]], requires_grad=True)
# Parameter containing:
# tensor([[-0.6805, -1.8942],
#         [-1.1642, -1.2139],
#         [ 2.4210, -1.6382]], requires_grad=True)
#
# === Training with seed 119 ===
# initial loss =  0.9546051025390625
# Epoch [500/5000], Loss: 0.4793, Accuracy: 0.7751
# Epoch [1000/5000], Loss: 0.4749, Accuracy: 0.7758
# Epoch [1500/5000], Loss: 0.4746, Accuracy: 0.7754
# Epoch [2000/5000], Loss: 0.4741, Accuracy: 0.7752
# Epoch [2500/5000], Loss: 0.4741, Accuracy: 0.7753
# Epoch [3000/5000], Loss: 0.4741, Accuracy: 0.7752
# Epoch [3500/5000], Loss: 0.4741, Accuracy: 0.7752
# Epoch [4000/5000], Loss: 0.4741, Accuracy: 0.7752
# Epoch [4500/5000], Loss: 0.4741, Accuracy: 0.7752
# Epoch [5000/5000], Loss: 0.4741, Accuracy: 0.7752
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_119_acc_0.7752.pkl
# Final accuracy: 0.7752
# Parameter containing:
# tensor([[-0.6805, -1.8942],
#         [-1.1642, -1.2139],
#         [ 2.4210, -1.6382]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.1178, -2.4086],
#         [ 1.9563, -1.6790],
#         [-1.4510, -2.4885]], requires_grad=True)
#
# === Training with seed 120 ===
# initial loss =  1.6741443872451782
# Epoch [500/5000], Loss: 0.6192, Accuracy: 0.6204
# Epoch [1000/5000], Loss: 0.4103, Accuracy: 0.8272
# Epoch [1500/5000], Loss: 0.3653, Accuracy: 0.8527
# Epoch [2000/5000], Loss: 0.3545, Accuracy: 0.8545
# Epoch [2500/5000], Loss: 0.3512, Accuracy: 0.8547
# Epoch [3000/5000], Loss: 0.3500, Accuracy: 0.8537
# Epoch [3500/5000], Loss: 0.3496, Accuracy: 0.8536
# Epoch [4000/5000], Loss: 0.3494, Accuracy: 0.8540
# Epoch [4500/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [5000/5000], Loss: 0.3494, Accuracy: 0.8539
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_120_acc_0.8539.pkl
# Final accuracy: 0.8539
# Parameter containing:
# tensor([[ 1.1178, -2.4086],
#         [ 1.9563, -1.6790],
#         [-1.4510, -2.4885]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7093,  2.3840],
#         [-2.1582,  1.9357],
#         [-1.9528, -0.4935]], requires_grad=True)
#
# === Training with seed 121 ===
# initial loss =  0.8400927782058716
# Epoch [500/5000], Loss: 0.5928, Accuracy: 0.6329
# Epoch [1000/5000], Loss: 0.4915, Accuracy: 0.7625
# Epoch [1500/5000], Loss: 0.4778, Accuracy: 0.7618
# Epoch [2000/5000], Loss: 0.4756, Accuracy: 0.7618
# Epoch [2500/5000], Loss: 0.4750, Accuracy: 0.7617
# Epoch [3000/5000], Loss: 0.4747, Accuracy: 0.7618
# Epoch [3500/5000], Loss: 0.4746, Accuracy: 0.7619
# Epoch [4000/5000], Loss: 0.4745, Accuracy: 0.7619
# Epoch [4500/5000], Loss: 0.4745, Accuracy: 0.7620
# Epoch [5000/5000], Loss: 0.4744, Accuracy: 0.7621
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_121_acc_0.7621.pkl
# Final accuracy: 0.7621
# Parameter containing:
# tensor([[-1.7093,  2.3840],
#         [-2.1582,  1.9357],
#         [-1.9528, -0.4935]], requires_grad=True)
# Parameter containing:
# tensor([[-2.2180,  1.1854],
#         [ 1.7868,  0.1466],
#         [ 1.1935, -1.6323]], requires_grad=True)
#
# === Training with seed 122 ===
# initial loss =  10.03594970703125
# Epoch [500/5000], Loss: 0.8510, Accuracy: 0.5000
# Epoch [1000/5000], Loss: 0.6639, Accuracy: 0.6090
# Epoch [1500/5000], Loss: 0.6631, Accuracy: 0.6097
# Epoch [2000/5000], Loss: 0.6529, Accuracy: 0.6150
# Epoch [2500/5000], Loss: 0.5836, Accuracy: 0.7074
# Epoch [3000/5000], Loss: 0.5233, Accuracy: 0.7568
# Epoch [3500/5000], Loss: 0.4951, Accuracy: 0.7631
# Epoch [4000/5000], Loss: 0.4852, Accuracy: 0.7627
# Epoch [4500/5000], Loss: 0.4809, Accuracy: 0.7618
# Epoch [5000/5000], Loss: 0.4784, Accuracy: 0.7616
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_122_acc_0.7616.pkl
# Final accuracy: 0.7616
# Parameter containing:
# tensor([[-2.2180,  1.1854],
#         [ 1.7868,  0.1466],
#         [ 1.1935, -1.6323]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.6370, -0.5896],
#         [ 0.8025,  1.7679],
#         [ 0.4658,  0.6836]], requires_grad=True)
#
# === Training with seed 123 ===
# initial loss =  1.783583402633667
# Epoch [500/5000], Loss: 0.6167, Accuracy: 0.6232
# Epoch [1000/5000], Loss: 0.5226, Accuracy: 0.7770
# Epoch [1500/5000], Loss: 0.4483, Accuracy: 0.8278
# Epoch [2000/5000], Loss: 0.4291, Accuracy: 0.8324
# Epoch [2500/5000], Loss: 0.3884, Accuracy: 0.8494
# Epoch [3000/5000], Loss: 0.3751, Accuracy: 0.8518
# Epoch [3500/5000], Loss: 0.3723, Accuracy: 0.8518
# Epoch [4000/5000], Loss: 0.3704, Accuracy: 0.8482
# Epoch [4500/5000], Loss: 0.3678, Accuracy: 0.8466
# Epoch [5000/5000], Loss: 0.3662, Accuracy: 0.8458
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_123_acc_0.8458.pkl
# Final accuracy: 0.8458
# Parameter containing:
# tensor([[ 1.6370, -0.5896],
#         [ 0.8025,  1.7679],
#         [ 0.4658,  0.6836]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0146,  0.7972],
#         [ 1.9645, -0.6595],
#         [-0.9666, -0.1287]], requires_grad=True)
#
# === Training with seed 124 ===
# initial loss =  1.5084370374679565
# Epoch [500/5000], Loss: 0.5406, Accuracy: 0.7267
# Epoch [1000/5000], Loss: 0.4274, Accuracy: 0.8337
# Epoch [1500/5000], Loss: 0.3590, Accuracy: 0.8568
# Epoch [2000/5000], Loss: 0.3516, Accuracy: 0.8551
# Epoch [2500/5000], Loss: 0.3498, Accuracy: 0.8540
# Epoch [3000/5000], Loss: 0.3495, Accuracy: 0.8541
# Epoch [3500/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [4000/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [4500/5000], Loss: 0.3494, Accuracy: 0.8539
# Epoch [5000/5000], Loss: 0.3494, Accuracy: 0.8539
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_124_acc_0.8539.pkl
# Final accuracy: 0.8539
# Parameter containing:
# tensor([[ 0.0146,  0.7972],
#         [ 1.9645, -0.6595],
#         [-0.9666, -0.1287]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.0365,  2.3633],
#         [-0.4849, -2.4662],
#         [-2.4124, -2.2552]], requires_grad=True)
#
# === Training with seed 125 ===
# initial loss =  4.331989288330078
# Epoch [500/5000], Loss: 0.8070, Accuracy: 0.4719
# Epoch [1000/5000], Loss: 0.5794, Accuracy: 0.7145
# Epoch [1500/5000], Loss: 0.5186, Accuracy: 0.7407
# Epoch [2000/5000], Loss: 0.5130, Accuracy: 0.7429
# Epoch [2500/5000], Loss: 0.5118, Accuracy: 0.7446
# Epoch [3000/5000], Loss: 0.5114, Accuracy: 0.7449
# Epoch [3500/5000], Loss: 0.5112, Accuracy: 0.7459
# Epoch [4000/5000], Loss: 0.5111, Accuracy: 0.7460
# Epoch [4500/5000], Loss: 0.5091, Accuracy: 0.7463
# Epoch [5000/5000], Loss: 0.4532, Accuracy: 0.7752
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_125_acc_0.7752.pkl
# Final accuracy: 0.7752
# Parameter containing:
# tensor([[ 2.0365,  2.3633],
#         [-0.4849, -2.4662],
#         [-2.4124, -2.2552]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7817, -0.0225],
#         [-2.4355, -0.8113],
#         [-1.7391, -0.5384]], requires_grad=True)
#
# === Training with seed 126 ===
# initial loss =  1.4845587015151978
# Epoch [500/5000], Loss: 0.5919, Accuracy: 0.7054
# Epoch [1000/5000], Loss: 0.4941, Accuracy: 0.7582
# Epoch [1500/5000], Loss: 0.4803, Accuracy: 0.7608
# Epoch [2000/5000], Loss: 0.4772, Accuracy: 0.7621
# Epoch [2500/5000], Loss: 0.4761, Accuracy: 0.7619
# Epoch [3000/5000], Loss: 0.4755, Accuracy: 0.7619
# Epoch [3500/5000], Loss: 0.4752, Accuracy: 0.7616
# Epoch [4000/5000], Loss: 0.4749, Accuracy: 0.7618
# Epoch [4500/5000], Loss: 0.4748, Accuracy: 0.7618
# Epoch [5000/5000], Loss: 0.4746, Accuracy: 0.7620
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_126_acc_0.7620.pkl
# Final accuracy: 0.7620
# Parameter containing:
# tensor([[-1.7817, -0.0225],
#         [-2.4355, -0.8113],
#         [-1.7391, -0.5384]], requires_grad=True)
# Parameter containing:
# tensor([[-1.5422, -2.2576],
#         [-1.0535,  2.3860],
#         [ 2.3552,  1.7956]], requires_grad=True)
#
# === Training with seed 127 ===
# initial loss =  1.7518490552902222
# Epoch [500/5000], Loss: 0.6284, Accuracy: 0.6679
# Epoch [1000/5000], Loss: 0.6101, Accuracy: 0.6635
# Epoch [1500/5000], Loss: 0.5846, Accuracy: 0.6905
# Epoch [2000/5000], Loss: 0.5561, Accuracy: 0.7131
# Epoch [2500/5000], Loss: 0.5421, Accuracy: 0.7258
# Epoch [3000/5000], Loss: 0.5370, Accuracy: 0.7317
# Epoch [3500/5000], Loss: 0.5348, Accuracy: 0.7311
# Epoch [4000/5000], Loss: 0.5336, Accuracy: 0.7310
# Epoch [4500/5000], Loss: 0.5330, Accuracy: 0.7318
# Epoch [5000/5000], Loss: 0.5327, Accuracy: 0.7319
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/training_data_seed_127_acc_0.7319.pkl
# Final accuracy: 0.7319
# Parameter containing:
# tensor([[-1.5422, -2.2576],
#         [-1.0535,  2.3860],
#         [ 2.3552,  1.7956]], requires_grad=True)
#
# === FINAL RESULTS ===
# Best model: Seed 37, Accuracy 0.8577
# Worst model: Seed 10, Accuracy 0.5000
# Best/worst model data saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/best_worst_models.pkl

# %%
print(f"\n=== FINAL RESULTS ===")
print(f"Best model: Seed {best_model_data['seed']}, Accuracy {best_model_data['accuracy']:.4f}")
print(f"Worst model: Seed {worst_model_data['seed']}, Accuracy {worst_model_data['accuracy']:.4f}")
print(f"Best/worst model data saved to: {best_worst_filename}")
# Out:
# === FINAL RESULTS ===
# Best model: Seed 37, Accuracy 0.8577
# Worst model: Seed 10, Accuracy 0.5000
# Best/worst model data saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/best_worst_models.pkl

# %%
def load_best_worst_data(filepath):
    """Load the best and worst model data"""
    with open(filepath, 'rb') as f:
        data = pickle.load(f)
    return data['best_model'], data['worst_model']

def interpolate_weights(weights1, weights2, alpha):
    """
    Interpolate between two weight dictionaries
    alpha = 0: returns weights1
    alpha = 1: returns weights2
    """
    interpolated = {}
    for name in weights1.keys():
        interpolated[name] = (1 - alpha) * weights1[name] + alpha * weights2[name]
    return interpolated

def set_model_weights(model, weight_dict):
    """Set model parameters from weight dictionary"""
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = weight_dict[name]

def compute_loss_at_point(model, X_tensor, y_tensor, criterion):
    """Compute loss at current model parameters"""
    with torch.no_grad():
        outputs = model(X_tensor)
        loss = criterion(outputs, y_tensor)
        return loss.item()

def create_loss_landscape_2d(best_model_data, worst_model_data, X_tensor, y_tensor, 
                           model_class, model_args, resolution=50, output_dir=None):
    """
    Create 2D loss landscape visualization
    
    Dimension 1 (x-axis): Best model initial -> Best model final
    Dimension 2 (y-axis): Worst model initial -> Best model final
    """
    
    # Create a fresh model for evaluation
    model = model_class(model_args)
    criterion = torch.nn.CrossEntropyLoss()
    
    # Create interpolation grids
    alphas = np.linspace(0, 1, resolution)
    betas = np.linspace(0, 1, resolution)
    
    # Initialize loss landscape
    loss_landscape = np.zeros((resolution, resolution))
    
    print("Computing loss landscape...")
    
    for i, alpha in enumerate(alphas):
        for j, beta in enumerate(betas):
            # Create a proper 2D interpolation grid
            # We want to interpolate between 4 corner points:
            # (0,0) = best_initial
            # (1,0) = best_final  
            # (0,1) = worst_initial
            # (1,1) = worst_final
            
            # Use bilinear interpolation
            # First interpolate along the bottom edge (beta=0): best_initial -> best_final
            bottom_edge = interpolate_weights(
                best_model_data['initial_params'],
                best_model_data['final_params'], 
                alpha
            )
            
            # Then interpolate along the top edge (beta=1): worst_initial -> best_final
            top_edge = interpolate_weights(
                worst_model_data['initial_params'],
                # best_model_data['final_params'],
                worst_model_data['final_params'], #SW Mod
                alpha
            )
            
            # Finally interpolate between bottom and top edges
            final_weights = interpolate_weights(bottom_edge, top_edge, beta)
            
            # Set model weights and compute loss
            set_model_weights(model, final_weights)
            loss = compute_loss_at_point(model, X_tensor, y_tensor, criterion)
            loss_landscape[j, i] = loss
        
        if i % 10 == 0:
            print(f"Progress: {i}/{resolution}")
    
    # Create the visualization
    plt.figure(figsize=(12, 10))
    
    # Create contour plot
    X, Y = np.meshgrid(alphas, betas)
    contour = plt.contour(X, Y, loss_landscape, levels=20, colors='black', alpha=0.6, linewidths=0.8)
    contourf = plt.contourf(X, Y, loss_landscape, levels=50, cmap='viridis', alpha=0.8)
    
    # Add colorbar
    cbar = plt.colorbar(contourf)
    cbar.set_label('Loss', fontsize=12)
    
    # Add contour labels
    plt.clabel(contour, inline=True, fontsize=8, fmt='%.3f')
    
    # Mark key points
    plt.plot(0, 0, 'ro', markersize=10, label=f'Best Initial (Acc: {best_model_data["accuracy"]:.3f})')
    plt.plot(1, 0, 'go', markersize=10, label=f'Best Final (Acc: {best_model_data["accuracy"]:.3f})')  
    plt.plot(0, 1, 'bo', markersize=10, label=f'Worst Initial (Acc: {worst_model_data["accuracy"]:.3f})')
    plt.plot(1, 1, 'go', markersize=8, alpha=0.7)  # Same as best final
    
    # Add arrows to show the training trajectories
    plt.annotate('', xy=(1, 0), xytext=(0, 0), 
                arrowprops=dict(arrowstyle='->', color='red', lw=2, alpha=0.7),
                label='Best model training path')
    
    # Labels and title
    plt.xlabel('Best Model: Initial → Final', fontsize=12)
    plt.ylabel('Worst Initial → Best Final', fontsize=12)
    plt.title('2D Loss Landscape\nInterpolating Between Key Weight Configurations', fontsize=14)
    
    # Legend
    plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
    
    # Grid
    plt.grid(True, alpha=0.3)
    
    # Tight layout
    plt.tight_layout()
    
    # Save if output directory specified
    if output_dir:
        viz_path = os.path.join(output_dir, 'loss_landscape_2d.png')
        plt.savefig(viz_path, dpi=300, bbox_inches='tight')
        print(f"Loss landscape saved to: {viz_path}")
    
    plt.show()
    
    return loss_landscape, alphas, betas

# %%
loss_landscape, alphas, betas = create_loss_landscape_2d(
    best_model_data, 
    worst_model_data, 
    X_tensor, 
    y_tensor,
    BaarleNet,  # Your model class
    [3],        # Your model args
    resolution=50,
    output_dir=output_dir
)
# Out:
# Computing loss landscape...
# Progress: 0/50
# Progress: 10/50
# Progress: 20/50
# Progress: 30/50
# Progress: 40/50
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_15892/3818586867.py:121: UserWarning: Legend does not support handles for Annotation instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
# Loss landscape saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/loss_landscape_2d.png

# %% [markdown]
# - Hey that's kinda what I wanted -> right? Can I just do this?
# - Maybe changing my weight initialization helped here?

# %%
all_training_data[0].keys()
# Out:
# dict_keys(['seed', 'weights_history', 'gradients_history', 'xy_history', 'loss_history', 'accuracy_history', 'initial_params', 'final_accuracy', 'final_model_state', 'final_params'])

# %%
final_accuracies=np.array([t['final_accuracy'] for t in all_training_data])
sI=np.argsort(final_accuracies)

# %%
final_accuracies[sI[:5]]
# Out:
# array([0.5   , 0.5   , 0.6148, 0.6148, 0.6148])

# %%
sI[:5]
# Out:
# array([ 10, 107,  38,  73, 113])

# %%
i=32

# %%
worst_model_data_2 = {
    'accuracy': all_training_data[i]['final_accuracy'],
    'seed': all_training_data[i]['seed'],
    'initial_params': all_training_data[i]['initial_params'],
    'final_params': all_training_data[i]['final_params']
}

# %%
worst_model_data_2
# Out:
# {'accuracy': 0.6148,
#  'seed': 32,
#  'initial_params': {'model.0.weight': tensor([[-2.0436,  1.0884],
#           [ 1.1356, -0.0163],
#           [ 2.1537, -0.6616]]),
#   'model.0.bias': tensor([-1.4756,  0.8232, -0.5568]),
#   'model.2.weight': tensor([[-2.1067, -1.7767, -1.5956],
#           [ 0.7198, -1.7480,  1.1402]]),
#   'model.2.bias': tensor([ 1.9336, -1.0143])},
#  'final_params': {'model.0.weight': tensor([[-1.5055,  0.5125],
#           [-0.1383, -0.7519],
#           [ 1.3480,  0.0101]]),
#   'model.0.bias': tensor([-2.0046,  1.5785, -1.3464]),
#   'model.2.weight': tensor([[-1.8057, -2.3696, -1.1190],
#           [ 0.4188, -1.1551,  0.6636]]),
#   'model.2.bias': tensor([ 1.4521, -0.5329])}}

# %%
loss_landscape, alphas, betas = create_loss_landscape_2d(
    best_model_data, 
    worst_model_data_2, 
    X_tensor, 
    y_tensor,
    BaarleNet,  # Your model class
    [3],        # Your model args
    resolution=50,
    output_dir=output_dir
)
# Out:
# Computing loss landscape...
# Progress: 0/50
# Progress: 10/50
# Progress: 20/50
# Progress: 30/50
# Progress: 40/50
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_15892/3818586867.py:121: UserWarning: Legend does not support handles for Annotation instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
# Loss landscape saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_5/loss_landscape_2d.png

# %%
worst_model_data
# Out:
# {'accuracy': 0.5,
#  'seed': 10,
#  'initial_params': {'model.0.weight': tensor([[-0.0884,  0.5750],
#           [-0.0163, -0.2394],
#           [-2.2124, -2.1565]]),
#   'model.0.bias': tensor([-2.2496, -2.4462, -2.3284]),
#   'model.2.weight': tensor([[-1.8939, -2.2548, -2.3452],
#           [ 1.0959,  1.5334,  1.6893]]),
#   'model.2.bias': tensor([1.3468, 0.8471])},
#  'final_params': {'model.0.weight': tensor([[-0.0884,  0.5750],
#           [-0.0163, -0.2394],
#           [-1.5348, -1.4751]]),
#   'model.0.bias': tensor([-2.2496, -2.4462, -2.9542]),
#   'model.2.weight': tensor([[-1.8939, -2.2548, -1.9656],
#           [ 1.0959,  1.5334,  1.3098]]),
#   'model.2.bias': tensor([1.0970, 1.0970])}}
