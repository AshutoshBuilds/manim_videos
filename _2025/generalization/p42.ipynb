# %% [markdown]
# # P42

# %%
import tensorflow as tf
import pickle

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable

from tqdm.auto import tqdm
import pandas as pd

# import tensorflow.gfile as gfile
# from tensorflow.gfile import Glob
import pickle
# Out:
# 2025-10-10 06:02:25.915405: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
fn='/home/stephen/double_descent/cifar10-resnet18k-50k-adam/dd_cifar10-resnet18k-50k-adam_Mlist'
with tf.io.gfile.GFile(fn, "rb") as file:
    Ms = pickle.load(file)

fn='/home/stephen/double_descent/cifar10-resnet18k-50k-adam/dd_cifar10-resnet18k-50k-adam_ks'
with tf.io.gfile.GFile(fn, "rb") as file:
    ks = pickle.load(file)

# %%
Ms[2]['Train Error'].shape
# Out:
# (64, 3999)

# %%
plt.clf()
fig=plt.figure(0,(12,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(Ms[1]['Train Error'][-1, :], alpha=0.9, c=CHILL_BROWN, linewidth=2);
plt.plot(Ms[1]['Test Error'][-1, :], alpha=0.9, c=YELLOW, linewidth=2);
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')

# %%
save_dir='/home/stephen/double_descent/p42'

for i in tqdm(range(Ms[1]['Test Error'].shape[1]-1)):
    plt.clf()
    fig=plt.figure(0,(12,6), facecolor='k') 
    ax=fig.add_subplot(111, facecolor='k')
    plt.plot(Ms[1]['Train Error'][-1, :i+1], alpha=0.9, c=CHILL_BROWN, linewidth=2);
    plt.plot(Ms[1]['Test Error'][-1, :i+1], alpha=0.9, c=YELLOW, linewidth=2);
    plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
    plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here
    
    plt.gca().spines['top'].set_color('#948979')
    plt.gca().spines['bottom'].set_color('#948979')
    plt.gca().spines['left'].set_color('#948979')
    plt.gca().spines['right'].set_color('#948979')

    plt.savefig(save_dir+'/'+str(i).zfill(4)+'.png', dpi=250, transparent=True)
# Out:
#   0%|          | 0/3998 [00:00<?, ?it/s]
# /tmp/ipykernel_821008/4101362978.py:5: UserWarning: Ignoring specified arguments in this call because figure with num: 0 already exists
#   fig=plt.figure(0,(12,6), facecolor='k')

# %%
# for i in tqdm(range(len(training_cache['loss_history']))):
#     plt.clf()
#     to_plot=training_cache['loss_history'][:i]
    
#     fig=plt.figure(0,(24,2), facecolor='k') 
#     ax=fig.add_subplot(111, facecolor='k')
#     # plt.plot(np.log(training_cache['loss_history']), c=CHILL_BROWN) #'#dfd0b9')
#     plt.plot(to_plot, c=CHILL_BROWN, linewidth=3, alpha=0.95) #'#dfd0b9')
#     plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
#     plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here
    
#     plt.gca().spines['top'].set_color('#948979')
#     plt.gca().spines['bottom'].set_color('#948979')
#     plt.gca().spines['left'].set_color('#948979')
#     plt.gca().spines['right'].set_color('#948979')
#     plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
#     # plt.xlim([-10, len(to_plot)+10])
#     plt.savefig(save_dir+'/'+str(i).zfill(4)+'.png', dpi=250, transparent=True)

# %%
plt.plot(Ms[1]['Test Error'][-1, :], alpha=0.8);
plt.plot(Ms[1]['Train Error'][-1, :], alpha=0.8);

# %%
plt.plot(Ms[2]['Test Error'][-1, :], alpha=0.8);

# %%
plt.plot(Ms[1]['Test Error'][-1, :], alpha=0.8);
plt.xscale('log')

# %%
plt.plot(Ms[0]['Test Error'][-1, :], alpha=0.8);
