# %% [markdown]
# # BaarleNet [Part 7d - more loss landscapes]

# %%
import numpy as np
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import torch.optim as optim
import cv2
from matplotlib.gridspec import GridSpec
from tqdm import tqdm
import os

# %%
def denorm(p, size=960):
    result = np.zeros_like(p)
    result[..., 0] = (p[..., 0] + 1) * (size / 2)
    result[..., 1] = size - ((p[..., 1] + 1) * (size / 2))
    return result

def get_relu_joint(weight_1, weight_2, bias, extent=1):
    if np.abs(weight_2) < 1e-8: 
        x_intercept = -bias / weight_1
        return [[x_intercept, -extent], [x_intercept, extent]] if -extent <= x_intercept <= extent else []
    elif np.abs(weight_1) < 1e-8:
        y_intercept = -bias / weight_2
        return [[-extent, y_intercept], [extent, y_intercept]] if -extent <= y_intercept <= extent else []
    else:
        points = []
        for x in [-extent, extent]:
            y = (-x * weight_1 - bias) / weight_2
            if -extent <= y <= extent: points.append([x, y])
        for y in [-extent, extent]:
            x = (-y * weight_2 - bias) / weight_1
            if -extent <= x <= extent: points.append([x, y])
        unique_points = []
        for p in points:
            is_duplicate = False
            for existing in unique_points:
                if abs(p[0] - existing[0]) < 1e-8 and abs(p[1] - existing[1]) < 1e-8:
                    is_duplicate = True
                    break
            if not is_duplicate:
                unique_points.append(p)
        return unique_points

def viz_map_with_predictions(ax, map, X, y):
    probe=np.zeros((100,100,2))
    for j, xx in enumerate(np.linspace(-1, 1, 100)):
        for k, yy in enumerate(np.linspace(-1, 1, 100)):
            probe[j, k]=[yy,xx]
    probe=probe.reshape(100**2, -1)
    probe_logits=model(torch.tensor(probe).float())
    probe_logits=probe_logits.detach().numpy().reshape(100,100,2)
    probe_softmax = torch.nn.Softmax(dim=1)(torch.tensor(probe_logits.reshape(-1, 2)))
    
    ax.imshow(map.mean(2), cmap='gray')
    ax.imshow(np.flipud(probe_softmax[:,1].reshape(100, 100)), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')
    
    X_denorm=denorm(X[:1000,:])
    # plt.scatter(X_denorm[:,0], X_denorm[:,1], c=y[:1000], s=2, alpha=0.8)
    labels=y[:1000]
    y_hat=torch.argmax(model(torch.tensor(X[:1000,:]).float()).detach(),1).numpy()
    tp_mask=np.logical_and(labels==1, y_hat==1)
    fp_mask=np.logical_and(labels==0, y_hat==1)
    fn_mask=np.logical_and(labels==1, y_hat==0)
    tn_mask=np.logical_and(labels==0, y_hat==0)
    ax.scatter(X_denorm[tp_mask,0], X_denorm[tp_mask,1], c='g', s=3, alpha=0.8)
    ax.scatter(X_denorm[fp_mask,0], X_denorm[fp_mask,1], c='r', marker='x', s=5, alpha=0.8)
    ax.scatter(X_denorm[fn_mask,0], X_denorm[fn_mask,1], c='orange', marker='x', s=5, alpha=0.8)
    ax.scatter(X_denorm[tn_mask,0], X_denorm[tn_mask,1], c='purple', marker='o', s=5, alpha=0.8)

def save_viz(model, save_path=None):
    plt.clf()
    probe=np.zeros((100,100,2))
    for j, xx in enumerate(np.linspace(-1, 1, 100)):
        for k, yy in enumerate(np.linspace(-1, 1, 100)):
            probe[j, k]=[yy,xx]
    probe=probe.reshape(100**2, -1)
    
    h1 = model.model[:2](torch.tensor(probe).float())
    h1 = h1.detach().numpy().reshape(100,100,3)

    h2 = model.model[:3](torch.tensor(probe).float())
    h2 = h2.detach().numpy().reshape(100,100,2)
        
    # First neuron (output index 0)
    j1 = get_relu_joint(model.model[0].weight[0,0].item(), model.model[0].weight[0,1].item(), model.model[0].bias[0].item(), extent=1)
    j1 = denorm(np.array(j1)) if j1 else []
    
    # Second neuron (output index 1)  
    j2 = get_relu_joint(model.model[0].weight[1,0].item(), model.model[0].weight[1,1].item(), model.model[0].bias[1].item(), extent=1)
    j2 = denorm(np.array(j2)) if j2 else []
    
    j3 = get_relu_joint(model.model[0].weight[2,0].item(), model.model[0].weight[2,1].item(), model.model[0].bias[2].item(), extent=1)
    j3 = denorm(np.array(j3)) if j3 else []
    
    fig=plt.figure(0,(10,10)); 
    for i in range(3):
        ax=fig.add_subplot(2,2,i+1)
        ax.imshow(map.mean(2), cmap='gray')
        ax.imshow(np.flipud(h1[:,:,i]>0), 
                   extent=[0, 960, 960, 0],  # This maps to image coordinates
                   alpha=0.7,
                   cmap='viridis')
        if i==0 and len(j1)>0: ax.plot([j1[0][0], j1[1][0]], [j1[0][1], j1[1][1]], '--', color='#FFFFFF', linewidth=2)
        if i==1 and len(j2)>0: ax.plot([j2[0][0], j2[1][0]], [j2[0][1], j2[1][1]], '--', color='#FFFFFF', linewidth=2)
        if i==2 and len(j3)>0: ax.plot([j3[0][0], j3[1][0]], [j3[0][1], j3[1][1]], '--', color='#FFFFFF', linewidth=2)
    
    ax=fig.add_subplot(2,2,4)
    probe_logits=model(torch.tensor(probe).float())
    probe_logits=probe_logits.detach().numpy().reshape(100,100,2)
    probe_softmax = torch.nn.Softmax(dim=1)(torch.tensor(probe_logits.reshape(-1, 2)))
    
    ax.imshow(map.mean(2), cmap='gray')
    # ax.imshow(np.flipud(probe_softmax[:,1].reshape(100, 100)), 
    #            extent=[0, 960, 960, 0],  # This maps to image coordinates
    #            alpha=0.7,
    #            cmap='viridis')
    
    ax.imshow(np.flipud((h2[:,:,1]-h2[:,:,0])>0), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')
    if save_path is not None: plt.savefig(save_path)

# %%
def flatten_weight_dict(weight_dict):
    """
    Flatten a dictionary of weight tensors into a single 1D numpy array
    """
    flattened = []
    for name, tensor in weight_dict.items():
        if tensor is not None:
            flattened.append(tensor.cpu().numpy().flatten())
    return np.concatenate(flattened)

def unflatten_to_weight_dict(flattened_weights, reference_dict):
    """
    Convert flattened weights back to the original dictionary structure
    """
    result = {}
    start_idx = 0
    
    for name, tensor in reference_dict.items():
        if tensor is not None:
            shape = tensor.shape
            size = tensor.numel()
            
            # Extract the portion for this parameter
            param_weights = flattened_weights[start_idx:start_idx + size]
            
            # Reshape and convert to tensor
            result[name] = torch.tensor(param_weights.reshape(shape)).float()
            start_idx += size
    
    return result

# Set model weights function (reused from previous code)
def set_model_weights(model, weight_dict):
    """Set model parameters from weight dictionary"""
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = weight_dict[name]

def compute_loss_at_point(model, X_tensor, y_tensor, criterion):
    """Compute loss at current model parameters"""
    with torch.no_grad():
        outputs = model(X_tensor)
        loss = criterion(outputs, y_tensor)
        return loss.item()

# %%
map=cv2.imread('Baarle-Nassau_-_Baarle-Hertog-en.svg.png')[:,:,(2,1,0)]

belgium_color=np.array([251,234,81])
netherlands_color=np.array([255, 255, 228])

netherlands_region=((map-netherlands_color)**2).sum(-1)<10
belgium_region=((map-belgium_color)**2).sum(-1)<10000

num_points_to_sample=10000 #10000

b_coords=np.array(np.where(belgium_region)).T.astype('float')
n_coords=np.array(np.where(netherlands_region)).T.astype('float')

#flip and normalize
belgium_coords_all=np.zeros_like(b_coords)
netherlands_coords_all=np.zeros_like(n_coords)

belgium_coords_all[:,0]=b_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
belgium_coords_all[:,1]=(960-b_coords[:,0])/(960/2)-1
netherlands_coords_all[:,0]=n_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
netherlands_coords_all[:,1]=(960-n_coords[:,0])/(960/2)-1

## Hmm to balance to classes or do more area proportional? Not sure yet. 
belgium_coords=belgium_coords_all[np.random.choice(len(belgium_coords_all), num_points_to_sample), :]
netherlands_coords=netherlands_coords_all[np.random.choice(len(netherlands_coords_all), num_points_to_sample), :]

X=np.vstack((netherlands_coords, belgium_coords))
y=np.concatenate((np.zeros(len(netherlands_coords)), np.ones(len(belgium_coords)))).astype('int')

rI=np.arange(len(y))
np.random.shuffle(rI)
X=X[rI,:]
y=y[rI]

# %%
plt.scatter(X[:,0], X[:,1], c=y, s=1, alpha=0.3); plt.axis('square');

# %%
class BaarleNet(nn.Module):
    def __init__(self, hidden_layers=[64]):
        super(BaarleNet, self).__init__()
        layers = [nn.Linear(2, hidden_layers[0]), nn.ReLU()]
        for i in range(len(hidden_layers)-1):
            layers.append(nn.Linear(hidden_layers[i], hidden_layers[i+1]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_layers[-1], 2))
        self.layers=layers
        self.model = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.model(x)

# %%
import pickle
import copy
import os

# %% [markdown]
# ## Run same loop, but save best and worst

# %%
X_tensor = torch.FloatTensor(X)
y_tensor = torch.tensor(y)

# Training parameters
num_epochs = 500 #Trying shorter to reduce arbitrary weight scaling
num_seeds = 128 #8 is nice for quick tests

# Configure output directory
output_dir = "/Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_4"  # Change this to your desired directory
os.makedirs(output_dir, exist_ok=True)
print(f"Saving results to: {output_dir}")

# Track best and worst models
best_model_data = {'accuracy': -1, 'seed': None, 'initial_params': None, 'final_params': None}
worst_model_data = {'accuracy': float('inf'), 'seed': None, 'initial_params': None, 'final_params': None}
all_training_data=[]

for seed_idx in range(num_seeds):
    random_seed = seed_idx  # You can change this to any seed generation logic
    torch.manual_seed(random_seed)
    
    # Initialize model and optimizer
    model = BaarleNet([3]) #[3] is probaby the move for this
    #Mess with initialization
    bound=3
    with torch.no_grad():
        model.model[0].weight.uniform_(-bound, bound)
        model.model[0].bias.uniform_(-bound, bound)  
        model.model[2].weight.uniform_(-bound, bound)
        model.model[2].bias.uniform_(-bound, bound)  

    print(model.model[0].weight)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    
    # Store initial parameters (deep copy)
    initial_params = {}
    for name, param in model.named_parameters():
        initial_params[name] = param.data.clone()
    
    # Data storage for this run
    training_data = {
        'seed': random_seed,
        'weights_history': [],
        'gradients_history': [],
        'xy_history': [],
        'loss_history': [],
        'accuracy_history': [],
        'initial_params': initial_params  # Store initial params in training data too
    }

    print(f"\n=== Training with seed {random_seed} ===")

    for epoch in range(num_epochs):
        # Get current data point
        current_idx = epoch % len(y)
        # Stochastic
        # current_x = torch.tensor(X[current_idx]).float()
        # current_y = torch.tensor(y[current_idx])

        #Try batch for a second
        current_x = torch.tensor(X).float()
        current_y = torch.tensor(y)  
        
        # Forward pass
        outputs = model(current_x)
        loss = criterion(outputs, current_y)
        if epoch==0:
            print('initial loss = ', loss.item())
        
        # Store current X,y values
        training_data['xy_history'].append({
            'epoch': epoch,
            'x': X[current_idx].copy(),
            'y': y[current_idx]
        })
        
        # Zero gradients
        optimizer.zero_grad()
        
        # Backward pass
        loss.backward()
        
        # Store model weights (deep copy to avoid reference issues)
        current_weights = {}
        for name, param in model.named_parameters():
            current_weights[name] = param.data.clone()
        training_data['weights_history'].append(current_weights)
        
        # Store model gradients (deep copy)
        current_gradients = {}
        for name, param in model.named_parameters():
            if param.grad is not None:
                current_gradients[name] = param.grad.clone()
            else:
                current_gradients[name] = None
        training_data['gradients_history'].append(current_gradients)
        
        # Update parameters
        optimizer.step()
        
        # Store loss
        training_data['loss_history'].append(loss.item())
        
        # Calculate and store accuracy periodically
        if (epoch + 1) % (num_epochs // 10) == 0:
            with torch.no_grad():
                outputs_batch = model(X_tensor)
                accuracy = (torch.argmax(outputs_batch, dim=1) == y_tensor).sum().item() / len(y)
                training_data['accuracy_history'].append({
                    'epoch': epoch,
                    'accuracy': accuracy
                })
                print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Accuracy: {accuracy:.4f}')
    
    # Calculate final accuracy
    with torch.no_grad():
        final_outputs = model(X_tensor)
        final_accuracy = (torch.argmax(final_outputs, dim=1) == y_tensor).sum().item() / len(y)
    
    # Store final parameters (deep copy)
    final_params = {}
    for name, param in model.named_parameters():
        final_params[name] = param.data.clone()
    
    # Check if this is the best or worst model so far
    if final_accuracy > best_model_data['accuracy']:
        best_model_data = {
            'accuracy': final_accuracy,
            'seed': random_seed,
            'initial_params': {name: param.clone() for name, param in initial_params.items()},
            'final_params': {name: param.clone() for name, param in final_params.items()}
        }
        print(f"*** NEW BEST MODEL: Seed {random_seed}, Accuracy {final_accuracy:.4f} ***")
    
    if final_accuracy < worst_model_data['accuracy']:
        worst_model_data = {
            'accuracy': final_accuracy,
            'seed': random_seed,
            'initial_params': {name: param.clone() for name, param in initial_params.items()},
            'final_params': {name: param.clone() for name, param in final_params.items()}
        }
        print(f"*** NEW WORST MODEL: Seed {random_seed}, Accuracy {final_accuracy:.4f} ***")
    
    # Save data as pickle file
    filename = os.path.join(output_dir, f"training_data_seed_{random_seed:02d}_acc_{final_accuracy:.4f}.pkl")
    
    # Add final accuracy and params to the data
    training_data['final_accuracy'] = final_accuracy
    training_data['final_model_state'] = model.state_dict()
    training_data['final_params'] = final_params
    
    with open(filename, 'wb') as f:
        pickle.dump(training_data, f)
    
    print(f"Saved training data to {filename}")
    print(f"Final accuracy: {final_accuracy:.4f}")

    # Restore initial weights for visualization
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = training_data['weights_history'][0][name]

    print(model.model[0].weight)
    viz_fn = os.path.join(output_dir, f"{final_accuracy:.4f}_random_init.png")
    save_viz(model, str(viz_fn))

    all_training_data.append(training_data)

# After all training is complete, save best and worst model data
best_worst_data = {
    'best_model': best_model_data,
    'worst_model': worst_model_data
}

best_worst_filename = os.path.join(output_dir, "best_worst_models.pkl")
with open(best_worst_filename, 'wb') as f:
    pickle.dump(best_worst_data, f)

print(f"\n=== FINAL RESULTS ===")
print(f"Best model: Seed {best_model_data['seed']}, Accuracy {best_model_data['accuracy']:.4f}")
print(f"Worst model: Seed {worst_model_data['seed']}, Accuracy {worst_model_data['accuracy']:.4f}")
print(f"Best/worst model data saved to: {best_worst_filename}")
# Out:
# Saving results to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3
# Parameter containing:
# tensor([[ 1.8001, -2.0338],
#         [-1.3064,  1.0897],
#         [ 2.4912, -0.6174]], requires_grad=True)
#
# === Training with seed 0 ===
# initial loss =  3.3407106399536133
# Epoch [50/500], Loss: 1.0145, Accuracy: 0.3186
# Epoch [100/500], Loss: 0.7420, Accuracy: 0.5927
# Epoch [150/500], Loss: 0.6966, Accuracy: 0.6190
# Epoch [200/500], Loss: 0.6632, Accuracy: 0.6201
# Epoch [250/500], Loss: 0.6384, Accuracy: 0.7220
# Epoch [300/500], Loss: 0.6180, Accuracy: 0.7277
# Epoch [350/500], Loss: 0.5979, Accuracy: 0.7337
# Epoch [400/500], Loss: 0.5786, Accuracy: 0.7423
# Epoch [450/500], Loss: 0.5630, Accuracy: 0.7491
# Epoch [500/500], Loss: 0.5505, Accuracy: 0.7545
# *** NEW BEST MODEL: Seed 0, Accuracy 0.7545 ***
# *** NEW WORST MODEL: Seed 0, Accuracy 0.7545 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_00_acc_0.7545.pkl
# Final accuracy: 0.7545
# Parameter containing:
# tensor([[ 1.8001, -2.0338],
#         [-1.3064,  1.0897],
#         [ 2.4912, -0.6174]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0120,  2.6225],
#         [ 0.9336, -1.1172],
#         [-1.8119, -0.5028]], requires_grad=True)
#
# === Training with seed 1 ===
# initial loss =  1.8637152910232544
# Epoch [50/500], Loss: 1.2560, Accuracy: 0.6179
# Epoch [100/500], Loss: 0.8726, Accuracy: 0.6925
# Epoch [150/500], Loss: 0.4751, Accuracy: 0.7707
# Epoch [200/500], Loss: 0.4673, Accuracy: 0.7624
# Epoch [250/500], Loss: 0.4645, Accuracy: 0.7634
# Epoch [300/500], Loss: 0.4631, Accuracy: 0.7649
# Epoch [350/500], Loss: 0.4624, Accuracy: 0.7614
# Epoch [400/500], Loss: 0.4620, Accuracy: 0.7594
# Epoch [450/500], Loss: 0.4617, Accuracy: 0.7592
# Epoch [500/500], Loss: 0.4615, Accuracy: 0.7589
# *** NEW BEST MODEL: Seed 1, Accuracy 0.7589 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_01_acc_0.7589.pkl
# Final accuracy: 0.7589
# Parameter containing:
# tensor([[-0.0120,  2.6225],
#         [ 0.9336, -1.1172],
#         [-1.8119, -0.5028]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7698, -1.1533],
#         [ 2.8852, -2.9384],
#         [-0.2038, -0.2377]], requires_grad=True)
#
# === Training with seed 2 ===
# initial loss =  1.584783911705017
# Epoch [50/500], Loss: 0.7238, Accuracy: 0.5746
# Epoch [100/500], Loss: 0.6262, Accuracy: 0.6485
# Epoch [150/500], Loss: 0.5417, Accuracy: 0.7438
# Epoch [200/500], Loss: 0.5029, Accuracy: 0.7600
# Epoch [250/500], Loss: 0.4905, Accuracy: 0.7580
# Epoch [300/500], Loss: 0.4869, Accuracy: 0.7573
# Epoch [350/500], Loss: 0.4858, Accuracy: 0.7572
# Epoch [400/500], Loss: 0.4854, Accuracy: 0.7577
# Epoch [450/500], Loss: 0.4853, Accuracy: 0.7578
# Epoch [500/500], Loss: 0.4853, Accuracy: 0.7580
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_02_acc_0.7580.pkl
# Final accuracy: 0.7580
# Parameter containing:
# tensor([[-1.7698, -1.1533],
#         [ 2.8852, -2.9384],
#         [-0.2038, -0.2377]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.6951,  2.0839],
#         [ 2.2491,  0.8899],
#         [-1.7115,  2.6958]], requires_grad=True)
#
# === Training with seed 3 ===
# initial loss =  1.0028269290924072
# Epoch [50/500], Loss: 0.6965, Accuracy: 0.5829
# Epoch [100/500], Loss: 0.6308, Accuracy: 0.6129
# Epoch [150/500], Loss: 0.5771, Accuracy: 0.6806
# Epoch [200/500], Loss: 0.5132, Accuracy: 0.7443
# Epoch [250/500], Loss: 0.4834, Accuracy: 0.7732
# Epoch [300/500], Loss: 0.4722, Accuracy: 0.7805
# Epoch [350/500], Loss: 0.4699, Accuracy: 0.7831
# Epoch [400/500], Loss: 0.4696, Accuracy: 0.7835
# Epoch [450/500], Loss: 0.4695, Accuracy: 0.7841
# Epoch [500/500], Loss: 0.4695, Accuracy: 0.7839
# *** NEW BEST MODEL: Seed 3, Accuracy 0.7839 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_03_acc_0.7839.pkl
# Final accuracy: 0.7839
# Parameter containing:
# tensor([[ 2.6951,  2.0839],
#         [ 2.2491,  0.8899],
#         [-1.7115,  2.6958]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7178, -1.1602],
#         [-2.7687,  0.1322],
#         [-1.0755,  0.6443]], requires_grad=True)
#
# === Training with seed 4 ===
# initial loss =  2.6269731521606445
# Epoch [50/500], Loss: 0.9657, Accuracy: 0.5243
# Epoch [100/500], Loss: 0.6901, Accuracy: 0.6460
# Epoch [150/500], Loss: 0.6572, Accuracy: 0.6644
# Epoch [200/500], Loss: 0.6405, Accuracy: 0.6750
# Epoch [250/500], Loss: 0.6208, Accuracy: 0.6768
# Epoch [300/500], Loss: 0.5927, Accuracy: 0.6764
# Epoch [350/500], Loss: 0.5593, Accuracy: 0.6763
# Epoch [400/500], Loss: 0.5320, Accuracy: 0.6773
# Epoch [450/500], Loss: 0.5108, Accuracy: 0.7784
# Epoch [500/500], Loss: 0.4951, Accuracy: 0.7935
# *** NEW BEST MODEL: Seed 4, Accuracy 0.7935 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_04_acc_0.7935.pkl
# Final accuracy: 0.7935
# Parameter containing:
# tensor([[-1.7178, -1.1602],
#         [-2.7687,  0.1322],
#         [-1.0755,  0.6443]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.9010, -2.6602],
#         [ 2.5207,  1.0186],
#         [-1.4312, -2.7557]], requires_grad=True)
#
# === Training with seed 5 ===
# initial loss =  3.4994161128997803
# Epoch [50/500], Loss: 1.0562, Accuracy: 0.5968
# Epoch [100/500], Loss: 0.6653, Accuracy: 0.6663
# Epoch [150/500], Loss: 0.6000, Accuracy: 0.6806
# Epoch [200/500], Loss: 0.5595, Accuracy: 0.7075
# Epoch [250/500], Loss: 0.5386, Accuracy: 0.7200
# Epoch [300/500], Loss: 0.5321, Accuracy: 0.7249
# Epoch [350/500], Loss: 0.5278, Accuracy: 0.7326
# Epoch [400/500], Loss: 0.5231, Accuracy: 0.7399
# Epoch [450/500], Loss: 0.5166, Accuracy: 0.7495
# Epoch [500/500], Loss: 0.5073, Accuracy: 0.7604
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_05_acc_0.7604.pkl
# Final accuracy: 0.7604
# Parameter containing:
# tensor([[ 0.9010, -2.6602],
#         [ 2.5207,  1.0186],
#         [-1.4312, -2.7557]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.6310, -0.8102],
#         [-1.4785, -2.0148],
#         [-1.3001, -0.6851]], requires_grad=True)
#
# === Training with seed 6 ===
# initial loss =  2.281954288482666
# Epoch [50/500], Loss: 0.7174, Accuracy: 0.6844
# Epoch [100/500], Loss: 0.6307, Accuracy: 0.6650
# Epoch [150/500], Loss: 0.5673, Accuracy: 0.6707
# Epoch [200/500], Loss: 0.5269, Accuracy: 0.7432
# Epoch [250/500], Loss: 0.5076, Accuracy: 0.7690
# Epoch [300/500], Loss: 0.4965, Accuracy: 0.7781
# Epoch [350/500], Loss: 0.4871, Accuracy: 0.7824
# Epoch [400/500], Loss: 0.4776, Accuracy: 0.7883
# Epoch [450/500], Loss: 0.4675, Accuracy: 0.7956
# Epoch [500/500], Loss: 0.4559, Accuracy: 0.8010
# *** NEW BEST MODEL: Seed 6, Accuracy 0.8010 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_06_acc_0.8010.pkl
# Final accuracy: 0.8010
# Parameter containing:
# tensor([[ 0.6310, -0.8102],
#         [-1.4785, -2.0148],
#         [-1.3001, -0.6851]], requires_grad=True)
# Parameter containing:
# tensor([[-2.5617,  2.8195],
#         [-2.3533,  2.2973],
#         [-0.5210,  1.5432]], requires_grad=True)
#
# === Training with seed 7 ===
# initial loss =  2.423189401626587
# Epoch [50/500], Loss: 0.7005, Accuracy: 0.5308
# Epoch [100/500], Loss: 0.6187, Accuracy: 0.6359
# Epoch [150/500], Loss: 0.6046, Accuracy: 0.6379
# Epoch [200/500], Loss: 0.5921, Accuracy: 0.6401
# Epoch [250/500], Loss: 0.5775, Accuracy: 0.7149
# Epoch [300/500], Loss: 0.5630, Accuracy: 0.7470
# Epoch [350/500], Loss: 0.5491, Accuracy: 0.7627
# Epoch [400/500], Loss: 0.5371, Accuracy: 0.7694
# Epoch [450/500], Loss: 0.5269, Accuracy: 0.7693
# Epoch [500/500], Loss: 0.5190, Accuracy: 0.7653
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_07_acc_0.7653.pkl
# Final accuracy: 0.7653
# Parameter containing:
# tensor([[-2.5617,  2.8195],
#         [-2.3533,  2.2973],
#         [-0.5210,  1.5432]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4719, -0.1902],
#         [-1.9906, -1.9725],
#         [ 0.0619, -2.3591]], requires_grad=True)
#
# === Training with seed 8 ===
# initial loss =  1.968930721282959
# Epoch [50/500], Loss: 1.0236, Accuracy: 0.4245
# Epoch [100/500], Loss: 0.7712, Accuracy: 0.5334
# Epoch [150/500], Loss: 0.7007, Accuracy: 0.5707
# Epoch [200/500], Loss: 0.6843, Accuracy: 0.5877
# Epoch [250/500], Loss: 0.6738, Accuracy: 0.5959
# Epoch [300/500], Loss: 0.6691, Accuracy: 0.6073
# Epoch [350/500], Loss: 0.6663, Accuracy: 0.6079
# Epoch [400/500], Loss: 0.6651, Accuracy: 0.6100
# Epoch [450/500], Loss: 0.6647, Accuracy: 0.6115
# Epoch [500/500], Loss: 0.6645, Accuracy: 0.6130
# *** NEW WORST MODEL: Seed 8, Accuracy 0.6130 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_08_acc_0.6130.pkl
# Final accuracy: 0.6130
# Parameter containing:
# tensor([[-1.4719, -0.1902],
#         [-1.9906, -1.9725],
#         [ 0.0619, -2.3591]], requires_grad=True)
# Parameter containing:
# tensor([[-0.9193, -0.3141],
#         [ 0.7893,  1.1685],
#         [ 1.9288,  2.4668]], requires_grad=True)
#
# === Training with seed 9 ===
# initial loss =  1.7715718746185303
# Epoch [50/500], Loss: 0.7399, Accuracy: 0.4998
# Epoch [100/500], Loss: 0.6634, Accuracy: 0.6136
# Epoch [150/500], Loss: 0.6315, Accuracy: 0.6031
# Epoch [200/500], Loss: 0.5988, Accuracy: 0.6552
# Epoch [250/500], Loss: 0.5864, Accuracy: 0.6670
# Epoch [300/500], Loss: 0.5760, Accuracy: 0.6964
# Epoch [350/500], Loss: 0.5470, Accuracy: 0.7458
# Epoch [400/500], Loss: 0.5140, Accuracy: 0.7772
# Epoch [450/500], Loss: 0.4622, Accuracy: 0.8159
# Epoch [500/500], Loss: 0.4362, Accuracy: 0.8261
# *** NEW BEST MODEL: Seed 9, Accuracy 0.8261 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_09_acc_0.8261.pkl
# Final accuracy: 0.8261
# Parameter containing:
# tensor([[-0.9193, -0.3141],
#         [ 0.7893,  1.1685],
#         [ 1.9288,  2.4668]], requires_grad=True)
# Parameter containing:
# tensor([[-0.1060,  0.6900],
#         [-0.0196, -0.2873],
#         [-2.6549, -2.5878]], requires_grad=True)
#
# === Training with seed 10 ===
# initial loss =  0.9541864991188049
# Epoch [50/500], Loss: 0.7187, Accuracy: 0.4772
# Epoch [100/500], Loss: 0.6962, Accuracy: 0.4937
# Epoch [150/500], Loss: 0.6940, Accuracy: 0.4973
# Epoch [200/500], Loss: 0.6935, Accuracy: 0.4985
# Epoch [250/500], Loss: 0.6933, Accuracy: 0.4990
# Epoch [300/500], Loss: 0.6932, Accuracy: 0.4995
# Epoch [350/500], Loss: 0.6932, Accuracy: 0.4996
# Epoch [400/500], Loss: 0.6932, Accuracy: 0.4996
# Epoch [450/500], Loss: 0.6932, Accuracy: 0.4998
# Epoch [500/500], Loss: 0.6932, Accuracy: 0.4999
# *** NEW WORST MODEL: Seed 10, Accuracy 0.4999 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_10_acc_0.4999.pkl
# Final accuracy: 0.4999
# Parameter containing:
# tensor([[-0.1060,  0.6900],
#         [-0.0196, -0.2873],
#         [-2.6549, -2.5878]], requires_grad=True)
# Parameter containing:
# tensor([[1.5600, 1.8213],
#         [1.5918, 2.2254],
#         [1.3383, 2.0186]], requires_grad=True)
#
# === Training with seed 11 ===
# initial loss =  3.8721680641174316
# Epoch [50/500], Loss: 1.4881, Accuracy: 0.4999
# Epoch [100/500], Loss: 0.7826, Accuracy: 0.4560
# Epoch [150/500], Loss: 0.7294, Accuracy: 0.4624
# Epoch [200/500], Loss: 0.6980, Accuracy: 0.4850
# Epoch [250/500], Loss: 0.6764, Accuracy: 0.5369
# Epoch [300/500], Loss: 0.6589, Accuracy: 0.6119
# Epoch [350/500], Loss: 0.6440, Accuracy: 0.6401
# Epoch [400/500], Loss: 0.6278, Accuracy: 0.6179
# Epoch [450/500], Loss: 0.6066, Accuracy: 0.6477
# Epoch [500/500], Loss: 0.5735, Accuracy: 0.7081
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_11_acc_0.7081.pkl
# Final accuracy: 0.7081
# Parameter containing:
# tensor([[1.5600, 1.8213],
#         [1.5918, 2.2254],
#         [1.3383, 2.0186]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.0656, -2.2465],
#         [-0.3263,  0.9603],
#         [-2.6677, -2.0562]], requires_grad=True)
#
# === Training with seed 12 ===
# initial loss =  1.7014341354370117
# Epoch [50/500], Loss: 0.8473, Accuracy: 0.5371
# Epoch [100/500], Loss: 0.6984, Accuracy: 0.5707
# Epoch [150/500], Loss: 0.6717, Accuracy: 0.5850
# Epoch [200/500], Loss: 0.6654, Accuracy: 0.6022
# Epoch [250/500], Loss: 0.6623, Accuracy: 0.6109
# Epoch [300/500], Loss: 0.6522, Accuracy: 0.6139
# Epoch [350/500], Loss: 0.6183, Accuracy: 0.6917
# Epoch [400/500], Loss: 0.5952, Accuracy: 0.7033
# Epoch [450/500], Loss: 0.5704, Accuracy: 0.7045
# Epoch [500/500], Loss: 0.5419, Accuracy: 0.7189
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_12_acc_0.7189.pkl
# Final accuracy: 0.7189
# Parameter containing:
# tensor([[ 2.0656, -2.2465],
#         [-0.3263,  0.9603],
#         [-2.6677, -2.0562]], requires_grad=True)
# Parameter containing:
# tensor([[-0.9660,  2.0200],
#         [-2.2267,  2.8161],
#         [-0.3029, -0.5816]], requires_grad=True)
#
# === Training with seed 13 ===
# initial loss =  5.303284168243408
# Epoch [50/500], Loss: 2.4081, Accuracy: 0.4860
# Epoch [100/500], Loss: 1.0528, Accuracy: 0.5637
# Epoch [150/500], Loss: 0.7952, Accuracy: 0.6077
# Epoch [200/500], Loss: 0.7466, Accuracy: 0.6006
# Epoch [250/500], Loss: 0.7212, Accuracy: 0.6063
# Epoch [300/500], Loss: 0.7021, Accuracy: 0.6081
# Epoch [350/500], Loss: 0.6877, Accuracy: 0.6106
# Epoch [400/500], Loss: 0.6775, Accuracy: 0.6117
# Epoch [450/500], Loss: 0.6705, Accuracy: 0.6101
# Epoch [500/500], Loss: 0.6650, Accuracy: 0.6087
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_13_acc_0.6087.pkl
# Final accuracy: 0.6087
# Parameter containing:
# tensor([[-0.9660,  2.0200],
#         [-2.2267,  2.8161],
#         [-0.3029, -0.5816]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.9235,  0.8476],
#         [-0.3316, -0.2446],
#         [ 2.6837,  0.7031]], requires_grad=True)
#
# === Training with seed 14 ===
# initial loss =  1.2568237781524658
# Epoch [50/500], Loss: 0.6311, Accuracy: 0.6783
# Epoch [100/500], Loss: 0.5843, Accuracy: 0.7288
# Epoch [150/500], Loss: 0.5427, Accuracy: 0.7489
# Epoch [200/500], Loss: 0.5174, Accuracy: 0.7571
# Epoch [250/500], Loss: 0.5026, Accuracy: 0.7584
# Epoch [300/500], Loss: 0.4932, Accuracy: 0.7572
# Epoch [350/500], Loss: 0.4893, Accuracy: 0.7577
# Epoch [400/500], Loss: 0.4876, Accuracy: 0.7565
# Epoch [450/500], Loss: 0.4869, Accuracy: 0.7563
# Epoch [500/500], Loss: 0.4864, Accuracy: 0.7558
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_14_acc_0.7558.pkl
# Final accuracy: 0.7558
# Parameter containing:
# tensor([[ 2.9235,  0.8476],
#         [-0.3316, -0.2446],
#         [ 2.6837,  0.7031]], requires_grad=True)
# Parameter containing:
# tensor([[-1.2008,  2.8449],
#         [-0.9484,  2.4795],
#         [-1.0869,  0.7296]], requires_grad=True)
#
# === Training with seed 15 ===
# initial loss =  3.2423179149627686
# Epoch [50/500], Loss: 0.6981, Accuracy: 0.6295
# Epoch [100/500], Loss: 0.6471, Accuracy: 0.6391
# Epoch [150/500], Loss: 0.6308, Accuracy: 0.6425
# Epoch [200/500], Loss: 0.6210, Accuracy: 0.6455
# Epoch [250/500], Loss: 0.6143, Accuracy: 0.6485
# Epoch [300/500], Loss: 0.6099, Accuracy: 0.6499
# Epoch [350/500], Loss: 0.6068, Accuracy: 0.6514
# Epoch [400/500], Loss: 0.6051, Accuracy: 0.6512
# Epoch [450/500], Loss: 0.6039, Accuracy: 0.6522
# Epoch [500/500], Loss: 0.6031, Accuracy: 0.6530
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_15_acc_0.6530.pkl
# Final accuracy: 0.6530
# Parameter containing:
# tensor([[-1.2008,  2.8449],
#         [-0.9484,  2.4795],
#         [-1.0869,  0.7296]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7914,  2.3927],
#         [-0.0388, -1.1854],
#         [ 1.6903,  2.7962]], requires_grad=True)
#
# === Training with seed 16 ===
# initial loss =  0.9634578227996826
# Epoch [50/500], Loss: 0.6093, Accuracy: 0.6483
# Epoch [100/500], Loss: 0.5916, Accuracy: 0.6664
# Epoch [150/500], Loss: 0.5694, Accuracy: 0.7032
# Epoch [200/500], Loss: 0.5353, Accuracy: 0.7487
# Epoch [250/500], Loss: 0.5023, Accuracy: 0.7753
# Epoch [300/500], Loss: 0.4739, Accuracy: 0.7865
# Epoch [350/500], Loss: 0.4585, Accuracy: 0.7882
# Epoch [400/500], Loss: 0.4507, Accuracy: 0.7923
# Epoch [450/500], Loss: 0.4465, Accuracy: 0.7943
# Epoch [500/500], Loss: 0.4437, Accuracy: 0.7955
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_16_acc_0.7955.pkl
# Final accuracy: 0.7955
# Parameter containing:
# tensor([[-1.7914,  2.3927],
#         [-0.0388, -1.1854],
#         [ 1.6903,  2.7962]], requires_grad=True)
# Parameter containing:
# tensor([[-2.1566,  0.6017],
#         [ 0.3947, -2.4306],
#         [-2.4183, -0.7714]], requires_grad=True)
#
# === Training with seed 17 ===
# initial loss =  4.392845630645752
# Epoch [50/500], Loss: 2.2488, Accuracy: 0.5455
# Epoch [100/500], Loss: 0.9730, Accuracy: 0.5916
# Epoch [150/500], Loss: 0.7079, Accuracy: 0.6329
# Epoch [200/500], Loss: 0.6646, Accuracy: 0.6524
# Epoch [250/500], Loss: 0.6559, Accuracy: 0.6577
# Epoch [300/500], Loss: 0.6533, Accuracy: 0.6620
# Epoch [350/500], Loss: 0.6518, Accuracy: 0.6629
# Epoch [400/500], Loss: 0.6507, Accuracy: 0.6632
# Epoch [450/500], Loss: 0.6497, Accuracy: 0.6633
# Epoch [500/500], Loss: 0.6487, Accuracy: 0.6629
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_17_acc_0.6629.pkl
# Final accuracy: 0.6629
# Parameter containing:
# tensor([[-2.1566,  0.6017],
#         [ 0.3947, -2.4306],
#         [-2.4183, -0.7714]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0316, -1.5221],
#         [ 0.7632,  1.4646],
#         [ 1.6584,  2.4718]], requires_grad=True)
#
# === Training with seed 18 ===
# initial loss =  2.7649028301239014
# Epoch [50/500], Loss: 1.9791, Accuracy: 0.5000
# Epoch [100/500], Loss: 1.5123, Accuracy: 0.5000
# Epoch [150/500], Loss: 1.1255, Accuracy: 0.5000
# Epoch [200/500], Loss: 0.8584, Accuracy: 0.5000
# Epoch [250/500], Loss: 0.7136, Accuracy: 0.5000
# Epoch [300/500], Loss: 0.6370, Accuracy: 0.5000
# Epoch [350/500], Loss: 0.6077, Accuracy: 0.6522
# Epoch [400/500], Loss: 0.5977, Accuracy: 0.6604
# Epoch [450/500], Loss: 0.5943, Accuracy: 0.6625
# Epoch [500/500], Loss: 0.5933, Accuracy: 0.6633
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_18_acc_0.6633.pkl
# Final accuracy: 0.6633
# Parameter containing:
# tensor([[ 0.0316, -1.5221],
#         [ 0.7632,  1.4646],
#         [ 1.6584,  2.4718]], requires_grad=True)
# Parameter containing:
# tensor([[-2.9603,  1.3749],
#         [-0.4171, -1.3419],
#         [-0.9132,  0.3061]], requires_grad=True)
#
# === Training with seed 19 ===
# initial loss =  1.1381349563598633
# Epoch [50/500], Loss: 0.5850, Accuracy: 0.6907
# Epoch [100/500], Loss: 0.5465, Accuracy: 0.7381
# Epoch [150/500], Loss: 0.5347, Accuracy: 0.7341
# Epoch [200/500], Loss: 0.5287, Accuracy: 0.7361
# Epoch [250/500], Loss: 0.5250, Accuracy: 0.7392
# Epoch [300/500], Loss: 0.5223, Accuracy: 0.7402
# Epoch [350/500], Loss: 0.5201, Accuracy: 0.7398
# Epoch [400/500], Loss: 0.5179, Accuracy: 0.7384
# Epoch [450/500], Loss: 0.5158, Accuracy: 0.7381
# Epoch [500/500], Loss: 0.5142, Accuracy: 0.7408
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_19_acc_0.7408.pkl
# Final accuracy: 0.7408
# Parameter containing:
# tensor([[-2.9603,  1.3749],
#         [-0.4171, -1.3419],
#         [-0.9132,  0.3061]], requires_grad=True)
# Parameter containing:
# tensor([[-0.3421,  0.7539],
#         [-2.7726,  1.2780],
#         [-1.0625,  2.7787]], requires_grad=True)
#
# === Training with seed 20 ===
# initial loss =  1.8195350170135498
# Epoch [50/500], Loss: 1.2203, Accuracy: 0.5000
# Epoch [100/500], Loss: 0.8767, Accuracy: 0.5000
# Epoch [150/500], Loss: 0.7028, Accuracy: 0.5000
# Epoch [200/500], Loss: 0.6160, Accuracy: 0.5000
# Epoch [250/500], Loss: 0.5846, Accuracy: 0.6956
# Epoch [300/500], Loss: 0.5661, Accuracy: 0.7008
# Epoch [350/500], Loss: 0.5540, Accuracy: 0.7180
# Epoch [400/500], Loss: 0.5480, Accuracy: 0.7217
# Epoch [450/500], Loss: 0.5452, Accuracy: 0.7243
# Epoch [500/500], Loss: 0.5434, Accuracy: 0.7254
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_20_acc_0.7254.pkl
# Final accuracy: 0.7254
# Parameter containing:
# tensor([[-0.3421,  0.7539],
#         [-2.7726,  1.2780],
#         [-1.0625,  2.7787]], requires_grad=True)
# Parameter containing:
# tensor([[-2.7946, -0.6038],
#         [ 1.3097,  1.8610],
#         [ 0.0058, -2.6667]], requires_grad=True)
#
# === Training with seed 21 ===
# initial loss =  1.5575653314590454
# Epoch [50/500], Loss: 0.7961, Accuracy: 0.4403
# Epoch [100/500], Loss: 0.6747, Accuracy: 0.5647
# Epoch [150/500], Loss: 0.6381, Accuracy: 0.6106
# Epoch [200/500], Loss: 0.5965, Accuracy: 0.6666
# Epoch [250/500], Loss: 0.5582, Accuracy: 0.7170
# Epoch [300/500], Loss: 0.5340, Accuracy: 0.7386
# Epoch [350/500], Loss: 0.5119, Accuracy: 0.7568
# Epoch [400/500], Loss: 0.5000, Accuracy: 0.7638
# Epoch [450/500], Loss: 0.4937, Accuracy: 0.7653
# Epoch [500/500], Loss: 0.4897, Accuracy: 0.7701
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_21_acc_0.7701.pkl
# Final accuracy: 0.7701
# Parameter containing:
# tensor([[-2.7946, -0.6038],
#         [ 1.3097,  1.8610],
#         [ 0.0058, -2.6667]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.7865,  2.1566],
#         [-0.8038,  1.1693],
#         [-0.9942,  1.0089]], requires_grad=True)
#
# === Training with seed 22 ===
# initial loss =  3.048647403717041
# Epoch [50/500], Loss: 1.2114, Accuracy: 0.5000
# Epoch [100/500], Loss: 0.6970, Accuracy: 0.5248
# Epoch [150/500], Loss: 0.6521, Accuracy: 0.5844
# Epoch [200/500], Loss: 0.6447, Accuracy: 0.6097
# Epoch [250/500], Loss: 0.6405, Accuracy: 0.6108
# Epoch [300/500], Loss: 0.6365, Accuracy: 0.6176
# Epoch [350/500], Loss: 0.6318, Accuracy: 0.6262
# Epoch [400/500], Loss: 0.6262, Accuracy: 0.6341
# Epoch [450/500], Loss: 0.6201, Accuracy: 0.6438
# Epoch [500/500], Loss: 0.6124, Accuracy: 0.6586
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_22_acc_0.6586.pkl
# Final accuracy: 0.6586
# Parameter containing:
# tensor([[ 1.7865,  2.1566],
#         [-0.8038,  1.1693],
#         [-0.9942,  1.0089]], requires_grad=True)
# Parameter containing:
# tensor([[-0.9911, -0.2754],
#         [-1.4884,  0.7861],
#         [-1.9761, -1.1266]], requires_grad=True)
#
# === Training with seed 23 ===
# initial loss =  0.7909505367279053
# Epoch [50/500], Loss: 0.5940, Accuracy: 0.6905
# Epoch [100/500], Loss: 0.5567, Accuracy: 0.7107
# Epoch [150/500], Loss: 0.5506, Accuracy: 0.7151
# Epoch [200/500], Loss: 0.5465, Accuracy: 0.7178
# Epoch [250/500], Loss: 0.5438, Accuracy: 0.7212
# Epoch [300/500], Loss: 0.5409, Accuracy: 0.7252
# Epoch [350/500], Loss: 0.5380, Accuracy: 0.7276
# Epoch [400/500], Loss: 0.5369, Accuracy: 0.7280
# Epoch [450/500], Loss: 0.5367, Accuracy: 0.7277
# Epoch [500/500], Loss: 0.5367, Accuracy: 0.7279
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_23_acc_0.7279.pkl
# Final accuracy: 0.7279
# Parameter containing:
# tensor([[-0.9911, -0.2754],
#         [-1.4884,  0.7861],
#         [-1.9761, -1.1266]], requires_grad=True)
# Parameter containing:
# tensor([[-1.1712, -1.2067],
#         [-0.8942, -2.6824],
#         [-1.8070,  1.8131]], requires_grad=True)
#
# === Training with seed 24 ===
# initial loss =  7.89273738861084
# Epoch [50/500], Loss: 4.5571, Accuracy: 0.5000
# Epoch [100/500], Loss: 2.5072, Accuracy: 0.5000
# Epoch [150/500], Loss: 1.3016, Accuracy: 0.5000
# Epoch [200/500], Loss: 0.8731, Accuracy: 0.3565
# Epoch [250/500], Loss: 0.7231, Accuracy: 0.3399
# Epoch [300/500], Loss: 0.6449, Accuracy: 0.5685
# Epoch [350/500], Loss: 0.6094, Accuracy: 0.6649
# Epoch [400/500], Loss: 0.5934, Accuracy: 0.7020
# Epoch [450/500], Loss: 0.5858, Accuracy: 0.7084
# Epoch [500/500], Loss: 0.5815, Accuracy: 0.7108
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_24_acc_0.7108.pkl
# Final accuracy: 0.7108
# Parameter containing:
# tensor([[-1.1712, -1.2067],
#         [-0.8942, -2.6824],
#         [-1.8070,  1.8131]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.1086,  2.8354],
#         [ 2.2876, -2.9662],
#         [-1.1661,  2.6305]], requires_grad=True)
#
# === Training with seed 25 ===
# initial loss =  1.1407551765441895
# Epoch [50/500], Loss: 0.6745, Accuracy: 0.6103
# Epoch [100/500], Loss: 0.6178, Accuracy: 0.7070
# Epoch [150/500], Loss: 0.5897, Accuracy: 0.7001
# Epoch [200/500], Loss: 0.5575, Accuracy: 0.6978
# Epoch [250/500], Loss: 0.5287, Accuracy: 0.7346
# Epoch [300/500], Loss: 0.5023, Accuracy: 0.7597
# Epoch [350/500], Loss: 0.4834, Accuracy: 0.7710
# Epoch [400/500], Loss: 0.4776, Accuracy: 0.7709
# Epoch [450/500], Loss: 0.4771, Accuracy: 0.7709
# Epoch [500/500], Loss: 0.4771, Accuracy: 0.7707
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_25_acc_0.7707.pkl
# Final accuracy: 0.7707
# Parameter containing:
# tensor([[ 0.1086,  2.8354],
#         [ 2.2876, -2.9662],
#         [-1.1661,  2.6305]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.5570,  2.4463],
#         [-2.2362, -2.9113],
#         [-0.6363,  2.6371]], requires_grad=True)
#
# === Training with seed 26 ===
# initial loss =  7.666134357452393
# Epoch [50/500], Loss: 3.9728, Accuracy: 0.5055
# Epoch [100/500], Loss: 1.6715, Accuracy: 0.5500
# Epoch [150/500], Loss: 0.9475, Accuracy: 0.5702
# Epoch [200/500], Loss: 0.7576, Accuracy: 0.6310
# Epoch [250/500], Loss: 0.6504, Accuracy: 0.6696
# Epoch [300/500], Loss: 0.5907, Accuracy: 0.7084
# Epoch [350/500], Loss: 0.5606, Accuracy: 0.7391
# Epoch [400/500], Loss: 0.5404, Accuracy: 0.7516
# Epoch [450/500], Loss: 0.5220, Accuracy: 0.7589
# Epoch [500/500], Loss: 0.5053, Accuracy: 0.7621
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_26_acc_0.7621.pkl
# Final accuracy: 0.7621
# Parameter containing:
# tensor([[ 2.5570,  2.4463],
#         [-2.2362, -2.9113],
#         [-0.6363,  2.6371]], requires_grad=True)
# Parameter containing:
# tensor([[-1.4956,  1.5881],
#         [ 1.7106, -2.8729],
#         [-1.6621,  0.9075]], requires_grad=True)
#
# === Training with seed 27 ===
# initial loss =  0.6289927959442139
# Epoch [50/500], Loss: 0.5371, Accuracy: 0.7655
# Epoch [100/500], Loss: 0.4392, Accuracy: 0.8301
# Epoch [150/500], Loss: 0.3928, Accuracy: 0.8393
# Epoch [200/500], Loss: 0.3803, Accuracy: 0.8377
# Epoch [250/500], Loss: 0.3769, Accuracy: 0.8357
# Epoch [300/500], Loss: 0.3753, Accuracy: 0.8378
# Epoch [350/500], Loss: 0.3743, Accuracy: 0.8390
# Epoch [400/500], Loss: 0.3737, Accuracy: 0.8401
# Epoch [450/500], Loss: 0.3733, Accuracy: 0.8403
# Epoch [500/500], Loss: 0.3731, Accuracy: 0.8408
# *** NEW BEST MODEL: Seed 27, Accuracy 0.8408 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_27_acc_0.8408.pkl
# Final accuracy: 0.8408
# Parameter containing:
# tensor([[-1.4956,  1.5881],
#         [ 1.7106, -2.8729],
#         [-1.6621,  0.9075]], requires_grad=True)
# Parameter containing:
# tensor([[-2.5618,  2.7519],
#         [-0.6420, -1.0113],
#         [ 2.8031,  0.1413]], requires_grad=True)
#
# === Training with seed 28 ===
# initial loss =  3.4322245121002197
# Epoch [50/500], Loss: 1.7765, Accuracy: 0.5937
# Epoch [100/500], Loss: 0.9792, Accuracy: 0.6199
# Epoch [150/500], Loss: 0.7449, Accuracy: 0.5859
# Epoch [200/500], Loss: 0.6846, Accuracy: 0.5531
# Epoch [250/500], Loss: 0.6547, Accuracy: 0.5925
# Epoch [300/500], Loss: 0.6326, Accuracy: 0.6563
# Epoch [350/500], Loss: 0.6119, Accuracy: 0.6551
# Epoch [400/500], Loss: 0.5966, Accuracy: 0.6554
# Epoch [450/500], Loss: 0.5876, Accuracy: 0.6763
# Epoch [500/500], Loss: 0.5809, Accuracy: 0.7235
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_28_acc_0.7235.pkl
# Final accuracy: 0.7235
# Parameter containing:
# tensor([[-2.5618,  2.7519],
#         [-0.6420, -1.0113],
#         [ 2.8031,  0.1413]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.9202,  1.1088],
#         [-0.4969,  2.6912],
#         [-0.4007, -0.6058]], requires_grad=True)
#
# === Training with seed 29 ===
# initial loss =  2.86739444732666
# Epoch [50/500], Loss: 1.1589, Accuracy: 0.5809
# Epoch [100/500], Loss: 0.8173, Accuracy: 0.5964
# Epoch [150/500], Loss: 0.6819, Accuracy: 0.6055
# Epoch [200/500], Loss: 0.6340, Accuracy: 0.6623
# Epoch [250/500], Loss: 0.6071, Accuracy: 0.7046
# Epoch [300/500], Loss: 0.5870, Accuracy: 0.7160
# Epoch [350/500], Loss: 0.5706, Accuracy: 0.7191
# Epoch [400/500], Loss: 0.5559, Accuracy: 0.7201
# Epoch [450/500], Loss: 0.5442, Accuracy: 0.7178
# Epoch [500/500], Loss: 0.5352, Accuracy: 0.7148
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_29_acc_0.7148.pkl
# Final accuracy: 0.7148
# Parameter containing:
# tensor([[ 1.9202,  1.1088],
#         [-0.4969,  2.6912],
#         [-0.4007, -0.6058]], requires_grad=True)
# Parameter containing:
# tensor([[-2.7522, -2.3240],
#         [ 1.1834,  2.2559],
#         [-1.1021, -1.2067]], requires_grad=True)
#
# === Training with seed 30 ===
# initial loss =  3.2068262100219727
# Epoch [50/500], Loss: 1.4011, Accuracy: 0.4229
# Epoch [100/500], Loss: 0.9237, Accuracy: 0.4187
# Epoch [150/500], Loss: 0.7600, Accuracy: 0.4055
# Epoch [200/500], Loss: 0.7026, Accuracy: 0.5451
# Epoch [250/500], Loss: 0.6729, Accuracy: 0.6029
# Epoch [300/500], Loss: 0.6638, Accuracy: 0.6277
# Epoch [350/500], Loss: 0.6604, Accuracy: 0.6227
# Epoch [400/500], Loss: 0.6569, Accuracy: 0.6144
# Epoch [450/500], Loss: 0.6525, Accuracy: 0.6071
# Epoch [500/500], Loss: 0.6462, Accuracy: 0.6105
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_30_acc_0.6105.pkl
# Final accuracy: 0.6105
# Parameter containing:
# tensor([[-2.7522, -2.3240],
#         [ 1.1834,  2.2559],
#         [-1.1021, -1.2067]], requires_grad=True)
# Parameter containing:
# tensor([[-2.1611, -2.1307],
#         [ 1.2971,  2.3180],
#         [ 1.4051,  2.3561]], requires_grad=True)
#
# === Training with seed 31 ===
# initial loss =  4.3650312423706055
# Epoch [50/500], Loss: 1.8611, Accuracy: 0.3363
# Epoch [100/500], Loss: 0.7888, Accuracy: 0.5136
# Epoch [150/500], Loss: 0.7154, Accuracy: 0.6137
# Epoch [200/500], Loss: 0.6867, Accuracy: 0.6463
# Epoch [250/500], Loss: 0.6703, Accuracy: 0.6325
# Epoch [300/500], Loss: 0.6599, Accuracy: 0.6192
# Epoch [350/500], Loss: 0.6538, Accuracy: 0.6131
# Epoch [400/500], Loss: 0.6498, Accuracy: 0.6080
# Epoch [450/500], Loss: 0.6468, Accuracy: 0.6080
# Epoch [500/500], Loss: 0.6447, Accuracy: 0.6091
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_31_acc_0.6091.pkl
# Final accuracy: 0.6091
# Parameter containing:
# tensor([[-2.1611, -2.1307],
#         [ 1.2971,  2.3180],
#         [ 1.4051,  2.3561]], requires_grad=True)
# Parameter containing:
# tensor([[-2.4523,  1.3061],
#         [ 1.3628, -0.0196],
#         [ 2.5845, -0.7939]], requires_grad=True)
#
# === Training with seed 32 ===
# initial loss =  1.9130550622940063
# Epoch [50/500], Loss: 0.8806, Accuracy: 0.3897
# Epoch [100/500], Loss: 0.6711, Accuracy: 0.5823
# Epoch [150/500], Loss: 0.6650, Accuracy: 0.6008
# Epoch [200/500], Loss: 0.6643, Accuracy: 0.6111
# Epoch [250/500], Loss: 0.6643, Accuracy: 0.6138
# Epoch [300/500], Loss: 0.6643, Accuracy: 0.6144
# Epoch [350/500], Loss: 0.6643, Accuracy: 0.6143
# Epoch [400/500], Loss: 0.6643, Accuracy: 0.6143
# Epoch [450/500], Loss: 0.6643, Accuracy: 0.6143
# Epoch [500/500], Loss: 0.6643, Accuracy: 0.6143
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_32_acc_0.6143.pkl
# Final accuracy: 0.6143
# Parameter containing:
# tensor([[-2.4523,  1.3061],
#         [ 1.3628, -0.0196],
#         [ 2.5845, -0.7939]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.1214,  0.3994],
#         [-1.4915, -2.7188],
#         [ 1.1835,  1.2605]], requires_grad=True)
#
# === Training with seed 33 ===
# initial loss =  1.0383212566375732
# Epoch [50/500], Loss: 0.7347, Accuracy: 0.5547
# Epoch [100/500], Loss: 0.6683, Accuracy: 0.6354
# Epoch [150/500], Loss: 0.5954, Accuracy: 0.7279
# Epoch [200/500], Loss: 0.5251, Accuracy: 0.7764
# Epoch [250/500], Loss: 0.4847, Accuracy: 0.7946
# Epoch [300/500], Loss: 0.4617, Accuracy: 0.8084
# Epoch [350/500], Loss: 0.4375, Accuracy: 0.8228
# Epoch [400/500], Loss: 0.3952, Accuracy: 0.8397
# Epoch [450/500], Loss: 0.3753, Accuracy: 0.8445
# Epoch [500/500], Loss: 0.3656, Accuracy: 0.8489
# *** NEW BEST MODEL: Seed 33, Accuracy 0.8489 ***
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_33_acc_0.8489.pkl
# Final accuracy: 0.8489
# Parameter containing:
# tensor([[ 2.1214,  0.3994],
#         [-1.4915, -2.7188],
#         [ 1.1835,  1.2605]], requires_grad=True)
# Parameter containing:
# tensor([[-1.5151, -1.8294],
#         [-1.1454, -0.3859],
#         [-0.6906, -2.9458]], requires_grad=True)
#
# === Training with seed 34 ===
# initial loss =  0.8719753623008728
# Epoch [50/500], Loss: 0.6236, Accuracy: 0.6917
# Epoch [100/500], Loss: 0.5945, Accuracy: 0.6819
# Epoch [150/500], Loss: 0.5511, Accuracy: 0.7265
# Epoch [200/500], Loss: 0.4955, Accuracy: 0.7462
# Epoch [250/500], Loss: 0.4609, Accuracy: 0.7790
# Epoch [300/500], Loss: 0.4163, Accuracy: 0.8204
# Epoch [350/500], Loss: 0.4028, Accuracy: 0.8295
# Epoch [400/500], Loss: 0.3977, Accuracy: 0.8313
# Epoch [450/500], Loss: 0.3944, Accuracy: 0.8320
# Epoch [500/500], Loss: 0.3829, Accuracy: 0.8303
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_34_acc_0.8303.pkl
# Final accuracy: 0.8303
# Parameter containing:
# tensor([[-1.5151, -1.8294],
#         [-1.1454, -0.3859],
#         [-0.6906, -2.9458]], requires_grad=True)
# Parameter containing:
# tensor([[-0.6459,  1.8991],
#         [ 1.1340,  2.7580],
#         [ 2.4191,  1.3521]], requires_grad=True)
#
# === Training with seed 35 ===
# initial loss =  4.785433292388916
# Epoch [50/500], Loss: 1.7803, Accuracy: 0.5857
# Epoch [100/500], Loss: 0.9215, Accuracy: 0.6538
# Epoch [150/500], Loss: 0.7275, Accuracy: 0.6444
# Epoch [200/500], Loss: 0.6800, Accuracy: 0.6277
# Epoch [250/500], Loss: 0.6603, Accuracy: 0.6331
# Epoch [300/500], Loss: 0.6357, Accuracy: 0.6427
# Epoch [350/500], Loss: 0.6096, Accuracy: 0.6722
# Epoch [400/500], Loss: 0.5808, Accuracy: 0.7091
# Epoch [450/500], Loss: 0.5539, Accuracy: 0.7186
# Epoch [500/500], Loss: 0.5330, Accuracy: 0.7387
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_35_acc_0.7387.pkl
# Final accuracy: 0.7387
# Parameter containing:
# tensor([[-0.6459,  1.8991],
#         [ 1.1340,  2.7580],
#         [ 2.4191,  1.3521]], requires_grad=True)
# Parameter containing:
# tensor([[-2.0079, -0.9864],
#         [-2.4085, -0.0515],
#         [-2.1066,  0.0328]], requires_grad=True)
#
# === Training with seed 36 ===
# initial loss =  0.7404287457466125
# Epoch [50/500], Loss: 0.6466, Accuracy: 0.6917
# Epoch [100/500], Loss: 0.5780, Accuracy: 0.7104
# Epoch [150/500], Loss: 0.5211, Accuracy: 0.7361
# Epoch [200/500], Loss: 0.5154, Accuracy: 0.7323
# Epoch [250/500], Loss: 0.5099, Accuracy: 0.7335
# Epoch [300/500], Loss: 0.5080, Accuracy: 0.7392
# Epoch [350/500], Loss: 0.5072, Accuracy: 0.7401
# Epoch [400/500], Loss: 0.5069, Accuracy: 0.7402
# Epoch [450/500], Loss: 0.5067, Accuracy: 0.7400
# Epoch [500/500], Loss: 0.5066, Accuracy: 0.7393
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_36_acc_0.7393.pkl
# Final accuracy: 0.7393
# Parameter containing:
# tensor([[-2.0079, -0.9864],
#         [-2.4085, -0.0515],
#         [-2.1066,  0.0328]], requires_grad=True)
# Parameter containing:
# tensor([[-2.9839,  2.2602],
#         [-1.2241,  2.5958],
#         [ 2.3432,  0.6873]], requires_grad=True)
#
# === Training with seed 37 ===
# initial loss =  0.8285471796989441
# Epoch [50/500], Loss: 0.5980, Accuracy: 0.7017
# Epoch [100/500], Loss: 0.5450, Accuracy: 0.7318
# Epoch [150/500], Loss: 0.4966, Accuracy: 0.7740
# Epoch [200/500], Loss: 0.4523, Accuracy: 0.8028
# Epoch [250/500], Loss: 0.4304, Accuracy: 0.8174
# Epoch [300/500], Loss: 0.4199, Accuracy: 0.8248
# Epoch [350/500], Loss: 0.4092, Accuracy: 0.8394
# Epoch [400/500], Loss: 0.3921, Accuracy: 0.8440
# Epoch [450/500], Loss: 0.3783, Accuracy: 0.8455
# Epoch [500/500], Loss: 0.3767, Accuracy: 0.8469
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_37_acc_0.8469.pkl
# Final accuracy: 0.8469
# Parameter containing:
# tensor([[-2.9839,  2.2602],
#         [-1.2241,  2.5958],
#         [ 2.3432,  0.6873]], requires_grad=True)
# Parameter containing:
# tensor([[-1.7034, -2.4032],
#         [ 2.5859,  2.5499],
#         [ 0.5622, -1.5651]], requires_grad=True)
#
# === Training with seed 38 ===
# initial loss =  4.494433403015137
# Epoch [50/500], Loss: 2.4060, Accuracy: 0.3548
# Epoch [100/500], Loss: 1.2444, Accuracy: 0.4101
# Epoch [150/500], Loss: 0.8315, Accuracy: 0.5293
# Epoch [200/500], Loss: 0.7492, Accuracy: 0.5661
# Epoch [250/500], Loss: 0.7138, Accuracy: 0.5678
# Epoch [300/500], Loss: 0.6971, Accuracy: 0.5886
# Epoch [350/500], Loss: 0.6889, Accuracy: 0.6188
# Epoch [400/500], Loss: 0.6843, Accuracy: 0.6251
# Epoch [450/500], Loss: 0.6810, Accuracy: 0.6264
# Epoch [500/500], Loss: 0.6783, Accuracy: 0.6256
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_38_acc_0.6256.pkl
# Final accuracy: 0.6256
# Parameter containing:
# tensor([[-1.7034, -2.4032],
#         [ 2.5859,  2.5499],
#         [ 0.5622, -1.5651]], requires_grad=True)
# Parameter containing:
# tensor([[-0.9684,  2.8197],
#         [ 1.4901,  1.6125],
#         [ 0.1580,  1.6625]], requires_grad=True)
#
# === Training with seed 39 ===
# initial loss =  2.8395397663116455
# Epoch [50/500], Loss: 1.4787, Accuracy: 0.4263
# Epoch [100/500], Loss: 0.7621, Accuracy: 0.5280
# Epoch [150/500], Loss: 0.6276, Accuracy: 0.5869
# Epoch [200/500], Loss: 0.5568, Accuracy: 0.6606
# Epoch [250/500], Loss: 0.5117, Accuracy: 0.7597
# Epoch [300/500], Loss: 0.4679, Accuracy: 0.7866
# Epoch [350/500], Loss: 0.4260, Accuracy: 0.8109
# Epoch [400/500], Loss: 0.4047, Accuracy: 0.8216
# Epoch [450/500], Loss: 0.3960, Accuracy: 0.8263
# Epoch [500/500], Loss: 0.3923, Accuracy: 0.8290
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_39_acc_0.8290.pkl
# Final accuracy: 0.8290
# Parameter containing:
# tensor([[-0.9684,  2.8197],
#         [ 1.4901,  1.6125],
#         [ 0.1580,  1.6625]], requires_grad=True)
# Parameter containing:
# tensor([[-2.3221,  1.0672],
#         [-2.8961, -2.2779],
#         [-2.1820,  1.8535]], requires_grad=True)
#
# === Training with seed 40 ===
# initial loss =  5.091128826141357
# Epoch [50/500], Loss: 2.6157, Accuracy: 0.5000
# Epoch [100/500], Loss: 1.2286, Accuracy: 0.5000
# Epoch [150/500], Loss: 0.7591, Accuracy: 0.5910
# Epoch [200/500], Loss: 0.6956, Accuracy: 0.6166
# Epoch [250/500], Loss: 0.6859, Accuracy: 0.6222
# Epoch [300/500], Loss: 0.6803, Accuracy: 0.6367
# Epoch [350/500], Loss: 0.6758, Accuracy: 0.6438
# Epoch [400/500], Loss: 0.6718, Accuracy: 0.6457
# Epoch [450/500], Loss: 0.6678, Accuracy: 0.6404
# Epoch [500/500], Loss: 0.6622, Accuracy: 0.6375
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_40_acc_0.6375.pkl
# Final accuracy: 0.6375
# Parameter containing:
# tensor([[-2.3221,  1.0672],
#         [-2.8961, -2.2779],
#         [-2.1820,  1.8535]], requires_grad=True)
# Parameter containing:
# tensor([[-0.0695, -1.7538],
#         [-1.1620, -2.6489],
#         [ 1.9881, -0.2603]], requires_grad=True)
#
# === Training with seed 41 ===
# initial loss =  1.731451392173767
# Epoch [50/500], Loss: 0.6412, Accuracy: 0.6630
# Epoch [100/500], Loss: 0.5818, Accuracy: 0.7308
# Epoch [150/500], Loss: 0.5410, Accuracy: 0.7759
# Epoch [200/500], Loss: 0.5169, Accuracy: 0.7651
# Epoch [250/500], Loss: 0.5034, Accuracy: 0.7611
# Epoch [300/500], Loss: 0.4949, Accuracy: 0.7622
# Epoch [350/500], Loss: 0.4889, Accuracy: 0.7644
# Epoch [400/500], Loss: 0.4837, Accuracy: 0.7675
# Epoch [450/500], Loss: 0.4786, Accuracy: 0.7735
# Epoch [500/500], Loss: 0.4737, Accuracy: 0.7811
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_41_acc_0.7811.pkl
# Final accuracy: 0.7811
# Parameter containing:
# tensor([[-0.0695, -1.7538],
#         [-1.1620, -2.6489],
#         [ 1.9881, -0.2603]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.4434, -1.4005],
#         [ 0.7647, -1.3822],
#         [-0.3518, -1.2185]], requires_grad=True)
#
# === Training with seed 42 ===
# initial loss =  3.29074764251709
# Epoch [50/500], Loss: 1.4940, Accuracy: 0.5000
# Epoch [100/500], Loss: 0.7480, Accuracy: 0.5000
# Epoch [150/500], Loss: 0.6598, Accuracy: 0.5795
# Epoch [200/500], Loss: 0.6557, Accuracy: 0.6742
# Epoch [250/500], Loss: 0.6530, Accuracy: 0.6775
# Epoch [300/500], Loss: 0.6485, Accuracy: 0.6756
# Epoch [350/500], Loss: 0.6412, Accuracy: 0.6490
# Epoch [400/500], Loss: 0.6323, Accuracy: 0.6439
# Epoch [450/500], Loss: 0.6240, Accuracy: 0.6536
# Epoch [500/500], Loss: 0.6177, Accuracy: 0.6626
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_42_acc_0.6626.pkl
# Final accuracy: 0.6626
# Parameter containing:
# tensor([[ 0.4434, -1.4005],
#         [ 0.7647, -1.3822],
#         [-0.3518, -1.2185]], requires_grad=True)
# Parameter containing:
# tensor([[-1.3433,  2.0374],
#         [-2.0624, -2.3568],
#         [ 1.3568, -1.0556]], requires_grad=True)
#
# === Training with seed 43 ===
# initial loss =  5.071099758148193
# Epoch [50/500], Loss: 1.8432, Accuracy: 0.4419
# Epoch [100/500], Loss: 0.7745, Accuracy: 0.4438
# Epoch [150/500], Loss: 0.6549, Accuracy: 0.6707
# Epoch [200/500], Loss: 0.6308, Accuracy: 0.6790
# Epoch [250/500], Loss: 0.6152, Accuracy: 0.6831
# Epoch [300/500], Loss: 0.5975, Accuracy: 0.7062
# Epoch [350/500], Loss: 0.5724, Accuracy: 0.7251
# Epoch [400/500], Loss: 0.5320, Accuracy: 0.7428
# Epoch [450/500], Loss: 0.4913, Accuracy: 0.7597
# Epoch [500/500], Loss: 0.4645, Accuracy: 0.7647
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_43_acc_0.7647.pkl
# Final accuracy: 0.7647
# Parameter containing:
# tensor([[-1.3433,  2.0374],
#         [-2.0624, -2.3568],
#         [ 1.3568, -1.0556]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.2699,  1.7873],
#         [-1.3293,  2.3683],
#         [ 1.0163,  2.3700]], requires_grad=True)
#
# === Training with seed 44 ===
# initial loss =  0.9678841829299927
# Epoch [50/500], Loss: 0.6279, Accuracy: 0.6341
# Epoch [100/500], Loss: 0.5960, Accuracy: 0.6580
# Epoch [150/500], Loss: 0.5918, Accuracy: 0.6695
# Epoch [200/500], Loss: 0.5591, Accuracy: 0.7206
# Epoch [250/500], Loss: 0.4982, Accuracy: 0.7715
# Epoch [300/500], Loss: 0.4816, Accuracy: 0.7766
# Epoch [350/500], Loss: 0.4804, Accuracy: 0.7772
# Epoch [400/500], Loss: 0.4800, Accuracy: 0.7777
# Epoch [450/500], Loss: 0.4796, Accuracy: 0.7794
# Epoch [500/500], Loss: 0.4790, Accuracy: 0.7795
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_44_acc_0.7795.pkl
# Final accuracy: 0.7795
# Parameter containing:
# tensor([[ 1.2699,  1.7873],
#         [-1.3293,  2.3683],
#         [ 1.0163,  2.3700]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.9169,  0.6736],
#         [ 2.9001, -1.9044],
#         [-2.2565, -0.4427]], requires_grad=True)
#
# === Training with seed 45 ===
# initial loss =  4.557809829711914
# Epoch [50/500], Loss: 1.0737, Accuracy: 0.6237
# Epoch [100/500], Loss: 0.6569, Accuracy: 0.6526
# Epoch [150/500], Loss: 0.6111, Accuracy: 0.7287
# Epoch [200/500], Loss: 0.5845, Accuracy: 0.7371
# Epoch [250/500], Loss: 0.5575, Accuracy: 0.7478
# Epoch [300/500], Loss: 0.5356, Accuracy: 0.7541
# Epoch [350/500], Loss: 0.5205, Accuracy: 0.7555
# Epoch [400/500], Loss: 0.5103, Accuracy: 0.7542
# Epoch [450/500], Loss: 0.5028, Accuracy: 0.7542
# Epoch [500/500], Loss: 0.4974, Accuracy: 0.7541
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_45_acc_0.7541.pkl
# Final accuracy: 0.7541
# Parameter containing:
# tensor([[ 0.9169,  0.6736],
#         [ 2.9001, -1.9044],
#         [-2.2565, -0.4427]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.8914, -0.1140],
#         [ 1.4328, -2.8128],
#         [ 1.2291,  1.4186]], requires_grad=True)
#
# === Training with seed 46 ===
# initial loss =  0.815178394317627
# Epoch [50/500], Loss: 0.6781, Accuracy: 0.4857
# Epoch [100/500], Loss: 0.6368, Accuracy: 0.6088
# Epoch [150/500], Loss: 0.6056, Accuracy: 0.6483
# Epoch [200/500], Loss: 0.5987, Accuracy: 0.6548
# Epoch [250/500], Loss: 0.5986, Accuracy: 0.6546
# Epoch [300/500], Loss: 0.5986, Accuracy: 0.6547
# Epoch [350/500], Loss: 0.5986, Accuracy: 0.6547
# Epoch [400/500], Loss: 0.5986, Accuracy: 0.6547
# Epoch [450/500], Loss: 0.5986, Accuracy: 0.6547
# Epoch [500/500], Loss: 0.5986, Accuracy: 0.6547
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_46_acc_0.6547.pkl
# Final accuracy: 0.6547
# Parameter containing:
# tensor([[ 1.8914, -0.1140],
#         [ 1.4328, -2.8128],
#         [ 1.2291,  1.4186]], requires_grad=True)
# Parameter containing:
# tensor([[-2.7897, -2.1466],
#         [-0.5661,  0.2044],
#         [ 0.5172, -2.1186]], requires_grad=True)
#
# === Training with seed 47 ===
# initial loss =  1.6237231492996216
# Epoch [50/500], Loss: 0.8750, Accuracy: 0.6805
# Epoch [100/500], Loss: 0.6664, Accuracy: 0.6869
# Epoch [150/500], Loss: 0.6025, Accuracy: 0.6907
# Epoch [200/500], Loss: 0.5831, Accuracy: 0.6936
# Epoch [250/500], Loss: 0.5658, Accuracy: 0.7018
# Epoch [300/500], Loss: 0.5433, Accuracy: 0.7083
# Epoch [350/500], Loss: 0.5328, Accuracy: 0.7169
# Epoch [400/500], Loss: 0.5300, Accuracy: 0.7258
# Epoch [450/500], Loss: 0.5290, Accuracy: 0.7302
# Epoch [500/500], Loss: 0.5286, Accuracy: 0.7328
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_47_acc_0.7328.pkl
# Final accuracy: 0.7328
# Parameter containing:
# tensor([[-2.7897, -2.1466],
#         [-0.5661,  0.2044],
#         [ 0.5172, -2.1186]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.2143, -0.3838],
#         [ 1.4105,  1.5113],
#         [-2.5579, -1.0460]], requires_grad=True)
#
# === Training with seed 48 ===
# initial loss =  0.8976275324821472
# Epoch [50/500], Loss: 0.5747, Accuracy: 0.7085
# Epoch [100/500], Loss: 0.5405, Accuracy: 0.7169
# Epoch [150/500], Loss: 0.5294, Accuracy: 0.7296
# Epoch [200/500], Loss: 0.5248, Accuracy: 0.7375
# Epoch [250/500], Loss: 0.5179, Accuracy: 0.7432
# Epoch [300/500], Loss: 0.5029, Accuracy: 0.7560
# Epoch [350/500], Loss: 0.4658, Accuracy: 0.7869
# Epoch [400/500], Loss: 0.4141, Accuracy: 0.8192
# Epoch [450/500], Loss: 0.3974, Accuracy: 0.8265
# Epoch [500/500], Loss: 0.3888, Accuracy: 0.8297
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_48_acc_0.8297.pkl
# Final accuracy: 0.8297
# Parameter containing:
# ...
# Final accuracy: 0.6143
# Parameter containing:
# tensor([[-0.9485, -0.3601],
#         [ 0.8047,  0.7343],
#         [ 0.8007,  2.1478]], requires_grad=True)
# Parameter containing:
# tensor([[-2.3545,  2.5242],
#         [-0.7521,  0.9261],
#         [-1.3535, -1.8779]], requires_grad=True)
#
# === Training with seed 112 ===
# initial loss =  2.9250969886779785
# Epoch [50/500], Loss: 1.1293, Accuracy: 0.6092
# Epoch [100/500], Loss: 0.7739, Accuracy: 0.6020
# Epoch [150/500], Loss: 0.6707, Accuracy: 0.6053
# Epoch [200/500], Loss: 0.6310, Accuracy: 0.6439
# Epoch [250/500], Loss: 0.5896, Accuracy: 0.7090
# Epoch [300/500], Loss: 0.5651, Accuracy: 0.7637
# Epoch [350/500], Loss: 0.5399, Accuracy: 0.7692
# Epoch [400/500], Loss: 0.5130, Accuracy: 0.7612
# Epoch [450/500], Loss: 0.4999, Accuracy: 0.7583
# Epoch [500/500], Loss: 0.4948, Accuracy: 0.7572
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_112_acc_0.7572.pkl
# Final accuracy: 0.7572
# Parameter containing:
# tensor([[-2.3545,  2.5242],
#         [-0.7521,  0.9261],
#         [-1.3535, -1.8779]], requires_grad=True)
# Parameter containing:
# tensor([[-1.9065, -1.3959],
#         [-1.8419, -0.8041],
#         [-0.8145,  0.6104]], requires_grad=True)
#
# === Training with seed 113 ===
# initial loss =  6.314547538757324
# Epoch [50/500], Loss: 3.1583, Accuracy: 0.5000
# Epoch [100/500], Loss: 1.0523, Accuracy: 0.5421
# Epoch [150/500], Loss: 0.7055, Accuracy: 0.5215
# Epoch [200/500], Loss: 0.6834, Accuracy: 0.5917
# Epoch [250/500], Loss: 0.6776, Accuracy: 0.6136
# Epoch [300/500], Loss: 0.6739, Accuracy: 0.6188
# Epoch [350/500], Loss: 0.6712, Accuracy: 0.6203
# Epoch [400/500], Loss: 0.6693, Accuracy: 0.6211
# Epoch [450/500], Loss: 0.6682, Accuracy: 0.6205
# Epoch [500/500], Loss: 0.6675, Accuracy: 0.6200
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_113_acc_0.6200.pkl
# Final accuracy: 0.6200
# Parameter containing:
# tensor([[-1.9065, -1.3959],
#         [-1.8419, -0.8041],
#         [-0.8145,  0.6104]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.2710,  1.2368],
#         [-1.3395,  2.1608],
#         [ 0.4931, -1.8440]], requires_grad=True)
#
# === Training with seed 114 ===
# initial loss =  4.102380275726318
# Epoch [50/500], Loss: 1.6472, Accuracy: 0.5581
# Epoch [100/500], Loss: 0.8632, Accuracy: 0.4904
# Epoch [150/500], Loss: 0.7270, Accuracy: 0.5329
# Epoch [200/500], Loss: 0.6739, Accuracy: 0.6115
# Epoch [250/500], Loss: 0.6450, Accuracy: 0.6353
# Epoch [300/500], Loss: 0.6287, Accuracy: 0.6522
# Epoch [350/500], Loss: 0.6138, Accuracy: 0.6958
# Epoch [400/500], Loss: 0.6006, Accuracy: 0.7302
# Epoch [450/500], Loss: 0.5920, Accuracy: 0.7492
# Epoch [500/500], Loss: 0.5861, Accuracy: 0.7565
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_114_acc_0.7565.pkl
# Final accuracy: 0.7565
# Parameter containing:
# tensor([[ 2.2710,  1.2368],
#         [-1.3395,  2.1608],
#         [ 0.4931, -1.8440]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.8189,  2.4874],
#         [-0.2083, -2.0800],
#         [ 2.4374,  2.7253]], requires_grad=True)
#
# === Training with seed 115 ===
# initial loss =  2.1634936332702637
# Epoch [50/500], Loss: 0.7942, Accuracy: 0.4989
# Epoch [100/500], Loss: 0.6518, Accuracy: 0.6392
# Epoch [150/500], Loss: 0.6439, Accuracy: 0.6397
# Epoch [200/500], Loss: 0.6417, Accuracy: 0.6404
# Epoch [250/500], Loss: 0.6399, Accuracy: 0.6431
# Epoch [300/500], Loss: 0.6381, Accuracy: 0.6480
# Epoch [350/500], Loss: 0.6359, Accuracy: 0.6542
# Epoch [400/500], Loss: 0.6319, Accuracy: 0.6636
# Epoch [450/500], Loss: 0.6248, Accuracy: 0.6757
# Epoch [500/500], Loss: 0.6137, Accuracy: 0.6929
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_115_acc_0.6929.pkl
# Final accuracy: 0.6929
# Parameter containing:
# tensor([[ 0.8189,  2.4874],
#         [-0.2083, -2.0800],
#         [ 2.4374,  2.7253]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3925, -1.9790],
#         [-2.2106,  0.2436],
#         [ 2.9927,  1.6915]], requires_grad=True)
#
# === Training with seed 116 ===
# initial loss =  3.770552396774292
# Epoch [50/500], Loss: 1.7850, Accuracy: 0.4424
# Epoch [100/500], Loss: 0.9701, Accuracy: 0.3582
# Epoch [150/500], Loss: 0.7817, Accuracy: 0.4038
# Epoch [200/500], Loss: 0.7267, Accuracy: 0.4576
# Epoch [250/500], Loss: 0.7018, Accuracy: 0.4711
# Epoch [300/500], Loss: 0.6877, Accuracy: 0.4924
# Epoch [350/500], Loss: 0.6775, Accuracy: 0.5253
# Epoch [400/500], Loss: 0.6683, Accuracy: 0.5546
# Epoch [450/500], Loss: 0.6598, Accuracy: 0.5746
# Epoch [500/500], Loss: 0.6525, Accuracy: 0.5825
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_116_acc_0.5825.pkl
# Final accuracy: 0.5825
# Parameter containing:
# tensor([[ 0.3925, -1.9790],
#         [-2.2106,  0.2436],
#         [ 2.9927,  1.6915]], requires_grad=True)
# Parameter containing:
# tensor([[-0.2616, -2.8106],
#         [ 1.7636, -2.8949],
#         [-2.4141, -0.5150]], requires_grad=True)
#
# === Training with seed 117 ===
# initial loss =  0.5654106736183167
# Epoch [50/500], Loss: 0.4498, Accuracy: 0.7870
# Epoch [100/500], Loss: 0.4203, Accuracy: 0.8018
# Epoch [150/500], Loss: 0.4096, Accuracy: 0.8085
# Epoch [200/500], Loss: 0.4025, Accuracy: 0.8116
# Epoch [250/500], Loss: 0.3998, Accuracy: 0.8112
# Epoch [300/500], Loss: 0.3985, Accuracy: 0.8104
# Epoch [350/500], Loss: 0.3979, Accuracy: 0.8098
# Epoch [400/500], Loss: 0.3977, Accuracy: 0.8100
# Epoch [450/500], Loss: 0.3976, Accuracy: 0.8097
# Epoch [500/500], Loss: 0.3975, Accuracy: 0.8094
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_117_acc_0.8094.pkl
# Final accuracy: 0.8094
# Parameter containing:
# tensor([[-0.2616, -2.8106],
#         [ 1.7636, -2.8949],
#         [-2.4141, -0.5150]], requires_grad=True)
# Parameter containing:
# tensor([[-0.1294, -2.9352],
#         [ 2.5742,  2.8120],
#         [ 0.6613, -2.2507]], requires_grad=True)
#
# === Training with seed 118 ===
# initial loss =  1.34865140914917
# Epoch [50/500], Loss: 0.7236, Accuracy: 0.6114
# Epoch [100/500], Loss: 0.6405, Accuracy: 0.6515
# Epoch [150/500], Loss: 0.5842, Accuracy: 0.6596
# Epoch [200/500], Loss: 0.5482, Accuracy: 0.6804
# Epoch [250/500], Loss: 0.5250, Accuracy: 0.6971
# Epoch [300/500], Loss: 0.4988, Accuracy: 0.7195
# Epoch [350/500], Loss: 0.4713, Accuracy: 0.7557
# Epoch [400/500], Loss: 0.4533, Accuracy: 0.8004
# Epoch [450/500], Loss: 0.4460, Accuracy: 0.8135
# Epoch [500/500], Loss: 0.4430, Accuracy: 0.8185
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_118_acc_0.8185.pkl
# Final accuracy: 0.8185
# Parameter containing:
# tensor([[-0.1294, -2.9352],
#         [ 2.5742,  2.8120],
#         [ 0.6613, -2.2507]], requires_grad=True)
# Parameter containing:
# tensor([[-0.8166, -2.2730],
#         [-1.3970, -1.4567],
#         [ 2.9052, -1.9658]], requires_grad=True)
#
# === Training with seed 119 ===
# initial loss =  1.2694499492645264
# Epoch [50/500], Loss: 0.5931, Accuracy: 0.6633
# Epoch [100/500], Loss: 0.5315, Accuracy: 0.7469
# Epoch [150/500], Loss: 0.4947, Accuracy: 0.7670
# Epoch [200/500], Loss: 0.4868, Accuracy: 0.7698
# Epoch [250/500], Loss: 0.4853, Accuracy: 0.7710
# Epoch [300/500], Loss: 0.4850, Accuracy: 0.7712
# Epoch [350/500], Loss: 0.4849, Accuracy: 0.7717
# Epoch [400/500], Loss: 0.4848, Accuracy: 0.7716
# Epoch [450/500], Loss: 0.4846, Accuracy: 0.7711
# Epoch [500/500], Loss: 0.4844, Accuracy: 0.7717
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_119_acc_0.7717.pkl
# Final accuracy: 0.7717
# Parameter containing:
# tensor([[-0.8166, -2.2730],
#         [-1.3970, -1.4567],
#         [ 2.9052, -1.9658]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.3414, -2.8904],
#         [ 2.3475, -2.0148],
#         [-1.7412, -2.9862]], requires_grad=True)
#
# === Training with seed 120 ===
# initial loss =  2.0933279991149902
# Epoch [50/500], Loss: 0.9317, Accuracy: 0.5612
# Epoch [100/500], Loss: 0.7613, Accuracy: 0.6009
# Epoch [150/500], Loss: 0.6654, Accuracy: 0.6039
# Epoch [200/500], Loss: 0.6055, Accuracy: 0.7480
# Epoch [250/500], Loss: 0.5601, Accuracy: 0.7428
# Epoch [300/500], Loss: 0.5071, Accuracy: 0.7618
# Epoch [350/500], Loss: 0.4468, Accuracy: 0.8088
# Epoch [400/500], Loss: 0.4130, Accuracy: 0.8305
# Epoch [450/500], Loss: 0.3975, Accuracy: 0.8350
# Epoch [500/500], Loss: 0.3865, Accuracy: 0.8371
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_120_acc_0.8371.pkl
# Final accuracy: 0.8371
# Parameter containing:
# tensor([[ 1.3414, -2.8904],
#         [ 2.3475, -2.0148],
#         [-1.7412, -2.9862]], requires_grad=True)
# Parameter containing:
# tensor([[-2.0512,  2.8608],
#         [-2.5898,  2.3229],
#         [-2.3434, -0.5922]], requires_grad=True)
#
# === Training with seed 121 ===
# initial loss =  1.037062168121338
# Epoch [50/500], Loss: 0.6828, Accuracy: 0.6335
# Epoch [100/500], Loss: 0.6387, Accuracy: 0.6202
# Epoch [150/500], Loss: 0.6189, Accuracy: 0.6253
# Epoch [200/500], Loss: 0.5977, Accuracy: 0.6354
# Epoch [250/500], Loss: 0.5682, Accuracy: 0.7423
# Epoch [300/500], Loss: 0.5419, Accuracy: 0.7701
# Epoch [350/500], Loss: 0.5158, Accuracy: 0.7593
# Epoch [400/500], Loss: 0.5023, Accuracy: 0.7577
# Epoch [450/500], Loss: 0.4960, Accuracy: 0.7573
# Epoch [500/500], Loss: 0.4928, Accuracy: 0.7568
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_121_acc_0.7568.pkl
# Final accuracy: 0.7568
# Parameter containing:
# tensor([[-2.0512,  2.8608],
#         [-2.5898,  2.3229],
#         [-2.3434, -0.5922]], requires_grad=True)
# Parameter containing:
# tensor([[-2.6617,  1.4225],
#         [ 2.1442,  0.1759],
#         [ 1.4321, -1.9588]], requires_grad=True)
#
# === Training with seed 122 ===
# initial loss =  14.143011093139648
# Epoch [50/500], Loss: 8.3089, Accuracy: 0.5000
# Epoch [100/500], Loss: 4.2408, Accuracy: 0.5000
# Epoch [150/500], Loss: 1.6805, Accuracy: 0.5000
# Epoch [200/500], Loss: 0.7233, Accuracy: 0.6465
# Epoch [250/500], Loss: 0.6644, Accuracy: 0.6093
# Epoch [300/500], Loss: 0.6641, Accuracy: 0.6129
# Epoch [350/500], Loss: 0.6640, Accuracy: 0.6132
# Epoch [400/500], Loss: 0.6639, Accuracy: 0.6130
# Epoch [450/500], Loss: 0.6636, Accuracy: 0.6127
# Epoch [500/500], Loss: 0.6631, Accuracy: 0.6127
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_122_acc_0.6127.pkl
# Final accuracy: 0.6127
# Parameter containing:
# tensor([[-2.6617,  1.4225],
#         [ 2.1442,  0.1759],
#         [ 1.4321, -1.9588]], requires_grad=True)
# Parameter containing:
# tensor([[ 1.9644, -0.7075],
#         [ 0.9630,  2.1214],
#         [ 0.5589,  0.8204]], requires_grad=True)
#
# === Training with seed 123 ===
# initial loss =  2.5108766555786133
# Epoch [50/500], Loss: 0.7891, Accuracy: 0.3183
# Epoch [100/500], Loss: 0.6674, Accuracy: 0.6757
# Epoch [150/500], Loss: 0.6442, Accuracy: 0.6112
# Epoch [200/500], Loss: 0.6252, Accuracy: 0.6100
# Epoch [250/500], Loss: 0.5988, Accuracy: 0.6403
# Epoch [300/500], Loss: 0.5789, Accuracy: 0.6596
# Epoch [350/500], Loss: 0.5633, Accuracy: 0.7147
# Epoch [400/500], Loss: 0.5451, Accuracy: 0.7481
# Epoch [450/500], Loss: 0.5220, Accuracy: 0.7752
# Epoch [500/500], Loss: 0.5015, Accuracy: 0.7870
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_123_acc_0.7870.pkl
# Final accuracy: 0.7870
# Parameter containing:
# tensor([[ 1.9644, -0.7075],
#         [ 0.9630,  2.1214],
#         [ 0.5589,  0.8204]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0176,  0.9567],
#         [ 2.3574, -0.7914],
#         [-1.1599, -0.1544]], requires_grad=True)
#
# === Training with seed 124 ===
# initial loss =  1.8946876525878906
# Epoch [50/500], Loss: 0.8646, Accuracy: 0.4876
# Epoch [100/500], Loss: 0.6080, Accuracy: 0.6479
# Epoch [150/500], Loss: 0.5462, Accuracy: 0.7147
# Epoch [200/500], Loss: 0.5192, Accuracy: 0.7511
# Epoch [250/500], Loss: 0.4717, Accuracy: 0.7912
# Epoch [300/500], Loss: 0.4426, Accuracy: 0.8148
# Epoch [350/500], Loss: 0.4187, Accuracy: 0.8262
# Epoch [400/500], Loss: 0.4014, Accuracy: 0.8367
# Epoch [450/500], Loss: 0.3896, Accuracy: 0.8441
# Epoch [500/500], Loss: 0.3816, Accuracy: 0.8478
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_124_acc_0.8478.pkl
# Final accuracy: 0.8478
# Parameter containing:
# tensor([[ 0.0176,  0.9567],
#         [ 2.3574, -0.7914],
#         [-1.1599, -0.1544]], requires_grad=True)
# Parameter containing:
# tensor([[ 2.4438,  2.8359],
#         [-0.5818, -2.9595],
#         [-2.8949, -2.7062]], requires_grad=True)
#
# === Training with seed 125 ===
# initial loss =  5.825693130493164
# Epoch [50/500], Loss: 3.5092, Accuracy: 0.4615
# Epoch [100/500], Loss: 2.0297, Accuracy: 0.4645
# Epoch [150/500], Loss: 1.0921, Accuracy: 0.4664
# Epoch [200/500], Loss: 0.7299, Accuracy: 0.5163
# Epoch [250/500], Loss: 0.6368, Accuracy: 0.6919
# Epoch [300/500], Loss: 0.6012, Accuracy: 0.7064
# Epoch [350/500], Loss: 0.5848, Accuracy: 0.7010
# Epoch [400/500], Loss: 0.5722, Accuracy: 0.7048
# Epoch [450/500], Loss: 0.5560, Accuracy: 0.7171
# Epoch [500/500], Loss: 0.5381, Accuracy: 0.7251
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_125_acc_0.7251.pkl
# Final accuracy: 0.7251
# Parameter containing:
# tensor([[ 2.4438,  2.8359],
#         [-0.5818, -2.9595],
#         [-2.8949, -2.7062]], requires_grad=True)
# Parameter containing:
# tensor([[-2.1381, -0.0270],
#         [-2.9226, -0.9735],
#         [-2.0870, -0.6461]], requires_grad=True)
#
# === Training with seed 126 ===
# initial loss =  1.6818146705627441
# Epoch [50/500], Loss: 0.8866, Accuracy: 0.5205
# Epoch [100/500], Loss: 0.6402, Accuracy: 0.6616
# Epoch [150/500], Loss: 0.5979, Accuracy: 0.7115
# Epoch [200/500], Loss: 0.5616, Accuracy: 0.7331
# Epoch [250/500], Loss: 0.5300, Accuracy: 0.7440
# Epoch [300/500], Loss: 0.5089, Accuracy: 0.7487
# Epoch [350/500], Loss: 0.4982, Accuracy: 0.7536
# Epoch [400/500], Loss: 0.4935, Accuracy: 0.7560
# Epoch [450/500], Loss: 0.4913, Accuracy: 0.7560
# Epoch [500/500], Loss: 0.4900, Accuracy: 0.7556
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_126_acc_0.7556.pkl
# Final accuracy: 0.7556
# Parameter containing:
# tensor([[-2.1381, -0.0270],
#         [-2.9226, -0.9735],
#         [-2.0870, -0.6461]], requires_grad=True)
# Parameter containing:
# tensor([[-1.8506, -2.7091],
#         [-1.2643,  2.8631],
#         [ 2.8263,  2.1548]], requires_grad=True)
#
# === Training with seed 127 ===
# initial loss =  2.4098052978515625
# Epoch [50/500], Loss: 0.8764, Accuracy: 0.4319
# Epoch [100/500], Loss: 0.6511, Accuracy: 0.5967
# Epoch [150/500], Loss: 0.6330, Accuracy: 0.6574
# Epoch [200/500], Loss: 0.6278, Accuracy: 0.6673
# Epoch [250/500], Loss: 0.6237, Accuracy: 0.6669
# Epoch [300/500], Loss: 0.6192, Accuracy: 0.6658
# Epoch [350/500], Loss: 0.6144, Accuracy: 0.6650
# Epoch [400/500], Loss: 0.6099, Accuracy: 0.6648
# Epoch [450/500], Loss: 0.6054, Accuracy: 0.6642
# Epoch [500/500], Loss: 0.6009, Accuracy: 0.6650
# Saved training data to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/training_data_seed_127_acc_0.6650.pkl
# Final accuracy: 0.6650
# Parameter containing:
# tensor([[-1.8506, -2.7091],
#         [-1.2643,  2.8631],
#         [ 2.8263,  2.1548]], requires_grad=True)
#
# === FINAL RESULTS ===
# Best model: Seed 76, Accuracy 0.8510
# Worst model: Seed 10, Accuracy 0.4999
# Best/worst model data saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/best_worst_models.pkl

# %%
best_model_data
# Out:
# {'accuracy': 0.85105,
#  'seed': 76,
#  'initial_params': {'model.0.weight': tensor([[-0.6216,  1.4949],
#           [-1.9600, -1.7431],
#           [ 2.3060, -1.0205]]),
#   'model.0.bias': tensor([ 0.3913, -2.9142, -1.1062]),
#   'model.2.weight': tensor([[ 0.4840,  0.2952, -1.4141],
#           [-0.2739, -1.7991, -0.5716]]),
#   'model.2.bias': tensor([ 1.7062, -2.4131])},
#  'final_params': {'model.0.weight': tensor([[ 0.7411, -2.1998],
#           [-3.6173, -1.6853],
#           [ 2.3647, -2.5069]]),
#   'model.0.bias': tensor([ 1.4025, -1.8640, -0.0323]),
#   'model.2.weight': tensor([[-1.6800,  1.5847,  1.0884],
#           [ 1.8901, -3.0886, -3.0741]]),
#   'model.2.bias': tensor([ 0.5264, -1.2333])}}

# %%
worst_model_data
# Out:
# {'accuracy': 0.4999,
#  'seed': 10,
#  'initial_params': {'model.0.weight': tensor([[-0.1060,  0.6900],
#           [-0.0196, -0.2873],
#           [-2.6549, -2.5878]]),
#   'model.0.bias': tensor([-2.6996, -2.9355, -2.7940]),
#   'model.2.weight': tensor([[-2.2727, -2.7058, -2.8142],
#           [ 1.3151,  1.8400,  2.0272]]),
#   'model.2.bias': tensor([1.6162, 1.0165])},
#  'final_params': {'model.0.weight': tensor([[-0.1060,  0.6900],
#           [-0.0196, -0.2873],
#           [-1.8511, -1.7834]]),
#   'model.0.bias': tensor([-2.6996, -2.9355, -3.5390]),
#   'model.2.weight': tensor([[-2.2727, -2.7058, -2.3052],
#           [ 1.3151,  1.8400,  1.5182]]),
#   'model.2.bias': tensor([1.3164, 1.3163])}}

# %%
all_initial_params=[]
all_final_params=[]
all_accuracies=[]
for i, t in enumerate(all_training_data):
    all_initial_params.append(flatten_weight_dict(t['initial_params']))
    all_final_params.append(flatten_weight_dict(t['final_params']))
    all_accuracies.append(t['final_accuracy'])
all_initial_params=np.array(all_initial_params)
all_final_params=np.array(all_final_params)

# %%
all_initial_params
# Out:
# array([[ 1.8000684 , -2.0338233 , -1.3063885 , ...,  2.5920024 ,
#         -1.944539  , -1.3809986 ],
#        [-0.01198447,  2.6225002 ,  0.9335704 , ...,  2.8456664 ,
#          1.9801794 , -2.7334132 ],
#        [-1.7697948 , -1.1533034 ,  2.8851542 , ..., -1.9469469 ,
#          0.7060468 ,  1.9744381 ],
#        ...,
#        [ 2.443781  ,  2.8359025 , -0.58184445, ...,  0.37383342,
#          2.2005582 , -2.8983436 ],
#        [-2.1380517 , -0.02700233, -2.9225957 , ...,  0.9170898 ,
#          1.9967501 , -2.2354927 ],
#        [-1.850627  , -2.7090878 , -1.2642585 , ...,  1.3447766 ,
#          1.5491084 ,  1.228716  ]], dtype=float32)

# %%
all_final_params
# Out:
# array([[ 3.41143   , -1.4308829 , -0.64767635, ...,  2.6066813 ,
#         -0.86821413, -2.457321  ],
#        [-2.1542985 ,  0.49225488,  3.7887714 , ...,  1.703521  ,
#          0.912084  , -1.6653168 ],
#        [-1.889387  ,  0.08438322,  4.897826  , ..., -1.0031581 ,
#          0.85763466,  1.822851  ],
#        ...,
#        [ 1.0492747 ,  1.2393668 , -4.155016  , ...,  2.0756385 ,
#          0.06972381, -0.76750976],
#        [-1.6342509 ,  0.3155066 , -5.1665525 , ...,  0.71488714,
#          1.3884511 , -1.6271942 ],
#        [-1.4902266 , -1.4685766 , -1.184339  , ...,  0.613779  ,
#          0.9946693 ,  1.783155  ]], dtype=float32)

# %%
all_accuracies
# Out:
# [0.7545,
#  0.7589,
#  0.758,
#  0.7839,
#  0.79355,
#  0.7604,
#  0.80095,
#  0.7653,
#  0.61305,
#  0.8261,
#  0.4999,
#  0.7081,
#  0.7189,
#  0.60865,
#  0.7558,
#  0.65295,
#  0.7955,
#  0.66285,
#  0.6633,
#  0.7408,
#  0.7254,
#  0.7701,
#  0.65865,
#  0.7279,
#  0.71085,
#  0.7707,
#  0.76215,
#  0.8408,
#  0.7235,
#  0.71485,
#  0.6105,
#  0.60915,
#  0.61435,
#  0.84895,
#  0.83025,
#  0.73865,
#  0.73935,
#  0.84695,
#  0.6256,
#  0.829,
#  0.63755,
#  0.78105,
#  0.66265,
#  0.76465,
#  0.7795,
#  0.75415,
#  0.6547,
#  0.7328,
#  0.8297,
#  0.7855,
#  0.6147,
#  0.6475,
#  0.77915,
#  0.5363,
#  0.8116,
#  0.7274,
#  0.7213,
#  0.7374,
#  0.65125,
#  0.686,
#  0.8027,
#  0.77215,
#  0.7717,
#  0.79665,
#  0.76265,
#  0.7408,
#  0.7426,
#  0.7031,
#  0.7966,
#  0.7773,
#  0.76275,
#  0.7788,
#  0.78265,
#  0.61445,
#  0.7619,
#  0.8001,
#  0.85105,
#  0.78015,
#  0.65485,
#  0.7597,
#  0.6939,
#  0.65235,
#  0.69025,
#  0.64145,
#  0.83835,
#  0.749,
#  0.7732,
#  0.7308,
#  0.834,
#  0.6073,
#  0.61435,
#  0.74095,
#  0.7813,
#  0.84265,
#  0.78455,
#  0.7578,
#  0.76315,
#  0.7554,
#  0.7311,
#  0.73175,
#  0.6092,
#  0.6456,
#  0.8461,
#  0.83395,
#  0.79255,
#  0.6844,
#  0.7084,
#  0.5,
#  0.84995,
#  0.75765,
#  0.7688,
#  0.61435,
#  0.7572,
#  0.62,
#  0.7565,
#  0.6929,
#  0.58245,
#  0.8094,
#  0.81855,
#  0.7717,
#  0.8371,
#  0.7568,
#  0.6127,
#  0.787,
#  0.84775,
#  0.7251,
#  0.7556,
#  0.66495]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import umap

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(all_final_params)

reducer = umap.UMAP(
    n_components=2,
    n_neighbors=15,
    min_dist=0.1,
    metric='euclidean',
    random_state=42
)

X_umap = reducer.fit_transform(X_scaled)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Create the scatter plot
plt.figure(figsize=(6, 5))
scatter = plt.scatter(X_umap[:, 0], X_umap[:, 1], 
                     c=all_accuracies, 
                     cmap='viridis', 
                     s=100, 
                     alpha=0.7)
plt.grid(1)
for i, accuracy in enumerate(all_accuracies):
    plt.annotate(f'{accuracy:.3f}', 
                (X_umap[i, 0], X_umap[i, 1]),
                xytext=(5, 5),  # offset the text by 5 points
                textcoords='offset points',
                fontsize=8,
                alpha=0.8)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(all_initial_params)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# Create the scatter plot
plt.figure(figsize=(6, 5))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                     c=all_accuracies, 
                     cmap='viridis', 
                     s=100, 
                     alpha=0.7)
plt.grid(1)
for i, accuracy in enumerate(all_accuracies):
    plt.annotate(f'{accuracy:.3f}', 
                (X_pca[i, 0], X_pca[i, 1]),
                xytext=(5, 5),  # offset the text by 5 points
                textcoords='offset points',
                fontsize=8,
                alpha=0.8)

# %%
all_params=np.vstack((all_initial_params, all_final_params))
all_accuracies_2=all_accuracies+all_accuracies

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(all_params)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# Create the scatter plot
plt.figure(figsize=(6, 5))
scatter = plt.scatter(X_pca[:len(all_params)//2, 0], X_pca[:len(all_params)//2, 1], 
                     c=all_accuracies_2[:len(all_params)//2], 
                     cmap='viridis', 
                     s=100, 
                     marker='o',
                     alpha=0.7)

scatter = plt.scatter(X_pca[len(all_params)//2:, 0], X_pca[len(all_params)//2:, 1], 
                     c=all_accuracies_2[len(all_params)//2:], 
                     cmap='viridis', 
                     s=100, 
                     marker='x',
                     alpha=0.7)

plt.grid(1)
for i, accuracy in enumerate(all_accuracies_2):
    plt.annotate(f'{accuracy:.3f}', 
                (X_pca[i, 0], X_pca[i, 1]),
                xytext=(5, 5),  # offset the text by 5 points
                textcoords='offset points',
                fontsize=8,
                alpha=0.8)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(all_final_params)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# Create the scatter plot
plt.figure(figsize=(12, 12))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                     c=all_accuracies, 
                     cmap='viridis', 
                     s=100, 
                     alpha=0.7)
plt.grid(1)
for i, accuracy in enumerate(all_accuracies):
    plt.annotate(f'{accuracy:.3f}', 
                (X_pca[i, 0], X_pca[i, 1]),
                xytext=(5, 5),  # offset the text by 5 points
                textcoords='offset points',
                fontsize=8,
                alpha=0.8)

# %%
def load_best_worst_data(filepath):
    """Load the best and worst model data"""
    with open(filepath, 'rb') as f:
        data = pickle.load(f)
    return data['best_model'], data['worst_model']

def interpolate_weights(weights1, weights2, alpha):
    """
    Interpolate between two weight dictionaries
    alpha = 0: returns weights1
    alpha = 1: returns weights2
    """
    interpolated = {}
    for name in weights1.keys():
        interpolated[name] = (1 - alpha) * weights1[name] + alpha * weights2[name]
    return interpolated

def set_model_weights(model, weight_dict):
    """Set model parameters from weight dictionary"""
    with torch.no_grad():
        for name, param in model.named_parameters():
            param.data = weight_dict[name]

def compute_loss_at_point(model, X_tensor, y_tensor, criterion):
    """Compute loss at current model parameters"""
    with torch.no_grad():
        outputs = model(X_tensor)
        loss = criterion(outputs, y_tensor)
        return loss.item()

def create_loss_landscape_2d(best_model_data, worst_model_data, X_tensor, y_tensor, 
                           model_class, model_args, resolution=50, output_dir=None):
    """
    Create 2D loss landscape visualization
    
    Dimension 1 (x-axis): Best model initial -> Best model final
    Dimension 2 (y-axis): Worst model initial -> Best model final
    """
    
    # Create a fresh model for evaluation
    model = model_class(model_args)
    criterion = torch.nn.CrossEntropyLoss()
    
    # Create interpolation grids
    alphas = np.linspace(0, 1, resolution)
    betas = np.linspace(0, 1, resolution)
    
    # Initialize loss landscape
    loss_landscape = np.zeros((resolution, resolution))
    
    print("Computing loss landscape...")
    
    for i, alpha in enumerate(alphas):
        for j, beta in enumerate(betas):
            # Create a proper 2D interpolation grid
            # We want to interpolate between 4 corner points:
            # (0,0) = best_initial
            # (1,0) = best_final  
            # (0,1) = worst_initial
            # (1,1) = worst_final
            
            # Use bilinear interpolation
            # First interpolate along the bottom edge (beta=0): best_initial -> best_final
            bottom_edge = interpolate_weights(
                best_model_data['initial_params'],
                best_model_data['final_params'], 
                alpha
            )
            
            # Then interpolate along the top edge (beta=1): worst_initial -> best_final
            top_edge = interpolate_weights(
                worst_model_data['initial_params'],
                # best_model_data['final_params'],
                worst_model_data['final_params'], #SW Mod
                alpha
            )
            
            # Finally interpolate between bottom and top edges
            final_weights = interpolate_weights(bottom_edge, top_edge, beta)
            
            # Set model weights and compute loss
            set_model_weights(model, final_weights)
            loss = compute_loss_at_point(model, X_tensor, y_tensor, criterion)
            loss_landscape[j, i] = loss
        
        if i % 10 == 0:
            print(f"Progress: {i}/{resolution}")
    
    # Create the visualization
    plt.figure(figsize=(12, 10))
    
    # Create contour plot
    X, Y = np.meshgrid(alphas, betas)
    contour = plt.contour(X, Y, loss_landscape, levels=20, colors='black', alpha=0.6, linewidths=0.8)
    contourf = plt.contourf(X, Y, loss_landscape, levels=50, cmap='viridis', alpha=0.8)
    
    # Add colorbar
    cbar = plt.colorbar(contourf)
    cbar.set_label('Loss', fontsize=12)
    
    # Add contour labels
    plt.clabel(contour, inline=True, fontsize=8, fmt='%.3f')
    
    # Mark key points
    plt.plot(0, 0, 'ro', markersize=10, label=f'Best Initial (Acc: {best_model_data["accuracy"]:.3f})')
    plt.plot(1, 0, 'go', markersize=10, label=f'Best Final (Acc: {best_model_data["accuracy"]:.3f})')  
    plt.plot(0, 1, 'bo', markersize=10, label=f'Worst Initial (Acc: {worst_model_data["accuracy"]:.3f})')
    plt.plot(1, 1, 'go', markersize=8, alpha=0.7)  # Same as best final
    
    # Add arrows to show the training trajectories
    plt.annotate('', xy=(1, 0), xytext=(0, 0), 
                arrowprops=dict(arrowstyle='->', color='red', lw=2, alpha=0.7),
                label='Best model training path')
    
    # Labels and title
    plt.xlabel('Best Model: Initial → Final', fontsize=12)
    plt.ylabel('Worst Initial → Best Final', fontsize=12)
    plt.title('2D Loss Landscape\nInterpolating Between Key Weight Configurations', fontsize=14)
    
    # Legend
    plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
    
    # Grid
    plt.grid(True, alpha=0.3)
    
    # Tight layout
    plt.tight_layout()
    
    # Save if output directory specified
    if output_dir:
        viz_path = os.path.join(output_dir, 'loss_landscape_2d.png')
        plt.savefig(viz_path, dpi=300, bbox_inches='tight')
        print(f"Loss landscape saved to: {viz_path}")
    
    plt.show()
    
    return loss_landscape, alphas, betas

# %%
loss_landscape, alphas, betas = create_loss_landscape_2d(
    best_model_data, 
    worst_model_data, 
    X_tensor, 
    y_tensor,
    BaarleNet,  # Your model class
    [3],        # Your model args
    resolution=50,
    output_dir=output_dir
)
# Out:
# Computing loss landscape...
# Progress: 0/50
# Progress: 10/50
# Progress: 20/50
# Progress: 30/50
# Progress: 40/50
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13594/3818586867.py:121: UserWarning: Legend does not support handles for Annotation instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
# Loss landscape saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/loss_landscape_2d.png

# %% [markdown]
# - Hey that's kinda what I wanted -> right? Can I just do this?
# - Maybe changing my weight initialization helped here?

# %%
all_training_data[0].keys()
# Out:
# dict_keys(['seed', 'weights_history', 'gradients_history', 'xy_history', 'loss_history', 'accuracy_history', 'initial_params', 'final_accuracy', 'final_model_state', 'final_params'])

# %%
final_accuracies=np.array([t['final_accuracy'] for t in all_training_data])
sI=np.argsort(final_accuracies)

# %%
final_accuracies[sI[:5]]
# Out:
# array([0.4999 , 0.5    , 0.5363 , 0.58245, 0.6073 ])

# %%
sI[:5]
# Out:
# array([ 10, 107,  53, 116,  89])

# %%
i=89

# %%
worst_model_data_2 = {
    'accuracy': all_training_data[i]['final_accuracy'],
    'seed': all_training_data[i]['seed'],
    'initial_params': all_training_data[i]['initial_params'],
    'final_params': all_training_data[i]['final_params']
}

# %%
worst_model_data_2
# Out:
# {'accuracy': 0.6073,
#  'seed': 89,
#  'initial_params': {'model.0.weight': tensor([[ 2.2434,  1.4565],
#           [-1.3462,  2.3677],
#           [-1.1537,  1.7052]]),
#   'model.0.bias': tensor([ 0.8051, -0.9677,  0.7008]),
#   'model.2.weight': tensor([[-0.4335, -0.0203, -2.5029],
#           [-1.7468,  2.1559,  2.6181]]),
#   'model.2.bias': tensor([-0.8205, -0.8069])},
#  'final_params': {'model.0.weight': tensor([[ 0.5278,  2.6150],
#           [-0.3712,  1.5125],
#           [ 0.2181,  0.6728]]),
#   'model.0.bias': tensor([ 0.6551, -1.7331,  0.1308]),
#   'model.2.weight': tensor([[-0.3483,  0.6253, -1.7197],
#           [-1.8320,  1.5103,  1.8349]]),
#   'model.2.bias': tensor([-1.0817, -0.5457])}}

# %%
loss_landscape, alphas, betas = create_loss_landscape_2d(
    best_model_data, 
    worst_model_data_2, 
    X_tensor, 
    y_tensor,
    BaarleNet,  # Your model class
    [3],        # Your model args
    resolution=50,
    output_dir=output_dir
)
# Out:
# Computing loss landscape...
# Progress: 0/50
# Progress: 10/50
# Progress: 20/50
# Progress: 30/50
# Progress: 40/50
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13594/3818586867.py:121: UserWarning: Legend does not support handles for Annotation instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.0))
# Loss landscape saved to: /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/3_starting_configs_3/loss_landscape_2d.png

# %%
all_accuracies
# Out:
# [0.7545,
#  0.7589,
#  0.758,
#  0.7839,
#  0.79355,
#  0.7604,
#  0.80095,
#  0.7653,
#  0.61305,
#  0.8261,
#  0.4999,
#  0.7081,
#  0.7189,
#  0.60865,
#  0.7558,
#  0.65295,
#  0.7955,
#  0.66285,
#  0.6633,
#  0.7408,
#  0.7254,
#  0.7701,
#  0.65865,
#  0.7279,
#  0.71085,
#  0.7707,
#  0.76215,
#  0.8408,
#  0.7235,
#  0.71485,
#  0.6105,
#  0.60915,
#  0.61435,
#  0.84895,
#  0.83025,
#  0.73865,
#  0.73935,
#  0.84695,
#  0.6256,
#  0.829,
#  0.63755,
#  0.78105,
#  0.66265,
#  0.76465,
#  0.7795,
#  0.75415,
#  0.6547,
#  0.7328,
#  0.8297,
#  0.7855,
#  0.6147,
#  0.6475,
#  0.77915,
#  0.5363,
#  0.8116,
#  0.7274,
#  0.7213,
#  0.7374,
#  0.65125,
#  0.686,
#  0.8027,
#  0.77215,
#  0.7717,
#  0.79665,
#  0.76265,
#  0.7408,
#  0.7426,
#  0.7031,
#  0.7966,
#  0.7773,
#  0.76275,
#  0.7788,
#  0.78265,
#  0.61445,
#  0.7619,
#  0.8001,
#  0.85105,
#  0.78015,
#  0.65485,
#  0.7597,
#  0.6939,
#  0.65235,
#  0.69025,
#  0.64145,
#  0.83835,
#  0.749,
#  0.7732,
#  0.7308,
#  0.834,
#  0.6073,
#  0.61435,
#  0.74095,
#  0.7813,
#  0.84265,
#  0.78455,
#  0.7578,
#  0.76315,
#  0.7554,
#  0.7311,
#  0.73175,
#  0.6092,
#  0.6456,
#  0.8461,
#  0.83395,
#  0.79255,
#  0.6844,
#  0.7084,
#  0.5,
#  0.84995,
#  0.75765,
#  0.7688,
#  0.61435,
#  0.7572,
#  0.62,
#  0.7565,
#  0.6929,
#  0.58245,
#  0.8094,
#  0.81855,
#  0.7717,
#  0.8371,
#  0.7568,
#  0.6127,
#  0.787,
#  0.84775,
#  0.7251,
#  0.7556,
#  0.66495]

# %% [markdown]
# ---

# %%
len(all_training_data)
# Out:
# 128

# %%
all_training_data[0].keys()
# Out:
# dict_keys(['seed', 'weights_history', 'gradients_history', 'xy_history', 'loss_history', 'accuracy_history', 'initial_params', 'final_accuracy', 'final_model_state', 'final_params'])

# %%
all_training_data[0]['initial_params']
# Out:
# {'model.0.weight': tensor([[ 1.8001, -2.0338],
#          [-1.3064,  1.0897],
#          [ 2.4912, -0.6174]]),
#  'model.0.bias': tensor([ 2.2449, -0.4836,  0.3174]),
#  'model.2.weight': tensor([[ 2.7164, -2.7830, -1.8886],
#          [-0.7595, -1.1694,  2.5920]]),
#  'model.2.bias': tensor([-1.9445, -1.3810])}

# %%
all_training_data[0]['final_params']
# Out:
# {'model.0.weight': tensor([[ 3.4114, -1.4309],
#          [-0.6477,  0.4900],
#          [ 1.6422, -0.8892]]),
#  'model.0.bias': tensor([ 1.0509, -1.1085,  1.1633]),
#  'model.2.weight': tensor([[ 2.3894, -2.3463, -1.9033],
#          [-0.4325, -1.6061,  2.6067]]),
#  'model.2.bias': tensor([-0.8682, -2.4573])}

# %%
all_training_data[2]['final_params']
# Out:
# {'model.0.weight': tensor([[-1.8894,  0.0844],
#          [ 4.8978, -2.0673],
#          [ 1.0954, -1.5990]]),
#  'model.0.bias': tensor([ 2.1121, -0.8457,  1.5869]),
#  'model.2.weight': tensor([[-0.2606, -1.0576, -2.6442],
#          [-1.3409, -3.3475, -1.0032]]),
#  'model.2.bias': tensor([0.8576, 1.8229])}

# %%
all_training_data[2]['final_accuracy']
# Out:
# 0.758

# %%
flatten_weight_dict(all_training_data[0]['initial_params'])
# Out:
# array([ 1.8000684 , -2.0338233 , -1.3063885 ,  1.0896513 ,  2.4911637 ,
#        -0.6174005 ,  2.2449353 , -0.48355007,  0.3174423 ,  2.7164288 ,
#        -2.783011  , -1.8886138 , -0.75949574, -1.1693999 ,  2.5920024 ,
#        -1.944539  , -1.3809986 ], dtype=float32)

# %%
flatten_weight_dict(all_training_data[0]['initial_params'])
# Out:
# array([ 1.8000684 , -2.0338233 , -1.3063885 ,  1.0896513 ,  2.4911637 ,
#        -0.6174005 ,  2.2449353 , -0.48355007,  0.3174423 ,  2.7164288 ,
#        -2.783011  , -1.8886138 , -0.75949574, -1.1693999 ,  2.5920024 ,
#        -1.944539  , -1.3809986 ], dtype=float32)

# %%
flatten_weight_dict(all_training_data[0]['final_params'])
# Out:
# array([ 3.41143   , -1.4308829 , -0.64767635,  0.49004903,  1.6422285 ,
#        -0.8891952 ,  1.0509201 , -1.1084635 ,  1.1633433 ,  2.3894124 ,
#        -2.3463197 , -1.9032907 , -0.43247867, -1.6060909 ,  2.6066813 ,
#        -0.86821413, -2.457321  ], dtype=float32)

# %%
all_training_data[0]['final_accuracy']
# Out:
# 0.7545

# %%
flatten_weight_dict(all_training_data[0]['weights_history'][0])
# Out:
# array([ 1.8000684 , -2.0338233 , -1.3063885 ,  1.0896513 ,  2.4911637 ,
#        -0.6174005 ,  2.2449353 , -0.48355007,  0.3174423 ,  2.7164288 ,
#        -2.783011  , -1.8886138 , -0.75949574, -1.1693999 ,  2.5920024 ,
#        -1.944539  , -1.3809986 ], dtype=float32)

# %%
flatten_weight_dict(all_training_data[0]['weights_history'][1000])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 flatten_weight_dict(all_training_data[0]['weights_history'][1000])
#
# IndexError: list index out of range

# %%
set_model_weights(model, worst_model_data['initial_params'])
compute_loss_at_point(model, X_tensor, y_tensor, criterion)

# %%
save_viz(model)
